# %% [markdown]
# # Pytorch classifier notebook
#
# V1 : only 1 split. First implementation
# All folds V1 : with all folds
# All folds V2 : add activation stats plot
# All folds V2.1 : back to  best MLP found so far, and backport fix of activation layers stats. Add weight decay and scheduler (fit one cycle) code
#
# All folds autoencoder MLP V1

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import matplotlib.pyplot as plt

from sklearn.metrics import accuracy_score

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision.transforms as transforms
import torchvision.utils as utils

from torch.utils.tensorboard import SummaryWriter
import io
import PIL.Image

torch.set_printoptions(edgeitems=2)
torch.manual_seed(42)

DATASET_INPUT_FILE = 'train.csv'

FEATURES_LIST_TOTRAIN = ['feature_'+str(i) for i in range(130)] + ['cross_41_42_43', 'cross_1_2']
#FEATURES_LIST_TOTRAIN = ['feature_'+str(i) for i in range(130)]

# For custom non-overlaped folds generation
TRAIN_PERCENT = 0.70  
TEST_PERCENT = 0.30

# If subsplit of training set : percentage of second training set  
TRAIN1_PERCENT = 0.20  

pd.set_option('display.max_rows', 500)

# %%
# Deterministic Behavior
seed = 42
#os.environ['PYTHONHASHSEED'] = str(seed)
# Torch RNG
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
torch.cuda.manual_seed_all(seed)
# Python RNG
np.random.seed(seed)
#random.seed(seed)
# CuDA Determinism
torch.backends.cudnn.deterministic = True
#torch.backends.cudnn.benchmark = False

# %%
#BATCH_SIZE = 50000
#BATCH_SIZE = 4096 # Gave once better results than 50000
#BATCH_SIZE = 2048

#BATCH_SIZE = 300000

#BATCH_SIZE = 4096
#BATCH_SIZE = 8192
#BATCH_SIZE = 32768
BATCH_SIZE = 40960
WEIGHT_DECAY = 1e-4 # Remettre à 1e-5
LEARNING_RATE = 1e-4

EARLY_STOPPING = True

NUM_EPOCHS = 1000
#NUM_EPOCHS = 36
MODEL_COMMENT = f'All folds MLP autoenc, 3 layers 130, 200 and 100, good model reloaded, batch size {BATCH_SIZE}, lr={LEARNING_RATE}, patience 5, standard scale, weight decay {WEIGHT_DECAY}, 0.7 dropout, with cross features, no scheduler, no std scale'

# %%
def pyStandardScale(tensor, mean, std):
    return((tensor - mean) / std)

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection._split import _BaseKFold, indexable, _num_samples
from sklearn.utils.validation import _deprecate_positional_args

# modified code for group gaps; source
# https://github.com/getgaurav2/scikit-learn/blob/d4a3af5cc9da3a76f0266932644b884c99724c57/sklearn/model_selection/_split.py#L2243
class PurgedGroupTimeSeriesSplit(_BaseKFold):
    """Time Series cross-validator variant with non-overlapping groups.
    Allows for a gap in groups to avoid potentially leaking info from
    train into test if the model has windowed or lag features.
    Provides train/test indices to split time series data samples
    that are observed at fixed time intervals according to a
    third-party provided group.
    In each split, test indices must be higher than before, and thus shuffling
    in cross validator is inappropriate.
    This cross-validation object is a variation of :class:`KFold`.
    In the kth split, it returns first k folds as train set and the
    (k+1)th fold as test set.
    The same group will not appear in two different folds (the number of
    distinct groups has to be at least equal to the number of folds).
    Note that unlike standard cross-validation methods, successive
    training sets are supersets of those that come before them.
    Read more in the :ref:`User Guide <cross_validation>`.
    Parameters
    ----------
    n_splits : int, default=5
        Number of splits. Must be at least 2.
    max_train_group_size : int, default=Inf
        Maximum group size for a single training set.
    group_gap : int, default=None
        Gap between train and test
    max_test_group_size : int, default=Inf
        We discard this number of groups from the end of each train split
    """

    @_deprecate_positional_args
    def __init__(self,
                 n_splits=5,
                 *,
                 max_train_group_size=np.inf,
                 max_test_group_size=np.inf,
                 group_gap=None,
                 verbose=False
                 ):
        super().__init__(n_splits, shuffle=False, random_state=None)
        self.max_train_group_size = max_train_group_size
        self.group_gap = group_gap
        self.max_test_group_size = max_test_group_size
        self.verbose = verbose

    def split(self, X, y=None, groups=None):
        """Generate indices to split data into training and test set.
        Parameters
        ----------
        X : array-like of shape (n_samples, n_features)
            Training data, where n_samples is the number of samples
            and n_features is the number of features.
        y : array-like of shape (n_samples,)
            Always ignored, exists for compatibility.
        groups : array-like of shape (n_samples,)
            Group labels for the samples used while splitting the dataset into
            train/test set.
        Yields
        ------
        train : ndarray
            The training set indices for that split.
        test : ndarray
            The testing set indices for that split.
        """
        if groups is None:
            raise ValueError(
                "The 'groups' parameter should not be None")
        X, y, groups = indexable(X, y, groups)
        n_samples = _num_samples(X)
        n_splits = self.n_splits
        group_gap = self.group_gap
        max_test_group_size = self.max_test_group_size
        max_train_group_size = self.max_train_group_size
        n_folds = n_splits + 1
        group_dict = {}
        u, ind = np.unique(groups, return_index=True)
        unique_groups = u[np.argsort(ind)]
        n_samples = _num_samples(X)
        n_groups = _num_samples(unique_groups)
        for idx in np.arange(n_samples):
            if (groups[idx] in group_dict):
                group_dict[groups[idx]].append(idx)
            else:
                group_dict[groups[idx]] = [idx]
        if n_folds > n_groups:
            raise ValueError(
                ("Cannot have number of folds={0} greater than"
                 " the number of groups={1}").format(n_folds,
                                                     n_groups))

        group_test_size = min(n_groups // n_folds, max_test_group_size)
        group_test_starts = range(n_groups - n_splits * group_test_size,
                                  n_groups, group_test_size)
        for group_test_start in group_test_starts:
            train_array = []
            test_array = []

            group_st = max(0, group_test_start - group_gap - max_train_group_size)
            for train_group_idx in unique_groups[group_st:(group_test_start - group_gap)]:
                train_array_tmp = group_dict[train_group_idx]
                
                train_array = np.sort(np.unique(
                                      np.concatenate((train_array,
                                                      train_array_tmp)),
                                      axis=None), axis=None)

            train_end = train_array.size
 
            for test_group_idx in unique_groups[group_test_start:
                                                group_test_start +
                                                group_test_size]:
                test_array_tmp = group_dict[test_group_idx]
                test_array = np.sort(np.unique(
                                              np.concatenate((test_array,
                                                              test_array_tmp)),
                                     axis=None), axis=None)

            test_array  = test_array[group_gap:]
            
            
            if self.verbose > 0:
                    pass
                    
            yield [int(i) for i in train_array], [int(i) for i in test_array]

from matplotlib.colors import ListedColormap
    
# this is code slightly modified from the sklearn docs here:
# https://scikit-learn.org/stable/auto_examples/model_selection/plot_cv_indices.html#sphx-glr-auto-examples-model-selection-plot-cv-indices-py
def plot_cv_indices(cv, X, y, group, ax, n_splits, lw=10):
    """Create a sample plot for indices of a cross-validation object."""
    
    cmap_cv = plt.cm.coolwarm

    jet = plt.cm.get_cmap('jet', 256)
    seq = np.linspace(0, 1, 256)
    _ = np.random.shuffle(seq)   # inplace
    cmap_data = ListedColormap(jet(seq))

    # Generate the training/testing visualizations for each CV split
    for ii, (tr, tt) in enumerate(cv.split(X=X, y=y, groups=group)):
        # Fill in indices with the training/test groups
        indices = np.array([np.nan] * len(X))
        indices[tt] = 1
        indices[tr] = 0

        # Visualize the results
        ax.scatter(range(len(indices)), [ii + .5] * len(indices),
                   c=indices, marker='_', lw=lw, cmap=cmap_cv,
                   vmin=-.2, vmax=1.2)

    # Plot the data classes and groups at the end
    ax.scatter(range(len(X)), [ii + 1.5] * len(X),
               c=y, marker='_', lw=lw, cmap=plt.cm.Set3)

    ax.scatter(range(len(X)), [ii + 2.5] * len(X),
               c=group, marker='_', lw=lw, cmap=cmap_data)

    # Formatting
    yticklabels = list(range(n_splits)) + ['target', 'day']
    ax.set(yticks=np.arange(n_splits+2) + .5, yticklabels=yticklabels,
           xlabel='Sample index', ylabel="CV iteration",
           ylim=[n_splits+2.2, -.2], xlim=[0, len(y)])
    ax.set_title('{}'.format(type(cv).__name__), fontsize=15)
    return ax


def plot_cv_indices_custom(cv_custom, X, y, group, ax, n_splits, lw=10):
    """Create a sample plot for indices of a cross-validation object."""
    
    cmap_cv = plt.cm.coolwarm

    jet = plt.cm.get_cmap('jet', 256)
    seq = np.linspace(0, 1, 256)
    _ = np.random.shuffle(seq)   # inplace
    cmap_data = ListedColormap(jet(seq))

    # Generate the training/testing visualizations for each CV split
    for ii, (tr, tt) in enumerate(cv_custom):
        # Fill in indices with the training/test groups
        indices = np.array([np.nan] * len(X))
        indices[tt] = 1
        indices[tr] = 0

        # Visualize the results
        ax.scatter(range(len(indices)), [ii + .5] * len(indices),
                   c=indices, marker='_', lw=lw, cmap=cmap_cv,
                   vmin=-.2, vmax=1.2)

    # Plot the data classes and groups at the end
    ax.scatter(range(len(X)), [ii + 1.5] * len(X),
               c=y, marker='_', lw=lw, cmap=plt.cm.Set3)

    ax.scatter(range(len(X)), [ii + 2.5] * len(X),
               c=group, marker='_', lw=lw, cmap=cmap_data)

    # Formatting
    yticklabels = list(range(n_splits)) + ['target', 'day']
    ax.set(yticks=np.arange(n_splits+2) + .5, yticklabels=yticklabels,
           xlabel='Sample index', ylabel="CV iteration",
           ylim=[n_splits+2.2, -.2], xlim=[0, len(y)])
    ax.set_title('{}'.format(type(cv).__name__), fontsize=15)
    return ax

# %%
# This function accounts for variable instance counts in each split by dividing utility_pi by number of instances (but this has been removed)
# It also does some copy of dataframe to prevent memory overwrite
def utility_function(df_test, df_test_predictions):
    df_test_copy = df_test.copy(deep=True)
    df_test_copy.loc[:, 'utility_pj'] = df_test_copy['weight'] * df_test_copy['resp'] * df_test_predictions
    #df_test_utility_pi = df_test_copy.groupby('date')['utility_pj'].sum() / df_test_copy.groupby('date')['utility_pj'].count()
    df_test_utility_pi = df_test_copy.groupby('date')['utility_pj'].sum()

    nb_unique_dates = df_test_utility_pi.shape[0]
    t = (df_test_utility_pi.sum() / np.sqrt(df_test_utility_pi.pow(2).sum())) * (np.sqrt(250 / np.abs(nb_unique_dates)))
    u = min(max(t, 0), 6) * df_test_utility_pi.sum()
    del df_test_copy
    
    return(u)

# %%
from bisect import bisect_left

# The aim of this function is to return closest date from an index
# So that split indices correspond to start or end of a new day
# myList contains list of instances that correspond to start of a new da

def take_closest(myList, myNumber):
    """
    Assumes myList is sorted. Returns closest value to myNumber.

    If two numbers are equally close, return the smallest number.
    """
    pos = bisect_left(myList, myNumber)
    if pos == 0:
        return myList[0]
    if pos == len(myList):
        return myList[-1]
    before = myList[pos - 1]
    after = myList[pos]
    if after - myNumber < myNumber - before:
       return after
    else:
       return before

# %%
class SaveOutputActivationStats:
    def __init__(self):
        self.outputs = []
        
    def __call__(self, module, module_in, module_out):
        #self.outputs.append(module_out)
        self.outputs.append({'mean': module_out.mean().item(), 'std': module_out.std().item(),'near_zero': (module_out<=0.05).long().sum().item()/module_out.numel()})
        
    def clear(self):
        self.outputs = []

# %%
#fig, ax = plt.subplots(1, 1)
#
#plot_cv_indices(cv, df.loc[:, FEATURES_LIST_TOTRAIN], (df['resp'] > 0), df['date'], 
#                         ax, 5, lw=20);

# %%
torch.device
# Out:
# torch.device

# %%
torch.cuda.is_available()
# Out:
# True

# %%
torch.cuda.current_device()
# Out:
# 0

# %%
torch.cuda.get_device_name(0)
# Out:
# 'GeForce RTX 3090'

# %% [markdown]
# # Load data

# %%
# Load data
    
df = pd.read_csv(DATASET_INPUT_FILE)
df['resp_positive'] = ((df['resp'])>0)*1  # Target to predict

print('Data loaded')
# Out:
# Data loaded

# %% [markdown]
# # Feature engineering

# %%
df['cross_41_42_43'] = df['feature_41'] + df['feature_42'] + df['feature_43']

# %%
df['cross_1_2'] = df['feature_1'] / (df['feature_2'] + 1e-5)

# %% [markdown]
# # Non overlap fold generation

# %%
date_indexes_list = df.groupby('date')['ts_id'].first().to_list()

# %%
base_train_split_size = int((df.shape[0] // 5) * TRAIN_PERCENT)

# %%
base_test_split_size = int((df.shape[0] // 5) * TEST_PERCENT)

# %%
train_split_start_indexes = [take_closest(date_indexes_list, (base_train_split_size + base_test_split_size)*fold_indice) for fold_indice in range(5)]

# %%
#test_split_start_indexes = [take_closest(date_indexes_list, (base_train_split_size + base_test_split_size)*fold_indice) for fold_indice in range(5)]

# %%
train_split_start_indexes
# Out:
# [0, 477711, 958233, 1435933, 1913985]

# %%
df.shape[0] - 1
# Out:
# 2390490

# %%
# We'll have 5 folds of 3 subsets each (2 training sets and 1 test set per fold)
# (1st training set of each fold will be used for 1st model, ie auto encoder)

NB_FOLDS = 5
last_index = df.shape[0] - 1

cv_table = []

for fold_indice in range(NB_FOLDS):
    fold_train_start_index = train_split_start_indexes[fold_indice]
    
    if (fold_indice == NB_FOLDS - 1):    
        nextfold_train_start_index = last_index
        
    else:
        nextfold_train_start_index = train_split_start_indexes[fold_indice + 1]
    
    fold_test_start_index = take_closest(date_indexes_list, int(TRAIN_PERCENT * (nextfold_train_start_index - fold_train_start_index) + fold_train_start_index  ))
    fold_train2_start_index = take_closest(date_indexes_list, int(TRAIN1_PERCENT * (fold_test_start_index - fold_train_start_index) + fold_train_start_index  ))
    
    cv_table.append(fold_train_start_index)
    cv_table.append(fold_train2_start_index)
    cv_table.append(fold_test_start_index)

# %%
cv_table.append(last_index)

# %%
cv_table
# Out:
# [0,
#  336609,
#  477711,
#  815783,
#  958233,
#  1290282,
#  1435933,
#  1771833,
#  1913985,
#  2248510,
#  2390490]

# %%
cv_table
# Out:
# [0,
#  66091,
#  336609,
#  477711,
#  546983,
#  815783,
#  958233,
#  1024471,
#  1290282,
#  1435933,
#  1505171,
#  1771833,
#  1913985,
#  1980610,
#  2248510,
#  2390490]

# %%
NB_FOLDS
# Out:
# 5

# %%
cv_tuples = []

for i in range(0, NB_FOLDS*3, 3):
    cv_tuples.append([df.loc[cv_table[i]:cv_table[i+1]-1, :].index.to_list(), df.loc[cv_table[i+1]:cv_table[i+2]-1, :].index.to_list(),
                      df.loc[cv_table[i+2]:cv_table[i+3]-1, :].index.to_list()])

# %%
len(cv_tuples[0][2])
# Out:
# 141102

# %%
cv_tuples_generator = iter(cv_tuples)

# %%
#fig, ax = plt.subplots(1, 1)

#plot_cv_indices_custom(cv_tuples_generator, df.loc[:, FEATURES_LIST_TOTRAIN], (df['resp'] > 0), df['date'], 
#                         ax, 5, lw=20); 

#cv_tuples_generator = iter(cv_tuples)

# %%
# Size of training set :
#train_sets_table =  [cv_tuples[i][0] for i in range(5)]
#sum([len(train_set_table) for train_set_table in train_sets_table])

# %%
# Our old time series split (with overlap : required 1 neural network trained per split)
# But in this script it's not needed because we're training 1 unique network, with a different fold strategy (non overlaped)
#cv = PurgedGroupTimeSeriesSplit(
#    n_splits=5,
#    max_train_group_size=180,
#    group_gap=20,
#    max_test_group_size=60
#)

# %%
#train_index, test_index = next(cv.split(df, (df['resp'] > 0)*1, df['date']))

# %%
#(df.loc[train_index, 'resp'] > 0).astype(np.byte)

# %%
f_mean = df.loc[:, FEATURES_LIST_TOTRAIN].mean(axis=0)

# %%
f_mean.shape
# Out:
# (132,)

# %%
df.fillna(f_mean, inplace=True)

# %%
#print('Sum of model parameters:')
#[print(p.sum()) for p in model.parameters()]

# %%
#writer = SummaryWriter()

#writer.add_text('test', 'test:'  + str(model).replace('\n', '<BR>'))

#writer.flush()
#writer.close()

# %%
#str([p.numel() for p in model.parameters()])

# %%
folds_list = []

for fold, (train1_index, train2_index, test_index) in enumerate(cv_tuples_generator):
    folds_list.append((train1_index, train2_index, test_index))

# %%
folds_list_train1 = [folds_list[i][0] for i in range(5)]
folds_list_train1_flat = [folds_list_train1_item for sublist in folds_list_train1 for folds_list_train1_item in sublist]
folds_list_train1_unique = list(set(folds_list_train1_flat))

folds_list_train2 = [folds_list[i][1] for i in range(5)]
folds_list_train2_flat = [folds_list_train2_item for sublist in folds_list_train2 for folds_list_train2_item in sublist]
folds_list_train2_unique = list(set(folds_list_train2_flat))

# %%
len(folds_list_train1_unique)
# Out:
# 337464

# %%
len(folds_list_train2_unique)
# Out:
# 1339691

# %%
np.sum([len(folds_list_train1_item) for folds_list_train1_item in folds_list_train1])
# Out:
# 337464

# %%
np.sum([len(folds_list_train2_item) for folds_list_train2_item in folds_list_train2])
# Out:
# 1339691

# %%
len(folds_list_train1_flat)
# Out:
# 337464

# %%
folds_list_test = [folds_list[i][2] for i in range(5)]
folds_list_test_flat = [folds_list_test_item for sublist in folds_list_test for folds_list_test_item in sublist]
folds_list_test_unique = set(folds_list_test_flat)

# %%
np.sum([len(folds_list_test_item) for folds_list_test_item in folds_list_test])
# Out:
# 713335

# %%
len(folds_list_test_flat)
# Out:
# 713335

# %%
len(folds_list_train1_flat) + len(folds_list_train2_flat) + len(folds_list_test_flat)
# Out:
# 2390490

# %%
df.loc[folds_list_test[4], FEATURES_LIST_TOTRAIN].to_numpy().shape
# Out:
# (141980, 132)

# %%
df.loc[(folds_list_train1_unique + folds_list_train2_unique), FEATURES_LIST_TOTRAIN].to_numpy().mean(axis=0)
# Out:
# array([ 8.80717644e-03,  3.95744688e-01,  3.30598383e-01,  9.19269355e-03,
#         3.41737231e-03, -4.98373337e-03, -1.45545905e-02,  5.53463122e-02,
#         2.51189577e-02,  2.64653797e-01,  1.67057019e-01,  9.48969805e-02,
#         4.45042790e-02,  1.52512931e-01,  7.99665062e-02,  2.21665321e-01,
#         1.28276579e-01,  1.21815651e-01,  1.09588524e-01,  2.97729634e-01,
#         2.64632475e-01,  1.88140797e-01,  1.72510551e-01,  2.54740088e-01,
#         2.32679030e-01,  2.97940493e-01,  2.68541703e-01,  1.39851314e-01,
#         1.62851070e-01,  3.30607342e-01,  3.43859128e-01,  2.26846867e-01,
#         2.51906578e-01,  3.16373591e-01,  3.35983802e-01,  3.52841811e-01,
#         3.67733150e-01,  2.65033910e-02,  1.86391003e-02,  4.32055347e-02,
#         5.29866264e-02,  4.54174332e-01,  3.77626910e-01,  4.16173233e-01,
#         4.39276747e-01,  4.86510954e-01,  4.92079562e-01,  3.68399752e-01,
#         5.01443867e-01,  5.43790672e-01,  5.30749706e-01,  4.56739647e-01,
#         5.64687434e-02,  3.89002328e-01,  3.76905870e-01,  7.75493023e-01,
#         9.24661926e-01,  7.85904285e-01,  8.08476673e-01,  8.98959229e-01,
#         5.53354064e-01,  5.55543923e-01,  5.59228729e-01,  5.61395594e-01,
#         4.42319747e-01,  6.18843515e-01,  6.17155676e-01,  5.97703343e-01,
#         5.98140180e-01,  3.77383876e-01,  2.38934027e-01,  3.08029141e-01,
#         4.10364940e-03, -3.22014114e-02, -1.63732094e-03, -1.99157502e-02,
#        -3.15887230e-02, -9.31837982e-02, -8.06525956e-03, -3.57893749e-02,
#        -2.51813861e-03, -1.48943426e-02, -3.49833836e-02, -1.01545643e-01,
#         3.93378053e-01,  5.41621784e-01,  3.92419488e-01,  4.28143324e-01,
#         4.97555570e-01,  3.99350446e-01,  4.33195657e-01,  5.23533021e-01,
#         4.22381683e-01,  4.22067148e-01,  4.34849531e-01,  4.54718798e-01,
#         3.98371929e-01,  5.42156600e-01,  3.97309991e-01,  4.25894241e-01,
#         4.86537870e-01,  4.10540989e-01,  4.33993394e-01,  4.83911662e-01,
#         4.16831858e-01,  4.19797394e-01,  4.61446120e-01,  4.55339003e-01,
#         3.94996429e-01,  3.82421608e-01,  3.90008956e-01,  3.91784003e-01,
#         3.80654475e-01,  4.03498016e-01,  4.32037166e-01,  3.76686342e-01,
#         4.27900680e-01,  4.20748665e-01,  3.95206479e-01,  4.46511474e-01,
#         3.61613784e-01,  2.99918273e-01,  3.70893592e-01,  3.03510372e-01,
#         3.60070016e-01,  2.77823672e-01,  3.74262602e-01,  2.57123659e-01,
#         3.73904036e-01,  2.68232995e-01,  1.24797447e+00,  1.72657383e+00])

# %%
len(list(set(folds_list_train1_unique + folds_list_train2_unique)))
# Out:
# 1677155

# %%
torch.mean(torch.tensor(df.loc[(folds_list_train1_unique + folds_list_train2_unique), FEATURES_LIST_TOTRAIN].to_numpy(), device='cpu'), axis=0)
# Out:
# tensor([ 8.8072e-03,  3.9574e-01,  3.3060e-01,  9.1927e-03,  3.4174e-03,
#         -4.9837e-03, -1.4555e-02,  5.5346e-02,  2.5119e-02,  2.6465e-01,
#          1.6706e-01,  9.4897e-02,  4.4504e-02,  1.5251e-01,  7.9967e-02,
#          2.2167e-01,  1.2828e-01,  1.2182e-01,  1.0959e-01,  2.9773e-01,
#          2.6463e-01,  1.8814e-01,  1.7251e-01,  2.5474e-01,  2.3268e-01,
#          2.9794e-01,  2.6854e-01,  1.3985e-01,  1.6285e-01,  3.3061e-01,
#          3.4386e-01,  2.2685e-01,  2.5191e-01,  3.1637e-01,  3.3598e-01,
#          3.5284e-01,  3.6773e-01,  2.6503e-02,  1.8639e-02,  4.3206e-02,
#          5.2987e-02,  4.5417e-01,  3.7763e-01,  4.1617e-01,  4.3928e-01,
#          4.8651e-01,  4.9208e-01,  3.6840e-01,  5.0144e-01,  5.4379e-01,
#          5.3075e-01,  4.5674e-01,  5.6469e-02,  3.8900e-01,  3.7691e-01,
#          7.7549e-01,  9.2466e-01,  7.8590e-01,  8.0848e-01,  8.9896e-01,
#          5.5335e-01,  5.5554e-01,  5.5923e-01,  5.6140e-01,  4.4232e-01,
#          6.1884e-01,  6.1716e-01,  5.9770e-01,  5.9814e-01,  3.7738e-01,
#          2.3893e-01,  3.0803e-01,  4.1036e-03, -3.2201e-02, -1.6373e-03,
#         -1.9916e-02, -3.1589e-02, -9.3184e-02, -8.0653e-03, -3.5789e-02,
#         -2.5181e-03, -1.4894e-02, -3.4983e-02, -1.0155e-01,  3.9338e-01,
#          5.4162e-01,  3.9242e-01,  4.2814e-01,  4.9756e-01,  3.9935e-01,
#          4.3320e-01,  5.2353e-01,  4.2238e-01,  4.2207e-01,  4.3485e-01,
#          4.5472e-01,  3.9837e-01,  5.4216e-01,  3.9731e-01,  4.2589e-01,
#          4.8654e-01,  4.1054e-01,  4.3399e-01,  4.8391e-01,  4.1683e-01,
#          4.1980e-01,  4.6145e-01,  4.5534e-01,  3.9500e-01,  3.8242e-01,
#          3.9001e-01,  3.9178e-01,  3.8065e-01,  4.0350e-01,  4.3204e-01,
#          3.7669e-01,  4.2790e-01,  4.2075e-01,  3.9521e-01,  4.4651e-01,
#          3.6161e-01,  2.9992e-01,  3.7089e-01,  3.0351e-01,  3.6007e-01,
#          2.7782e-01,  3.7426e-01,  2.5712e-01,  3.7390e-01,  2.6823e-01,
#          1.2480e+00,  1.7266e+00], dtype=torch.float64)

# %%
torch.tensor(f_mean)
# Out:
# tensor([ 9.8386e-03,  3.8558e-01,  3.5769e-01,  8.9192e-03,  4.1501e-03,
#         -3.7146e-03, -1.2589e-02,  5.1777e-02,  2.6828e-02,  2.4881e-01,
#          1.8235e-01,  8.9122e-02,  4.9486e-02,  1.4311e-01,  8.9027e-02,
#          2.1168e-01,  1.4630e-01,  1.2122e-01,  1.1358e-01,  2.9381e-01,
#          2.6877e-01,  1.8691e-01,  1.7698e-01,  2.5244e-01,  2.3856e-01,
#          2.9407e-01,  2.7318e-01,  1.3548e-01,  1.6088e-01,  3.2189e-01,
#          3.4253e-01,  2.2056e-01,  2.5013e-01,  3.0822e-01,  3.3535e-01,
#          3.4145e-01,  3.6583e-01,  2.9320e-02,  2.2892e-02,  4.0022e-02,
#          5.0750e-02,  4.4505e-01,  3.6018e-01,  3.4603e-01,  4.1153e-01,
#          4.3803e-01,  4.7612e-01,  3.4787e-01,  4.9963e-01,  5.6400e-01,
#          5.1226e-01,  4.5739e-01,  4.5744e-02,  3.6270e-01,  3.5887e-01,
#          6.5260e-01,  8.0495e-01,  6.6135e-01,  6.7981e-01,  7.6259e-01,
#          5.5640e-01,  5.5817e-01,  5.4554e-01,  5.4678e-01,  4.3506e-01,
#          6.0757e-01,  6.0850e-01,  5.9519e-01,  5.9594e-01,  3.6954e-01,
#          2.4337e-01,  3.3227e-01,  5.3933e-03, -3.2868e-02, -2.0445e-04,
#         -1.9092e-02, -3.1898e-02, -7.6800e-02, -6.0595e-03, -3.5435e-02,
#         -2.0995e-03, -1.4418e-02, -3.4615e-02, -8.0085e-02,  3.9822e-01,
#          5.5782e-01,  4.0240e-01,  4.4445e-01,  5.1409e-01,  4.0052e-01,
#          4.1025e-01,  5.2051e-01,  4.0508e-01,  4.0883e-01,  4.2889e-01,
#          4.1763e-01,  4.0227e-01,  5.5909e-01,  4.0711e-01,  4.3686e-01,
#          5.0012e-01,  4.0856e-01,  4.0506e-01,  4.8141e-01,  4.0166e-01,
#          4.0706e-01,  4.5305e-01,  4.1501e-01,  3.9999e-01,  4.1654e-01,
#          4.0074e-01,  4.0688e-01,  4.1228e-01,  4.0264e-01,  4.0711e-01,
#          3.7342e-01,  4.0443e-01,  4.0103e-01,  3.8582e-01,  4.1560e-01,
#          3.3513e-01,  2.6878e-01,  3.4355e-01,  2.8000e-01,  3.3515e-01,
#          2.4488e-01,  3.3918e-01,  2.3238e-01,  3.4256e-01,  2.4562e-01,
#          1.1513e+00,  1.4864e+00], dtype=torch.float64)

# %% [markdown]
# # Training auto encoder

# %%
print('Training started')
patience=5

utility_scores = [None] * 5
accuracy_scores = [None] * 5

writer = SummaryWriter()

ts_train = torch.tensor(df.loc[folds_list_train1_unique, FEATURES_LIST_TOTRAIN].to_numpy(), device='cuda')
#ts_train_y = torch.tensor((df.loc[folds_list_train_unique, 'resp'] > 0).astype(np.byte).to_numpy(), device='cuda')

# Normalize data
ts_train_mean = torch.mean(ts_train, axis=0)
ts_train_std = torch.std(ts_train, axis=0)
#ts_train_mean = torch.tensor(f_mean)
# If you want to use Standard scale : calculate mean from f_mean and std scale from whole dataset
#ts_train = pyStandardScale(ts_train, ts_train_mean, ts_train_std)

train_dataset = torch.utils.data.TensorDataset(ts_train)
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)

ts_test = [None] * 5
#ts_test_y = [None] * 5    
test_dataset = [None] * 5
test_loader = [None] * 5

for fold_indice in range(5):
    ts_test[fold_indice] = torch.tensor(df.loc[folds_list_test[fold_indice], FEATURES_LIST_TOTRAIN].to_numpy(), device='cuda')
    ts_test_y[fold_indice] = torch.tensor((df.loc[folds_list_test[fold_indice], 'resp'] > 0).astype(np.byte).to_numpy(), device='cuda')

    # Normalize
    #ts_test[fold_indice] = pyStandardScale(ts_test[fold_indice], ts_train_mean, ts_train_std)
    
    test_dataset[fold_indice] = torch.utils.data.TensorDataset(ts_test[fold_indice], ts_test_y[fold_indice])
    test_loader[fold_indice] = torch.utils.data.DataLoader(test_dataset[fold_indice], batch_size=BATCH_SIZE)

torch.manual_seed(seed)

model = nn.Sequential(
        #nn.Dropout(0.2),
        nn.Linear(len(FEATURES_LIST_TOTRAIN), 200),
        #nn.BatchNorm1d(130),
        nn.ReLU(),
        nn.Dropout(0.7),

        nn.Linear(200, 100),
        #nn.BatchNorm1d(130),
        nn.ReLU(),
        nn.Dropout(0.7),
    
        nn.Linear(100, 1),
        nn.Sigmoid(),
    ).double().to('cuda')
    
print('Number of model parameters :')
numel_list = [p.numel() for p in model.parameters()]
sum(numel_list), numel_list

loss_fn = nn.BCELoss().to('cuda')
#optimizer = torch.optim.Adam(model.parameters(), lr=1e-3) 
optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE, weight_decay=WEIGHT_DECAY) 

scheduler = None
#scheduler = torch.optim.lr_scheduler.OneCycleLR(optimizer=optimizer, pct_start=0.1, div_factor=1e3,
#                                                         max_lr=1e-4, epochs=NUM_EPOCHS, steps_per_epoch=len(train_loader))

model.eval()
#start_accuracy = accuracy_score(ts_test_y.cpu().numpy(), (model(ts_test).squeeze() > 0.5).cpu().numpy())
#start_utility_score = utility_function(df.loc[test_index], (model(ts_test).squeeze() > 0.5).cpu().numpy())
#print('Start Validation Accuracy: {:.4f}'.format(start_accuracy))
#print('Start Validation Utility: {:.4f}'.format(start_utility_score))


Val_Loss = 0
N_Samples = 0

the_last_loss = 100
the_last_utility_score = 0
the_last_accuracy = 0
trigger_times=0
early_stopping_met = False

for epoch in range(NUM_EPOCHS): 
    running_loss = 0.0        
    
    ### Call back to save activation stats (mean, std dev and near 0 values after activation functions)
    # Setting hook for activation layers stats

    hook_handles = []
    save_output_activation_stats = []

    for layer in model.modules():
        if ('activation' in str(type(layer))):
            save_output_activation_stats_1layer = SaveOutputActivationStats()
            handle = layer.register_forward_hook(save_output_activation_stats_1layer)
            save_output_activation_stats.append(save_output_activation_stats_1layer)
            hook_handles.append(handle)    
            
    model.train()

    for batch in train_loader:
        #inputs, labels = batch[0], batch[1]
        inputs, labels = batch[0].to('cuda'), batch[1].to('cuda')
        optimizer.zero_grad()

        with torch.set_grad_enabled(True):
            outputs = model(inputs)
            loss = loss_fn(outputs, labels.unsqueeze(-1).double())
            loss.backward()
            optimizer.step()
            
            if scheduler:
                scheduler.step()

    # update local train loss
        running_loss += loss.item() * inputs.size(0)

    # update global train loss
    epoch_loss = running_loss / len(train_loader.dataset)
    print('Epoch({}) - Training Loss: {:.4f}'.format(epoch, epoch_loss))

    writer.add_scalar(f"Global train/loss", epoch_loss, epoch)

    # Write activation stats graphs
    for layer_number,save_output_activation_stats_layer in enumerate(save_output_activation_stats):
        df_stats_layer = pd.DataFrame(save_output_activation_stats_layer.outputs)

        fig, ax = plt.subplots(1, 3, figsize=(25, 4))

        ax[0].set_title(f'Layer {layer_number} : Mean activation value', fontsize=16)
        ax[0].set_xlabel('Batch instances')
        ax[0].set_ylabel('Mean')
        ax[0].plot(range(df_stats_layer.shape[0]), df_stats_layer['mean'])

        ax[1].set_title(f'Layer {layer_number} : Std deviation activation value', fontsize=16)
        ax[1].set_xlabel('Batch instances')
        ax[1].set_ylabel('Standard deviation')
        ax[1].plot(range(df_stats_layer.shape[0]), df_stats_layer['std'])

        ax[2].set_title(f'Layer {layer_number} : Percentage of activation values near zero', fontsize=16)
        ax[2].set_xlabel('Batch instances')
        ax[2].set_ylabel('Percentage')
        ax[2].plot(range(df_stats_layer.shape[0]), df_stats_layer['near_zero']);
        
        plot_buf = io.BytesIO()
        plt.savefig(plot_buf, format='jpeg')
        plt.close()
        
        plot_buf.seek(0)
        image = PIL.Image.open(plot_buf)
        image = transforms.ToTensor()(image)
        writer.add_image("Train activation stats/Activation stats layer " + str(layer_number), image, epoch)
    
    # Validation 
    model.eval()

    vrunning_loss = [None] * 5
    num_samples = [None] * 5
    vepoch_loss_folds = [None] * 5
    vepoch_accuracy_folds = [None] * 5
    vepoch_utility_score_folds = [None] * 5
    
    for fold_indice in range(5):    
        vrunning_loss[fold_indice] = 0.0
        num_samples[fold_indice] = 0

        for batch in test_loader[fold_indice]:
            inputs, labels = batch[0].to('cuda'), batch[1].to('cuda')

            optimizer.zero_grad()
            with torch.no_grad():
                outputs = model(inputs)
                loss = loss_fn(outputs, labels.unsqueeze(-1).double())

            vrunning_loss[fold_indice] += loss.item() * inputs.size(0)
            num_samples[fold_indice] += labels.size(0)
            
            vepoch_loss_folds[fold_indice] = vrunning_loss[fold_indice] / num_samples[fold_indice]

        print('Epoch({}) - Fold {} - Validation Loss : {:.4f}'.format(epoch, fold_indice, vepoch_loss_folds[fold_indice]))

        model.eval()
        with torch.no_grad():
            vepoch_accuracy_folds[fold_indice] = accuracy_score(ts_test_y[fold_indice].cpu().numpy(), (model(ts_test[fold_indice]).squeeze() > 0.5).cpu().numpy())
            vepoch_utility_score_folds[fold_indice] = utility_function(df.loc[folds_list_test[fold_indice]], (model(ts_test[fold_indice]).squeeze() > 0.5).cpu().numpy())
        print('Epoch({}) - Fold {} - Validation Accuracy : {:.4f}'.format(epoch, fold_indice, vepoch_accuracy_folds[fold_indice]))
        print('Epoch({}) - Fold {} - Validation Utility score : {:.4f}'.format(epoch, fold_indice, vepoch_utility_score_folds[fold_indice]))
        
            
    # update epoch loss
    vepoch_loss = sum(vepoch_loss_folds) / len(vepoch_loss_folds)
    vepoch_accuracy = sum(vepoch_accuracy_folds) / len(vepoch_accuracy_folds)
    vepoch_utility_score = sum(vepoch_utility_score_folds) #/ len(vepoch_utility_score_folds)
    print('Epoch({}) - GLOBAL - Validation Loss: {:.4f}'.format(epoch, vepoch_loss))
    print('Epoch({}) - GLOBAL - Validation Accuracy: {:.4f}'.format(epoch, vepoch_accuracy))
    print('Epoch({}) - GLOBAL - Validation Utility score: {:.4f}'.format(epoch, vepoch_utility_score))

    #print(f'Sum of model parameters ({epoch}):')
    #[print(p.sum()) for p in model.parameters()]

    writer.add_scalar("Global valid/Loss", vepoch_loss, epoch)
    writer.add_scalar("Global valid/Accuracy", vepoch_accuracy, epoch)
    writer.add_scalar("Global valid/Utility", vepoch_utility_score, epoch)

    for fold_indice in range(5):
        writer.add_scalar("Fold valid Loss/Loss fold "+str(fold_indice), vepoch_loss_folds[fold_indice], epoch)
        writer.add_scalar("Fold valid Accuracy/Accuracy fold "+str(fold_indice), vepoch_accuracy_folds[fold_indice], epoch)
        writer.add_scalar("Fold valid Utility/Utility fold "+str(fold_indice), vepoch_utility_score_folds[fold_indice], epoch)
        
    
    writer.flush()

    # Check if Early Stopping
    #if vepoch_loss > the_last_loss:
    #if (vepoch_utility_score < the_last_utility_score) and (vepoch_loss > the_last_loss) and (vepoch_accuracy < the_last_accuracy):
    
    if (vepoch_loss > the_last_loss):
        if (EARLY_STOPPING == True):
            trigger_times += 1

            print(f'Intermediate early stopping : vepoch_loss = {vepoch_loss:.4f}, the_last_loss={the_last_loss:.4f}')
            #print(f'Intermediate early stopping : vepoch_accuracy = {vepoch_accuracy:.4f}, the_last_utility_score={the_last_accuracy:.4f}')
            #print(f'Intermediate early stopping : vepoch_utility_score = {vepoch_utility_score:.4f}, the_last_utility_score={the_last_utility_score:.4f}')

            if trigger_times >= patience:
                print('Meet Early stopping!')
                early_stopping_met = True
                ##torch.save(model.state_dict(), f'model_{fold}.pt')
                break
    else:
        trigger_times = 0
        the_last_loss = vepoch_loss
        the_last_utility_score = vepoch_utility_score
        the_last_accuracy = vepoch_accuracy
        
        the_last_utility_score_folds = vepoch_utility_score_folds
        the_last_accuracy_folds = vepoch_accuracy_folds
        
        the_best_epoch = epoch

        # Save model for the best version so far
        print(f'Saving model corresponding to last_utility_score == {the_last_utility_score}')
        torch.save(model.state_dict(), f'model_NN_allfolds_V1.pt')

    print('\n')

if (early_stopping_met == False):
    print("Didn't meet early stopping : saving final model")
    # Save model if don't meet early stopping
    torch.save(model.state_dict(), f'model_NN_allfolds_V1.pt')

#utility_scores.append(the_last_utility_score)
#accuracy_scores.append(the_last_accuracy)
writer.add_text(f"Global valid/Utility", f"Best utility: {the_last_utility_score}", the_best_epoch)
        
scores_results = {'utility_score': the_last_utility_score, 'utility_scores': the_last_utility_score_folds, 'utility_score_std': np.std(the_last_utility_score_folds), 'accuracy_scores': the_last_accuracy_folds}

writer.add_text('Final utility score', str(scores_results))
writer.add_text('Batch size', str(BATCH_SIZE))
writer.add_text('Patience', str(patience))
writer.add_text('Number of epochs', str(NUM_EPOCHS))
writer.add_text('Number of parameters per layer', str([p.numel() for p in model.parameters()]))
writer.add_text('Model architecture', str(model).replace('\n', '<BR>'))
writer.add_text('Comment', MODEL_COMMENT)

writer.close()

print('Training summary:')
print(scores_results)

# %% [markdown]
# # Training

# %%
print('Training started')
patience=5

utility_scores = [None] * 5
accuracy_scores = [None] * 5

writer = SummaryWriter()

ts_train = torch.tensor(df.loc[folds_list_train_unique, FEATURES_LIST_TOTRAIN].to_numpy(), device='cuda')
ts_train_y = torch.tensor((df.loc[folds_list_train_unique, 'resp'] > 0).astype(np.byte).to_numpy(), device='cuda')

# Normalize data
ts_train_mean = torch.mean(ts_train, axis=0)
ts_train_std = torch.std(ts_train, axis=0)
#ts_train = pyStandardScale(ts_train, ts_train_mean, ts_train_std)

train_dataset = torch.utils.data.TensorDataset(ts_train, ts_train_y)
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True) # pin_memory : VOIR RESULTAT

ts_test = [None] * 5
ts_test_y = [None] * 5    
test_dataset = [None] * 5
test_loader = [None] * 5

for fold_indice in range(5):
    ts_test[fold_indice] = torch.tensor(df.loc[folds_list_test[fold_indice], FEATURES_LIST_TOTRAIN].to_numpy(), device='cuda')
    ts_test_y[fold_indice] = torch.tensor((df.loc[folds_list_test[fold_indice], 'resp'] > 0).astype(np.byte).to_numpy(), device='cuda')

    # Normalize
    #ts_test[fold_indice] = pyStandardScale(ts_test[fold_indice], ts_train_mean, ts_train_std)
    
    test_dataset[fold_indice] = torch.utils.data.TensorDataset(ts_test[fold_indice], ts_test_y[fold_indice])
    test_loader[fold_indice] = torch.utils.data.DataLoader(test_dataset[fold_indice], batch_size=BATCH_SIZE)

torch.manual_seed(seed)

model = nn.Sequential(
        #nn.Dropout(0.2),
        nn.Linear(len(FEATURES_LIST_TOTRAIN), 200),
        #nn.BatchNorm1d(130),
        nn.ReLU(),
        nn.Dropout(0.7),

        nn.Linear(200, 100),
        #nn.BatchNorm1d(130),
        nn.ReLU(),
        nn.Dropout(0.7),
    
        nn.Linear(100, 1),
        nn.Sigmoid(),
    ).double().to('cuda')
    
print('Number of model parameters :')
numel_list = [p.numel() for p in model.parameters()]
sum(numel_list), numel_list

loss_fn = nn.BCELoss().to('cuda')
#optimizer = torch.optim.Adam(model.parameters(), lr=1e-3) 
optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE, weight_decay=WEIGHT_DECAY) 

scheduler = None
#scheduler = torch.optim.lr_scheduler.OneCycleLR(optimizer=optimizer, pct_start=0.1, div_factor=1e3,
#                                                         max_lr=1e-4, epochs=NUM_EPOCHS, steps_per_epoch=len(train_loader))

model.eval()
#start_accuracy = accuracy_score(ts_test_y.cpu().numpy(), (model(ts_test).squeeze() > 0.5).cpu().numpy())
#start_utility_score = utility_function(df.loc[test_index], (model(ts_test).squeeze() > 0.5).cpu().numpy())
#print('Start Validation Accuracy: {:.4f}'.format(start_accuracy))
#print('Start Validation Utility: {:.4f}'.format(start_utility_score))


Val_Loss = 0
N_Samples = 0

the_last_loss = 100
the_last_utility_score = 0
the_last_accuracy = 0
trigger_times=0
early_stopping_met = False

for epoch in range(NUM_EPOCHS): 
    running_loss = 0.0        
    
    ### Call back to save activation stats (mean, std dev and near 0 values after activation functions)
    # Setting hook for activation layers stats

    hook_handles = []
    save_output_activation_stats = []

    for layer in model.modules():
        if ('activation' in str(type(layer))):
            save_output_activation_stats_1layer = SaveOutputActivationStats()
            handle = layer.register_forward_hook(save_output_activation_stats_1layer)
            save_output_activation_stats.append(save_output_activation_stats_1layer)
            hook_handles.append(handle)    
            
    model.train()

    for batch in train_loader:
        #inputs, labels = batch[0], batch[1]
        inputs, labels = batch[0].to('cuda'), batch[1].to('cuda')
        optimizer.zero_grad()

        with torch.set_grad_enabled(True):
            outputs = model(inputs)
            loss = loss_fn(outputs, labels.unsqueeze(-1).double())
            loss.backward()
            optimizer.step()
            
            if scheduler:
                scheduler.step()

    # update local train loss
        running_loss += loss.item() * inputs.size(0)

    # update global train loss
    epoch_loss = running_loss / len(train_loader.dataset)
    print('Epoch({}) - Training Loss: {:.4f}'.format(epoch, epoch_loss))

    writer.add_scalar(f"Global train/loss", epoch_loss, epoch)

    # Write activation stats graphs
    for layer_number,save_output_activation_stats_layer in enumerate(save_output_activation_stats):
        df_stats_layer = pd.DataFrame(save_output_activation_stats_layer.outputs)

        fig, ax = plt.subplots(1, 3, figsize=(25, 4))

        ax[0].set_title(f'Layer {layer_number} : Mean activation value', fontsize=16)
        ax[0].set_xlabel('Batch instances')
        ax[0].set_ylabel('Mean')
        ax[0].plot(range(df_stats_layer.shape[0]), df_stats_layer['mean'])

        ax[1].set_title(f'Layer {layer_number} : Std deviation activation value', fontsize=16)
        ax[1].set_xlabel('Batch instances')
        ax[1].set_ylabel('Standard deviation')
        ax[1].plot(range(df_stats_layer.shape[0]), df_stats_layer['std'])

        ax[2].set_title(f'Layer {layer_number} : Percentage of activation values near zero', fontsize=16)
        ax[2].set_xlabel('Batch instances')
        ax[2].set_ylabel('Percentage')
        ax[2].plot(range(df_stats_layer.shape[0]), df_stats_layer['near_zero']);
        
        plot_buf = io.BytesIO()
        plt.savefig(plot_buf, format='jpeg')
        plt.close()
        
        plot_buf.seek(0)
        image = PIL.Image.open(plot_buf)
        image = transforms.ToTensor()(image)
        writer.add_image("Train activation stats/Activation stats layer " + str(layer_number), image, epoch)
    
    # Validation 
    model.eval()

    vrunning_loss = [None] * 5
    num_samples = [None] * 5
    vepoch_loss_folds = [None] * 5
    vepoch_accuracy_folds = [None] * 5
    vepoch_utility_score_folds = [None] * 5
    
    for fold_indice in range(5):    
        vrunning_loss[fold_indice] = 0.0
        num_samples[fold_indice] = 0

        for batch in test_loader[fold_indice]:
            inputs, labels = batch[0].to('cuda'), batch[1].to('cuda')

            optimizer.zero_grad()
            with torch.no_grad():
                outputs = model(inputs)
                loss = loss_fn(outputs, labels.unsqueeze(-1).double())

            vrunning_loss[fold_indice] += loss.item() * inputs.size(0)
            num_samples[fold_indice] += labels.size(0)
            
            vepoch_loss_folds[fold_indice] = vrunning_loss[fold_indice] / num_samples[fold_indice]

        print('Epoch({}) - Fold {} - Validation Loss : {:.4f}'.format(epoch, fold_indice, vepoch_loss_folds[fold_indice]))

        model.eval()
        with torch.no_grad():
            vepoch_accuracy_folds[fold_indice] = accuracy_score(ts_test_y[fold_indice].cpu().numpy(), (model(ts_test[fold_indice]).squeeze() > 0.5).cpu().numpy())
            vepoch_utility_score_folds[fold_indice] = utility_function(df.loc[folds_list_test[fold_indice]], (model(ts_test[fold_indice]).squeeze() > 0.5).cpu().numpy())
        print('Epoch({}) - Fold {} - Validation Accuracy : {:.4f}'.format(epoch, fold_indice, vepoch_accuracy_folds[fold_indice]))
        print('Epoch({}) - Fold {} - Validation Utility score : {:.4f}'.format(epoch, fold_indice, vepoch_utility_score_folds[fold_indice]))
        
            
    # update epoch loss
    vepoch_loss = sum(vepoch_loss_folds) / len(vepoch_loss_folds)
    vepoch_accuracy = sum(vepoch_accuracy_folds) / len(vepoch_accuracy_folds)
    vepoch_utility_score = sum(vepoch_utility_score_folds) #/ len(vepoch_utility_score_folds)
    print('Epoch({}) - GLOBAL - Validation Loss: {:.4f}'.format(epoch, vepoch_loss))
    print('Epoch({}) - GLOBAL - Validation Accuracy: {:.4f}'.format(epoch, vepoch_accuracy))
    print('Epoch({}) - GLOBAL - Validation Utility score: {:.4f}'.format(epoch, vepoch_utility_score))

    #print(f'Sum of model parameters ({epoch}):')
    #[print(p.sum()) for p in model.parameters()]

    writer.add_scalar("Global valid/Loss", vepoch_loss, epoch)
    writer.add_scalar("Global valid/Accuracy", vepoch_accuracy, epoch)
    writer.add_scalar("Global valid/Utility", vepoch_utility_score, epoch)

    for fold_indice in range(5):
        writer.add_scalar("Fold valid Loss/Loss fold "+str(fold_indice), vepoch_loss_folds[fold_indice], epoch)
        writer.add_scalar("Fold valid Accuracy/Accuracy fold "+str(fold_indice), vepoch_accuracy_folds[fold_indice], epoch)
        writer.add_scalar("Fold valid Utility/Utility fold "+str(fold_indice), vepoch_utility_score_folds[fold_indice], epoch)
        
    
    writer.flush()

    # Check if Early Stopping
    #if vepoch_loss > the_last_loss:
    #if (vepoch_utility_score < the_last_utility_score) and (vepoch_loss > the_last_loss) and (vepoch_accuracy < the_last_accuracy):
    
    if (vepoch_loss > the_last_loss):
        if (EARLY_STOPPING == True):
            trigger_times += 1

            print(f'Intermediate early stopping : vepoch_loss = {vepoch_loss:.4f}, the_last_loss={the_last_loss:.4f}')
            #print(f'Intermediate early stopping : vepoch_accuracy = {vepoch_accuracy:.4f}, the_last_utility_score={the_last_accuracy:.4f}')
            #print(f'Intermediate early stopping : vepoch_utility_score = {vepoch_utility_score:.4f}, the_last_utility_score={the_last_utility_score:.4f}')

            if trigger_times >= patience:
                print('Meet Early stopping!')
                early_stopping_met = True
                ##torch.save(model.state_dict(), f'model_{fold}.pt')
                break
    else:
        trigger_times = 0
        the_last_loss = vepoch_loss
        the_last_utility_score = vepoch_utility_score
        the_last_accuracy = vepoch_accuracy
        
        the_last_utility_score_folds = vepoch_utility_score_folds
        the_last_accuracy_folds = vepoch_accuracy_folds
        
        the_best_epoch = epoch

        # Save model for the best version so far
        print(f'Saving model corresponding to last_utility_score == {the_last_utility_score}')
        torch.save(model.state_dict(), f'model_NN_allfolds_V1.pt')

    print('\n')

if (early_stopping_met == False):
    print("Didn't meet early stopping : saving final model")
    # Save model if don't meet early stopping
    torch.save(model.state_dict(), f'model_NN_allfolds_V1.pt')

#utility_scores.append(the_last_utility_score)
#accuracy_scores.append(the_last_accuracy)
writer.add_text(f"Global valid/Utility", f"Best utility: {the_last_utility_score}", the_best_epoch)
        
scores_results = {'utility_score': the_last_utility_score, 'utility_scores': the_last_utility_score_folds, 'utility_score_std': np.std(the_last_utility_score_folds), 'accuracy_scores': the_last_accuracy_folds}

writer.add_text('Final utility score', str(scores_results))
writer.add_text('Batch size', str(BATCH_SIZE))
writer.add_text('Patience', str(patience))
writer.add_text('Number of epochs', str(NUM_EPOCHS))
writer.add_text('Number of parameters per layer', str([p.numel() for p in model.parameters()]))
writer.add_text('Model architecture', str(model).replace('\n', '<BR>'))
writer.add_text('Comment', MODEL_COMMENT)

writer.close()

print('Training summary:')
print(scores_results)
# Out:
# Training started
# Number of model parameters :
# Epoch(0) - Training Loss: 0.7547
# Epoch(0) - Fold 0 - Validation Loss : 0.6954
# Epoch(0) - Fold 0 - Validation Accuracy : 0.5115
# Epoch(0) - Fold 0 - Validation Utility score : 86.1725
# Epoch(0) - Fold 1 - Validation Loss : 0.6947
# Epoch(0) - Fold 1 - Validation Accuracy : 0.5132
# Epoch(0) - Fold 1 - Validation Utility score : 102.8200
# Epoch(0) - Fold 2 - Validation Loss : 0.6952
# Epoch(0) - Fold 2 - Validation Accuracy : 0.5040
# Epoch(0) - Fold 2 - Validation Utility score : -0.0000
# Epoch(0) - Fold 3 - Validation Loss : 0.6960
# Epoch(0) - Fold 3 - Validation Accuracy : 0.5029
# Epoch(0) - Fold 3 - Validation Utility score : -0.0000
# Epoch(0) - Fold 4 - Validation Loss : 0.6965
# Epoch(0) - Fold 4 - Validation Accuracy : 0.5074
# Epoch(0) - Fold 4 - Validation Utility score : 265.3359
# Epoch(0) - GLOBAL - Validation Loss: 0.6956
# Epoch(0) - GLOBAL - Validation Accuracy: 0.5078
# Epoch(0) - GLOBAL - Validation Utility score: 454.3283
# Saving model corresponding to last_utility_score == 454.3283475095663
#
#
# Epoch(1) - Training Loss: 0.7259
# Epoch(1) - Fold 0 - Validation Loss : 0.6950
# Epoch(1) - Fold 0 - Validation Accuracy : 0.5086
# Epoch(1) - Fold 0 - Validation Utility score : 0.3384
# Epoch(1) - Fold 1 - Validation Loss : 0.6945
# Epoch(1) - Fold 1 - Validation Accuracy : 0.5104
# Epoch(1) - Fold 1 - Validation Utility score : 14.9695
# Epoch(1) - Fold 2 - Validation Loss : 0.6948
# Epoch(1) - Fold 2 - Validation Accuracy : 0.5022
# Epoch(1) - Fold 2 - Validation Utility score : -0.0000
# Epoch(1) - Fold 3 - Validation Loss : 0.6949
# Epoch(1) - Fold 3 - Validation Accuracy : 0.5038
# Epoch(1) - Fold 3 - Validation Utility score : -0.0000
# Epoch(1) - Fold 4 - Validation Loss : 0.6956
# Epoch(1) - Fold 4 - Validation Accuracy : 0.5037
# Epoch(1) - Fold 4 - Validation Utility score : 171.4608
# Epoch(1) - GLOBAL - Validation Loss: 0.6950
# Epoch(1) - GLOBAL - Validation Accuracy: 0.5057
# Epoch(1) - GLOBAL - Validation Utility score: 186.7688
# Saving model corresponding to last_utility_score == 186.76880837204638
#
#
# Epoch(2) - Training Loss: 0.7132
# Epoch(2) - Fold 0 - Validation Loss : 0.6939
# Epoch(2) - Fold 0 - Validation Accuracy : 0.5055
# Epoch(2) - Fold 0 - Validation Utility score : -0.0000
# Epoch(2) - Fold 1 - Validation Loss : 0.6945
# Epoch(2) - Fold 1 - Validation Accuracy : 0.5090
# Epoch(2) - Fold 1 - Validation Utility score : 1.2455
# Epoch(2) - Fold 2 - Validation Loss : 0.6944
# Epoch(2) - Fold 2 - Validation Accuracy : 0.5023
# Epoch(2) - Fold 2 - Validation Utility score : -0.0000
# Epoch(2) - Fold 3 - Validation Loss : 0.6938
# Epoch(2) - Fold 3 - Validation Accuracy : 0.5026
# Epoch(2) - Fold 3 - Validation Utility score : -0.0000
# Epoch(2) - Fold 4 - Validation Loss : 0.6944
# Epoch(2) - Fold 4 - Validation Accuracy : 0.5025
# Epoch(2) - Fold 4 - Validation Utility score : 75.5615
# Epoch(2) - GLOBAL - Validation Loss: 0.6942
# Epoch(2) - GLOBAL - Validation Accuracy: 0.5044
# Epoch(2) - GLOBAL - Validation Utility score: 76.8070
# Saving model corresponding to last_utility_score == 76.80701933110544
#
#
# Epoch(3) - Training Loss: 0.7079
# Epoch(3) - Fold 0 - Validation Loss : 0.6937
# Epoch(3) - Fold 0 - Validation Accuracy : 0.5020
# Epoch(3) - Fold 0 - Validation Utility score : -0.0000
# Epoch(3) - Fold 1 - Validation Loss : 0.6939
# Epoch(3) - Fold 1 - Validation Accuracy : 0.5076
# Epoch(3) - Fold 1 - Validation Utility score : -0.0000
# Epoch(3) - Fold 2 - Validation Loss : 0.6937
# Epoch(3) - Fold 2 - Validation Accuracy : 0.5026
# Epoch(3) - Fold 2 - Validation Utility score : -0.0000
# Epoch(3) - Fold 3 - Validation Loss : 0.6936
# Epoch(3) - Fold 3 - Validation Accuracy : 0.5016
# Epoch(3) - Fold 3 - Validation Utility score : -0.0000
# Epoch(3) - Fold 4 - Validation Loss : 0.6941
# Epoch(3) - Fold 4 - Validation Accuracy : 0.5006
# Epoch(3) - Fold 4 - Validation Utility score : 41.2144
# Epoch(3) - GLOBAL - Validation Loss: 0.6938
# Epoch(3) - GLOBAL - Validation Accuracy: 0.5029
# Epoch(3) - GLOBAL - Validation Utility score: 41.2144
# Saving model corresponding to last_utility_score == 41.214382040528335
#
#
# Epoch(4) - Training Loss: 0.7045
# Epoch(4) - Fold 0 - Validation Loss : 0.6936
# Epoch(4) - Fold 0 - Validation Accuracy : 0.5011
# Epoch(4) - Fold 0 - Validation Utility score : -0.0000
# Epoch(4) - Fold 1 - Validation Loss : 0.6938
# Epoch(4) - Fold 1 - Validation Accuracy : 0.5070
# Epoch(4) - Fold 1 - Validation Utility score : -0.0000
# Epoch(4) - Fold 2 - Validation Loss : 0.6935
# Epoch(4) - Fold 2 - Validation Accuracy : 0.5028
# Epoch(4) - Fold 2 - Validation Utility score : -0.0000
# Epoch(4) - Fold 3 - Validation Loss : 0.6936
# Epoch(4) - Fold 3 - Validation Accuracy : 0.5011
# Epoch(4) - Fold 3 - Validation Utility score : -0.0000
# Epoch(4) - Fold 4 - Validation Loss : 0.6940
# Epoch(4) - Fold 4 - Validation Accuracy : 0.5000
# Epoch(4) - Fold 4 - Validation Utility score : 32.2091
# Epoch(4) - GLOBAL - Validation Loss: 0.6937
# Epoch(4) - GLOBAL - Validation Accuracy: 0.5024
# Epoch(4) - GLOBAL - Validation Utility score: 32.2091
# Saving model corresponding to last_utility_score == 32.209138632761615
#
#
# Epoch(5) - Training Loss: 0.7023
# Epoch(5) - Fold 0 - Validation Loss : 0.6937
# Epoch(5) - Fold 0 - Validation Accuracy : 0.5002
# Epoch(5) - Fold 0 - Validation Utility score : -0.0000
# Epoch(5) - Fold 1 - Validation Loss : 0.6939
# Epoch(5) - Fold 1 - Validation Accuracy : 0.5065
# Epoch(5) - Fold 1 - Validation Utility score : -0.0000
# Epoch(5) - Fold 2 - Validation Loss : 0.6935
# Epoch(5) - Fold 2 - Validation Accuracy : 0.5025
# Epoch(5) - Fold 2 - Validation Utility score : -0.0000
# Epoch(5) - Fold 3 - Validation Loss : 0.6936
# Epoch(5) - Fold 3 - Validation Accuracy : 0.5009
# Epoch(5) - Fold 3 - Validation Utility score : -0.0000
# Epoch(5) - Fold 4 - Validation Loss : 0.6940
# Epoch(5) - Fold 4 - Validation Accuracy : 0.4995
# Epoch(5) - Fold 4 - Validation Utility score : 24.1173
# Epoch(5) - GLOBAL - Validation Loss: 0.6937
# Epoch(5) - GLOBAL - Validation Accuracy: 0.5019
# Epoch(5) - GLOBAL - Validation Utility score: 24.1173
# Intermediate early stopping : vepoch_loss = 0.6937, the_last_loss=0.6937
#
#
# Epoch(6) - Training Loss: 0.7004
# Epoch(6) - Fold 0 - Validation Loss : 0.6934
# Epoch(6) - Fold 0 - Validation Accuracy : 0.5003
# Epoch(6) - Fold 0 - Validation Utility score : -0.0000
# Epoch(6) - Fold 1 - Validation Loss : 0.6938
# Epoch(6) - Fold 1 - Validation Accuracy : 0.5065
# Epoch(6) - Fold 1 - Validation Utility score : -0.0000
# Epoch(6) - Fold 2 - Validation Loss : 0.6934
# Epoch(6) - Fold 2 - Validation Accuracy : 0.5024
# Epoch(6) - Fold 2 - Validation Utility score : -0.0000
# Epoch(6) - Fold 3 - Validation Loss : 0.6934
# Epoch(6) - Fold 3 - Validation Accuracy : 0.5009
# Epoch(6) - Fold 3 - Validation Utility score : -0.0000
# Epoch(6) - Fold 4 - Validation Loss : 0.6936
# Epoch(6) - Fold 4 - Validation Accuracy : 0.4992
# Epoch(6) - Fold 4 - Validation Utility score : 22.3223
# Epoch(6) - GLOBAL - Validation Loss: 0.6935
# Epoch(6) - GLOBAL - Validation Accuracy: 0.5019
# Epoch(6) - GLOBAL - Validation Utility score: 22.3223
# Saving model corresponding to last_utility_score == 22.32230637615362
#
#
# Epoch(7) - Training Loss: 0.6994
# Epoch(7) - Fold 0 - Validation Loss : 0.6933
# Epoch(7) - Fold 0 - Validation Accuracy : 0.5003
# Epoch(7) - Fold 0 - Validation Utility score : -0.0000
# Epoch(7) - Fold 1 - Validation Loss : 0.6938
# Epoch(7) - Fold 1 - Validation Accuracy : 0.5065
# Epoch(7) - Fold 1 - Validation Utility score : -0.0000
# Epoch(7) - Fold 2 - Validation Loss : 0.6934
# Epoch(7) - Fold 2 - Validation Accuracy : 0.5022
# Epoch(7) - Fold 2 - Validation Utility score : -0.0000
# Epoch(7) - Fold 3 - Validation Loss : 0.6933
# Epoch(7) - Fold 3 - Validation Accuracy : 0.5005
# Epoch(7) - Fold 3 - Validation Utility score : -0.0000
# Epoch(7) - Fold 4 - Validation Loss : 0.6935
# Epoch(7) - Fold 4 - Validation Accuracy : 0.4990
# Epoch(7) - Fold 4 - Validation Utility score : 19.4305
# Epoch(7) - GLOBAL - Validation Loss: 0.6935
# Epoch(7) - GLOBAL - Validation Accuracy: 0.5017
# Epoch(7) - GLOBAL - Validation Utility score: 19.4305
# Saving model corresponding to last_utility_score == 19.430489514075912
#
#
# Epoch(8) - Training Loss: 0.6982
# Epoch(8) - Fold 0 - Validation Loss : 0.6932
# Epoch(8) - Fold 0 - Validation Accuracy : 0.5002
# Epoch(8) - Fold 0 - Validation Utility score : -0.0000
# Epoch(8) - Fold 1 - Validation Loss : 0.6937
# Epoch(8) - Fold 1 - Validation Accuracy : 0.5064
# Epoch(8) - Fold 1 - Validation Utility score : -0.0000
# Epoch(8) - Fold 2 - Validation Loss : 0.6933
# Epoch(8) - Fold 2 - Validation Accuracy : 0.5021
# Epoch(8) - Fold 2 - Validation Utility score : -0.0000
# Epoch(8) - Fold 3 - Validation Loss : 0.6933
# Epoch(8) - Fold 3 - Validation Accuracy : 0.5004
# Epoch(8) - Fold 3 - Validation Utility score : -0.0000
# Epoch(8) - Fold 4 - Validation Loss : 0.6934
# Epoch(8) - Fold 4 - Validation Accuracy : 0.4990
# Epoch(8) - Fold 4 - Validation Utility score : 20.3390
# Epoch(8) - GLOBAL - Validation Loss: 0.6934
# Epoch(8) - GLOBAL - Validation Accuracy: 0.5016
# Epoch(8) - GLOBAL - Validation Utility score: 20.3390
# Saving model corresponding to last_utility_score == 20.33904695317198
#
#
# Epoch(9) - Training Loss: 0.6974
# Epoch(9) - Fold 0 - Validation Loss : 0.6932
# Epoch(9) - Fold 0 - Validation Accuracy : 0.5002
# Epoch(9) - Fold 0 - Validation Utility score : -0.0000
# Epoch(9) - Fold 1 - Validation Loss : 0.6937
# Epoch(9) - Fold 1 - Validation Accuracy : 0.5063
# Epoch(9) - Fold 1 - Validation Utility score : -0.0000
# Epoch(9) - Fold 2 - Validation Loss : 0.6933
# Epoch(9) - Fold 2 - Validation Accuracy : 0.5021
# Epoch(9) - Fold 2 - Validation Utility score : -0.0000
# Epoch(9) - Fold 3 - Validation Loss : 0.6933
# Epoch(9) - Fold 3 - Validation Accuracy : 0.5004
# Epoch(9) - Fold 3 - Validation Utility score : -0.0000
# Epoch(9) - Fold 4 - Validation Loss : 0.6934
# Epoch(9) - Fold 4 - Validation Accuracy : 0.4990
# Epoch(9) - Fold 4 - Validation Utility score : 19.8516
# Epoch(9) - GLOBAL - Validation Loss: 0.6934
# Epoch(9) - GLOBAL - Validation Accuracy: 0.5016
# Epoch(9) - GLOBAL - Validation Utility score: 19.8516
# Saving model corresponding to last_utility_score == 19.8516007018281
#
#
# Epoch(10) - Training Loss: 0.6968
# Epoch(10) - Fold 0 - Validation Loss : 0.6932
# Epoch(10) - Fold 0 - Validation Accuracy : 0.5001
# Epoch(10) - Fold 0 - Validation Utility score : -0.0000
# Epoch(10) - Fold 1 - Validation Loss : 0.6937
# Epoch(10) - Fold 1 - Validation Accuracy : 0.5063
# Epoch(10) - Fold 1 - Validation Utility score : -0.0000
# Epoch(10) - Fold 2 - Validation Loss : 0.6934
# Epoch(10) - Fold 2 - Validation Accuracy : 0.5020
# Epoch(10) - Fold 2 - Validation Utility score : -0.0000
# Epoch(10) - Fold 3 - Validation Loss : 0.6932
# Epoch(10) - Fold 3 - Validation Accuracy : 0.5002
# Epoch(10) - Fold 3 - Validation Utility score : -0.0000
# Epoch(10) - Fold 4 - Validation Loss : 0.6934
# Epoch(10) - Fold 4 - Validation Accuracy : 0.4990
# Epoch(10) - Fold 4 - Validation Utility score : 19.0465
# Epoch(10) - GLOBAL - Validation Loss: 0.6934
# Epoch(10) - GLOBAL - Validation Accuracy: 0.5015
# Epoch(10) - GLOBAL - Validation Utility score: 19.0465
# Intermediate early stopping : vepoch_loss = 0.6934, the_last_loss=0.6934
#
#
# Epoch(11) - Training Loss: 0.6963
# Epoch(11) - Fold 0 - Validation Loss : 0.6932
# Epoch(11) - Fold 0 - Validation Accuracy : 0.5003
# Epoch(11) - Fold 0 - Validation Utility score : -0.0000
# Epoch(11) - Fold 1 - Validation Loss : 0.6937
# Epoch(11) - Fold 1 - Validation Accuracy : 0.5063
# Epoch(11) - Fold 1 - Validation Utility score : -0.0000
# Epoch(11) - Fold 2 - Validation Loss : 0.6932
# Epoch(11) - Fold 2 - Validation Accuracy : 0.5019
# Epoch(11) - Fold 2 - Validation Utility score : -0.0000
# Epoch(11) - Fold 3 - Validation Loss : 0.6933
# Epoch(11) - Fold 3 - Validation Accuracy : 0.5001
# Epoch(11) - Fold 3 - Validation Utility score : -0.0000
# Epoch(11) - Fold 4 - Validation Loss : 0.6933
# Epoch(11) - Fold 4 - Validation Accuracy : 0.4990
# Epoch(11) - Fold 4 - Validation Utility score : 19.6736
# Epoch(11) - GLOBAL - Validation Loss: 0.6933
# Epoch(11) - GLOBAL - Validation Accuracy: 0.5015
# Epoch(11) - GLOBAL - Validation Utility score: 19.6736
# Saving model corresponding to last_utility_score == 19.67358511956504
#
#
# Epoch(12) - Training Loss: 0.6959
# Epoch(12) - Fold 0 - Validation Loss : 0.6931
# Epoch(12) - Fold 0 - Validation Accuracy : 0.5003
# Epoch(12) - Fold 0 - Validation Utility score : -0.0000
# Epoch(12) - Fold 1 - Validation Loss : 0.6937
# Epoch(12) - Fold 1 - Validation Accuracy : 0.5063
# Epoch(12) - Fold 1 - Validation Utility score : -0.0000
# Epoch(12) - Fold 2 - Validation Loss : 0.6932
# Epoch(12) - Fold 2 - Validation Accuracy : 0.5020
# Epoch(12) - Fold 2 - Validation Utility score : -0.0000
# Epoch(12) - Fold 3 - Validation Loss : 0.6932
# Epoch(12) - Fold 3 - Validation Accuracy : 0.5002
# Epoch(12) - Fold 3 - Validation Utility score : -0.0000
# Epoch(12) - Fold 4 - Validation Loss : 0.6933
# Epoch(12) - Fold 4 - Validation Accuracy : 0.4990
# Epoch(12) - Fold 4 - Validation Utility score : 19.0562
# Epoch(12) - GLOBAL - Validation Loss: 0.6933
# Epoch(12) - GLOBAL - Validation Accuracy: 0.5015
# Epoch(12) - GLOBAL - Validation Utility score: 19.0562
# Saving model corresponding to last_utility_score == 19.056228521305524
#
#
# Epoch(13) - Training Loss: 0.6956
# Epoch(13) - Fold 0 - Validation Loss : 0.6931
# Epoch(13) - Fold 0 - Validation Accuracy : 0.5002
# Epoch(13) - Fold 0 - Validation Utility score : -0.0000
# Epoch(13) - Fold 1 - Validation Loss : 0.6931
# Epoch(13) - Fold 1 - Validation Accuracy : 0.5063
# Epoch(13) - Fold 1 - Validation Utility score : -0.0000
# Epoch(13) - Fold 2 - Validation Loss : 0.6933
# Epoch(13) - Fold 2 - Validation Accuracy : 0.5021
# Epoch(13) - Fold 2 - Validation Utility score : -0.0000
# Epoch(13) - Fold 3 - Validation Loss : 0.6932
# Epoch(13) - Fold 3 - Validation Accuracy : 0.5001
# Epoch(13) - Fold 3 - Validation Utility score : -0.0000
# Epoch(13) - Fold 4 - Validation Loss : 0.6932
# Epoch(13) - Fold 4 - Validation Accuracy : 0.4990
# Epoch(13) - Fold 4 - Validation Utility score : 19.6568
# Epoch(13) - GLOBAL - Validation Loss: 0.6932
# Epoch(13) - GLOBAL - Validation Accuracy: 0.5016
# Epoch(13) - GLOBAL - Validation Utility score: 19.6568
# Saving model corresponding to last_utility_score == 19.656753915323122
#
#
# Epoch(14) - Training Loss: 0.6952
# Epoch(14) - Fold 0 - Validation Loss : 0.6931
# Epoch(14) - Fold 0 - Validation Accuracy : 0.5003
# Epoch(14) - Fold 0 - Validation Utility score : -0.0000
# Epoch(14) - Fold 1 - Validation Loss : 0.6931
# Epoch(14) - Fold 1 - Validation Accuracy : 0.5064
# Epoch(14) - Fold 1 - Validation Utility score : -0.0000
# Epoch(14) - Fold 2 - Validation Loss : 0.6932
# Epoch(14) - Fold 2 - Validation Accuracy : 0.5021
# Epoch(14) - Fold 2 - Validation Utility score : -0.0000
# Epoch(14) - Fold 3 - Validation Loss : 0.6932
# Epoch(14) - Fold 3 - Validation Accuracy : 0.5001
# Epoch(14) - Fold 3 - Validation Utility score : -0.0000
# Epoch(14) - Fold 4 - Validation Loss : 0.6932
# Epoch(14) - Fold 4 - Validation Accuracy : 0.4990
# Epoch(14) - Fold 4 - Validation Utility score : 19.3792
# Epoch(14) - GLOBAL - Validation Loss: 0.6932
# Epoch(14) - GLOBAL - Validation Accuracy: 0.5016
# Epoch(14) - GLOBAL - Validation Utility score: 19.3792
# Saving model corresponding to last_utility_score == 19.379171075778903
#
#
# Epoch(15) - Training Loss: 0.6951
# Epoch(15) - Fold 0 - Validation Loss : 0.6931
# Epoch(15) - Fold 0 - Validation Accuracy : 0.5004
# Epoch(15) - Fold 0 - Validation Utility score : -0.0000
# Epoch(15) - Fold 1 - Validation Loss : 0.6930
# Epoch(15) - Fold 1 - Validation Accuracy : 0.5063
# Epoch(15) - Fold 1 - Validation Utility score : -0.0000
# Epoch(15) - Fold 2 - Validation Loss : 0.6933
# Epoch(15) - Fold 2 - Validation Accuracy : 0.5021
# Epoch(15) - Fold 2 - Validation Utility score : -0.0000
# Epoch(15) - Fold 3 - Validation Loss : 0.6932
# Epoch(15) - Fold 3 - Validation Accuracy : 0.5001
# Epoch(15) - Fold 3 - Validation Utility score : -0.0000
# Epoch(15) - Fold 4 - Validation Loss : 0.6932
# Epoch(15) - Fold 4 - Validation Accuracy : 0.4992
# Epoch(15) - Fold 4 - Validation Utility score : 22.2328
# Epoch(15) - GLOBAL - Validation Loss: 0.6931
# Epoch(15) - GLOBAL - Validation Accuracy: 0.5016
# Epoch(15) - GLOBAL - Validation Utility score: 22.2328
# Saving model corresponding to last_utility_score == 22.232830277482222
#
#
# Epoch(16) - Training Loss: 0.6949
# Epoch(16) - Fold 0 - Validation Loss : 0.6931
# Epoch(16) - Fold 0 - Validation Accuracy : 0.5005
# Epoch(16) - Fold 0 - Validation Utility score : -0.0000
# Epoch(16) - Fold 1 - Validation Loss : 0.6929
# Epoch(16) - Fold 1 - Validation Accuracy : 0.5064
# Epoch(16) - Fold 1 - Validation Utility score : -0.0000
# Epoch(16) - Fold 2 - Validation Loss : 0.6933
# Epoch(16) - Fold 2 - Validation Accuracy : 0.5022
# Epoch(16) - Fold 2 - Validation Utility score : -0.0000
# Epoch(16) - Fold 3 - Validation Loss : 0.6932
# Epoch(16) - Fold 3 - Validation Accuracy : 0.5000
# Epoch(16) - Fold 3 - Validation Utility score : -0.0000
# Epoch(16) - Fold 4 - Validation Loss : 0.6932
# Epoch(16) - Fold 4 - Validation Accuracy : 0.4993
# Epoch(16) - Fold 4 - Validation Utility score : 25.3861
# Epoch(16) - GLOBAL - Validation Loss: 0.6931
# Epoch(16) - GLOBAL - Validation Accuracy: 0.5017
# Epoch(16) - GLOBAL - Validation Utility score: 25.3861
# Saving model corresponding to last_utility_score == 25.3860581017609
#
#
# Epoch(17) - Training Loss: 0.6945
# Epoch(17) - Fold 0 - Validation Loss : 0.6931
# Epoch(17) - Fold 0 - Validation Accuracy : 0.5006
# Epoch(17) - Fold 0 - Validation Utility score : -0.0000
# Epoch(17) - Fold 1 - Validation Loss : 0.6929
# Epoch(17) - Fold 1 - Validation Accuracy : 0.5064
# Epoch(17) - Fold 1 - Validation Utility score : -0.0000
# Epoch(17) - Fold 2 - Validation Loss : 0.6933
# Epoch(17) - Fold 2 - Validation Accuracy : 0.5022
# Epoch(17) - Fold 2 - Validation Utility score : -0.0000
# Epoch(17) - Fold 3 - Validation Loss : 0.6932
# Epoch(17) - Fold 3 - Validation Accuracy : 0.5002
# Epoch(17) - Fold 3 - Validation Utility score : -0.0000
# Epoch(17) - Fold 4 - Validation Loss : 0.6932
# Epoch(17) - Fold 4 - Validation Accuracy : 0.4995
# Epoch(17) - Fold 4 - Validation Utility score : 27.8088
# Epoch(17) - GLOBAL - Validation Loss: 0.6931
# Epoch(17) - GLOBAL - Validation Accuracy: 0.5018
# Epoch(17) - GLOBAL - Validation Utility score: 27.8088
# Saving model corresponding to last_utility_score == 27.80883362820661
#
#
# Epoch(18) - Training Loss: 0.6944
# Epoch(18) - Fold 0 - Validation Loss : 0.6931
# Epoch(18) - Fold 0 - Validation Accuracy : 0.5008
# Epoch(18) - Fold 0 - Validation Utility score : -0.0000
# Epoch(18) - Fold 1 - Validation Loss : 0.6929
# Epoch(18) - Fold 1 - Validation Accuracy : 0.5065
# Epoch(18) - Fold 1 - Validation Utility score : -0.0000
# Epoch(18) - Fold 2 - Validation Loss : 0.6932
# Epoch(18) - Fold 2 - Validation Accuracy : 0.5023
# Epoch(18) - Fold 2 - Validation Utility score : -0.0000
# Epoch(18) - Fold 3 - Validation Loss : 0.6932
# Epoch(18) - Fold 3 - Validation Accuracy : 0.5002
# Epoch(18) - Fold 3 - Validation Utility score : -0.0000
# Epoch(18) - Fold 4 - Validation Loss : 0.6932
# Epoch(18) - Fold 4 - Validation Accuracy : 0.4998
# Epoch(18) - Fold 4 - Validation Utility score : 32.0787
# Epoch(18) - GLOBAL - Validation Loss: 0.6931
# Epoch(18) - GLOBAL - Validation Accuracy: 0.5019
# Epoch(18) - GLOBAL - Validation Utility score: 32.0787
# Saving model corresponding to last_utility_score == 32.07872351895094
#
#
# Epoch(19) - Training Loss: 0.6944
# Epoch(19) - Fold 0 - Validation Loss : 0.6930
# Epoch(19) - Fold 0 - Validation Accuracy : 0.5009
# Epoch(19) - Fold 0 - Validation Utility score : -0.0000
# Epoch(19) - Fold 1 - Validation Loss : 0.6929
# Epoch(19) - Fold 1 - Validation Accuracy : 0.5066
# Epoch(19) - Fold 1 - Validation Utility score : -0.0000
# Epoch(19) - Fold 2 - Validation Loss : 0.6931
# Epoch(19) - Fold 2 - Validation Accuracy : 0.5025
# Epoch(19) - Fold 2 - Validation Utility score : -0.0000
# Epoch(19) - Fold 3 - Validation Loss : 0.6932
# Epoch(19) - Fold 3 - Validation Accuracy : 0.5001
# Epoch(19) - Fold 3 - Validation Utility score : -0.0000
# Epoch(19) - Fold 4 - Validation Loss : 0.6932
# Epoch(19) - Fold 4 - Validation Accuracy : 0.5001
# Epoch(19) - Fold 4 - Validation Utility score : 39.4548
# Epoch(19) - GLOBAL - Validation Loss: 0.6931
# Epoch(19) - GLOBAL - Validation Accuracy: 0.5020
# Epoch(19) - GLOBAL - Validation Utility score: 39.4548
# Saving model corresponding to last_utility_score == 39.454846311448215
#
#
# Epoch(20) - Training Loss: 0.6944
# Epoch(20) - Fold 0 - Validation Loss : 0.6930
# Epoch(20) - Fold 0 - Validation Accuracy : 0.5009
# Epoch(20) - Fold 0 - Validation Utility score : -0.0000
# Epoch(20) - Fold 1 - Validation Loss : 0.6929
# Epoch(20) - Fold 1 - Validation Accuracy : 0.5069
# Epoch(20) - Fold 1 - Validation Utility score : -0.0000
# Epoch(20) - Fold 2 - Validation Loss : 0.6931
# Epoch(20) - Fold 2 - Validation Accuracy : 0.5025
# Epoch(20) - Fold 2 - Validation Utility score : -0.0000
# Epoch(20) - Fold 3 - Validation Loss : 0.6932
# Epoch(20) - Fold 3 - Validation Accuracy : 0.5002
# Epoch(20) - Fold 3 - Validation Utility score : -0.0000
# Epoch(20) - Fold 4 - Validation Loss : 0.6931
# Epoch(20) - Fold 4 - Validation Accuracy : 0.5004
# Epoch(20) - Fold 4 - Validation Utility score : 44.4308
# Epoch(20) - GLOBAL - Validation Loss: 0.6931
# Epoch(20) - GLOBAL - Validation Accuracy: 0.5022
# Epoch(20) - GLOBAL - Validation Utility score: 44.4308
# Saving model corresponding to last_utility_score == 44.430783485013734
#
#
# Epoch(21) - Training Loss: 0.6943
# Epoch(21) - Fold 0 - Validation Loss : 0.6930
# Epoch(21) - Fold 0 - Validation Accuracy : 0.5014
# Epoch(21) - Fold 0 - Validation Utility score : -0.0000
# Epoch(21) - Fold 1 - Validation Loss : 0.6929
# Epoch(21) - Fold 1 - Validation Accuracy : 0.5073
# Epoch(21) - Fold 1 - Validation Utility score : -0.0000
# Epoch(21) - Fold 2 - Validation Loss : 0.6931
# Epoch(21) - Fold 2 - Validation Accuracy : 0.5029
# Epoch(21) - Fold 2 - Validation Utility score : -0.0000
# Epoch(21) - Fold 3 - Validation Loss : 0.6932
# Epoch(21) - Fold 3 - Validation Accuracy : 0.5008
# Epoch(21) - Fold 3 - Validation Utility score : -0.0000
# Epoch(21) - Fold 4 - Validation Loss : 0.6931
# Epoch(21) - Fold 4 - Validation Accuracy : 0.5012
# Epoch(21) - Fold 4 - Validation Utility score : 64.5481
# Epoch(21) - GLOBAL - Validation Loss: 0.6930
# Epoch(21) - GLOBAL - Validation Accuracy: 0.5027
# Epoch(21) - GLOBAL - Validation Utility score: 64.5481
# Saving model corresponding to last_utility_score == 64.54807041030364
#
#
# Epoch(22) - Training Loss: 0.6942
# Epoch(22) - Fold 0 - Validation Loss : 0.6930
# Epoch(22) - Fold 0 - Validation Accuracy : 0.5019
# Epoch(22) - Fold 0 - Validation Utility score : -0.0000
# Epoch(22) - Fold 1 - Validation Loss : 0.6929
# Epoch(22) - Fold 1 - Validation Accuracy : 0.5076
# Epoch(22) - Fold 1 - Validation Utility score : -0.0000
# Epoch(22) - Fold 2 - Validation Loss : 0.6931
# Epoch(22) - Fold 2 - Validation Accuracy : 0.5034
# Epoch(22) - Fold 2 - Validation Utility score : -0.0000
# Epoch(22) - Fold 3 - Validation Loss : 0.6932
# Epoch(22) - Fold 3 - Validation Accuracy : 0.5012
# Epoch(22) - Fold 3 - Validation Utility score : -0.0000
# Epoch(22) - Fold 4 - Validation Loss : 0.6930
# Epoch(22) - Fold 4 - Validation Accuracy : 0.5017
# Epoch(22) - Fold 4 - Validation Utility score : 70.2524
# Epoch(22) - GLOBAL - Validation Loss: 0.6930
# Epoch(22) - GLOBAL - Validation Accuracy: 0.5031
# Epoch(22) - GLOBAL - Validation Utility score: 70.2524
# Saving model corresponding to last_utility_score == 70.25242023624159
#
#
# Epoch(23) - Training Loss: 0.6939
# Epoch(23) - Fold 0 - Validation Loss : 0.6929
# Epoch(23) - Fold 0 - Validation Accuracy : 0.5027
# Epoch(23) - Fold 0 - Validation Utility score : -0.0000
# Epoch(23) - Fold 1 - Validation Loss : 0.6929
# Epoch(23) - Fold 1 - Validation Accuracy : 0.5082
# Epoch(23) - Fold 1 - Validation Utility score : -0.0000
# Epoch(23) - Fold 2 - Validation Loss : 0.6931
# Epoch(23) - Fold 2 - Validation Accuracy : 0.5038
# Epoch(23) - Fold 2 - Validation Utility score : -0.0000
# Epoch(23) - Fold 3 - Validation Loss : 0.6931
# Epoch(23) - Fold 3 - Validation Accuracy : 0.5017
# Epoch(23) - Fold 3 - Validation Utility score : -0.0000
# Epoch(23) - Fold 4 - Validation Loss : 0.6930
# Epoch(23) - Fold 4 - Validation Accuracy : 0.5026
# Epoch(23) - Fold 4 - Validation Utility score : 101.8981
# Epoch(23) - GLOBAL - Validation Loss: 0.6930
# Epoch(23) - GLOBAL - Validation Accuracy: 0.5038
# Epoch(23) - GLOBAL - Validation Utility score: 101.8981
# Saving model corresponding to last_utility_score == 101.8981479192216
#
#
# Epoch(24) - Training Loss: 0.6937
# Epoch(24) - Fold 0 - Validation Loss : 0.6929
# Epoch(24) - Fold 0 - Validation Accuracy : 0.5036
# Epoch(24) - Fold 0 - Validation Utility score : -0.0000
# Epoch(24) - Fold 1 - Validation Loss : 0.6928
# Epoch(24) - Fold 1 - Validation Accuracy : 0.5086
# Epoch(24) - Fold 1 - Validation Utility score : 0.0000
# Epoch(24) - Fold 2 - Validation Loss : 0.6930
# Epoch(24) - Fold 2 - Validation Accuracy : 0.5043
# Epoch(24) - Fold 2 - Validation Utility score : -0.0000
# Epoch(24) - Fold 3 - Validation Loss : 0.6931
# Epoch(24) - Fold 3 - Validation Accuracy : 0.5019
# Epoch(24) - Fold 3 - Validation Utility score : -0.0000
# Epoch(24) - Fold 4 - Validation Loss : 0.6930
# Epoch(24) - Fold 4 - Validation Accuracy : 0.5029
# Epoch(24) - Fold 4 - Validation Utility score : 107.8835
# Epoch(24) - GLOBAL - Validation Loss: 0.6930
# Epoch(24) - GLOBAL - Validation Accuracy: 0.5043
# Epoch(24) - GLOBAL - Validation Utility score: 107.8835
# Saving model corresponding to last_utility_score == 107.88351213629544
#
#
# Epoch(25) - Training Loss: 0.6936
# Epoch(25) - Fold 0 - Validation Loss : 0.6929
# Epoch(25) - Fold 0 - Validation Accuracy : 0.5042
# Epoch(25) - Fold 0 - Validation Utility score : -0.0000
# Epoch(25) - Fold 1 - Validation Loss : 0.6928
# Epoch(25) - Fold 1 - Validation Accuracy : 0.5091
# Epoch(25) - Fold 1 - Validation Utility score : 0.9484
# Epoch(25) - Fold 2 - Validation Loss : 0.6930
# Epoch(25) - Fold 2 - Validation Accuracy : 0.5050
# Epoch(25) - Fold 2 - Validation Utility score : -0.0000
# Epoch(25) - Fold 3 - Validation Loss : 0.6931
# Epoch(25) - Fold 3 - Validation Accuracy : 0.5022
# Epoch(25) - Fold 3 - Validation Utility score : -0.0000
# Epoch(25) - Fold 4 - Validation Loss : 0.6929
# Epoch(25) - Fold 4 - Validation Accuracy : 0.5035
# Epoch(25) - Fold 4 - Validation Utility score : 157.2819
# Epoch(25) - GLOBAL - Validation Loss: 0.6930
# Epoch(25) - GLOBAL - Validation Accuracy: 0.5048
# Epoch(25) - GLOBAL - Validation Utility score: 158.2303
# Saving model corresponding to last_utility_score == 158.23032029038245
#
#
# Epoch(26) - Training Loss: 0.6938
# Epoch(26) - Fold 0 - Validation Loss : 0.6929
# Epoch(26) - Fold 0 - Validation Accuracy : 0.5052
# Epoch(26) - Fold 0 - Validation Utility score : -0.0000
# Epoch(26) - Fold 1 - Validation Loss : 0.6928
# Epoch(26) - Fold 1 - Validation Accuracy : 0.5103
# Epoch(26) - Fold 1 - Validation Utility score : 8.5304
# Epoch(26) - Fold 2 - Validation Loss : 0.6930
# Epoch(26) - Fold 2 - Validation Accuracy : 0.5054
# Epoch(26) - Fold 2 - Validation Utility score : -0.0000
# Epoch(26) - Fold 3 - Validation Loss : 0.6931
# Epoch(26) - Fold 3 - Validation Accuracy : 0.5023
# Epoch(26) - Fold 3 - Validation Utility score : -0.0000
# Epoch(26) - Fold 4 - Validation Loss : 0.6929
# Epoch(26) - Fold 4 - Validation Accuracy : 0.5040
# Epoch(26) - Fold 4 - Validation Utility score : 187.0094
# Epoch(26) - GLOBAL - Validation Loss: 0.6929
# Epoch(26) - GLOBAL - Validation Accuracy: 0.5054
# Epoch(26) - GLOBAL - Validation Utility score: 195.5398
# Saving model corresponding to last_utility_score == 195.53977608721732
#
#
# Epoch(27) - Training Loss: 0.6930
# Epoch(27) - Fold 0 - Validation Loss : 0.6928
# Epoch(27) - Fold 0 - Validation Accuracy : 0.5065
# Epoch(27) - Fold 0 - Validation Utility score : -0.0000
# Epoch(27) - Fold 1 - Validation Loss : 0.6928
# Epoch(27) - Fold 1 - Validation Accuracy : 0.5107
# Epoch(27) - Fold 1 - Validation Utility score : 11.1469
# Epoch(27) - Fold 2 - Validation Loss : 0.6930
# Epoch(27) - Fold 2 - Validation Accuracy : 0.5058
# Epoch(27) - Fold 2 - Validation Utility score : -0.0000
# Epoch(27) - Fold 3 - Validation Loss : 0.6931
# Epoch(27) - Fold 3 - Validation Accuracy : 0.5026
# Epoch(27) - Fold 3 - Validation Utility score : -0.0000
# Epoch(27) - Fold 4 - Validation Loss : 0.6929
# Epoch(27) - Fold 4 - Validation Accuracy : 0.5048
# Epoch(27) - Fold 4 - Validation Utility score : 216.7052
# Epoch(27) - GLOBAL - Validation Loss: 0.6929
# Epoch(27) - GLOBAL - Validation Accuracy: 0.5061
# Epoch(27) - GLOBAL - Validation Utility score: 227.8521
# Saving model corresponding to last_utility_score == 227.8521090159178
#
#
# Epoch(28) - Training Loss: 0.6934
# Epoch(28) - Fold 0 - Validation Loss : 0.6928
# Epoch(28) - Fold 0 - Validation Accuracy : 0.5067
# Epoch(28) - Fold 0 - Validation Utility score : -0.0000
# Epoch(28) - Fold 1 - Validation Loss : 0.6928
# Epoch(28) - Fold 1 - Validation Accuracy : 0.5115
# Epoch(28) - Fold 1 - Validation Utility score : 17.6611
# Epoch(28) - Fold 2 - Validation Loss : 0.6929
# Epoch(28) - Fold 2 - Validation Accuracy : 0.5060
# Epoch(28) - Fold 2 - Validation Utility score : -0.0000
# Epoch(28) - Fold 3 - Validation Loss : 0.6931
# Epoch(28) - Fold 3 - Validation Accuracy : 0.5031
# Epoch(28) - Fold 3 - Validation Utility score : -0.0000
# Epoch(28) - Fold 4 - Validation Loss : 0.6929
# Epoch(28) - Fold 4 - Validation Accuracy : 0.5055
# Epoch(28) - Fold 4 - Validation Utility score : 273.2029
# Epoch(28) - GLOBAL - Validation Loss: 0.6929
# Epoch(28) - GLOBAL - Validation Accuracy: 0.5066
# Epoch(28) - GLOBAL - Validation Utility score: 290.8641
# Saving model corresponding to last_utility_score == 290.8640624599474
#
#
# Epoch(29) - Training Loss: 0.6934
# Epoch(29) - Fold 0 - Validation Loss : 0.6928
# Epoch(29) - Fold 0 - Validation Accuracy : 0.5080
# Epoch(29) - Fold 0 - Validation Utility score : -0.0000
# Epoch(29) - Fold 1 - Validation Loss : 0.6927
# Epoch(29) - Fold 1 - Validation Accuracy : 0.5119
# Epoch(29) - Fold 1 - Validation Utility score : 28.6747
# Epoch(29) - Fold 2 - Validation Loss : 0.6929
# Epoch(29) - Fold 2 - Validation Accuracy : 0.5065
# Epoch(29) - Fold 2 - Validation Utility score : -0.0000
# Epoch(29) - Fold 3 - Validation Loss : 0.6931
# Epoch(29) - Fold 3 - Validation Accuracy : 0.5035
# Epoch(29) - Fold 3 - Validation Utility score : -0.0000
# Epoch(29) - Fold 4 - Validation Loss : 0.6928
# Epoch(29) - Fold 4 - Validation Accuracy : 0.5060
# Epoch(29) - Fold 4 - Validation Utility score : 292.4968
# Epoch(29) - GLOBAL - Validation Loss: 0.6929
# Epoch(29) - GLOBAL - Validation Accuracy: 0.5072
# Epoch(29) - GLOBAL - Validation Utility score: 321.1715
# Saving model corresponding to last_utility_score == 321.1715094609239
#
#
# Epoch(30) - Training Loss: 0.6931
# Epoch(30) - Fold 0 - Validation Loss : 0.6927
# Epoch(30) - Fold 0 - Validation Accuracy : 0.5093
# Epoch(30) - Fold 0 - Validation Utility score : -0.0000
# Epoch(30) - Fold 1 - Validation Loss : 0.6927
# Epoch(30) - Fold 1 - Validation Accuracy : 0.5129
# Epoch(30) - Fold 1 - Validation Utility score : 45.4473
# Epoch(30) - Fold 2 - Validation Loss : 0.6929
# Epoch(30) - Fold 2 - Validation Accuracy : 0.5064
# Epoch(30) - Fold 2 - Validation Utility score : -0.0000
# Epoch(30) - Fold 3 - Validation Loss : 0.6931
# Epoch(30) - Fold 3 - Validation Accuracy : 0.5037
# Epoch(30) - Fold 3 - Validation Utility score : -0.0000
# Epoch(30) - Fold 4 - Validation Loss : 0.6928
# Epoch(30) - Fold 4 - Validation Accuracy : 0.5066
# Epoch(30) - Fold 4 - Validation Utility score : 334.7107
# Epoch(30) - GLOBAL - Validation Loss: 0.6928
# Epoch(30) - GLOBAL - Validation Accuracy: 0.5078
# Epoch(30) - GLOBAL - Validation Utility score: 380.1581
# Saving model corresponding to last_utility_score == 380.1580628330898
#
#
# Epoch(31) - Training Loss: 0.6931
# Epoch(31) - Fold 0 - Validation Loss : 0.6927
# Epoch(31) - Fold 0 - Validation Accuracy : 0.5101
# Epoch(31) - Fold 0 - Validation Utility score : -0.0000
# Epoch(31) - Fold 1 - Validation Loss : 0.6927
# Epoch(31) - Fold 1 - Validation Accuracy : 0.5134
# Epoch(31) - Fold 1 - Validation Utility score : 62.9999
# Epoch(31) - Fold 2 - Validation Loss : 0.6929
# Epoch(31) - Fold 2 - Validation Accuracy : 0.5066
# Epoch(31) - Fold 2 - Validation Utility score : -0.0000
# Epoch(31) - Fold 3 - Validation Loss : 0.6931
# Epoch(31) - Fold 3 - Validation Accuracy : 0.5038
# Epoch(31) - Fold 3 - Validation Utility score : -0.0000
# Epoch(31) - Fold 4 - Validation Loss : 0.6928
# Epoch(31) - Fold 4 - Validation Accuracy : 0.5070
# Epoch(31) - Fold 4 - Validation Utility score : 348.7892
# Epoch(31) - GLOBAL - Validation Loss: 0.6928
# Epoch(31) - GLOBAL - Validation Accuracy: 0.5082
# Epoch(31) - GLOBAL - Validation Utility score: 411.7891
# Saving model corresponding to last_utility_score == 411.789101676873
#
#
# Epoch(32) - Training Loss: 0.6930
# Epoch(32) - Fold 0 - Validation Loss : 0.6927
# Epoch(32) - Fold 0 - Validation Accuracy : 0.5109
# Epoch(32) - Fold 0 - Validation Utility score : 0.0470
# Epoch(32) - Fold 1 - Validation Loss : 0.6927
# Epoch(32) - Fold 1 - Validation Accuracy : 0.5141
# Epoch(32) - Fold 1 - Validation Utility score : 83.7138
# Epoch(32) - Fold 2 - Validation Loss : 0.6929
# Epoch(32) - Fold 2 - Validation Accuracy : 0.5066
# Epoch(32) - Fold 2 - Validation Utility score : -0.0000
# Epoch(32) - Fold 3 - Validation Loss : 0.6931
# Epoch(32) - Fold 3 - Validation Accuracy : 0.5041
# Epoch(32) - Fold 3 - Validation Utility score : -0.0000
# Epoch(32) - Fold 4 - Validation Loss : 0.6927
# Epoch(32) - Fold 4 - Validation Accuracy : 0.5074
# Epoch(32) - Fold 4 - Validation Utility score : 361.1965
# Epoch(32) - GLOBAL - Validation Loss: 0.6928
# Epoch(32) - GLOBAL - Validation Accuracy: 0.5086
# Epoch(32) - GLOBAL - Validation Utility score: 444.9573
# Saving model corresponding to last_utility_score == 444.9573272264976
#
#
# Epoch(33) - Training Loss: 0.6929
# Epoch(33) - Fold 0 - Validation Loss : 0.6927
# Epoch(33) - Fold 0 - Validation Accuracy : 0.5121
# Epoch(33) - Fold 0 - Validation Utility score : 4.7920
# Epoch(33) - Fold 1 - Validation Loss : 0.6926
# Epoch(33) - Fold 1 - Validation Accuracy : 0.5149
# Epoch(33) - Fold 1 - Validation Utility score : 101.4390
# Epoch(33) - Fold 2 - Validation Loss : 0.6929
# Epoch(33) - Fold 2 - Validation Accuracy : 0.5070
# Epoch(33) - Fold 2 - Validation Utility score : -0.0000
# Epoch(33) - Fold 3 - Validation Loss : 0.6931
# Epoch(33) - Fold 3 - Validation Accuracy : 0.5041
# Epoch(33) - Fold 3 - Validation Utility score : -0.0000
# Epoch(33) - Fold 4 - Validation Loss : 0.6927
# Epoch(33) - Fold 4 - Validation Accuracy : 0.5083
# Epoch(33) - Fold 4 - Validation Utility score : 381.7829
# Epoch(33) - GLOBAL - Validation Loss: 0.6928
# Epoch(33) - GLOBAL - Validation Accuracy: 0.5093
# Epoch(33) - GLOBAL - Validation Utility score: 488.0138
# Saving model corresponding to last_utility_score == 488.01381866591504
#
#
# Epoch(34) - Training Loss: 0.6930
# Epoch(34) - Fold 0 - Validation Loss : 0.6926
# Epoch(34) - Fold 0 - Validation Accuracy : 0.5132
# Epoch(34) - Fold 0 - Validation Utility score : 14.4557
# Epoch(34) - Fold 1 - Validation Loss : 0.6926
# Epoch(34) - Fold 1 - Validation Accuracy : 0.5155
# Epoch(34) - Fold 1 - Validation Utility score : 144.1590
# Epoch(34) - Fold 2 - Validation Loss : 0.6928
# Epoch(34) - Fold 2 - Validation Accuracy : 0.5068
# Epoch(34) - Fold 2 - Validation Utility score : -0.0000
# Epoch(34) - Fold 3 - Validation Loss : 0.6931
# Epoch(34) - Fold 3 - Validation Accuracy : 0.5043
# Epoch(34) - Fold 3 - Validation Utility score : -0.0000
# Epoch(34) - Fold 4 - Validation Loss : 0.6926
# Epoch(34) - Fold 4 - Validation Accuracy : 0.5090
# Epoch(34) - Fold 4 - Validation Utility score : 415.9756
# Epoch(34) - GLOBAL - Validation Loss: 0.6928
# Epoch(34) - GLOBAL - Validation Accuracy: 0.5098
# Epoch(34) - GLOBAL - Validation Utility score: 574.5903
# Saving model corresponding to last_utility_score == 574.5903205144629
#
#
# Epoch(35) - Training Loss: 0.6930
# Epoch(35) - Fold 0 - Validation Loss : 0.6926
# Epoch(35) - Fold 0 - Validation Accuracy : 0.5133
# Epoch(35) - Fold 0 - Validation Utility score : 15.7751
# Epoch(35) - Fold 1 - Validation Loss : 0.6926
# Epoch(35) - Fold 1 - Validation Accuracy : 0.5155
# Epoch(35) - Fold 1 - Validation Utility score : 145.9462
# Epoch(35) - Fold 2 - Validation Loss : 0.6928
# Epoch(35) - Fold 2 - Validation Accuracy : 0.5068
# Epoch(35) - Fold 2 - Validation Utility score : -0.0000
# Epoch(35) - Fold 3 - Validation Loss : 0.6931
# Epoch(35) - Fold 3 - Validation Accuracy : 0.5046
# Epoch(35) - Fold 3 - Validation Utility score : -0.0000
# Epoch(35) - Fold 4 - Validation Loss : 0.6927
# Epoch(35) - Fold 4 - Validation Accuracy : 0.5088
# Epoch(35) - Fold 4 - Validation Utility score : 406.8341
# Epoch(35) - GLOBAL - Validation Loss: 0.6928
# Epoch(35) - GLOBAL - Validation Accuracy: 0.5098
# Epoch(35) - GLOBAL - Validation Utility score: 568.5554
# Intermediate early stopping : vepoch_loss = 0.6928, the_last_loss=0.6928
#
#
# Epoch(36) - Training Loss: 0.6928
# Epoch(36) - Fold 0 - Validation Loss : 0.6926
# Epoch(36) - Fold 0 - Validation Accuracy : 0.5142
# Epoch(36) - Fold 0 - Validation Utility score : 32.4016
# Epoch(36) - Fold 1 - Validation Loss : 0.6926
# Epoch(36) - Fold 1 - Validation Accuracy : 0.5162
# Epoch(36) - Fold 1 - Validation Utility score : 172.8306
# Epoch(36) - Fold 2 - Validation Loss : 0.6928
# Epoch(36) - Fold 2 - Validation Accuracy : 0.5068
# Epoch(36) - Fold 2 - Validation Utility score : -0.0000
# Epoch(36) - Fold 3 - Validation Loss : 0.6931
# Epoch(36) - Fold 3 - Validation Accuracy : 0.5048
# Epoch(36) - Fold 3 - Validation Utility score : -0.0000
# Epoch(36) - Fold 4 - Validation Loss : 0.6926
# Epoch(36) - Fold 4 - Validation Accuracy : 0.5091
# Epoch(36) - Fold 4 - Validation Utility score : 421.8971
# Epoch(36) - GLOBAL - Validation Loss: 0.6927
# Epoch(36) - GLOBAL - Validation Accuracy: 0.5102
# Epoch(36) - GLOBAL - Validation Utility score: 627.1292
# Saving model corresponding to last_utility_score == 627.1292119966741
#
#
# Epoch(37) - Training Loss: 0.6927
# Epoch(37) - Fold 0 - Validation Loss : 0.6926
# Epoch(37) - Fold 0 - Validation Accuracy : 0.5152
# Epoch(37) - Fold 0 - Validation Utility score : 47.4170
# Epoch(37) - Fold 1 - Validation Loss : 0.6926
# Epoch(37) - Fold 1 - Validation Accuracy : 0.5172
# Epoch(37) - Fold 1 - Validation Utility score : 194.0303
# Epoch(37) - Fold 2 - Validation Loss : 0.6928
# Epoch(37) - Fold 2 - Validation Accuracy : 0.5065
# Epoch(37) - Fold 2 - Validation Utility score : -0.0000
# Epoch(37) - Fold 3 - Validation Loss : 0.6930
# Epoch(37) - Fold 3 - Validation Accuracy : 0.5049
# Epoch(37) - Fold 3 - Validation Utility score : -0.0000
# Epoch(37) - Fold 4 - Validation Loss : 0.6926
# Epoch(37) - Fold 4 - Validation Accuracy : 0.5094
# Epoch(37) - Fold 4 - Validation Utility score : 451.5249
# Epoch(37) - GLOBAL - Validation Loss: 0.6927
# Epoch(37) - GLOBAL - Validation Accuracy: 0.5106
# Epoch(37) - GLOBAL - Validation Utility score: 692.9722
# Saving model corresponding to last_utility_score == 692.9722158546158
#
#
# Epoch(38) - Training Loss: 0.6926
# Epoch(38) - Fold 0 - Validation Loss : 0.6925
# Epoch(38) - Fold 0 - Validation Accuracy : 0.5155
# Epoch(38) - Fold 0 - Validation Utility score : 54.9824
# Epoch(38) - Fold 1 - Validation Loss : 0.6925
# Epoch(38) - Fold 1 - Validation Accuracy : 0.5174
# Epoch(38) - Fold 1 - Validation Utility score : 216.3535
# Epoch(38) - Fold 2 - Validation Loss : 0.6928
# Epoch(38) - Fold 2 - Validation Accuracy : 0.5067
# Epoch(38) - Fold 2 - Validation Utility score : -0.0000
# Epoch(38) - Fold 3 - Validation Loss : 0.6930
# Epoch(38) - Fold 3 - Validation Accuracy : 0.5051
# Epoch(38) - Fold 3 - Validation Utility score : -0.0000
# Epoch(38) - Fold 4 - Validation Loss : 0.6925
# Epoch(38) - Fold 4 - Validation Accuracy : 0.5098
# Epoch(38) - Fold 4 - Validation Utility score : 475.6139
# Epoch(38) - GLOBAL - Validation Loss: 0.6927
# Epoch(38) - GLOBAL - Validation Accuracy: 0.5109
# Epoch(38) - GLOBAL - Validation Utility score: 746.9497
# Saving model corresponding to last_utility_score == 746.9497292621211
#
#
# Epoch(39) - Training Loss: 0.6926
# Epoch(39) - Fold 0 - Validation Loss : 0.6925
# Epoch(39) - Fold 0 - Validation Accuracy : 0.5162
# Epoch(39) - Fold 0 - Validation Utility score : 69.8556
# Epoch(39) - Fold 1 - Validation Loss : 0.6925
# Epoch(39) - Fold 1 - Validation Accuracy : 0.5182
# Epoch(39) - Fold 1 - Validation Utility score : 244.7713
# Epoch(39) - Fold 2 - Validation Loss : 0.6928
# Epoch(39) - Fold 2 - Validation Accuracy : 0.5066
# Epoch(39) - Fold 2 - Validation Utility score : -0.0000
# Epoch(39) - Fold 3 - Validation Loss : 0.6930
# Epoch(39) - Fold 3 - Validation Accuracy : 0.5053
# Epoch(39) - Fold 3 - Validation Utility score : -0.0000
# Epoch(39) - Fold 4 - Validation Loss : 0.6925
# Epoch(39) - Fold 4 - Validation Accuracy : 0.5101
# Epoch(39) - Fold 4 - Validation Utility score : 521.5628
# Epoch(39) - GLOBAL - Validation Loss: 0.6927
# Epoch(39) - GLOBAL - Validation Accuracy: 0.5113
# Epoch(39) - GLOBAL - Validation Utility score: 836.1897
# Saving model corresponding to last_utility_score == 836.1896953984499
#
#
# Epoch(40) - Training Loss: 0.6925
# Epoch(40) - Fold 0 - Validation Loss : 0.6925
# Epoch(40) - Fold 0 - Validation Accuracy : 0.5169
# Epoch(40) - Fold 0 - Validation Utility score : 72.7150
# Epoch(40) - Fold 1 - Validation Loss : 0.6925
# Epoch(40) - Fold 1 - Validation Accuracy : 0.5189
# Epoch(40) - Fold 1 - Validation Utility score : 247.8401
# Epoch(40) - Fold 2 - Validation Loss : 0.6928
# Epoch(40) - Fold 2 - Validation Accuracy : 0.5068
# Epoch(40) - Fold 2 - Validation Utility score : -0.0000
# Epoch(40) - Fold 3 - Validation Loss : 0.6930
# Epoch(40) - Fold 3 - Validation Accuracy : 0.5059
# Epoch(40) - Fold 3 - Validation Utility score : -0.0000
# Epoch(40) - Fold 4 - Validation Loss : 0.6925
# Epoch(40) - Fold 4 - Validation Accuracy : 0.5108
# Epoch(40) - Fold 4 - Validation Utility score : 574.0769
# Epoch(40) - GLOBAL - Validation Loss: 0.6926
# Epoch(40) - GLOBAL - Validation Accuracy: 0.5119
# Epoch(40) - GLOBAL - Validation Utility score: 894.6320
# Saving model corresponding to last_utility_score == 894.6320098511931
#
#
# Epoch(41) - Training Loss: 0.6926
# Epoch(41) - Fold 0 - Validation Loss : 0.6924
# Epoch(41) - Fold 0 - Validation Accuracy : 0.5174
# Epoch(41) - Fold 0 - Validation Utility score : 97.2881
# Epoch(41) - Fold 1 - Validation Loss : 0.6925
# Epoch(41) - Fold 1 - Validation Accuracy : 0.5191
# Epoch(41) - Fold 1 - Validation Utility score : 279.2990
# Epoch(41) - Fold 2 - Validation Loss : 0.6928
# Epoch(41) - Fold 2 - Validation Accuracy : 0.5068
# Epoch(41) - Fold 2 - Validation Utility score : -0.0000
# Epoch(41) - Fold 3 - Validation Loss : 0.6930
# Epoch(41) - Fold 3 - Validation Accuracy : 0.5057
# Epoch(41) - Fold 3 - Validation Utility score : -0.0000
# Epoch(41) - Fold 4 - Validation Loss : 0.6924
# Epoch(41) - Fold 4 - Validation Accuracy : 0.5107
# Epoch(41) - Fold 4 - Validation Utility score : 626.9699
# Epoch(41) - GLOBAL - Validation Loss: 0.6926
# Epoch(41) - GLOBAL - Validation Accuracy: 0.5119
# Epoch(41) - GLOBAL - Validation Utility score: 1003.5570
# Saving model corresponding to last_utility_score == 1003.5569872503653
#
#
# Epoch(42) - Training Loss: 0.6923
# Epoch(42) - Fold 0 - Validation Loss : 0.6924
# Epoch(42) - Fold 0 - Validation Accuracy : 0.5175
# Epoch(42) - Fold 0 - Validation Utility score : 105.9910
# Epoch(42) - Fold 1 - Validation Loss : 0.6924
# Epoch(42) - Fold 1 - Validation Accuracy : 0.5198
# Epoch(42) - Fold 1 - Validation Utility score : 320.2407
# Epoch(42) - Fold 2 - Validation Loss : 0.6928
# Epoch(42) - Fold 2 - Validation Accuracy : 0.5068
# Epoch(42) - Fold 2 - Validation Utility score : -0.0000
# Epoch(42) - Fold 3 - Validation Loss : 0.6930
# Epoch(42) - Fold 3 - Validation Accuracy : 0.5055
# Epoch(42) - Fold 3 - Validation Utility score : -0.0000
# Epoch(42) - Fold 4 - Validation Loss : 0.6924
# Epoch(42) - Fold 4 - Validation Accuracy : 0.5111
# Epoch(42) - Fold 4 - Validation Utility score : 673.4382
# Epoch(42) - GLOBAL - Validation Loss: 0.6926
# Epoch(42) - GLOBAL - Validation Accuracy: 0.5121
# Epoch(42) - GLOBAL - Validation Utility score: 1099.6700
# Saving model corresponding to last_utility_score == 1099.6699523278953
#
#
# Epoch(43) - Training Loss: 0.6924
# Epoch(43) - Fold 0 - Validation Loss : 0.6924
# Epoch(43) - Fold 0 - Validation Accuracy : 0.5180
# Epoch(43) - Fold 0 - Validation Utility score : 128.8860
# Epoch(43) - Fold 1 - Validation Loss : 0.6924
# Epoch(43) - Fold 1 - Validation Accuracy : 0.5204
# Epoch(43) - Fold 1 - Validation Utility score : 353.0192
# Epoch(43) - Fold 2 - Validation Loss : 0.6928
# Epoch(43) - Fold 2 - Validation Accuracy : 0.5066
# Epoch(43) - Fold 2 - Validation Utility score : -0.0000
# Epoch(43) - Fold 3 - Validation Loss : 0.6930
# Epoch(43) - Fold 3 - Validation Accuracy : 0.5054
# Epoch(43) - Fold 3 - Validation Utility score : -0.0000
# Epoch(43) - Fold 4 - Validation Loss : 0.6923
# Epoch(43) - Fold 4 - Validation Accuracy : 0.5113
# Epoch(43) - Fold 4 - Validation Utility score : 707.0681
# Epoch(43) - GLOBAL - Validation Loss: 0.6926
# Epoch(43) - GLOBAL - Validation Accuracy: 0.5123
# Epoch(43) - GLOBAL - Validation Utility score: 1188.9732
# Saving model corresponding to last_utility_score == 1188.973213420059
#
#
# Epoch(44) - Training Loss: 0.6924
# Epoch(44) - Fold 0 - Validation Loss : 0.6924
# Epoch(44) - Fold 0 - Validation Accuracy : 0.5189
# Epoch(44) - Fold 0 - Validation Utility score : 143.6802
# Epoch(44) - Fold 1 - Validation Loss : 0.6924
# Epoch(44) - Fold 1 - Validation Accuracy : 0.5203
# Epoch(44) - Fold 1 - Validation Utility score : 342.8286
# Epoch(44) - Fold 2 - Validation Loss : 0.6928
# Epoch(44) - Fold 2 - Validation Accuracy : 0.5066
# Epoch(44) - Fold 2 - Validation Utility score : -0.0000
# Epoch(44) - Fold 3 - Validation Loss : 0.6930
# Epoch(44) - Fold 3 - Validation Accuracy : 0.5056
# Epoch(44) - Fold 3 - Validation Utility score : -0.0000
# Epoch(44) - Fold 4 - Validation Loss : 0.6923
# Epoch(44) - Fold 4 - Validation Accuracy : 0.5116
# Epoch(44) - Fold 4 - Validation Utility score : 732.5502
# Epoch(44) - GLOBAL - Validation Loss: 0.6926
# Epoch(44) - GLOBAL - Validation Accuracy: 0.5126
# Epoch(44) - GLOBAL - Validation Utility score: 1219.0589
# Saving model corresponding to last_utility_score == 1219.0589448163487
#
#
# Epoch(45) - Training Loss: 0.6924
# Epoch(45) - Fold 0 - Validation Loss : 0.6923
# Epoch(45) - Fold 0 - Validation Accuracy : 0.5196
# Epoch(45) - Fold 0 - Validation Utility score : 180.7537
# Epoch(45) - Fold 1 - Validation Loss : 0.6924
# Epoch(45) - Fold 1 - Validation Accuracy : 0.5206
# Epoch(45) - Fold 1 - Validation Utility score : 320.6617
# Epoch(45) - Fold 2 - Validation Loss : 0.6928
# Epoch(45) - Fold 2 - Validation Accuracy : 0.5071
# Epoch(45) - Fold 2 - Validation Utility score : -0.0000
# Epoch(45) - Fold 3 - Validation Loss : 0.6930
# Epoch(45) - Fold 3 - Validation Accuracy : 0.5057
# Epoch(45) - Fold 3 - Validation Utility score : -0.0000
# Epoch(45) - Fold 4 - Validation Loss : 0.6923
# Epoch(45) - Fold 4 - Validation Accuracy : 0.5117
# Epoch(45) - Fold 4 - Validation Utility score : 716.5580
# Epoch(45) - GLOBAL - Validation Loss: 0.6925
# Epoch(45) - GLOBAL - Validation Accuracy: 0.5129
# Epoch(45) - GLOBAL - Validation Utility score: 1217.9734
# Saving model corresponding to last_utility_score == 1217.9733834143472
#
#
# Epoch(46) - Training Loss: 0.6923
# Epoch(46) - Fold 0 - Validation Loss : 0.6923
# Epoch(46) - Fold 0 - Validation Accuracy : 0.5195
# Epoch(46) - Fold 0 - Validation Utility score : 171.3814
# Epoch(46) - Fold 1 - Validation Loss : 0.6923
# Epoch(46) - Fold 1 - Validation Accuracy : 0.5206
# Epoch(46) - Fold 1 - Validation Utility score : 320.9778
# Epoch(46) - Fold 2 - Validation Loss : 0.6928
# Epoch(46) - Fold 2 - Validation Accuracy : 0.5068
# Epoch(46) - Fold 2 - Validation Utility score : -0.0000
# Epoch(46) - Fold 3 - Validation Loss : 0.6930
# Epoch(46) - Fold 3 - Validation Accuracy : 0.5054
# Epoch(46) - Fold 3 - Validation Utility score : -0.0000
# Epoch(46) - Fold 4 - Validation Loss : 0.6922
# Epoch(46) - Fold 4 - Validation Accuracy : 0.5117
# Epoch(46) - Fold 4 - Validation Utility score : 744.8574
# Epoch(46) - GLOBAL - Validation Loss: 0.6925
# Epoch(46) - GLOBAL - Validation Accuracy: 0.5128
# Epoch(46) - GLOBAL - Validation Utility score: 1237.2166
# Saving model corresponding to last_utility_score == 1237.2165915282562
#
#
# Epoch(47) - Training Loss: 0.6923
# Epoch(47) - Fold 0 - Validation Loss : 0.6923
# Epoch(47) - Fold 0 - Validation Accuracy : 0.5197
# Epoch(47) - Fold 0 - Validation Utility score : 203.7532
# Epoch(47) - Fold 1 - Validation Loss : 0.6923
# Epoch(47) - Fold 1 - Validation Accuracy : 0.5209
# Epoch(47) - Fold 1 - Validation Utility score : 308.8180
# Epoch(47) - Fold 2 - Validation Loss : 0.6928
# Epoch(47) - Fold 2 - Validation Accuracy : 0.5073
# Epoch(47) - Fold 2 - Validation Utility score : -0.0000
# Epoch(47) - Fold 3 - Validation Loss : 0.6930
# Epoch(47) - Fold 3 - Validation Accuracy : 0.5054
# Epoch(47) - Fold 3 - Validation Utility score : -0.0000
# Epoch(47) - Fold 4 - Validation Loss : 0.6922
# Epoch(47) - Fold 4 - Validation Accuracy : 0.5119
# Epoch(47) - Fold 4 - Validation Utility score : 751.7210
# Epoch(47) - GLOBAL - Validation Loss: 0.6925
# Epoch(47) - GLOBAL - Validation Accuracy: 0.5130
# Epoch(47) - GLOBAL - Validation Utility score: 1264.2923
# Saving model corresponding to last_utility_score == 1264.2922811829671
#
#
# Epoch(48) - Training Loss: 0.6922
# Epoch(48) - Fold 0 - Validation Loss : 0.6923
# Epoch(48) - Fold 0 - Validation Accuracy : 0.5193
# Epoch(48) - Fold 0 - Validation Utility score : 198.1740
# Epoch(48) - Fold 1 - Validation Loss : 0.6923
# Epoch(48) - Fold 1 - Validation Accuracy : 0.5210
# Epoch(48) - Fold 1 - Validation Utility score : 333.7964
# Epoch(48) - Fold 2 - Validation Loss : 0.6928
# Epoch(48) - Fold 2 - Validation Accuracy : 0.5071
# Epoch(48) - Fold 2 - Validation Utility score : -0.0000
# Epoch(48) - Fold 3 - Validation Loss : 0.6929
# Epoch(48) - Fold 3 - Validation Accuracy : 0.5053
# Epoch(48) - Fold 3 - Validation Utility score : -0.0000
# Epoch(48) - Fold 4 - Validation Loss : 0.6922
# Epoch(48) - Fold 4 - Validation Accuracy : 0.5118
# Epoch(48) - Fold 4 - Validation Utility score : 752.6761
# Epoch(48) - GLOBAL - Validation Loss: 0.6925
# Epoch(48) - GLOBAL - Validation Accuracy: 0.5129
# Epoch(48) - GLOBAL - Validation Utility score: 1284.6465
# Intermediate early stopping : vepoch_loss = 0.6925, the_last_loss=0.6925
#
#
# Epoch(49) - Training Loss: 0.6923
# Epoch(49) - Fold 0 - Validation Loss : 0.6922
# Epoch(49) - Fold 0 - Validation Accuracy : 0.5197
# Epoch(49) - Fold 0 - Validation Utility score : 192.3888
# Epoch(49) - Fold 1 - Validation Loss : 0.6922
# Epoch(49) - Fold 1 - Validation Accuracy : 0.5210
# Epoch(49) - Fold 1 - Validation Utility score : 330.9975
# Epoch(49) - Fold 2 - Validation Loss : 0.6928
# Epoch(49) - Fold 2 - Validation Accuracy : 0.5075
# Epoch(49) - Fold 2 - Validation Utility score : -0.0000
# Epoch(49) - Fold 3 - Validation Loss : 0.6930
# Epoch(49) - Fold 3 - Validation Accuracy : 0.5053
# Epoch(49) - Fold 3 - Validation Utility score : -0.0000
# Epoch(49) - Fold 4 - Validation Loss : 0.6921
# Epoch(49) - Fold 4 - Validation Accuracy : 0.5120
# Epoch(49) - Fold 4 - Validation Utility score : 753.1191
# Epoch(49) - GLOBAL - Validation Loss: 0.6925
# Epoch(49) - GLOBAL - Validation Accuracy: 0.5131
# Epoch(49) - GLOBAL - Validation Utility score: 1276.5053
# Saving model corresponding to last_utility_score == 1276.5053088508605
#
#
# Epoch(50) - Training Loss: 0.6923
# Epoch(50) - Fold 0 - Validation Loss : 0.6922
# Epoch(50) - Fold 0 - Validation Accuracy : 0.5195
# Epoch(50) - Fold 0 - Validation Utility score : 190.6215
# Epoch(50) - Fold 1 - Validation Loss : 0.6922
# Epoch(50) - Fold 1 - Validation Accuracy : 0.5212
# Epoch(50) - Fold 1 - Validation Utility score : 328.6871
# Epoch(50) - Fold 2 - Validation Loss : 0.6928
# Epoch(50) - Fold 2 - Validation Accuracy : 0.5074
# Epoch(50) - Fold 2 - Validation Utility score : -0.0000
# Epoch(50) - Fold 3 - Validation Loss : 0.6929
# Epoch(50) - Fold 3 - Validation Accuracy : 0.5051
# Epoch(50) - Fold 3 - Validation Utility score : -0.0000
# Epoch(50) - Fold 4 - Validation Loss : 0.6921
# Epoch(50) - Fold 4 - Validation Accuracy : 0.5122
# Epoch(50) - Fold 4 - Validation Utility score : 765.7542
# Epoch(50) - GLOBAL - Validation Loss: 0.6925
# Epoch(50) - GLOBAL - Validation Accuracy: 0.5131
# Epoch(50) - GLOBAL - Validation Utility score: 1285.0629
# Saving model corresponding to last_utility_score == 1285.0628571573902
#
#
# Epoch(51) - Training Loss: 0.6920
# Epoch(51) - Fold 0 - Validation Loss : 0.6922
# Epoch(51) - Fold 0 - Validation Accuracy : 0.5200
# Epoch(51) - Fold 0 - Validation Utility score : 218.5349
# Epoch(51) - Fold 1 - Validation Loss : 0.6922
# Epoch(51) - Fold 1 - Validation Accuracy : 0.5210
# Epoch(51) - Fold 1 - Validation Utility score : 327.5843
# Epoch(51) - Fold 2 - Validation Loss : 0.6928
# Epoch(51) - Fold 2 - Validation Accuracy : 0.5076
# Epoch(51) - Fold 2 - Validation Utility score : -0.0000
# Epoch(51) - Fold 3 - Validation Loss : 0.6929
# Epoch(51) - Fold 3 - Validation Accuracy : 0.5051
# Epoch(51) - Fold 3 - Validation Utility score : -0.0000
# Epoch(51) - Fold 4 - Validation Loss : 0.6921
# Epoch(51) - Fold 4 - Validation Accuracy : 0.5122
# Epoch(51) - Fold 4 - Validation Utility score : 767.2076
# Epoch(51) - GLOBAL - Validation Loss: 0.6925
# Epoch(51) - GLOBAL - Validation Accuracy: 0.5132
# Epoch(51) - GLOBAL - Validation Utility score: 1313.3268
# Saving model corresponding to last_utility_score == 1313.3268382878587
#
#
# Epoch(52) - Training Loss: 0.6920
# Epoch(52) - Fold 0 - Validation Loss : 0.6922
# Epoch(52) - Fold 0 - Validation Accuracy : 0.5203
# Epoch(52) - Fold 0 - Validation Utility score : 228.2594
# Epoch(52) - Fold 1 - Validation Loss : 0.6922
# Epoch(52) - Fold 1 - Validation Accuracy : 0.5212
# Epoch(52) - Fold 1 - Validation Utility score : 311.4505
# Epoch(52) - Fold 2 - Validation Loss : 0.6928
# Epoch(52) - Fold 2 - Validation Accuracy : 0.5079
# Epoch(52) - Fold 2 - Validation Utility score : -0.0000
# Epoch(52) - Fold 3 - Validation Loss : 0.6929
# Epoch(52) - Fold 3 - Validation Accuracy : 0.5050
# Epoch(52) - Fold 3 - Validation Utility score : -0.0000
# Epoch(52) - Fold 4 - Validation Loss : 0.6921
# Epoch(52) - Fold 4 - Validation Accuracy : 0.5122
# Epoch(52) - Fold 4 - Validation Utility score : 741.4617
# Epoch(52) - GLOBAL - Validation Loss: 0.6924
# Epoch(52) - GLOBAL - Validation Accuracy: 0.5133
# Epoch(52) - GLOBAL - Validation Utility score: 1281.1717
# Saving model corresponding to last_utility_score == 1281.1716890404368

# %% [markdown]
# ### Note

# %% [markdown]
# Note utility score précédent :
#
# {'utility_score': 2699.3290911247423, 'utility_scores': [433.21587581983806, 842.8579165327393, -0.0, -0.0, 1423.255298772165], 'utility_score_std': 541.5654345633293, 'accuracy_scores': [0.5243157432212159, 0.5228992628992629, 0.5123754728769456, 0.5104606336878834, 0.5277785603606142]}
#
# (avec std scale)
#
#
# Training summary:
# {'utility_score': 2697.374406045479, 'utility_scores': [448.22515142892547, 938.181355255796, -0.0, -0.0, 1310.9678993607574], 'utility_score_std': 518.5674763422022, 'accuracy_scores': [0.5212753894345934, 0.5206107406107406, 0.5085924573123425, 0.5062820079914457, 0.525750105648683]}
#
#
# Essayer :
# > avec features supplémentaires
# > augmenter le dropout de la couche avec bcp de 0, ou supprimer la couche
# > bouger le weight decay : essayer 1e-5, et 1e-3
# > augmenter la taille du batch

# %%
'''
model_load = nn.Sequential(
        #nn.Dropout(0.2),
        nn.Linear(len(FEATURES_LIST_TOTRAIN), 130),
        #nn.BatchNorm1d(130),
        nn.ReLU(),
        nn.Dropout(0.3),

        nn.Linear(130, 130),
        #nn.BatchNorm1d(130),
        nn.ReLU(),
        nn.Dropout(0.3),    

        nn.Linear(130, 130),
        #nn.BatchNorm1d(130),
        nn.ReLU(),
        nn.Dropout(0.3),    

        nn.Linear(130, 130),
        #nn.BatchNorm1d(130),
        nn.ReLU(),
        nn.Dropout(0.3),    

        nn.Linear(130, 130),
        #nn.BatchNorm1d(130),
        nn.ReLU(),
        nn.Dropout(0.3),    

        nn.Linear(130, 130),
        #nn.BatchNorm1d(130),
        nn.ReLU(),
        nn.Dropout(0.3),    
    
        nn.Linear(130, 130),
        #nn.BatchNorm1d(130),
        nn.ReLU(),
        nn.Dropout(0.3),    
    
        nn.Linear(130, 130),
        #nn.BatchNorm1d(130),
        nn.ReLU(),
        nn.Dropout(0.3),    

        nn.Linear(130, 60),
        #nn.BatchNorm1d(130),
        nn.ReLU(),
        nn.Dropout(0.3),    
    
        nn.Linear(60, 30),
        #nn.BatchNorm1d(130),
        nn.ReLU(),
        nn.Dropout(0.3),    
       
        nn.Linear(30, 1),
        nn.Sigmoid(),
    ).double().to('cuda')
    
model_load.load_state_dict(torch.load(f'model_NN_allfolds_V1.pt',map_location=torch.device('cuda')))
'''

#model_load.eval()
#print(accuracy_score(ts_test_y.cpu().numpy(), (model_load(ts_test).squeeze() > 0.5).cpu().numpy()))
#
#model_load.eval()
#print(utility_function(df.loc[test_index], (model_load(ts_test).squeeze() > 0.5).cpu().numpy()))

# %% [markdown]
# # Data for model inference

# %% [markdown]
# ## First, fill NA with :

# %%
list(f_mean)
# Out:
# [0.009838564545944745,
#  0.38557755173112973,
#  0.35768747744650975,
#  0.00891916614596665,
#  0.0041500560373424495,
#  -0.0037146189993207766,
#  -0.012589244366156346,
#  0.051776552018932685,
#  0.026828095990947754,
#  0.24881331937245502,
#  0.18234851148590248,
#  0.08912156181298928,
#  0.049485535154017296,
#  0.14310535183278583,
#  0.08902722352210106,
#  0.21167757450938102,
#  0.146300650876364,
#  0.12121931699105562,
#  0.11358210894993667,
#  0.2938148492026861,
#  0.26876788737703755,
#  0.18691131282167164,
#  0.1769785779830002,
#  0.25244128771902047,
#  0.23856075429165213,
#  0.29407078502434514,
#  0.273177703966479,
#  0.13548298050171867,
#  0.16087630644126466,
#  0.32189235718153003,
#  0.3425343272966006,
#  0.2205604165416505,
#  0.25013120792951216,
#  0.3082216783372597,
#  0.3353533199754549,
#  0.34145307300650396,
#  0.36582532760649067,
#  0.029320465264380657,
#  0.02289177995103487,
#  0.04002162079212139,
#  0.05074972651124518,
#  0.4450543980970518,
#  0.36018357114469624,
#  0.34602868865463743,
#  0.4115306048129169,
#  0.43803102237933605,
#  0.47611584684954844,
#  0.3478667314970123,
#  0.4996310121501766,
#  0.5640008775247856,
#  0.5122603244317466,
#  0.45738658177408503,
#  0.04574377016024373,
#  0.36269998611838594,
#  0.35886983636928554,
#  0.652597182609052,
#  0.8049459750150331,
#  0.6613497470714732,
#  0.679812464521779,
#  0.7625897106372482,
#  0.5563956951455176,
#  0.5581652498654769,
#  0.5455413826521486,
#  0.546778335577234,
#  0.43505876086903456,
#  0.6075653248439333,
#  0.6085039517279847,
#  0.5951947177318683,
#  0.5959424881601522,
#  0.36954104040881697,
#  0.24337091134397526,
#  0.33227354399541986,
#  0.005393298121375514,
#  -0.03286771852370292,
#  -0.00020445421701550574,
#  -0.019091946690617916,
#  -0.031898281803949866,
#  -0.07680002772370834,
#  -0.00605952373252944,
#  -0.035434597323818526,
#  -0.002099458966825259,
#  -0.014418274525843731,
#  -0.03461507559647192,
#  -0.0800853052057879,
#  0.3982158398248166,
#  0.5578243392749649,
#  0.4024042638598482,
#  0.44445105036718896,
#  0.5140947514539359,
#  0.40051646364922716,
#  0.41025294617564356,
#  0.5205121351461534,
#  0.4050807138243217,
#  0.4088298932713245,
#  0.42889387778006083,
#  0.41763183586073954,
#  0.40226847198530646,
#  0.5590945852445534,
#  0.40710700821605167,
#  0.4368573700084827,
#  0.5001226990638947,
#  0.40856460238921344,
#  0.40506301819893675,
#  0.48140573756748783,
#  0.40165573205168165,
#  0.40706131905131204,
#  0.4530453026311098,
#  0.41501192155955596,
#  0.39999263512557864,
#  0.4165405195231404,
#  0.4007356675614491,
#  0.40687807118570485,
#  0.41228491406734663,
#  0.4026373333613518,
#  0.40711205681095564,
#  0.37341742416551793,
#  0.40443262685246384,
#  0.40103337181422305,
#  0.38581705373929415,
#  0.41559987309867774,
#  0.33512703226889273,
#  0.2687757036832287,
#  0.34355231662463237,
#  0.27999728178893696,
#  0.33515369461396705,
#  0.24487524464105123,
#  0.3391777949954427,
#  0.2323808666181667,
#  0.3425608266217579,
#  0.24561818215100586]

# %% [markdown]
# ## Then, normalize with :

# %%
ts_train_mean
# Out:
# tensor([ 0.0088,  0.3957,  0.3306,  0.0092,  0.0034, -0.0050, -0.0146,  0.0553,
#          0.0251,  0.2647,  0.1671,  0.0949,  0.0445,  0.1525,  0.0800,  0.2217,
#          0.1283,  0.1218,  0.1096,  0.2977,  0.2646,  0.1881,  0.1725,  0.2547,
#          0.2327,  0.2979,  0.2685,  0.1399,  0.1629,  0.3306,  0.3439,  0.2268,
#          0.2519,  0.3164,  0.3360,  0.3528,  0.3677,  0.0265,  0.0186,  0.0432,
#          0.0530,  0.4542,  0.3776,  0.4162,  0.4393,  0.4865,  0.4921,  0.3684,
#          0.5014,  0.5438,  0.5307,  0.4567,  0.0565,  0.3890,  0.3769,  0.7755,
#          0.9247,  0.7859,  0.8085,  0.8990,  0.5534,  0.5555,  0.5592,  0.5614,
#          0.4423,  0.6188,  0.6172,  0.5977,  0.5981,  0.3774,  0.2389,  0.3080,
#          0.0041, -0.0322, -0.0016, -0.0199, -0.0316, -0.0932, -0.0081, -0.0358,
#         -0.0025, -0.0149, -0.0350, -0.1015,  0.3934,  0.5416,  0.3924,  0.4281,
#          0.4976,  0.3994,  0.4332,  0.5235,  0.4224,  0.4221,  0.4348,  0.4547,
#          0.3984,  0.5422,  0.3973,  0.4259,  0.4865,  0.4105,  0.4340,  0.4839,
#          0.4168,  0.4198,  0.4614,  0.4553,  0.3950,  0.3824,  0.3900,  0.3918,
#          0.3807,  0.4035,  0.4320,  0.3767,  0.4279,  0.4207,  0.3952,  0.4465,
#          0.3616,  0.2999,  0.3709,  0.3035,  0.3601,  0.2778,  0.3743,  0.2571,
#          0.3739,  0.2682], device='cuda:0', dtype=torch.float64)

# %%
ts_train_std
# Out:
# tensor([ 1.0000,  2.5724,  2.4543,  1.9501,  1.7327,  1.7503,  1.6707,  1.6297,
#          1.8147,  2.4146,  1.7088,  1.6546,  2.3538,  2.2777,  2.0171,  1.8925,
#          2.2236,  1.5821,  1.9931,  1.7196,  1.9315,  2.4339,  1.7864,  2.1404,
#          2.6117,  2.0852,  2.2918,  1.4115,  1.8827,  1.7403,  2.0817,  1.6850,
#          2.4817,  1.9481,  2.0704,  2.4316,  2.2853,  2.0566,  2.1225,  1.6162,
#          2.3138,  1.9912,  2.4127,  2.3259,  2.7887,  1.9650,  2.8462,  2.2005,
#          3.0387,  3.5713,  3.7193,  2.8348,  1.8877,  2.2007,  1.9352,  7.1295,
#         11.0556,  7.5957,  8.1579,  9.9465,  2.2164,  1.9947,  2.1712,  2.2567,
#          2.3735,  2.1915,  1.7553,  2.5883,  2.5263,  2.2991,  2.4406,  1.8076,
#          1.8125,  2.1476,  1.7792,  1.9738,  2.2283,  2.6795,  2.1807,  1.7949,
#          1.7688,  2.2805,  1.9767,  2.4821,  1.9748,  2.4948,  1.9679,  2.6387,
#          2.5943,  2.6160,  2.0864,  2.6942,  2.0670,  2.2104,  2.1212,  2.5054,
#          2.1243,  2.5619,  2.3017,  2.1175,  2.2689,  2.6136,  2.3357,  2.2557,
#          1.8389,  2.0931,  2.7896,  2.4935,  2.4409,  2.5761,  1.9721,  1.9469,
#          2.6040,  2.8786,  2.1073,  2.3353,  2.3193,  2.5076,  2.4064,  2.0617,
#          1.9008,  2.1498,  2.1102,  1.9852,  1.7631,  2.2454,  2.5548,  1.8003,
#          2.3295,  1.7714], device='cuda:0', dtype=torch.float64)
