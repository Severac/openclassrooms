# %% [markdown]
# # Pytorch classifier notebook
#
# V1 : only 1 split. First implementation
# All folds V1 : with all folds
# All folds V2 : add activation stats plot
# All folds V2.1 : back to  best MLP found so far, and backport fix of activation layers stats. Add weight decay and scheduler (fit one cycle) code
#
# All folds autoencoder MLP V1

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import matplotlib.pyplot as plt

from sklearn.metrics import accuracy_score

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision.transforms as transforms
import torchvision.utils as utils

from torch.utils.tensorboard import SummaryWriter
import io
import PIL.Image

import datetime

torch.set_printoptions(edgeitems=2)
torch.manual_seed(42)

DATASET_INPUT_FILE = 'train.csv'

#FEATURES_LIST_TOTRAIN = ['feature_'+str(i) for i in range(130)] + ['cross_41_42_43', 'cross_1_2']
FEATURES_LIST_TOTRAIN = ['feature_'+str(i) for i in range(130)]

# For custom non-overlaped folds generation
TRAIN_PERCENT = 0.70  
TEST_PERCENT = 0.30

# If subsplit of training set : percentage of second training set  
TRAIN1_PERCENT = 0.20  

pd.set_option('display.max_rows', 500)

# %%
# Deterministic Behavior
seed = 42
#os.environ['PYTHONHASHSEED'] = str(seed)
# Torch RNG
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
torch.cuda.manual_seed_all(seed)
# Python RNG
np.random.seed(seed)
#random.seed(seed)
# CuDA Determinism
torch.backends.cudnn.deterministic = True
#torch.backends.cudnn.benchmark = False

# %%
#BATCH_SIZE = 50000
#BATCH_SIZE = 4096 # Gave once better results than 50000
#BATCH_SIZE = 2048

#BATCH_SIZE = 300000

#BATCH_SIZE = 4096
#BATCH_SIZE = 8192
#BATCH_SIZE = 32768
BATCH_SIZE = 8192
WEIGHT_DECAY = 1e-4 # Remettre à 1e-5
LEARNING_RATE = 1e-4

EARLY_STOPPING = True

NUM_EPOCHS = 1000
#NUM_EPOCHS = 36

MODEL_FILE = f'model_NN_allfolds_V1.pt'

BATCH_SIZE_AE = 40960
NUM_EPOCHS_AE = 1000
LEARNING_RATE_AE = 1e-3
WEIGHT_DECAY_AE = 1e-4
MODEL_FILE_AE = f'model_NN_AE_allfolds_V1.pt'

RETRAIN_MODEl_AE = False


MODEL_COMMENT_AE = f'All folds MLP autoenc, 2 layers 64 32, good model reloaded, batch size {BATCH_SIZE_AE}, lr={LEARNING_RATE_AE}, patience 5, standard scale, weight decay {WEIGHT_DECAY_AE}, dropout 0.5, with cross features, no scheduler, no std scale'
MODEL_COMMENT = f'All folds MLP with autoenc (decoded features), 3 layers 130, 200 and 100, good model reloaded, batch size {BATCH_SIZE}, lr={LEARNING_RATE}, patience 5, standard scale, weight decay {WEIGHT_DECAY}, 0.7 dropout, without cross features, no scheduler, no std scale'

# %%
def pyStandardScale(tensor, mean, std):
    return((tensor - mean) / std)

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection._split import _BaseKFold, indexable, _num_samples
from sklearn.utils.validation import _deprecate_positional_args

# modified code for group gaps; source
# https://github.com/getgaurav2/scikit-learn/blob/d4a3af5cc9da3a76f0266932644b884c99724c57/sklearn/model_selection/_split.py#L2243
class PurgedGroupTimeSeriesSplit(_BaseKFold):
    """Time Series cross-validator variant with non-overlapping groups.
    Allows for a gap in groups to avoid potentially leaking info from
    train into test if the model has windowed or lag features.
    Provides train/test indices to split time series data samples
    that are observed at fixed time intervals according to a
    third-party provided group.
    In each split, test indices must be higher than before, and thus shuffling
    in cross validator is inappropriate.
    This cross-validation object is a variation of :class:`KFold`.
    In the kth split, it returns first k folds as train set and the
    (k+1)th fold as test set.
    The same group will not appear in two different folds (the number of
    distinct groups has to be at least equal to the number of folds).
    Note that unlike standard cross-validation methods, successive
    training sets are supersets of those that come before them.
    Read more in the :ref:`User Guide <cross_validation>`.
    Parameters
    ----------
    n_splits : int, default=5
        Number of splits. Must be at least 2.
    max_train_group_size : int, default=Inf
        Maximum group size for a single training set.
    group_gap : int, default=None
        Gap between train and test
    max_test_group_size : int, default=Inf
        We discard this number of groups from the end of each train split
    """

    @_deprecate_positional_args
    def __init__(self,
                 n_splits=5,
                 *,
                 max_train_group_size=np.inf,
                 max_test_group_size=np.inf,
                 group_gap=None,
                 verbose=False
                 ):
        super().__init__(n_splits, shuffle=False, random_state=None)
        self.max_train_group_size = max_train_group_size
        self.group_gap = group_gap
        self.max_test_group_size = max_test_group_size
        self.verbose = verbose

    def split(self, X, y=None, groups=None):
        """Generate indices to split data into training and test set.
        Parameters
        ----------
        X : array-like of shape (n_samples, n_features)
            Training data, where n_samples is the number of samples
            and n_features is the number of features.
        y : array-like of shape (n_samples,)
            Always ignored, exists for compatibility.
        groups : array-like of shape (n_samples,)
            Group labels for the samples used while splitting the dataset into
            train/test set.
        Yields
        ------
        train : ndarray
            The training set indices for that split.
        test : ndarray
            The testing set indices for that split.
        """
        if groups is None:
            raise ValueError(
                "The 'groups' parameter should not be None")
        X, y, groups = indexable(X, y, groups)
        n_samples = _num_samples(X)
        n_splits = self.n_splits
        group_gap = self.group_gap
        max_test_group_size = self.max_test_group_size
        max_train_group_size = self.max_train_group_size
        n_folds = n_splits + 1
        group_dict = {}
        u, ind = np.unique(groups, return_index=True)
        unique_groups = u[np.argsort(ind)]
        n_samples = _num_samples(X)
        n_groups = _num_samples(unique_groups)
        for idx in np.arange(n_samples):
            if (groups[idx] in group_dict):
                group_dict[groups[idx]].append(idx)
            else:
                group_dict[groups[idx]] = [idx]
        if n_folds > n_groups:
            raise ValueError(
                ("Cannot have number of folds={0} greater than"
                 " the number of groups={1}").format(n_folds,
                                                     n_groups))

        group_test_size = min(n_groups // n_folds, max_test_group_size)
        group_test_starts = range(n_groups - n_splits * group_test_size,
                                  n_groups, group_test_size)
        for group_test_start in group_test_starts:
            train_array = []
            test_array = []

            group_st = max(0, group_test_start - group_gap - max_train_group_size)
            for train_group_idx in unique_groups[group_st:(group_test_start - group_gap)]:
                train_array_tmp = group_dict[train_group_idx]
                
                train_array = np.sort(np.unique(
                                      np.concatenate((train_array,
                                                      train_array_tmp)),
                                      axis=None), axis=None)

            train_end = train_array.size
 
            for test_group_idx in unique_groups[group_test_start:
                                                group_test_start +
                                                group_test_size]:
                test_array_tmp = group_dict[test_group_idx]
                test_array = np.sort(np.unique(
                                              np.concatenate((test_array,
                                                              test_array_tmp)),
                                     axis=None), axis=None)

            test_array  = test_array[group_gap:]
            
            
            if self.verbose > 0:
                    pass
                    
            yield [int(i) for i in train_array], [int(i) for i in test_array]

from matplotlib.colors import ListedColormap
    
# this is code slightly modified from the sklearn docs here:
# https://scikit-learn.org/stable/auto_examples/model_selection/plot_cv_indices.html#sphx-glr-auto-examples-model-selection-plot-cv-indices-py
def plot_cv_indices(cv, X, y, group, ax, n_splits, lw=10):
    """Create a sample plot for indices of a cross-validation object."""
    
    cmap_cv = plt.cm.coolwarm

    jet = plt.cm.get_cmap('jet', 256)
    seq = np.linspace(0, 1, 256)
    _ = np.random.shuffle(seq)   # inplace
    cmap_data = ListedColormap(jet(seq))

    # Generate the training/testing visualizations for each CV split
    for ii, (tr, tt) in enumerate(cv.split(X=X, y=y, groups=group)):
        # Fill in indices with the training/test groups
        indices = np.array([np.nan] * len(X))
        indices[tt] = 1
        indices[tr] = 0

        # Visualize the results
        ax.scatter(range(len(indices)), [ii + .5] * len(indices),
                   c=indices, marker='_', lw=lw, cmap=cmap_cv,
                   vmin=-.2, vmax=1.2)

    # Plot the data classes and groups at the end
    ax.scatter(range(len(X)), [ii + 1.5] * len(X),
               c=y, marker='_', lw=lw, cmap=plt.cm.Set3)

    ax.scatter(range(len(X)), [ii + 2.5] * len(X),
               c=group, marker='_', lw=lw, cmap=cmap_data)

    # Formatting
    yticklabels = list(range(n_splits)) + ['target', 'day']
    ax.set(yticks=np.arange(n_splits+2) + .5, yticklabels=yticklabels,
           xlabel='Sample index', ylabel="CV iteration",
           ylim=[n_splits+2.2, -.2], xlim=[0, len(y)])
    ax.set_title('{}'.format(type(cv).__name__), fontsize=15)
    return ax


def plot_cv_indices_custom(cv_custom, X, y, group, ax, n_splits, lw=10):
    """Create a sample plot for indices of a cross-validation object."""
    
    cmap_cv = plt.cm.coolwarm

    jet = plt.cm.get_cmap('jet', 256)
    seq = np.linspace(0, 1, 256)
    _ = np.random.shuffle(seq)   # inplace
    cmap_data = ListedColormap(jet(seq))

    # Generate the training/testing visualizations for each CV split
    for ii, (tr, tt) in enumerate(cv_custom):
        # Fill in indices with the training/test groups
        indices = np.array([np.nan] * len(X))
        indices[tt] = 1
        indices[tr] = 0

        # Visualize the results
        ax.scatter(range(len(indices)), [ii + .5] * len(indices),
                   c=indices, marker='_', lw=lw, cmap=cmap_cv,
                   vmin=-.2, vmax=1.2)

    # Plot the data classes and groups at the end
    ax.scatter(range(len(X)), [ii + 1.5] * len(X),
               c=y, marker='_', lw=lw, cmap=plt.cm.Set3)

    ax.scatter(range(len(X)), [ii + 2.5] * len(X),
               c=group, marker='_', lw=lw, cmap=cmap_data)

    # Formatting
    yticklabels = list(range(n_splits)) + ['target', 'day']
    ax.set(yticks=np.arange(n_splits+2) + .5, yticklabels=yticklabels,
           xlabel='Sample index', ylabel="CV iteration",
           ylim=[n_splits+2.2, -.2], xlim=[0, len(y)])
    ax.set_title('{}'.format(type(cv).__name__), fontsize=15)
    return ax

# %%
# This function accounts for variable instance counts in each split by dividing utility_pi by number of instances (but this has been removed)
# It also does some copy of dataframe to prevent memory overwrite
def utility_function(df_test, df_test_predictions):
    df_test_copy = df_test.copy(deep=True)
    df_test_copy.loc[:, 'utility_pj'] = df_test_copy['weight'] * df_test_copy['resp'] * df_test_predictions
    #df_test_utility_pi = df_test_copy.groupby('date')['utility_pj'].sum() / df_test_copy.groupby('date')['utility_pj'].count()
    df_test_utility_pi = df_test_copy.groupby('date')['utility_pj'].sum()

    nb_unique_dates = df_test_utility_pi.shape[0]
    t = (df_test_utility_pi.sum() / np.sqrt(df_test_utility_pi.pow(2).sum())) * (np.sqrt(250 / np.abs(nb_unique_dates)))
    u = min(max(t, 0), 6) * df_test_utility_pi.sum()
    del df_test_copy
    
    return(u)

# %%
from bisect import bisect_left

# The aim of this function is to return closest date from an index
# So that split indices correspond to start or end of a new day
# myList contains list of instances that correspond to start of a new da

def take_closest(myList, myNumber):
    """
    Assumes myList is sorted. Returns closest value to myNumber.

    If two numbers are equally close, return the smallest number.
    """
    pos = bisect_left(myList, myNumber)
    if pos == 0:
        return myList[0]
    if pos == len(myList):
        return myList[-1]
    before = myList[pos - 1]
    after = myList[pos]
    if after - myNumber < myNumber - before:
       return after
    else:
       return before

# %%
class SaveOutputActivationStats:
    def __init__(self):
        self.outputs = []
        
    def __call__(self, module, module_in, module_out):
        #self.outputs.append(module_out)
        #print('Save output callback :')
        #print(module)
        #print({'mean': module_out.mean().item(), 'std': module_out.std().item(),'near_zero': (module_out<=0.05).long().sum().item()/module_out.numel()})
        self.outputs.append({'mean': module_out.mean().item(), 'std': module_out.std().item(),'near_zero': (module_out<=0.05).long().sum().item()/module_out.numel()})
        
    def clear(self):
        self.outputs = []

# %%
#fig, ax = plt.subplots(1, 1)
#
#plot_cv_indices(cv, df.loc[:, FEATURES_LIST_TOTRAIN], (df['resp'] > 0), df['date'], 
#                         ax, 5, lw=20);

# %%
torch.device
# Out:
# torch.device

# %%
torch.cuda.is_available()
# Out:
# True

# %%
torch.cuda.current_device()
# Out:
# 0

# %%
torch.cuda.get_device_name(0)
# Out:
# 'GeForce RTX 3090'

# %% [markdown]
# # Load data

# %%
# Load data
    
df = pd.read_csv(DATASET_INPUT_FILE)
df['resp_positive'] = ((df['resp'])>0)*1  # Target to predict

print('Data loaded')
# Out:
# Data loaded

# %% [markdown]
# # Feature engineering

# %%
#df['cross_41_42_43'] = df['feature_41'] + df['feature_42'] + df['feature_43']

# %%
#df['cross_1_2'] = df['feature_1'] / (df['feature_2'] + 1e-5)

# %% [markdown]
# # Non overlap fold generation

# %%
date_indexes_list = df.groupby('date')['ts_id'].first().to_list()

# %%
base_train_split_size = int((df.shape[0] // 5) * TRAIN_PERCENT)

# %%
base_test_split_size = int((df.shape[0] // 5) * TEST_PERCENT)

# %%
train_split_start_indexes = [take_closest(date_indexes_list, (base_train_split_size + base_test_split_size)*fold_indice) for fold_indice in range(5)]

# %%
#test_split_start_indexes = [take_closest(date_indexes_list, (base_train_split_size + base_test_split_size)*fold_indice) for fold_indice in range(5)]

# %%
train_split_start_indexes
# Out:
# [0, 477711, 958233, 1435933, 1913985]

# %%
df.shape[0] - 1
# Out:
# 2390490

# %%
# We'll have 5 folds of 3 subsets each (2 training sets and 1 test set per fold)
# (1st training set of each fold will be used for 1st model, ie auto encoder)

NB_FOLDS = 5
last_index = df.shape[0] - 1

cv_table = []

for fold_indice in range(NB_FOLDS):
    fold_train_start_index = train_split_start_indexes[fold_indice]
    
    if (fold_indice == NB_FOLDS - 1):    
        nextfold_train_start_index = last_index
        
    else:
        nextfold_train_start_index = train_split_start_indexes[fold_indice + 1]
    
    fold_test_start_index = take_closest(date_indexes_list, int(TRAIN_PERCENT * (nextfold_train_start_index - fold_train_start_index) + fold_train_start_index  ))
    fold_train2_start_index = take_closest(date_indexes_list, int(TRAIN1_PERCENT * (fold_test_start_index - fold_train_start_index) + fold_train_start_index  ))
    
    cv_table.append(fold_train_start_index)
    cv_table.append(fold_train2_start_index)
    cv_table.append(fold_test_start_index)

# %%
cv_table.append(last_index)

# %%
cv_table
# Out:
# [0,
#  66091,
#  336609,
#  477711,
#  546983,
#  815783,
#  958233,
#  1024471,
#  1290282,
#  1435933,
#  1505171,
#  1771833,
#  1913985,
#  1980610,
#  2248510,
#  2390490]

# %%
cv_table
# Out:
# [0,
#  66091,
#  336609,
#  477711,
#  546983,
#  815783,
#  958233,
#  1024471,
#  1290282,
#  1435933,
#  1505171,
#  1771833,
#  1913985,
#  1980610,
#  2248510,
#  2390490]

# %%
NB_FOLDS
# Out:
# 5

# %%
cv_tuples = []

for i in range(0, NB_FOLDS*3, 3):
    cv_tuples.append([df.loc[cv_table[i]:cv_table[i+1]-1, :].index.to_list(), df.loc[cv_table[i+1]:cv_table[i+2]-1, :].index.to_list(),
                      df.loc[cv_table[i+2]:cv_table[i+3]-1, :].index.to_list()])

# %%
len(cv_tuples[0][2])
# Out:
# 141102

# %%
cv_tuples_generator = iter(cv_tuples)

# %%
#fig, ax = plt.subplots(1, 1)

#plot_cv_indices_custom(cv_tuples_generator, df.loc[:, FEATURES_LIST_TOTRAIN], (df['resp'] > 0), df['date'], 
#                         ax, 5, lw=20); 

#cv_tuples_generator = iter(cv_tuples)

# %%
# Size of training set :
#train_sets_table =  [cv_tuples[i][0] for i in range(5)]
#sum([len(train_set_table) for train_set_table in train_sets_table])

# %%
# Our old time series split (with overlap : required 1 neural network trained per split)
# But in this script it's not needed because we're training 1 unique network, with a different fold strategy (non overlaped)
#cv = PurgedGroupTimeSeriesSplit(
#    n_splits=5,
#    max_train_group_size=180,
#    group_gap=20,
#    max_test_group_size=60
#)

# %%
#train_index, test_index = next(cv.split(df, (df['resp'] > 0)*1, df['date']))

# %%
#(df.loc[train_index, 'resp'] > 0).astype(np.byte)

# %%
f_mean = df.loc[:, FEATURES_LIST_TOTRAIN].mean(axis=0)

# %%
f_mean.shape
# Out:
# (130,)

# %%
df.fillna(f_mean, inplace=True)

# %%
#print('Sum of model parameters:')
#[print(p.sum()) for p in model.parameters()]

# %%
#writer = SummaryWriter()

#writer.add_text('test', 'test:'  + str(model).replace('\n', '<BR>'))

#writer.flush()
#writer.close()

# %%
#str([p.numel() for p in model.parameters()])

# %%
folds_list = []

for fold, (train1_index, train2_index, test_index) in enumerate(cv_tuples_generator):
    folds_list.append((train1_index, train2_index, test_index))

# %%
folds_list_train1 = [folds_list[i][0] for i in range(5)]
folds_list_train1_flat = [folds_list_train1_item for sublist in folds_list_train1 for folds_list_train1_item in sublist]
folds_list_train1_unique = list(set(folds_list_train1_flat))

folds_list_train2 = [folds_list[i][1] for i in range(5)]
folds_list_train2_flat = [folds_list_train2_item for sublist in folds_list_train2 for folds_list_train2_item in sublist]
folds_list_train2_unique = list(set(folds_list_train2_flat))

# %%
len(folds_list_train1_unique)
# Out:
# 337464

# %%
len(folds_list_train2_unique)
# Out:
# 1339691

# %%
np.sum([len(folds_list_train1_item) for folds_list_train1_item in folds_list_train1])
# Out:
# 337464

# %%
np.sum([len(folds_list_train2_item) for folds_list_train2_item in folds_list_train2])
# Out:
# 1339691

# %%
len(folds_list_train1_flat)
# Out:
# 337464

# %%
folds_list_test = [folds_list[i][2] for i in range(5)]
folds_list_test_flat = [folds_list_test_item for sublist in folds_list_test for folds_list_test_item in sublist]
folds_list_test_unique = set(folds_list_test_flat)

# %%
np.sum([len(folds_list_test_item) for folds_list_test_item in folds_list_test])
# Out:
# 713335

# %%
len(folds_list_test_flat)
# Out:
# 713335

# %%
len(folds_list_train1_flat) + len(folds_list_train2_flat) + len(folds_list_test_flat)
# Out:
# 2390490

# %%
df.loc[folds_list_test[4], FEATURES_LIST_TOTRAIN].to_numpy().shape
# Out:
# (141980, 130)

# %%
df.loc[(folds_list_train1_unique + folds_list_train2_unique), FEATURES_LIST_TOTRAIN].to_numpy().mean(axis=0)
# Out:
# array([ 0.00880718,  0.39574469,  0.33059838,  0.00919269,  0.00341737,
#        -0.00498373, -0.01455459,  0.05534631,  0.02511896,  0.2646538 ,
#         0.16705702,  0.09489698,  0.04450428,  0.15251293,  0.07996651,
#         0.22166532,  0.12827658,  0.12181565,  0.10958852,  0.29772963,
#         0.26463247,  0.1881408 ,  0.17251055,  0.25474009,  0.23267903,
#         0.29794049,  0.2685417 ,  0.13985131,  0.16285107,  0.33060734,
#         0.34385913,  0.22684687,  0.25190658,  0.31637359,  0.3359838 ,
#         0.35284181,  0.36773315,  0.02650339,  0.0186391 ,  0.04320553,
#         0.05298663,  0.45417433,  0.37762691,  0.41617323,  0.43927675,
#         0.48651095,  0.49207956,  0.36839975,  0.50144387,  0.54379067,
#         0.53074971,  0.45673965,  0.05646874,  0.38900233,  0.37690587,
#         0.77549302,  0.92466193,  0.78590429,  0.80847667,  0.89895923,
#         0.55335406,  0.55554392,  0.55922873,  0.56139559,  0.44231975,
#         0.61884351,  0.61715568,  0.59770334,  0.59814018,  0.37738388,
#         0.23893403,  0.30802914,  0.00410365, -0.03220141, -0.00163732,
#        -0.01991575, -0.03158872, -0.0931838 , -0.00806526, -0.03578937,
#        -0.00251814, -0.01489434, -0.03498338, -0.10154564,  0.39337805,
#         0.54162178,  0.39241949,  0.42814332,  0.49755557,  0.39935045,
#         0.43319566,  0.52353302,  0.42238168,  0.42206715,  0.43484953,
#         0.4547188 ,  0.39837193,  0.5421566 ,  0.39730999,  0.42589424,
#         0.48653787,  0.41054099,  0.43399339,  0.48391166,  0.41683186,
#         0.41979739,  0.46144612,  0.455339  ,  0.39499643,  0.38242161,
#         0.39000896,  0.391784  ,  0.38065447,  0.40349802,  0.43203717,
#         0.37668634,  0.42790068,  0.42074866,  0.39520648,  0.44651147,
#         0.36161378,  0.29991827,  0.37089359,  0.30351037,  0.36007002,
#         0.27782367,  0.3742626 ,  0.25712366,  0.37390404,  0.268233  ])

# %%
len(list(set(folds_list_train1_unique + folds_list_train2_unique)))
# Out:
# 1677155

# %%
torch.mean(torch.tensor(df.loc[(folds_list_train1_unique + folds_list_train2_unique), FEATURES_LIST_TOTRAIN].to_numpy(), device='cpu'), axis=0)
# Out:
# tensor([ 0.0088,  0.3957,  0.3306,  0.0092,  0.0034, -0.0050, -0.0146,  0.0553,
#          0.0251,  0.2647,  0.1671,  0.0949,  0.0445,  0.1525,  0.0800,  0.2217,
#          0.1283,  0.1218,  0.1096,  0.2977,  0.2646,  0.1881,  0.1725,  0.2547,
#          0.2327,  0.2979,  0.2685,  0.1399,  0.1629,  0.3306,  0.3439,  0.2268,
#          0.2519,  0.3164,  0.3360,  0.3528,  0.3677,  0.0265,  0.0186,  0.0432,
#          0.0530,  0.4542,  0.3776,  0.4162,  0.4393,  0.4865,  0.4921,  0.3684,
#          0.5014,  0.5438,  0.5307,  0.4567,  0.0565,  0.3890,  0.3769,  0.7755,
#          0.9247,  0.7859,  0.8085,  0.8990,  0.5534,  0.5555,  0.5592,  0.5614,
#          0.4423,  0.6188,  0.6172,  0.5977,  0.5981,  0.3774,  0.2389,  0.3080,
#          0.0041, -0.0322, -0.0016, -0.0199, -0.0316, -0.0932, -0.0081, -0.0358,
#         -0.0025, -0.0149, -0.0350, -0.1015,  0.3934,  0.5416,  0.3924,  0.4281,
#          0.4976,  0.3994,  0.4332,  0.5235,  0.4224,  0.4221,  0.4348,  0.4547,
#          0.3984,  0.5422,  0.3973,  0.4259,  0.4865,  0.4105,  0.4340,  0.4839,
#          0.4168,  0.4198,  0.4614,  0.4553,  0.3950,  0.3824,  0.3900,  0.3918,
#          0.3807,  0.4035,  0.4320,  0.3767,  0.4279,  0.4207,  0.3952,  0.4465,
#          0.3616,  0.2999,  0.3709,  0.3035,  0.3601,  0.2778,  0.3743,  0.2571,
#          0.3739,  0.2682], dtype=torch.float64)

# %%
torch.tensor(f_mean)
# Out:
# tensor([ 9.8386e-03,  3.8558e-01,  3.5769e-01,  8.9192e-03,  4.1501e-03,
#         -3.7146e-03, -1.2589e-02,  5.1777e-02,  2.6828e-02,  2.4881e-01,
#          1.8235e-01,  8.9122e-02,  4.9486e-02,  1.4311e-01,  8.9027e-02,
#          2.1168e-01,  1.4630e-01,  1.2122e-01,  1.1358e-01,  2.9381e-01,
#          2.6877e-01,  1.8691e-01,  1.7698e-01,  2.5244e-01,  2.3856e-01,
#          2.9407e-01,  2.7318e-01,  1.3548e-01,  1.6088e-01,  3.2189e-01,
#          3.4253e-01,  2.2056e-01,  2.5013e-01,  3.0822e-01,  3.3535e-01,
#          3.4145e-01,  3.6583e-01,  2.9320e-02,  2.2892e-02,  4.0022e-02,
#          5.0750e-02,  4.4505e-01,  3.6018e-01,  3.4603e-01,  4.1153e-01,
#          4.3803e-01,  4.7612e-01,  3.4787e-01,  4.9963e-01,  5.6400e-01,
#          5.1226e-01,  4.5739e-01,  4.5744e-02,  3.6270e-01,  3.5887e-01,
#          6.5260e-01,  8.0495e-01,  6.6135e-01,  6.7981e-01,  7.6259e-01,
#          5.5640e-01,  5.5817e-01,  5.4554e-01,  5.4678e-01,  4.3506e-01,
#          6.0757e-01,  6.0850e-01,  5.9519e-01,  5.9594e-01,  3.6954e-01,
#          2.4337e-01,  3.3227e-01,  5.3933e-03, -3.2868e-02, -2.0445e-04,
#         -1.9092e-02, -3.1898e-02, -7.6800e-02, -6.0595e-03, -3.5435e-02,
#         -2.0995e-03, -1.4418e-02, -3.4615e-02, -8.0085e-02,  3.9822e-01,
#          5.5782e-01,  4.0240e-01,  4.4445e-01,  5.1409e-01,  4.0052e-01,
#          4.1025e-01,  5.2051e-01,  4.0508e-01,  4.0883e-01,  4.2889e-01,
#          4.1763e-01,  4.0227e-01,  5.5909e-01,  4.0711e-01,  4.3686e-01,
#          5.0012e-01,  4.0856e-01,  4.0506e-01,  4.8141e-01,  4.0166e-01,
#          4.0706e-01,  4.5305e-01,  4.1501e-01,  3.9999e-01,  4.1654e-01,
#          4.0074e-01,  4.0688e-01,  4.1228e-01,  4.0264e-01,  4.0711e-01,
#          3.7342e-01,  4.0443e-01,  4.0103e-01,  3.8582e-01,  4.1560e-01,
#          3.3513e-01,  2.6878e-01,  3.4355e-01,  2.8000e-01,  3.3515e-01,
#          2.4488e-01,  3.3918e-01,  2.3238e-01,  3.4256e-01,  2.4562e-01],
#        dtype=torch.float64)

# %% [markdown]
# # Training auto encoder

# %%
torch.manual_seed(seed)  
    
class AutoEncoder(nn.Module):
    def __init__(self):
        super(AutoEncoder,self).__init__()
        
        self.encoder = nn.Sequential(
            nn.Dropout(0.5),
            nn.Linear(len(FEATURES_LIST_TOTRAIN), 64),
            nn.ReLU(),
            nn.Linear(64, 32),
            nn.ReLU(),
        )
        
        self.decoder = nn.Sequential(             
            nn.Linear(32, 64),
            nn.ReLU(),
            nn.Linear(64, len(FEATURES_LIST_TOTRAIN)),
        )
        
    def forward(self,x):
        x = self.encoder(x)
        x = self.decoder(x)
        return x        

model = AutoEncoder().double().to('cuda')
    
#print('Number of model parameters :')
#numel_list = [p.numel() for p in model.parameters()]
#sum(numel_list), numel_list
    
if (RETRAIN_MODEl_AE == False):
    model_AE = model
    model_AE.load_state_dict(torch.load(MODEL_FILE_AE,map_location=torch.device('cuda')))
    print('Model AE loaded')

else:    
    print('Training started')
    patience=5

    utility_scores = [None] * 5
    accuracy_scores = [None] * 5

    today = datetime.datetime.now()
    now_str = today.strftime("%b%d_%H-%M-%S")
    tensorboard_dir_AE = 'runs_AE/' + now_str
    writer = SummaryWriter(log_dir=tensorboard_dir_AE)

    ts_train = torch.tensor(df.loc[folds_list_train1_unique, FEATURES_LIST_TOTRAIN].to_numpy(), device='cuda')
    #ts_train_y = torch.tensor((df.loc[folds_list_train_unique, 'resp'] > 0).astype(np.byte).to_numpy(), device='cuda')

    # Normalize data
    ts_train_mean = torch.mean(ts_train, axis=0)
    ts_train_std = torch.std(ts_train, axis=0)
    #ts_train_mean = torch.tensor(f_mean)
    # If you want to use Standard scale : calculate mean from f_mean and std scale from whole dataset
    #ts_train = pyStandardScale(ts_train, ts_train_mean, ts_train_std)

    train_dataset = torch.utils.data.TensorDataset(ts_train)
    train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=BATCH_SIZE_AE, shuffle=True)

    ts_test = [None] * 5
    #ts_test_y = [None] * 5    
    test_dataset = [None] * 5
    test_loader = [None] * 5

    for fold_indice in range(5):
        ts_test[fold_indice] = torch.tensor(df.loc[folds_list_test[fold_indice], FEATURES_LIST_TOTRAIN].to_numpy(), device='cuda')
        #ts_test_y[fold_indice] = torch.tensor((df.loc[folds_list_test[fold_indice], 'resp'] > 0).astype(np.byte).to_numpy(), device='cuda')

        # Normalize
        #ts_test[fold_indice] = pyStandardScale(ts_test[fold_indice], ts_train_mean, ts_train_std)

        test_dataset[fold_indice] = torch.utils.data.TensorDataset(ts_test[fold_indice])
        test_loader[fold_indice] = torch.utils.data.DataLoader(test_dataset[fold_indice], batch_size=BATCH_SIZE_AE)

    loss_fn = nn.MSELoss().to('cuda')
    #optimizer = torch.optim.Adam(model.parameters(), lr=1e-3) 
    optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE_AE, weight_decay=WEIGHT_DECAY_AE) 

    scheduler = None
    #scheduler = torch.optim.lr_scheduler.OneCycleLR(optimizer=optimizer, pct_start=0.1, div_factor=1e3,
    #                                                         max_lr=1e-4, epochs=NUM_EPOCHS, steps_per_epoch=len(train_loader))

    #model.eval()
    #start_accuracy = accuracy_score(ts_test_y.cpu().numpy(), (model(ts_test).squeeze() > 0.5).cpu().numpy())
    #start_utility_score = utility_function(df.loc[test_index], (model(ts_test).squeeze() > 0.5).cpu().numpy())
    #print('Start Validation Accuracy: {:.4f}'.format(start_accuracy))
    #print('Start Validation Utility: {:.4f}'.format(start_utility_score))

    Val_Loss = 0
    N_Samples = 0

    the_last_loss = 10000
    the_last_utility_score = 0
    the_last_accuracy = 0
    trigger_times=0
    early_stopping_met = False

    for epoch in range(NUM_EPOCHS_AE): 
        running_loss = 0.0        

        ### Call back to save activation stats (mean, std dev and near 0 values after activation functions)
        # Setting hook for activation layers stats

        hook_handles = []
        save_output_activation_stats = []

        for layer in model.modules():
            if ('activation' in str(type(layer))):
                save_output_activation_stats_1layer = SaveOutputActivationStats()
                handle = layer.register_forward_hook(save_output_activation_stats_1layer)
                save_output_activation_stats.append(save_output_activation_stats_1layer)
                hook_handles.append(handle)    

        model.train()

        for batch in train_loader:
            #inputs, labels = batch[0], batch[1]
            inputs = batch[0].to('cuda')
            optimizer.zero_grad()

            with torch.set_grad_enabled(True):
                outputs = model(inputs)
                loss = loss_fn(outputs, inputs.double())
                loss.backward()
                optimizer.step()

                if scheduler:
                    scheduler.step()

        # update local train loss
            running_loss += loss.item() * inputs.size(0)

        # update global train loss
        epoch_loss = running_loss / len(train_loader.dataset)
        print('Epoch({}) - Training Loss: {:.4f}'.format(epoch, epoch_loss))

        writer.add_scalar(f"Global train/loss", epoch_loss, epoch)

        # Write activation stats graphs
        for layer_number,save_output_activation_stats_layer in enumerate(save_output_activation_stats):
            df_stats_layer = pd.DataFrame(save_output_activation_stats_layer.outputs)

            fig, ax = plt.subplots(1, 3, figsize=(25, 4))

            ax[0].set_title(f'Layer {layer_number} : Mean activation value', fontsize=16)
            ax[0].set_xlabel('Batch instances')
            ax[0].set_ylabel('Mean')
            ax[0].plot(range(df_stats_layer.shape[0]), df_stats_layer['mean'])

            ax[1].set_title(f'Layer {layer_number} : Std deviation activation value', fontsize=16)
            ax[1].set_xlabel('Batch instances')
            ax[1].set_ylabel('Standard deviation')
            ax[1].plot(range(df_stats_layer.shape[0]), df_stats_layer['std'])

            ax[2].set_title(f'Layer {layer_number} : Percentage of activation values near zero', fontsize=16)
            ax[2].set_xlabel('Batch instances')
            ax[2].set_ylabel('Percentage')
            ax[2].plot(range(df_stats_layer.shape[0]), df_stats_layer['near_zero']);

            plot_buf = io.BytesIO()
            plt.savefig(plot_buf, format='jpeg')
            plt.close()

            plot_buf.seek(0)
            image = PIL.Image.open(plot_buf)
            image = transforms.ToTensor()(image)
            writer.add_image("Train activation stats/Activation stats layer " + str(layer_number), image, epoch)

        # Validation 
        model.eval()

        vrunning_loss = [None] * 5
        num_samples = [None] * 5
        vepoch_loss_folds = [None] * 5
        vepoch_accuracy_folds = [None] * 5
        vepoch_utility_score_folds = [None] * 5

        for fold_indice in range(5):    
            vrunning_loss[fold_indice] = 0.0
            num_samples[fold_indice] = 0

            for batch in test_loader[fold_indice]:
                inputs = batch[0].to('cuda')

                optimizer.zero_grad()
                with torch.no_grad():
                    outputs = model(inputs)
                    loss = loss_fn(outputs, inputs.double())

                vrunning_loss[fold_indice] += loss.item() * inputs.size(0)
                num_samples[fold_indice] += inputs.size(0)

                vepoch_loss_folds[fold_indice] = vrunning_loss[fold_indice] / num_samples[fold_indice]

            print('Epoch({}) - Fold {} - Validation Loss : {:.4f}'.format(epoch, fold_indice, vepoch_loss_folds[fold_indice]))        

        # update epoch loss
        vepoch_loss = sum(vepoch_loss_folds) / len(vepoch_loss_folds)
        print('Epoch({}) - GLOBAL - Validation Loss: {:.4f}'.format(epoch, vepoch_loss))

        #print(f'Sum of model parameters ({epoch}):')
        #[print(p.sum()) for p in model.parameters()]

        writer.add_scalar("Global valid/Loss", vepoch_loss, epoch)

        for fold_indice in range(5):
            writer.add_scalar("Fold valid Loss/Loss fold "+str(fold_indice), vepoch_loss_folds[fold_indice], epoch)        

        writer.flush()

        # Check if Early Stopping

        if (vepoch_loss > the_last_loss):
            if (EARLY_STOPPING == True):
                trigger_times += 1

                print(f'Intermediate early stopping : vepoch_loss = {vepoch_loss:.4f}, the_last_loss={the_last_loss:.4f}')

                if trigger_times >= patience:
                    print('Meet Early stopping!')
                    early_stopping_met = True
                    ##torch.save(model.state_dict(), f'model_{fold}.pt')
                    break
        else:
            trigger_times = 0
            the_last_loss = vepoch_loss

            the_best_epoch = epoch

            # Save model for the best version so far
            print(f'Saving model corresponding to last_loss == {the_last_loss}')
            torch.save(model.state_dict(), MODEL_FILE_AE)

        print('\n')

    if (early_stopping_met == False):
        print("Didn't meet early stopping : saving final model")
        # Save model if don't meet early stopping
        torch.save(model.state_dict(), MODEL_FILE_AE)

    writer.add_text(f"Global valid/Loss", f"Best loss: {the_last_loss}", the_best_epoch)

    scores_results = {'Loss': the_last_loss, 'Loss folds': vepoch_loss_folds, 'Loss_std': np.std(vepoch_loss_folds)}

    writer.add_text('Final score', str(scores_results))
    writer.add_text('Batch size', str(BATCH_SIZE_AE))
    writer.add_text('Patience', str(patience))
    writer.add_text('Number of epochs', str(NUM_EPOCHS_AE))
    writer.add_text('Best epoch', str(the_best_epoch))
    writer.add_text('Number of parameters per layer', str([p.numel() for p in model.parameters()]))
    writer.add_text('Model architecture', str(model).replace('\n', '<BR>'))
    writer.add_text('Comment', MODEL_COMMENT_AE)

    writer.close()

    print('Training summary:')
    print(scores_results)

    model_AE = model
    model_AE.eval()
    print('Training ended')
# Out:
# Training started
# Epoch(0) - Training Loss: 8.4552
# Epoch(0) - Fold 0 - Validation Loss : 7.4755
# Epoch(0) - Fold 1 - Validation Loss : 5.9368
# Epoch(0) - Fold 2 - Validation Loss : 5.1554
# Epoch(0) - Fold 3 - Validation Loss : 5.0550
# Epoch(0) - Fold 4 - Validation Loss : 4.6616
# Epoch(0) - GLOBAL - Validation Loss: 5.6569
# Saving model corresponding to last_loss == 5.656853811882923
#
#
# Epoch(1) - Training Loss: 8.1171
# Epoch(1) - Fold 0 - Validation Loss : 6.9563
# Epoch(1) - Fold 1 - Validation Loss : 5.5597
# Epoch(1) - Fold 2 - Validation Loss : 4.7793
# Epoch(1) - Fold 3 - Validation Loss : 4.6929
# Epoch(1) - Fold 4 - Validation Loss : 4.3494
# Epoch(1) - GLOBAL - Validation Loss: 5.2675
# Saving model corresponding to last_loss == 5.267520049354945
#
#
# Epoch(2) - Training Loss: 7.5170
# Epoch(2) - Fold 0 - Validation Loss : 6.2390
# Epoch(2) - Fold 1 - Validation Loss : 5.0236
# Epoch(2) - Fold 2 - Validation Loss : 4.3018
# Epoch(2) - Fold 3 - Validation Loss : 4.2382
# Epoch(2) - Fold 4 - Validation Loss : 3.9277
# Epoch(2) - GLOBAL - Validation Loss: 4.7461
# Saving model corresponding to last_loss == 4.746057224608443
#
#
# Epoch(3) - Training Loss: 6.6143
# Epoch(3) - Fold 0 - Validation Loss : 5.6329
# Epoch(3) - Fold 1 - Validation Loss : 4.4595
# Epoch(3) - Fold 2 - Validation Loss : 4.0172
# Epoch(3) - Fold 3 - Validation Loss : 3.9337
# Epoch(3) - Fold 4 - Validation Loss : 3.5859
# Epoch(3) - GLOBAL - Validation Loss: 4.3258
# Saving model corresponding to last_loss == 4.325845416660023
#
#
# Epoch(4) - Training Loss: 5.5354
# Epoch(4) - Fold 0 - Validation Loss : 4.9775
# Epoch(4) - Fold 1 - Validation Loss : 3.8158
# Epoch(4) - Fold 2 - Validation Loss : 3.7590
# Epoch(4) - Fold 3 - Validation Loss : 3.6590
# Epoch(4) - Fold 4 - Validation Loss : 3.2484
# Epoch(4) - GLOBAL - Validation Loss: 3.8919
# Saving model corresponding to last_loss == 3.8919213626571207
#
#
# Epoch(5) - Training Loss: 4.7892
# Epoch(5) - Fold 0 - Validation Loss : 4.4124
# Epoch(5) - Fold 1 - Validation Loss : 3.3757
# Epoch(5) - Fold 2 - Validation Loss : 3.3621
# Epoch(5) - Fold 3 - Validation Loss : 3.2846
# Epoch(5) - Fold 4 - Validation Loss : 2.8813
# Epoch(5) - GLOBAL - Validation Loss: 3.4632
# Saving model corresponding to last_loss == 3.4632308955599207
#
#
# Epoch(6) - Training Loss: 4.4158
# Epoch(6) - Fold 0 - Validation Loss : 3.9719
# Epoch(6) - Fold 1 - Validation Loss : 3.0755
# Epoch(6) - Fold 2 - Validation Loss : 2.9787
# Epoch(6) - Fold 3 - Validation Loss : 2.9383
# Epoch(6) - Fold 4 - Validation Loss : 2.5751
# Epoch(6) - GLOBAL - Validation Loss: 3.1079
# Saving model corresponding to last_loss == 3.1079362939444266
#
#
# Epoch(7) - Training Loss: 4.1469
# Epoch(7) - Fold 0 - Validation Loss : 3.6376
# Epoch(7) - Fold 1 - Validation Loss : 2.8465
# Epoch(7) - Fold 2 - Validation Loss : 2.6950
# Epoch(7) - Fold 3 - Validation Loss : 2.6756
# Epoch(7) - Fold 4 - Validation Loss : 2.3464
# Epoch(7) - GLOBAL - Validation Loss: 2.8402
# Saving model corresponding to last_loss == 2.8402098179918287
#
#
# Epoch(8) - Training Loss: 3.8238
# Epoch(8) - Fold 0 - Validation Loss : 3.2941
# Epoch(8) - Fold 1 - Validation Loss : 2.5969
# Epoch(8) - Fold 2 - Validation Loss : 2.4509
# Epoch(8) - Fold 3 - Validation Loss : 2.4453
# Epoch(8) - Fold 4 - Validation Loss : 2.1346
# Epoch(8) - GLOBAL - Validation Loss: 2.5843
# Saving model corresponding to last_loss == 2.584345850367491
#
#
# Epoch(9) - Training Loss: 3.5740
# Epoch(9) - Fold 0 - Validation Loss : 2.9527
# Epoch(9) - Fold 1 - Validation Loss : 2.3676
# Epoch(9) - Fold 2 - Validation Loss : 2.2307
# Epoch(9) - Fold 3 - Validation Loss : 2.2368
# Epoch(9) - Fold 4 - Validation Loss : 1.9446
# Epoch(9) - GLOBAL - Validation Loss: 2.3465
# Saving model corresponding to last_loss == 2.346494320503518
#
#
# Epoch(10) - Training Loss: 3.3633
# Epoch(10) - Fold 0 - Validation Loss : 2.6947
# Epoch(10) - Fold 1 - Validation Loss : 2.2033
# Epoch(10) - Fold 2 - Validation Loss : 2.0499
# Epoch(10) - Fold 3 - Validation Loss : 2.0613
# Epoch(10) - Fold 4 - Validation Loss : 1.7922
# Epoch(10) - GLOBAL - Validation Loss: 2.1603
# Saving model corresponding to last_loss == 2.1602946332783337
#
#
# Epoch(11) - Training Loss: 3.2512
# Epoch(11) - Fold 0 - Validation Loss : 2.4613
# Epoch(11) - Fold 1 - Validation Loss : 2.0318
# Epoch(11) - Fold 2 - Validation Loss : 1.8891
# Epoch(11) - Fold 3 - Validation Loss : 1.9004
# Epoch(11) - Fold 4 - Validation Loss : 1.6505
# Epoch(11) - GLOBAL - Validation Loss: 1.9866
# Saving model corresponding to last_loss == 1.9866168184170259
#
#
# Epoch(12) - Training Loss: 3.0109
# Epoch(12) - Fold 0 - Validation Loss : 2.2804
# Epoch(12) - Fold 1 - Validation Loss : 1.8860
# Epoch(12) - Fold 2 - Validation Loss : 1.7687
# Epoch(12) - Fold 3 - Validation Loss : 1.7844
# Epoch(12) - Fold 4 - Validation Loss : 1.5397
# Epoch(12) - GLOBAL - Validation Loss: 1.8518
# Saving model corresponding to last_loss == 1.8518463311035114
#
#
# Epoch(13) - Training Loss: 2.9260
# Epoch(13) - Fold 0 - Validation Loss : 2.1663
# Epoch(13) - Fold 1 - Validation Loss : 1.8007
# Epoch(13) - Fold 2 - Validation Loss : 1.6834
# Epoch(13) - Fold 3 - Validation Loss : 1.6999
# Epoch(13) - Fold 4 - Validation Loss : 1.4656
# Epoch(13) - GLOBAL - Validation Loss: 1.7632
# Saving model corresponding to last_loss == 1.7631844499400742
#
#
# Epoch(14) - Training Loss: 2.7615
# Epoch(14) - Fold 0 - Validation Loss : 2.0808
# Epoch(14) - Fold 1 - Validation Loss : 1.7201
# Epoch(14) - Fold 2 - Validation Loss : 1.6107
# Epoch(14) - Fold 3 - Validation Loss : 1.6244
# Epoch(14) - Fold 4 - Validation Loss : 1.3973
# Epoch(14) - GLOBAL - Validation Loss: 1.6867
# Saving model corresponding to last_loss == 1.6866653619308019
#
#
# Epoch(15) - Training Loss: 2.6963
# Epoch(15) - Fold 0 - Validation Loss : 2.0009
# Epoch(15) - Fold 1 - Validation Loss : 1.6509
# Epoch(15) - Fold 2 - Validation Loss : 1.5468
# Epoch(15) - Fold 3 - Validation Loss : 1.5582
# Epoch(15) - Fold 4 - Validation Loss : 1.3397
# Epoch(15) - GLOBAL - Validation Loss: 1.6193
# Saving model corresponding to last_loss == 1.619315211329544
#
#
# Epoch(16) - Training Loss: 2.6223
# Epoch(16) - Fold 0 - Validation Loss : 1.9369
# Epoch(16) - Fold 1 - Validation Loss : 1.6084
# Epoch(16) - Fold 2 - Validation Loss : 1.4929
# Epoch(16) - Fold 3 - Validation Loss : 1.5032
# Epoch(16) - Fold 4 - Validation Loss : 1.2959
# Epoch(16) - GLOBAL - Validation Loss: 1.5675
# Saving model corresponding to last_loss == 1.5674548314301344
#
#
# Epoch(17) - Training Loss: 2.6371
# Epoch(17) - Fold 0 - Validation Loss : 1.9176
# Epoch(17) - Fold 1 - Validation Loss : 1.5916
# Epoch(17) - Fold 2 - Validation Loss : 1.4529
# Epoch(17) - Fold 3 - Validation Loss : 1.4616
# Epoch(17) - Fold 4 - Validation Loss : 1.2682
# Epoch(17) - GLOBAL - Validation Loss: 1.5384
# Saving model corresponding to last_loss == 1.5383647991512945
#
#
# Epoch(18) - Training Loss: 2.6043
# Epoch(18) - Fold 0 - Validation Loss : 1.8734
# Epoch(18) - Fold 1 - Validation Loss : 1.5439
# Epoch(18) - Fold 2 - Validation Loss : 1.4235
# Epoch(18) - Fold 3 - Validation Loss : 1.4285
# Epoch(18) - Fold 4 - Validation Loss : 1.2368
# Epoch(18) - GLOBAL - Validation Loss: 1.5012
# Saving model corresponding to last_loss == 1.501226374251256
#
#
# Epoch(19) - Training Loss: 2.5494
# Epoch(19) - Fold 0 - Validation Loss : 1.8522
# Epoch(19) - Fold 1 - Validation Loss : 1.5390
# Epoch(19) - Fold 2 - Validation Loss : 1.3866
# Epoch(19) - Fold 3 - Validation Loss : 1.3924
# Epoch(19) - Fold 4 - Validation Loss : 1.2133
# Epoch(19) - GLOBAL - Validation Loss: 1.4767
# Saving model corresponding to last_loss == 1.4767267344021744
#
#
# Epoch(20) - Training Loss: 2.6433
# Epoch(20) - Fold 0 - Validation Loss : 1.8061
# Epoch(20) - Fold 1 - Validation Loss : 1.5037
# Epoch(20) - Fold 2 - Validation Loss : 1.3569
# Epoch(20) - Fold 3 - Validation Loss : 1.3618
# Epoch(20) - Fold 4 - Validation Loss : 1.1860
# Epoch(20) - GLOBAL - Validation Loss: 1.4429
# Saving model corresponding to last_loss == 1.442908579169495
#
#
# Epoch(21) - Training Loss: 2.4125
# Epoch(21) - Fold 0 - Validation Loss : 1.8115
# Epoch(21) - Fold 1 - Validation Loss : 1.5070
# Epoch(21) - Fold 2 - Validation Loss : 1.3393
# Epoch(21) - Fold 3 - Validation Loss : 1.3449
# Epoch(21) - Fold 4 - Validation Loss : 1.1779
# Epoch(21) - GLOBAL - Validation Loss: 1.4361
# Saving model corresponding to last_loss == 1.4361138690545039
#
#
# Epoch(22) - Training Loss: 2.5358
# Epoch(22) - Fold 0 - Validation Loss : 1.7885
# Epoch(22) - Fold 1 - Validation Loss : 1.4935
# Epoch(22) - Fold 2 - Validation Loss : 1.3141
# Epoch(22) - Fold 3 - Validation Loss : 1.3219
# Epoch(22) - Fold 4 - Validation Loss : 1.1608
# Epoch(22) - GLOBAL - Validation Loss: 1.4158
# Saving model corresponding to last_loss == 1.4157647765226797
#
#
# Epoch(23) - Training Loss: 2.3908
# Epoch(23) - Fold 0 - Validation Loss : 1.7941
# Epoch(23) - Fold 1 - Validation Loss : 1.4982
# Epoch(23) - Fold 2 - Validation Loss : 1.2963
# Epoch(23) - Fold 3 - Validation Loss : 1.3050
# Epoch(23) - Fold 4 - Validation Loss : 1.1530
# Epoch(23) - GLOBAL - Validation Loss: 1.4093
# Saving model corresponding to last_loss == 1.4093087137122702
#
#
# Epoch(24) - Training Loss: 2.4504
# Epoch(24) - Fold 0 - Validation Loss : 1.7421
# Epoch(24) - Fold 1 - Validation Loss : 1.4471
# Epoch(24) - Fold 2 - Validation Loss : 1.2720
# Epoch(24) - Fold 3 - Validation Loss : 1.2813
# Epoch(24) - Fold 4 - Validation Loss : 1.1250
# Epoch(24) - GLOBAL - Validation Loss: 1.3735
# Saving model corresponding to last_loss == 1.3735108139837322
#
#
# Epoch(25) - Training Loss: 2.3625
# Epoch(25) - Fold 0 - Validation Loss : 1.7736
# Epoch(25) - Fold 1 - Validation Loss : 1.4833
# Epoch(25) - Fold 2 - Validation Loss : 1.2686
# Epoch(25) - Fold 3 - Validation Loss : 1.2763
# Epoch(25) - Fold 4 - Validation Loss : 1.1369
# Epoch(25) - GLOBAL - Validation Loss: 1.3877
# Intermediate early stopping : vepoch_loss = 1.3877, the_last_loss=1.3735
#
#
# Epoch(26) - Training Loss: 2.3932
# Epoch(26) - Fold 0 - Validation Loss : 1.7502
# Epoch(26) - Fold 1 - Validation Loss : 1.4580
# Epoch(26) - Fold 2 - Validation Loss : 1.2443
# Epoch(26) - Fold 3 - Validation Loss : 1.2554
# Epoch(26) - Fold 4 - Validation Loss : 1.1130
# Epoch(26) - GLOBAL - Validation Loss: 1.3642
# Saving model corresponding to last_loss == 1.3641767886563838
#
#
# Epoch(27) - Training Loss: 2.3110
# Epoch(27) - Fold 0 - Validation Loss : 1.7068
# Epoch(27) - Fold 1 - Validation Loss : 1.4242
# Epoch(27) - Fold 2 - Validation Loss : 1.2231
# Epoch(27) - Fold 3 - Validation Loss : 1.2356
# Epoch(27) - Fold 4 - Validation Loss : 1.0923
# Epoch(27) - GLOBAL - Validation Loss: 1.3364
# Saving model corresponding to last_loss == 1.3363959766817257
#
#
# Epoch(28) - Training Loss: 2.3644
# Epoch(28) - Fold 0 - Validation Loss : 1.7286
# Epoch(28) - Fold 1 - Validation Loss : 1.4427
# Epoch(28) - Fold 2 - Validation Loss : 1.2101
# Epoch(28) - Fold 3 - Validation Loss : 1.2230
# Epoch(28) - Fold 4 - Validation Loss : 1.0900
# Epoch(28) - GLOBAL - Validation Loss: 1.3389
# Intermediate early stopping : vepoch_loss = 1.3389, the_last_loss=1.3364
#
#
# Epoch(29) - Training Loss: 2.3072
# Epoch(29) - Fold 0 - Validation Loss : 1.7201
# Epoch(29) - Fold 1 - Validation Loss : 1.4422
# Epoch(29) - Fold 2 - Validation Loss : 1.1960
# Epoch(29) - Fold 3 - Validation Loss : 1.2108
# Epoch(29) - Fold 4 - Validation Loss : 1.0802
# Epoch(29) - GLOBAL - Validation Loss: 1.3299
# Saving model corresponding to last_loss == 1.3298602794909316
#
#
# Epoch(30) - Training Loss: 2.3313
# Epoch(30) - Fold 0 - Validation Loss : 1.6990
# Epoch(30) - Fold 1 - Validation Loss : 1.4091
# Epoch(30) - Fold 2 - Validation Loss : 1.1782
# Epoch(30) - Fold 3 - Validation Loss : 1.1930
# Epoch(30) - Fold 4 - Validation Loss : 1.0605
# Epoch(30) - GLOBAL - Validation Loss: 1.3080
# Saving model corresponding to last_loss == 1.3079536650664363
#
#
# Epoch(31) - Training Loss: 2.2264
# Epoch(31) - Fold 0 - Validation Loss : 1.7125
# Epoch(31) - Fold 1 - Validation Loss : 1.4303
# Epoch(31) - Fold 2 - Validation Loss : 1.1662
# Epoch(31) - Fold 3 - Validation Loss : 1.1830
# Epoch(31) - Fold 4 - Validation Loss : 1.0606
# Epoch(31) - GLOBAL - Validation Loss: 1.3105
# Intermediate early stopping : vepoch_loss = 1.3105, the_last_loss=1.3080
#
#
# Epoch(32) - Training Loss: 2.2586
# Epoch(32) - Fold 0 - Validation Loss : 1.6838
# Epoch(32) - Fold 1 - Validation Loss : 1.4057
# Epoch(32) - Fold 2 - Validation Loss : 1.1560
# Epoch(32) - Fold 3 - Validation Loss : 1.1742
# Epoch(32) - Fold 4 - Validation Loss : 1.0501
# Epoch(32) - GLOBAL - Validation Loss: 1.2939
# Saving model corresponding to last_loss == 1.293947658731798
#
#
# Epoch(33) - Training Loss: 2.2912
# Epoch(33) - Fold 0 - Validation Loss : 1.6943
# Epoch(33) - Fold 1 - Validation Loss : 1.4152
# Epoch(33) - Fold 2 - Validation Loss : 1.1471
# Epoch(33) - Fold 3 - Validation Loss : 1.1667
# Epoch(33) - Fold 4 - Validation Loss : 1.0461
# Epoch(33) - GLOBAL - Validation Loss: 1.2939
# Saving model corresponding to last_loss == 1.293883576875031
#
#
# Epoch(34) - Training Loss: 2.2022
# Epoch(34) - Fold 0 - Validation Loss : 1.6496
# Epoch(34) - Fold 1 - Validation Loss : 1.3761
# Epoch(34) - Fold 2 - Validation Loss : 1.1278
# Epoch(34) - Fold 3 - Validation Loss : 1.1466
# Epoch(34) - Fold 4 - Validation Loss : 1.0234
# Epoch(34) - GLOBAL - Validation Loss: 1.2647
# Saving model corresponding to last_loss == 1.2647200605309503
#
#
# Epoch(35) - Training Loss: 2.2054
# Epoch(35) - Fold 0 - Validation Loss : 1.6612
# Epoch(35) - Fold 1 - Validation Loss : 1.3832
# Epoch(35) - Fold 2 - Validation Loss : 1.1231
# Epoch(35) - Fold 3 - Validation Loss : 1.1426
# Epoch(35) - Fold 4 - Validation Loss : 1.0221
# Epoch(35) - GLOBAL - Validation Loss: 1.2664
# Intermediate early stopping : vepoch_loss = 1.2664, the_last_loss=1.2647
#
#
# Epoch(36) - Training Loss: 2.2921
# Epoch(36) - Fold 0 - Validation Loss : 1.6285
# Epoch(36) - Fold 1 - Validation Loss : 1.3495
# Epoch(36) - Fold 2 - Validation Loss : 1.1134
# Epoch(36) - Fold 3 - Validation Loss : 1.1330
# Epoch(36) - Fold 4 - Validation Loss : 1.0077
# Epoch(36) - GLOBAL - Validation Loss: 1.2464
# Saving model corresponding to last_loss == 1.2463883953583932
#
#
# Epoch(37) - Training Loss: 2.2141
# Epoch(37) - Fold 0 - Validation Loss : 1.6463
# Epoch(37) - Fold 1 - Validation Loss : 1.3786
# Epoch(37) - Fold 2 - Validation Loss : 1.1067
# Epoch(37) - Fold 3 - Validation Loss : 1.1278
# Epoch(37) - Fold 4 - Validation Loss : 1.0119
# Epoch(37) - GLOBAL - Validation Loss: 1.2543
# Intermediate early stopping : vepoch_loss = 1.2543, the_last_loss=1.2464
#
#
# Epoch(38) - Training Loss: 2.2007
# Epoch(38) - Fold 0 - Validation Loss : 1.6099
# Epoch(38) - Fold 1 - Validation Loss : 1.3490
# Epoch(38) - Fold 2 - Validation Loss : 1.0945
# Epoch(38) - Fold 3 - Validation Loss : 1.1156
# Epoch(38) - Fold 4 - Validation Loss : 0.9980
# Epoch(38) - GLOBAL - Validation Loss: 1.2334
# Saving model corresponding to last_loss == 1.233412419883844
#
#
# Epoch(39) - Training Loss: 2.1338
# Epoch(39) - Fold 0 - Validation Loss : 1.6508
# Epoch(39) - Fold 1 - Validation Loss : 1.3809
# Epoch(39) - Fold 2 - Validation Loss : 1.0986
# Epoch(39) - Fold 3 - Validation Loss : 1.1198
# Epoch(39) - Fold 4 - Validation Loss : 1.0112
# Epoch(39) - GLOBAL - Validation Loss: 1.2523
# Intermediate early stopping : vepoch_loss = 1.2523, the_last_loss=1.2334
#
#
# Epoch(40) - Training Loss: 2.2195
# Epoch(40) - Fold 0 - Validation Loss : 1.6460
# Epoch(40) - Fold 1 - Validation Loss : 1.3802
# Epoch(40) - Fold 2 - Validation Loss : 1.0917
# Epoch(40) - Fold 3 - Validation Loss : 1.1127
# Epoch(40) - Fold 4 - Validation Loss : 1.0056
# Epoch(40) - GLOBAL - Validation Loss: 1.2472
# Intermediate early stopping : vepoch_loss = 1.2472, the_last_loss=1.2334
#
#
# Epoch(41) - Training Loss: 2.1835
# Epoch(41) - Fold 0 - Validation Loss : 1.6123
# Epoch(41) - Fold 1 - Validation Loss : 1.3475
# Epoch(41) - Fold 2 - Validation Loss : 1.0799
# Epoch(41) - Fold 3 - Validation Loss : 1.1009
# Epoch(41) - Fold 4 - Validation Loss : 0.9881
# Epoch(41) - GLOBAL - Validation Loss: 1.2257
# Saving model corresponding to last_loss == 1.2257278952316462
#
#
# Epoch(42) - Training Loss: 2.1259
# Epoch(42) - Fold 0 - Validation Loss : 1.6269
# Epoch(42) - Fold 1 - Validation Loss : 1.3664
# Epoch(42) - Fold 2 - Validation Loss : 1.0784
# Epoch(42) - Fold 3 - Validation Loss : 1.0977
# Epoch(42) - Fold 4 - Validation Loss : 0.9920
# Epoch(42) - GLOBAL - Validation Loss: 1.2323
# Intermediate early stopping : vepoch_loss = 1.2323, the_last_loss=1.2257
#
#
# Epoch(43) - Training Loss: 2.1269
# Epoch(43) - Fold 0 - Validation Loss : 1.6431
# Epoch(43) - Fold 1 - Validation Loss : 1.3877
# Epoch(43) - Fold 2 - Validation Loss : 1.0788
# Epoch(43) - Fold 3 - Validation Loss : 1.1004
# Epoch(43) - Fold 4 - Validation Loss : 1.0001
# Epoch(43) - GLOBAL - Validation Loss: 1.2420
# Intermediate early stopping : vepoch_loss = 1.2420, the_last_loss=1.2257
#
#
# Epoch(44) - Training Loss: 2.1230
# Epoch(44) - Fold 0 - Validation Loss : 1.6056
# Epoch(44) - Fold 1 - Validation Loss : 1.3473
# Epoch(44) - Fold 2 - Validation Loss : 1.0639
# Epoch(44) - Fold 3 - Validation Loss : 1.0845
# Epoch(44) - Fold 4 - Validation Loss : 0.9811
# Epoch(44) - GLOBAL - Validation Loss: 1.2165
# Saving model corresponding to last_loss == 1.2164784285622383
#
#
# Epoch(45) - Training Loss: 2.1164
# Epoch(45) - Fold 0 - Validation Loss : 1.5762
# Epoch(45) - Fold 1 - Validation Loss : 1.3186
# Epoch(45) - Fold 2 - Validation Loss : 1.0572
# Epoch(45) - Fold 3 - Validation Loss : 1.0758
# Epoch(45) - Fold 4 - Validation Loss : 0.9696
# Epoch(45) - GLOBAL - Validation Loss: 1.1995
# Saving model corresponding to last_loss == 1.1994848816308243
#
#
# Epoch(46) - Training Loss: 2.1151
# Epoch(46) - Fold 0 - Validation Loss : 1.5840
# Epoch(46) - Fold 1 - Validation Loss : 1.3291
# Epoch(46) - Fold 2 - Validation Loss : 1.0485
# Epoch(46) - Fold 3 - Validation Loss : 1.0698
# Epoch(46) - Fold 4 - Validation Loss : 0.9671
# Epoch(46) - GLOBAL - Validation Loss: 1.1997
# Intermediate early stopping : vepoch_loss = 1.1997, the_last_loss=1.1995
#
#
# Epoch(47) - Training Loss: 2.1534
# Epoch(47) - Fold 0 - Validation Loss : 1.5526
# Epoch(47) - Fold 1 - Validation Loss : 1.2980
# Epoch(47) - Fold 2 - Validation Loss : 1.0414
# Epoch(47) - Fold 3 - Validation Loss : 1.0611
# Epoch(47) - Fold 4 - Validation Loss : 0.9541
# Epoch(47) - GLOBAL - Validation Loss: 1.1814
# Saving model corresponding to last_loss == 1.1814247299030303
#
#
# Epoch(48) - Training Loss: 2.1464
# Epoch(48) - Fold 0 - Validation Loss : 1.5647
# Epoch(48) - Fold 1 - Validation Loss : 1.3102
# Epoch(48) - Fold 2 - Validation Loss : 1.0379
# Epoch(48) - Fold 3 - Validation Loss : 1.0578
# Epoch(48) - Fold 4 - Validation Loss : 0.9569
# Epoch(48) - GLOBAL - Validation Loss: 1.1855
# Intermediate early stopping : vepoch_loss = 1.1855, the_last_loss=1.1814
#
#
# Epoch(49) - Training Loss: 2.1549
# Epoch(49) - Fold 0 - Validation Loss : 1.5830
# Epoch(49) - Fold 1 - Validation Loss : 1.3243
# Epoch(49) - Fold 2 - Validation Loss : 1.0377
# Epoch(49) - Fold 3 - Validation Loss : 1.0571
# Epoch(49) - Fold 4 - Validation Loss : 0.9601
# Epoch(49) - GLOBAL - Validation Loss: 1.1924
# Intermediate early stopping : vepoch_loss = 1.1924, the_last_loss=1.1814
#
#
# Epoch(50) - Training Loss: 2.0550
# Epoch(50) - Fold 0 - Validation Loss : 1.5689
# Epoch(50) - Fold 1 - Validation Loss : 1.3131
# Epoch(50) - Fold 2 - Validation Loss : 1.0276
# Epoch(50) - Fold 3 - Validation Loss : 1.0467
# Epoch(50) - Fold 4 - Validation Loss : 0.9495
# Epoch(50) - GLOBAL - Validation Loss: 1.1812
# Saving model corresponding to last_loss == 1.181175431252385
#
#
# Epoch(51) - Training Loss: 2.0771
# Epoch(51) - Fold 0 - Validation Loss : 1.5479
# Epoch(51) - Fold 1 - Validation Loss : 1.2894
# Epoch(51) - Fold 2 - Validation Loss : 1.0226
# Epoch(51) - Fold 3 - Validation Loss : 1.0400
# Epoch(51) - Fold 4 - Validation Loss : 0.9392
# Epoch(51) - GLOBAL - Validation Loss: 1.1678
# Saving model corresponding to last_loss == 1.1678143894444342
#
#
# Epoch(52) - Training Loss: 2.0413
# Epoch(52) - Fold 0 - Validation Loss : 1.5804
# Epoch(52) - Fold 1 - Validation Loss : 1.3262
# Epoch(52) - Fold 2 - Validation Loss : 1.0215
# Epoch(52) - Fold 3 - Validation Loss : 1.0397
# Epoch(52) - Fold 4 - Validation Loss : 0.9483
# Epoch(52) - GLOBAL - Validation Loss: 1.1832
# Intermediate early stopping : vepoch_loss = 1.1832, the_last_loss=1.1678
#
#
# Epoch(53) - Training Loss: 2.1154
# Epoch(53) - Fold 0 - Validation Loss : 1.5412
# Epoch(53) - Fold 1 - Validation Loss : 1.2857
# Epoch(53) - Fold 2 - Validation Loss : 1.0128
# Epoch(53) - Fold 3 - Validation Loss : 1.0302
# Epoch(53) - Fold 4 - Validation Loss : 0.9327
# Epoch(53) - GLOBAL - Validation Loss: 1.1605
# Saving model corresponding to last_loss == 1.1605096133895967
#
#
# Epoch(54) - Training Loss: 2.1021
# Epoch(54) - Fold 0 - Validation Loss : 1.5544
# Epoch(54) - Fold 1 - Validation Loss : 1.3095
# Epoch(54) - Fold 2 - Validation Loss : 1.0051
# Epoch(54) - Fold 3 - Validation Loss : 1.0239
# Epoch(54) - Fold 4 - Validation Loss : 0.9366
# Epoch(54) - GLOBAL - Validation Loss: 1.1659
# Intermediate early stopping : vepoch_loss = 1.1659, the_last_loss=1.1605
#
#
# Epoch(55) - Training Loss: 2.0987
# Epoch(55) - Fold 0 - Validation Loss : 1.5592
# Epoch(55) - Fold 1 - Validation Loss : 1.3038
# Epoch(55) - Fold 2 - Validation Loss : 1.0086
# Epoch(55) - Fold 3 - Validation Loss : 1.0262
# Epoch(55) - Fold 4 - Validation Loss : 0.9367
# Epoch(55) - GLOBAL - Validation Loss: 1.1669
# Intermediate early stopping : vepoch_loss = 1.1669, the_last_loss=1.1605
#
#
# Epoch(56) - Training Loss: 2.0514
# Epoch(56) - Fold 0 - Validation Loss : 1.5482
# Epoch(56) - Fold 1 - Validation Loss : 1.2906
# Epoch(56) - Fold 2 - Validation Loss : 1.0025
# Epoch(56) - Fold 3 - Validation Loss : 1.0184
# Epoch(56) - Fold 4 - Validation Loss : 0.9277
# Epoch(56) - GLOBAL - Validation Loss: 1.1575
# Saving model corresponding to last_loss == 1.1574767674088924
#
#
# Epoch(57) - Training Loss: 2.1017
# Epoch(57) - Fold 0 - Validation Loss : 1.5262
# Epoch(57) - Fold 1 - Validation Loss : 1.2774
# Epoch(57) - Fold 2 - Validation Loss : 0.9908
# Epoch(57) - Fold 3 - Validation Loss : 1.0078
# Epoch(57) - Fold 4 - Validation Loss : 0.9202
# Epoch(57) - GLOBAL - Validation Loss: 1.1445
# Saving model corresponding to last_loss == 1.1444791462849764
#
#
# Epoch(58) - Training Loss: 2.0483
# Epoch(58) - Fold 0 - Validation Loss : 1.5271
# Epoch(58) - Fold 1 - Validation Loss : 1.2791
# Epoch(58) - Fold 2 - Validation Loss : 0.9882
# Epoch(58) - Fold 3 - Validation Loss : 1.0056
# Epoch(58) - Fold 4 - Validation Loss : 0.9169
# Epoch(58) - GLOBAL - Validation Loss: 1.1434
# Saving model corresponding to last_loss == 1.1433548304275996
#
#
# Epoch(59) - Training Loss: 2.1239
# Epoch(59) - Fold 0 - Validation Loss : 1.5198
# Epoch(59) - Fold 1 - Validation Loss : 1.2747
# Epoch(59) - Fold 2 - Validation Loss : 0.9808
# Epoch(59) - Fold 3 - Validation Loss : 0.9989
# Epoch(59) - Fold 4 - Validation Loss : 0.9117
# Epoch(59) - GLOBAL - Validation Loss: 1.1372
# Saving model corresponding to last_loss == 1.1371769624452803
#
#
# Epoch(60) - Training Loss: 2.0379
# Epoch(60) - Fold 0 - Validation Loss : 1.5037
# Epoch(60) - Fold 1 - Validation Loss : 1.2543
# Epoch(60) - Fold 2 - Validation Loss : 0.9737
# Epoch(60) - Fold 3 - Validation Loss : 0.9907
# Epoch(60) - Fold 4 - Validation Loss : 0.9012
# Epoch(60) - GLOBAL - Validation Loss: 1.1247
# Saving model corresponding to last_loss == 1.1247184130782488
#
#
# Epoch(61) - Training Loss: 1.9998
# Epoch(61) - Fold 0 - Validation Loss : 1.5149
# Epoch(61) - Fold 1 - Validation Loss : 1.2634
# Epoch(61) - Fold 2 - Validation Loss : 0.9729
# Epoch(61) - Fold 3 - Validation Loss : 0.9897
# Epoch(61) - Fold 4 - Validation Loss : 0.9023
# Epoch(61) - GLOBAL - Validation Loss: 1.1286
# Intermediate early stopping : vepoch_loss = 1.1286, the_last_loss=1.1247
#
#
# Epoch(62) - Training Loss: 2.0815
# Epoch(62) - Fold 0 - Validation Loss : 1.4898
# Epoch(62) - Fold 1 - Validation Loss : 1.2439
# Epoch(62) - Fold 2 - Validation Loss : 0.9664
# Epoch(62) - Fold 3 - Validation Loss : 0.9838
# Epoch(62) - Fold 4 - Validation Loss : 0.8938
# Epoch(62) - GLOBAL - Validation Loss: 1.1155
# Saving model corresponding to last_loss == 1.1155212562464238
#
#
# Epoch(63) - Training Loss: 1.9792
# Epoch(63) - Fold 0 - Validation Loss : 1.5270
# Epoch(63) - Fold 1 - Validation Loss : 1.2826
# Epoch(63) - Fold 2 - Validation Loss : 0.9657
# Epoch(63) - Fold 3 - Validation Loss : 0.9844
# Epoch(63) - Fold 4 - Validation Loss : 0.9044
# Epoch(63) - GLOBAL - Validation Loss: 1.1328
# Intermediate early stopping : vepoch_loss = 1.1328, the_last_loss=1.1155
#
#
# Epoch(64) - Training Loss: 2.0105
# Epoch(64) - Fold 0 - Validation Loss : 1.5072
# Epoch(64) - Fold 1 - Validation Loss : 1.2562
# Epoch(64) - Fold 2 - Validation Loss : 0.9618
# Epoch(64) - Fold 3 - Validation Loss : 0.9796
# Epoch(64) - Fold 4 - Validation Loss : 0.8956
# Epoch(64) - GLOBAL - Validation Loss: 1.1201
# Intermediate early stopping : vepoch_loss = 1.1201, the_last_loss=1.1155
#
#
# Epoch(65) - Training Loss: 2.0941
# Epoch(65) - Fold 0 - Validation Loss : 1.5183
# Epoch(65) - Fold 1 - Validation Loss : 1.2615
# Epoch(65) - Fold 2 - Validation Loss : 0.9633
# Epoch(65) - Fold 3 - Validation Loss : 0.9814
# Epoch(65) - Fold 4 - Validation Loss : 0.8983
# Epoch(65) - GLOBAL - Validation Loss: 1.1245
# Intermediate early stopping : vepoch_loss = 1.1245, the_last_loss=1.1155
#
#
# Epoch(66) - Training Loss: 2.0433
# Epoch(66) - Fold 0 - Validation Loss : 1.4792
# Epoch(66) - Fold 1 - Validation Loss : 1.2274
# Epoch(66) - Fold 2 - Validation Loss : 0.9526
# Epoch(66) - Fold 3 - Validation Loss : 0.9686
# Epoch(66) - Fold 4 - Validation Loss : 0.8806
# Epoch(66) - GLOBAL - Validation Loss: 1.1017
# Saving model corresponding to last_loss == 1.1016852192101314
#
#
# Epoch(67) - Training Loss: 1.9776
# Epoch(67) - Fold 0 - Validation Loss : 1.5123
# Epoch(67) - Fold 1 - Validation Loss : 1.2622
# Epoch(67) - Fold 2 - Validation Loss : 0.9543
# Epoch(67) - Fold 3 - Validation Loss : 0.9704
# Epoch(67) - Fold 4 - Validation Loss : 0.8903
# Epoch(67) - GLOBAL - Validation Loss: 1.1179
# Intermediate early stopping : vepoch_loss = 1.1179, the_last_loss=1.1017
#
#
# Epoch(68) - Training Loss: 2.0561
# Epoch(68) - Fold 0 - Validation Loss : 1.4972
# Epoch(68) - Fold 1 - Validation Loss : 1.2443
# Epoch(68) - Fold 2 - Validation Loss : 0.9517
# Epoch(68) - Fold 3 - Validation Loss : 0.9682
# Epoch(68) - Fold 4 - Validation Loss : 0.8849
# Epoch(68) - GLOBAL - Validation Loss: 1.1092
# Intermediate early stopping : vepoch_loss = 1.1092, the_last_loss=1.1017
#
#
# Epoch(69) - Training Loss: 2.1094
# Epoch(69) - Fold 0 - Validation Loss : 1.5053
# Epoch(69) - Fold 1 - Validation Loss : 1.2439
# Epoch(69) - Fold 2 - Validation Loss : 0.9511
# Epoch(69) - Fold 3 - Validation Loss : 0.9687
# Epoch(69) - Fold 4 - Validation Loss : 0.8850
# Epoch(69) - GLOBAL - Validation Loss: 1.1108
# Intermediate early stopping : vepoch_loss = 1.1108, the_last_loss=1.1017
#
#
# Epoch(70) - Training Loss: 2.0121
# Epoch(70) - Fold 0 - Validation Loss : 1.4848
# Epoch(70) - Fold 1 - Validation Loss : 1.2273
# Epoch(70) - Fold 2 - Validation Loss : 0.9426
# Epoch(70) - Fold 3 - Validation Loss : 0.9589
# Epoch(70) - Fold 4 - Validation Loss : 0.8759
# Epoch(70) - GLOBAL - Validation Loss: 1.0979
# Saving model corresponding to last_loss == 1.0979193975638852
#
#
# Epoch(71) - Training Loss: 2.0056
# Epoch(71) - Fold 0 - Validation Loss : 1.4980
# Epoch(71) - Fold 1 - Validation Loss : 1.2469
# Epoch(71) - Fold 2 - Validation Loss : 0.9413
# Epoch(71) - Fold 3 - Validation Loss : 0.9574
# Epoch(71) - Fold 4 - Validation Loss : 0.8800
# Epoch(71) - GLOBAL - Validation Loss: 1.1047
# Intermediate early stopping : vepoch_loss = 1.1047, the_last_loss=1.0979
#
#
# Epoch(72) - Training Loss: 2.0093
# Epoch(72) - Fold 0 - Validation Loss : 1.5048
# Epoch(72) - Fold 1 - Validation Loss : 1.2546
# Epoch(72) - Fold 2 - Validation Loss : 0.9461
# Epoch(72) - Fold 3 - Validation Loss : 0.9629
# Epoch(72) - Fold 4 - Validation Loss : 0.8880
# Epoch(72) - GLOBAL - Validation Loss: 1.1113
# Intermediate early stopping : vepoch_loss = 1.1113, the_last_loss=1.0979
#
#
# Epoch(73) - Training Loss: 2.0688
# Epoch(73) - Fold 0 - Validation Loss : 1.4981
# Epoch(73) - Fold 1 - Validation Loss : 1.2484
# Epoch(73) - Fold 2 - Validation Loss : 0.9358
# Epoch(73) - Fold 3 - Validation Loss : 0.9537
# Epoch(73) - Fold 4 - Validation Loss : 0.8794
# Epoch(73) - GLOBAL - Validation Loss: 1.1031
# Intermediate early stopping : vepoch_loss = 1.1031, the_last_loss=1.0979
#
#
# Epoch(74) - Training Loss: 1.9772
# Epoch(74) - Fold 0 - Validation Loss : 1.4929
# Epoch(74) - Fold 1 - Validation Loss : 1.2338
# Epoch(74) - Fold 2 - Validation Loss : 0.9340
# Epoch(74) - Fold 3 - Validation Loss : 0.9509
# Epoch(74) - Fold 4 - Validation Loss : 0.8721
# Epoch(74) - GLOBAL - Validation Loss: 1.0967
# Saving model corresponding to last_loss == 1.0967447642365635
#
#
# Epoch(75) - Training Loss: 1.9167
# Epoch(75) - Fold 0 - Validation Loss : 1.4837
# Epoch(75) - Fold 1 - Validation Loss : 1.2283
# Epoch(75) - Fold 2 - Validation Loss : 0.9275
# Epoch(75) - Fold 3 - Validation Loss : 0.9441
# Epoch(75) - Fold 4 - Validation Loss : 0.8658
# Epoch(75) - GLOBAL - Validation Loss: 1.0899
# Saving model corresponding to last_loss == 1.0898713274447922
#
#
# Epoch(76) - Training Loss: 1.9940
# Epoch(76) - Fold 0 - Validation Loss : 1.4937
# Epoch(76) - Fold 1 - Validation Loss : 1.2349
# Epoch(76) - Fold 2 - Validation Loss : 0.9314
# Epoch(76) - Fold 3 - Validation Loss : 0.9472
# Epoch(76) - Fold 4 - Validation Loss : 0.8693
# Epoch(76) - GLOBAL - Validation Loss: 1.0953
# Intermediate early stopping : vepoch_loss = 1.0953, the_last_loss=1.0899
#
#
# Epoch(77) - Training Loss: 2.0469
# Epoch(77) - Fold 0 - Validation Loss : 1.4736
# Epoch(77) - Fold 1 - Validation Loss : 1.2160
# Epoch(77) - Fold 2 - Validation Loss : 0.9256
# Epoch(77) - Fold 3 - Validation Loss : 0.9425
# Epoch(77) - Fold 4 - Validation Loss : 0.8632
# Epoch(77) - GLOBAL - Validation Loss: 1.0842
# Saving model corresponding to last_loss == 1.0841884033076075
#
#
# Epoch(78) - Training Loss: 1.9688
# Epoch(78) - Fold 0 - Validation Loss : 1.5087
# Epoch(78) - Fold 1 - Validation Loss : 1.2483
# Epoch(78) - Fold 2 - Validation Loss : 0.9279
# Epoch(78) - Fold 3 - Validation Loss : 0.9461
# Epoch(78) - Fold 4 - Validation Loss : 0.8727
# Epoch(78) - GLOBAL - Validation Loss: 1.1007
# Intermediate early stopping : vepoch_loss = 1.1007, the_last_loss=1.0842
#
#
# Epoch(79) - Training Loss: 1.9377
# Epoch(79) - Fold 0 - Validation Loss : 1.4918
# Epoch(79) - Fold 1 - Validation Loss : 1.2384
# Epoch(79) - Fold 2 - Validation Loss : 0.9212
# Epoch(79) - Fold 3 - Validation Loss : 0.9396
# Epoch(79) - Fold 4 - Validation Loss : 0.8665
# Epoch(79) - GLOBAL - Validation Loss: 1.0915
# Intermediate early stopping : vepoch_loss = 1.0915, the_last_loss=1.0842
#
#
# Epoch(80) - Training Loss: 1.9104
# Epoch(80) - Fold 0 - Validation Loss : 1.4924
# Epoch(80) - Fold 1 - Validation Loss : 1.2323
# Epoch(80) - Fold 2 - Validation Loss : 0.9204
# Epoch(80) - Fold 3 - Validation Loss : 0.9385
# Epoch(80) - Fold 4 - Validation Loss : 0.8651
# Epoch(80) - GLOBAL - Validation Loss: 1.0897
# Intermediate early stopping : vepoch_loss = 1.0897, the_last_loss=1.0842
#
#
# Epoch(81) - Training Loss: 2.0149
# Epoch(81) - Fold 0 - Validation Loss : 1.4968
# Epoch(81) - Fold 1 - Validation Loss : 1.2361
# Epoch(81) - Fold 2 - Validation Loss : 0.9171
# Epoch(81) - Fold 3 - Validation Loss : 0.9345
# Epoch(81) - Fold 4 - Validation Loss : 0.8622
# Epoch(81) - GLOBAL - Validation Loss: 1.0893
# Intermediate early stopping : vepoch_loss = 1.0893, the_last_loss=1.0842
#
#
# Epoch(82) - Training Loss: 2.0499
# Epoch(82) - Fold 0 - Validation Loss : 1.5058
# Epoch(82) - Fold 1 - Validation Loss : 1.2485
# Epoch(82) - Fold 2 - Validation Loss : 0.9228
# Epoch(82) - Fold 3 - Validation Loss : 0.9413
# Epoch(82) - Fold 4 - Validation Loss : 0.8701
# Epoch(82) - GLOBAL - Validation Loss: 1.0977
# Intermediate early stopping : vepoch_loss = 1.0977, the_last_loss=1.0842
# Meet Early stopping!
# Training summary:
# {'Loss': 1.0841884033076075, 'Loss folds': [1.5058213054558478, 1.248467895061566, 0.9228299488247185, 0.9413162146004086, 0.8701007496570252], 'Loss_std': 0.24336425365204215}
# Training ended

# %%
df[FEATURES_LIST_TOTRAIN].mean().mean()
# Out:
# 0.3105054402961592

# %%
1.08 / df[FEATURES_LIST_TOTRAIN].mean().mean()
# Out:
# 3.4781999277368514

# %%
#ts_train.mean(axis=0)

# %%
#loss_fn(ts_train[0:5, :], model_AE(ts_train[0:5, :]))

# %%
#model_AE(ts_train[0:5, :])[0, 5]

# %%
#ts_train[0, 5]

# %%
#loss_fn(ts_train[50, 5], model_AE(ts_train[:, :])[50, 5])

# %% [markdown]
# # Training main model

# %%
print('Training started')
patience=5

utility_scores = [None] * 5
accuracy_scores = [None] * 5

writer = SummaryWriter()

ts_train = torch.tensor(df.loc[folds_list_train2_unique, FEATURES_LIST_TOTRAIN].to_numpy(), device='cuda')
ts_train_y = torch.tensor((df.loc[folds_list_train2_unique, 'resp'] > 0).astype(np.byte).to_numpy(), device='cuda')

# Normalize data
ts_train_mean = torch.mean(ts_train, axis=0)
ts_train_std = torch.std(ts_train, axis=0)
#ts_train = pyStandardScale(ts_train, ts_train_mean, ts_train_std)

train_dataset = torch.utils.data.TensorDataset(ts_train, ts_train_y)
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True) # pin_memory : VOIR RESULTAT

ts_test = [None] * 5
ts_test_y = [None] * 5    
test_dataset = [None] * 5
test_loader = [None] * 5

for fold_indice in range(5):
    ts_test[fold_indice] = torch.tensor(df.loc[folds_list_test[fold_indice], FEATURES_LIST_TOTRAIN].to_numpy(), device='cuda')
    ts_test_y[fold_indice] = torch.tensor((df.loc[folds_list_test[fold_indice], 'resp'] > 0).astype(np.byte).to_numpy(), device='cuda')

    # Normalize
    #ts_test[fold_indice] = pyStandardScale(ts_test[fold_indice], ts_train_mean, ts_train_std)
    
    test_dataset[fold_indice] = torch.utils.data.TensorDataset(ts_test[fold_indice], ts_test_y[fold_indice])
    test_loader[fold_indice] = torch.utils.data.DataLoader(test_dataset[fold_indice], batch_size=BATCH_SIZE)

torch.manual_seed(seed)
    
class MLP(nn.Module):
    def __init__(self, AEncoder):
    #def __init__(self):
        super(MLP,self).__init__()
        
        self.AEncoder = AEncoder
        
        #self.layer1 = nn.Linear(len(FEATURES_LIST_TOTRAIN) + self.AEncoder.decoder[0].in_features, 200)
        self.layer1 = nn.Linear(len(FEATURES_LIST_TOTRAIN) * 2, 200) # <= % near 0 élevé
        self.act1 = nn.ReLU()
        self.dropout1 = nn.Dropout(0.7)

        self.layer2 = nn.Linear(200, 100)
        self.act2 = nn.ReLU()
        self.dropout2 = nn.Dropout(0.7)
        
        self.layer3 = nn.Linear(100, 1)
        self.act3 = nn.Sigmoid()
        
    def encoder(self, x):
        self.AEncoder.eval()
        
        encoded = self.AEncoder.encoder(x)
        
        return encoded
    
    def encoder_decoder(self, x):
        self.AEncoder.eval()
        
        encoded_decoded = self.AEncoder(x)
        
        return encoded_decoded
    
    def forward(self,x):
        #x_encoded = self.encoder(x)
        x_decoded = self.encoder_decoder(x)
        
        #x = torch.cat((x, x_encoded), dim=1)
        x = torch.cat((x, x_decoded), dim=1)
        
        x = self.dropout1(self.act1(self.layer1(x)))
        x = self.dropout2(self.act2(self.layer2(x)))
        
        x = self.act3(self.layer3(x))
        
        return x        

#model = MLP(model_AE)
model = MLP(model_AE).double().to('cuda')

'''
model = nn.Sequential(
        #nn.Dropout(0.2),
        nn.Linear(len(FEATURES_LIST_TOTRAIN), 200),
        #nn.BatchNorm1d(130),
        nn.ReLU(),
        nn.Dropout(0.7),

        nn.Linear(200, 100),
        #nn.BatchNorm1d(130),
        nn.ReLU(),
        nn.Dropout(0.7),
    
        nn.Linear(100, 1),
        nn.Sigmoid(),
    ).double().to('cuda')
'''
   
print('Number of model parameters :')
numel_list = [p.numel() for p in model.parameters()]
sum(numel_list), numel_list

loss_fn = nn.BCELoss().to('cuda')
#optimizer = torch.optim.Adam(model.parameters(), lr=1e-3) 
optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE, weight_decay=WEIGHT_DECAY) 

scheduler = None
#scheduler = torch.optim.lr_scheduler.OneCycleLR(optimizer=optimizer, pct_start=0.1, div_factor=1e3,
#                                                         max_lr=1e-4, epochs=NUM_EPOCHS, steps_per_epoch=len(train_loader))

model.eval()
#start_accuracy = accuracy_score(ts_test_y.cpu().numpy(), (model(ts_test).squeeze() > 0.5).cpu().numpy())
#start_utility_score = utility_function(df.loc[test_index], (model(ts_test).squeeze() > 0.5).cpu().numpy())
#print('Start Validation Accuracy: {:.4f}'.format(start_accuracy))
#print('Start Validation Utility: {:.4f}'.format(start_utility_score))


Val_Loss = 0
N_Samples = 0

the_last_loss = 100
the_last_utility_score = 0
the_last_accuracy = 0
trigger_times=0
early_stopping_met = False

for epoch in range(NUM_EPOCHS): 
    running_loss = 0.0        
    
    ### Call back to save activation stats (mean, std dev and near 0 values after activation functions)
    # Setting hook for activation layers stats

    hook_handles = []
    save_output_activation_stats = []

    for layer in model.modules():
        if ('activation' in str(type(layer))):
            save_output_activation_stats_1layer = SaveOutputActivationStats()
            handle = layer.register_forward_hook(save_output_activation_stats_1layer)
            save_output_activation_stats.append(save_output_activation_stats_1layer)
            hook_handles.append(handle)    
            
    model.train()

    for batch in train_loader:
        #inputs, labels = batch[0], batch[1]
        inputs, labels = batch[0].to('cuda'), batch[1].to('cuda')
        optimizer.zero_grad()

        with torch.set_grad_enabled(True):
            outputs = model(inputs)
            loss = loss_fn(outputs, labels.unsqueeze(-1).double())
            loss.backward()
            optimizer.step()
            
            if scheduler:
                scheduler.step()

    # update local train loss
        running_loss += loss.item() * inputs.size(0)

    # update global train loss
    epoch_loss = running_loss / len(train_loader.dataset)
    print('Epoch({}) - Training Loss: {:.4f}'.format(epoch, epoch_loss))

    writer.add_scalar(f"Global train/loss", epoch_loss, epoch)

    # Write activation stats graphs
    for layer_number,save_output_activation_stats_layer in enumerate(save_output_activation_stats):
        df_stats_layer = pd.DataFrame(save_output_activation_stats_layer.outputs)
        
        if ((df_stats_layer.shape[0] == 0) and (df_stats_layer.shape[1] == 0)):
            print(f'Activation stats: No data returned for stats at layer {layer_number}')

        else:
            fig, ax = plt.subplots(1, 3, figsize=(25, 4))

            ax[0].set_title(f'Layer {layer_number} : Mean activation value', fontsize=16)
            ax[0].set_xlabel('Batch instances')
            ax[0].set_ylabel('Mean')
            ax[0].plot(range(df_stats_layer.shape[0]), df_stats_layer['mean'])

            ax[1].set_title(f'Layer {layer_number} : Std deviation activation value', fontsize=16)
            ax[1].set_xlabel('Batch instances')
            ax[1].set_ylabel('Standard deviation')
            ax[1].plot(range(df_stats_layer.shape[0]), df_stats_layer['std'])

            ax[2].set_title(f'Layer {layer_number} : Percentage of activation values near zero', fontsize=16)
            ax[2].set_xlabel('Batch instances')
            ax[2].set_ylabel('Percentage')
            ax[2].plot(range(df_stats_layer.shape[0]), df_stats_layer['near_zero']);

            plot_buf = io.BytesIO()
            plt.savefig(plot_buf, format='jpeg')
            plt.close()

            plot_buf.seek(0)
            image = PIL.Image.open(plot_buf)
            image = transforms.ToTensor()(image)
            writer.add_image("Train activation stats/Activation stats layer " + str(layer_number), image, epoch)
    
    # Validation 
    model.eval()

    vrunning_loss = [None] * 5
    num_samples = [None] * 5
    vepoch_loss_folds = [None] * 5
    vepoch_accuracy_folds = [None] * 5
    vepoch_utility_score_folds = [None] * 5
    
    for fold_indice in range(5):    
        vrunning_loss[fold_indice] = 0.0
        num_samples[fold_indice] = 0

        for batch in test_loader[fold_indice]:
            inputs, labels = batch[0].to('cuda'), batch[1].to('cuda')

            optimizer.zero_grad()
            with torch.no_grad():
                outputs = model(inputs)
                loss = loss_fn(outputs, labels.unsqueeze(-1).double())

            vrunning_loss[fold_indice] += loss.item() * inputs.size(0)
            num_samples[fold_indice] += labels.size(0)
            
            vepoch_loss_folds[fold_indice] = vrunning_loss[fold_indice] / num_samples[fold_indice]

        print('Epoch({}) - Fold {} - Validation Loss : {:.4f}'.format(epoch, fold_indice, vepoch_loss_folds[fold_indice]))

        model.eval()
        with torch.no_grad():
            vepoch_accuracy_folds[fold_indice] = accuracy_score(ts_test_y[fold_indice].cpu().numpy(), (model(ts_test[fold_indice]).squeeze() > 0.5).cpu().numpy())
            vepoch_utility_score_folds[fold_indice] = utility_function(df.loc[folds_list_test[fold_indice]], (model(ts_test[fold_indice]).squeeze() > 0.5).cpu().numpy())
        print('Epoch({}) - Fold {} - Validation Accuracy : {:.4f}'.format(epoch, fold_indice, vepoch_accuracy_folds[fold_indice]))
        print('Epoch({}) - Fold {} - Validation Utility score : {:.4f}'.format(epoch, fold_indice, vepoch_utility_score_folds[fold_indice]))
        
            
    # update epoch loss
    vepoch_loss = sum(vepoch_loss_folds) / len(vepoch_loss_folds)
    vepoch_accuracy = sum(vepoch_accuracy_folds) / len(vepoch_accuracy_folds)
    vepoch_utility_score = sum(vepoch_utility_score_folds) #/ len(vepoch_utility_score_folds)
    print('Epoch({}) - GLOBAL - Validation Loss: {:.4f}'.format(epoch, vepoch_loss))
    print('Epoch({}) - GLOBAL - Validation Accuracy: {:.4f}'.format(epoch, vepoch_accuracy))
    print('Epoch({}) - GLOBAL - Validation Utility score: {:.4f}'.format(epoch, vepoch_utility_score))

    #print(f'Sum of model parameters ({epoch}):')
    #[print(p.sum()) for p in model.parameters()]

    writer.add_scalar("Global valid/Loss", vepoch_loss, epoch)
    writer.add_scalar("Global valid/Accuracy", vepoch_accuracy, epoch)
    writer.add_scalar("Global valid/Utility", vepoch_utility_score, epoch)

    for fold_indice in range(5):
        writer.add_scalar("Fold valid Loss/Loss fold "+str(fold_indice), vepoch_loss_folds[fold_indice], epoch)
        writer.add_scalar("Fold valid Accuracy/Accuracy fold "+str(fold_indice), vepoch_accuracy_folds[fold_indice], epoch)
        writer.add_scalar("Fold valid Utility/Utility fold "+str(fold_indice), vepoch_utility_score_folds[fold_indice], epoch)
        
    
    writer.flush()

    # Check if Early Stopping
    #if vepoch_loss > the_last_loss:
    #if (vepoch_utility_score < the_last_utility_score) and (vepoch_loss > the_last_loss) and (vepoch_accuracy < the_last_accuracy):
    
    if (vepoch_loss > the_last_loss):
        if (EARLY_STOPPING == True):
            trigger_times += 1

            print(f'Intermediate early stopping : vepoch_loss = {vepoch_loss:.4f}, the_last_loss={the_last_loss:.4f}')
            #print(f'Intermediate early stopping : vepoch_accuracy = {vepoch_accuracy:.4f}, the_last_utility_score={the_last_accuracy:.4f}')
            #print(f'Intermediate early stopping : vepoch_utility_score = {vepoch_utility_score:.4f}, the_last_utility_score={the_last_utility_score:.4f}')

            if trigger_times >= patience:
                print('Meet Early stopping!')
                early_stopping_met = True
                ##torch.save(model.state_dict(), f'model_{fold}.pt')
                break
    else:
        trigger_times = 0
        the_last_loss = vepoch_loss
        the_last_utility_score = vepoch_utility_score
        the_last_accuracy = vepoch_accuracy
        
        the_last_utility_score_folds = vepoch_utility_score_folds
        the_last_accuracy_folds = vepoch_accuracy_folds
        
        the_best_epoch = epoch

        # Save model for the best version so far
        print(f'Saving model corresponding to last_utility_score == {the_last_utility_score}')
        torch.save(model.state_dict(), MODEL_FILE)

    print('\n')

if (early_stopping_met == False):
    print("Didn't meet early stopping : saving final model")
    # Save model if don't meet early stopping
    torch.save(model.state_dict(), MODEL_FILE)

#utility_scores.append(the_last_utility_score)
#accuracy_scores.append(the_last_accuracy)
writer.add_text(f"Global valid/Utility", f"Best utility: {the_last_utility_score}", the_best_epoch)
        
scores_results = {'utility_score': the_last_utility_score, 'utility_scores': the_last_utility_score_folds, 'utility_score_std': np.std(the_last_utility_score_folds), 'accuracy_scores': the_last_accuracy_folds}

writer.add_text('Final utility score', str(scores_results))
writer.add_text('Batch size', str(BATCH_SIZE))
writer.add_text('Patience', str(patience))
writer.add_text('Number of epochs', str(NUM_EPOCHS))
writer.add_text('Best epoch', str(the_best_epoch))
writer.add_text('Number of parameters per layer', str([p.numel() for p in model.parameters()]))
writer.add_text('Model architecture', str(model).replace('\n', '<BR>'))
writer.add_text('Comment', MODEL_COMMENT)

writer.close()

print('Training summary:')
print(scores_results)
# Out:
# Training started
# Number of model parameters :
# Epoch(0) - Training Loss: 0.7025
# Epoch(0) - Fold 0 - Validation Loss : 0.6930
# Epoch(0) - Fold 0 - Validation Accuracy : 0.5049
# Epoch(0) - Fold 0 - Validation Utility score : -0.0000
# Epoch(0) - Fold 1 - Validation Loss : 0.6927
# Epoch(0) - Fold 1 - Validation Accuracy : 0.5092
# Epoch(0) - Fold 1 - Validation Utility score : -0.0000
# Epoch(0) - Fold 2 - Validation Loss : 0.6933
# Epoch(0) - Fold 2 - Validation Accuracy : 0.5025
# Epoch(0) - Fold 2 - Validation Utility score : -0.0000
# Epoch(0) - Fold 3 - Validation Loss : 0.6934
# Epoch(0) - Fold 3 - Validation Accuracy : 0.5012
# Epoch(0) - Fold 3 - Validation Utility score : -0.0000
# Epoch(0) - Fold 4 - Validation Loss : 0.6933
# Epoch(0) - Fold 4 - Validation Accuracy : 0.5006
# Epoch(0) - Fold 4 - Validation Utility score : 48.2034
# Epoch(0) - GLOBAL - Validation Loss: 0.6931
# Epoch(0) - GLOBAL - Validation Accuracy: 0.5037
# Epoch(0) - GLOBAL - Validation Utility score: 48.2034
# Saving model corresponding to last_utility_score == 48.20339646996944
#
#
# Epoch(1) - Training Loss: 0.6935
# Epoch(1) - Fold 0 - Validation Loss : 0.6926
# Epoch(1) - Fold 0 - Validation Accuracy : 0.5134
# Epoch(1) - Fold 0 - Validation Utility score : 10.1482
# Epoch(1) - Fold 1 - Validation Loss : 0.6925
# Epoch(1) - Fold 1 - Validation Accuracy : 0.5132
# Epoch(1) - Fold 1 - Validation Utility score : 8.0105
# Epoch(1) - Fold 2 - Validation Loss : 0.6932
# Epoch(1) - Fold 2 - Validation Accuracy : 0.5005
# Epoch(1) - Fold 2 - Validation Utility score : -0.0000
# Epoch(1) - Fold 3 - Validation Loss : 0.6932
# Epoch(1) - Fold 3 - Validation Accuracy : 0.5051
# Epoch(1) - Fold 3 - Validation Utility score : -0.0000
# Epoch(1) - Fold 4 - Validation Loss : 0.6929
# Epoch(1) - Fold 4 - Validation Accuracy : 0.5058
# Epoch(1) - Fold 4 - Validation Utility score : 238.3270
# Epoch(1) - GLOBAL - Validation Loss: 0.6929
# Epoch(1) - GLOBAL - Validation Accuracy: 0.5076
# Epoch(1) - GLOBAL - Validation Utility score: 256.4857
# Saving model corresponding to last_utility_score == 256.4857075569598
#
#
# Epoch(2) - Training Loss: 0.6929
# Epoch(2) - Fold 0 - Validation Loss : 0.6922
# Epoch(2) - Fold 0 - Validation Accuracy : 0.5191
# Epoch(2) - Fold 0 - Validation Utility score : 17.9707
# Epoch(2) - Fold 1 - Validation Loss : 0.6922
# Epoch(2) - Fold 1 - Validation Accuracy : 0.5193
# Epoch(2) - Fold 1 - Validation Utility score : 91.3668
# Epoch(2) - Fold 2 - Validation Loss : 0.6931
# Epoch(2) - Fold 2 - Validation Accuracy : 0.5024
# Epoch(2) - Fold 2 - Validation Utility score : -0.0000
# Epoch(2) - Fold 3 - Validation Loss : 0.6930
# Epoch(2) - Fold 3 - Validation Accuracy : 0.5075
# Epoch(2) - Fold 3 - Validation Utility score : -0.0000
# Epoch(2) - Fold 4 - Validation Loss : 0.6926
# Epoch(2) - Fold 4 - Validation Accuracy : 0.5105
# Epoch(2) - Fold 4 - Validation Utility score : 510.1156
# Epoch(2) - GLOBAL - Validation Loss: 0.6926
# Epoch(2) - GLOBAL - Validation Accuracy: 0.5118
# Epoch(2) - GLOBAL - Validation Utility score: 619.4532
# Saving model corresponding to last_utility_score == 619.4531811931919
#
#
# Epoch(3) - Training Loss: 0.6925
# Epoch(3) - Fold 0 - Validation Loss : 0.6918
# Epoch(3) - Fold 0 - Validation Accuracy : 0.5225
# Epoch(3) - Fold 0 - Validation Utility score : 56.2991
# Epoch(3) - Fold 1 - Validation Loss : 0.6919
# Epoch(3) - Fold 1 - Validation Accuracy : 0.5212
# Epoch(3) - Fold 1 - Validation Utility score : 179.5734
# Epoch(3) - Fold 2 - Validation Loss : 0.6930
# Epoch(3) - Fold 2 - Validation Accuracy : 0.5046
# Epoch(3) - Fold 2 - Validation Utility score : -0.0000
# Epoch(3) - Fold 3 - Validation Loss : 0.6930
# Epoch(3) - Fold 3 - Validation Accuracy : 0.5071
# Epoch(3) - Fold 3 - Validation Utility score : -0.0000
# Epoch(3) - Fold 4 - Validation Loss : 0.6922
# Epoch(3) - Fold 4 - Validation Accuracy : 0.5129
# Epoch(3) - Fold 4 - Validation Utility score : 667.6057
# Epoch(3) - GLOBAL - Validation Loss: 0.6924
# Epoch(3) - GLOBAL - Validation Accuracy: 0.5137
# Epoch(3) - GLOBAL - Validation Utility score: 903.4782
# Saving model corresponding to last_utility_score == 903.4782476117625
#
#
# Epoch(4) - Training Loss: 0.6922
# Epoch(4) - Fold 0 - Validation Loss : 0.6916
# Epoch(4) - Fold 0 - Validation Accuracy : 0.5231
# Epoch(4) - Fold 0 - Validation Utility score : 107.1317
# Epoch(4) - Fold 1 - Validation Loss : 0.6918
# Epoch(4) - Fold 1 - Validation Accuracy : 0.5205
# Epoch(4) - Fold 1 - Validation Utility score : 168.8467
# Epoch(4) - Fold 2 - Validation Loss : 0.6931
# Epoch(4) - Fold 2 - Validation Accuracy : 0.5040
# Epoch(4) - Fold 2 - Validation Utility score : -0.0000
# Epoch(4) - Fold 3 - Validation Loss : 0.6929
# Epoch(4) - Fold 3 - Validation Accuracy : 0.5084
# Epoch(4) - Fold 3 - Validation Utility score : -0.0000
# Epoch(4) - Fold 4 - Validation Loss : 0.6920
# Epoch(4) - Fold 4 - Validation Accuracy : 0.5138
# Epoch(4) - Fold 4 - Validation Utility score : 764.2174
# Epoch(4) - GLOBAL - Validation Loss: 0.6923
# Epoch(4) - GLOBAL - Validation Accuracy: 0.5140
# Epoch(4) - GLOBAL - Validation Utility score: 1040.1957
# Saving model corresponding to last_utility_score == 1040.1957409884726
#
#
# Epoch(5) - Training Loss: 0.6920
# Epoch(5) - Fold 0 - Validation Loss : 0.6915
# Epoch(5) - Fold 0 - Validation Accuracy : 0.5238
# Epoch(5) - Fold 0 - Validation Utility score : 93.8094
# Epoch(5) - Fold 1 - Validation Loss : 0.6916
# Epoch(5) - Fold 1 - Validation Accuracy : 0.5212
# Epoch(5) - Fold 1 - Validation Utility score : 315.9102
# Epoch(5) - Fold 2 - Validation Loss : 0.6930
# Epoch(5) - Fold 2 - Validation Accuracy : 0.5054
# Epoch(5) - Fold 2 - Validation Utility score : -0.0000
# Epoch(5) - Fold 3 - Validation Loss : 0.6928
# Epoch(5) - Fold 3 - Validation Accuracy : 0.5081
# Epoch(5) - Fold 3 - Validation Utility score : -0.0000
# Epoch(5) - Fold 4 - Validation Loss : 0.6917
# Epoch(5) - Fold 4 - Validation Accuracy : 0.5157
# Epoch(5) - Fold 4 - Validation Utility score : 913.9429
# Epoch(5) - GLOBAL - Validation Loss: 0.6921
# Epoch(5) - GLOBAL - Validation Accuracy: 0.5148
# Epoch(5) - GLOBAL - Validation Utility score: 1323.6624
# Saving model corresponding to last_utility_score == 1323.6624387516833
#
#
# Epoch(6) - Training Loss: 0.6918
# Epoch(6) - Fold 0 - Validation Loss : 0.6913
# Epoch(6) - Fold 0 - Validation Accuracy : 0.5247
# Epoch(6) - Fold 0 - Validation Utility score : 200.2484
# Epoch(6) - Fold 1 - Validation Loss : 0.6914
# Epoch(6) - Fold 1 - Validation Accuracy : 0.5219
# Epoch(6) - Fold 1 - Validation Utility score : 299.6783
# Epoch(6) - Fold 2 - Validation Loss : 0.6931
# Epoch(6) - Fold 2 - Validation Accuracy : 0.5053
# Epoch(6) - Fold 2 - Validation Utility score : -0.0000
# Epoch(6) - Fold 3 - Validation Loss : 0.6928
# Epoch(6) - Fold 3 - Validation Accuracy : 0.5083
# Epoch(6) - Fold 3 - Validation Utility score : -0.0000
# Epoch(6) - Fold 4 - Validation Loss : 0.6915
# Epoch(6) - Fold 4 - Validation Accuracy : 0.5155
# Epoch(6) - Fold 4 - Validation Utility score : 958.8728
# Epoch(6) - GLOBAL - Validation Loss: 0.6920
# Epoch(6) - GLOBAL - Validation Accuracy: 0.5151
# Epoch(6) - GLOBAL - Validation Utility score: 1458.7995
# Saving model corresponding to last_utility_score == 1458.79952824105
#
#
# Epoch(7) - Training Loss: 0.6916
# Epoch(7) - Fold 0 - Validation Loss : 0.6914
# Epoch(7) - Fold 0 - Validation Accuracy : 0.5225
# Epoch(7) - Fold 0 - Validation Utility score : 127.4590
# Epoch(7) - Fold 1 - Validation Loss : 0.6914
# Epoch(7) - Fold 1 - Validation Accuracy : 0.5212
# Epoch(7) - Fold 1 - Validation Utility score : 217.6458
# Epoch(7) - Fold 2 - Validation Loss : 0.6931
# Epoch(7) - Fold 2 - Validation Accuracy : 0.5051
# Epoch(7) - Fold 2 - Validation Utility score : -0.0000
# Epoch(7) - Fold 3 - Validation Loss : 0.6928
# Epoch(7) - Fold 3 - Validation Accuracy : 0.5071
# Epoch(7) - Fold 3 - Validation Utility score : -0.0000
# Epoch(7) - Fold 4 - Validation Loss : 0.6915
# Epoch(7) - Fold 4 - Validation Accuracy : 0.5155
# Epoch(7) - Fold 4 - Validation Utility score : 905.3651
# Epoch(7) - GLOBAL - Validation Loss: 0.6921
# Epoch(7) - GLOBAL - Validation Accuracy: 0.5143
# Epoch(7) - GLOBAL - Validation Utility score: 1250.4699
# Intermediate early stopping : vepoch_loss = 0.6921, the_last_loss=0.6920
#
#
# Epoch(8) - Training Loss: 0.6914
# Epoch(8) - Fold 0 - Validation Loss : 0.6913
# Epoch(8) - Fold 0 - Validation Accuracy : 0.5236
# Epoch(8) - Fold 0 - Validation Utility score : 202.4573
# Epoch(8) - Fold 1 - Validation Loss : 0.6913
# Epoch(8) - Fold 1 - Validation Accuracy : 0.5225
# Epoch(8) - Fold 1 - Validation Utility score : 288.2248
# Epoch(8) - Fold 2 - Validation Loss : 0.6931
# Epoch(8) - Fold 2 - Validation Accuracy : 0.5060
# Epoch(8) - Fold 2 - Validation Utility score : -0.0000
# Epoch(8) - Fold 3 - Validation Loss : 0.6928
# Epoch(8) - Fold 3 - Validation Accuracy : 0.5073
# Epoch(8) - Fold 3 - Validation Utility score : -0.0000
# Epoch(8) - Fold 4 - Validation Loss : 0.6914
# Epoch(8) - Fold 4 - Validation Accuracy : 0.5166
# Epoch(8) - Fold 4 - Validation Utility score : 961.1244
# Epoch(8) - GLOBAL - Validation Loss: 0.6920
# Epoch(8) - GLOBAL - Validation Accuracy: 0.5152
# Epoch(8) - GLOBAL - Validation Utility score: 1451.8066
# Saving model corresponding to last_utility_score == 1451.806554047246
#
#
# Epoch(9) - Training Loss: 0.6913
# Epoch(9) - Fold 0 - Validation Loss : 0.6913
# Epoch(9) - Fold 0 - Validation Accuracy : 0.5233
# Epoch(9) - Fold 0 - Validation Utility score : 156.8141
# Epoch(9) - Fold 1 - Validation Loss : 0.6913
# Epoch(9) - Fold 1 - Validation Accuracy : 0.5222
# Epoch(9) - Fold 1 - Validation Utility score : 288.2529
# Epoch(9) - Fold 2 - Validation Loss : 0.6931
# Epoch(9) - Fold 2 - Validation Accuracy : 0.5057
# Epoch(9) - Fold 2 - Validation Utility score : -0.0000
# Epoch(9) - Fold 3 - Validation Loss : 0.6928
# Epoch(9) - Fold 3 - Validation Accuracy : 0.5074
# Epoch(9) - Fold 3 - Validation Utility score : -0.0000
# Epoch(9) - Fold 4 - Validation Loss : 0.6913
# Epoch(9) - Fold 4 - Validation Accuracy : 0.5161
# Epoch(9) - Fold 4 - Validation Utility score : 980.5843
# Epoch(9) - GLOBAL - Validation Loss: 0.6920
# Epoch(9) - GLOBAL - Validation Accuracy: 0.5149
# Epoch(9) - GLOBAL - Validation Utility score: 1425.6513
# Saving model corresponding to last_utility_score == 1425.6512835101607
#
#
# Epoch(10) - Training Loss: 0.6911
# Epoch(10) - Fold 0 - Validation Loss : 0.6912
# Epoch(10) - Fold 0 - Validation Accuracy : 0.5236
# Epoch(10) - Fold 0 - Validation Utility score : 186.6439
# Epoch(10) - Fold 1 - Validation Loss : 0.6911
# Epoch(10) - Fold 1 - Validation Accuracy : 0.5230
# Epoch(10) - Fold 1 - Validation Utility score : 410.4006
# Epoch(10) - Fold 2 - Validation Loss : 0.6932
# Epoch(10) - Fold 2 - Validation Accuracy : 0.5076
# Epoch(10) - Fold 2 - Validation Utility score : -0.0000
# Epoch(10) - Fold 3 - Validation Loss : 0.6928
# Epoch(10) - Fold 3 - Validation Accuracy : 0.5091
# Epoch(10) - Fold 3 - Validation Utility score : -0.0000
# Epoch(10) - Fold 4 - Validation Loss : 0.6910
# Epoch(10) - Fold 4 - Validation Accuracy : 0.5182
# Epoch(10) - Fold 4 - Validation Utility score : 1232.1260
# Epoch(10) - GLOBAL - Validation Loss: 0.6919
# Epoch(10) - GLOBAL - Validation Accuracy: 0.5163
# Epoch(10) - GLOBAL - Validation Utility score: 1829.1704
# Saving model corresponding to last_utility_score == 1829.1704386118777
#
#
# Epoch(11) - Training Loss: 0.6909
# Epoch(11) - Fold 0 - Validation Loss : 0.6912
# Epoch(11) - Fold 0 - Validation Accuracy : 0.5240
# Epoch(11) - Fold 0 - Validation Utility score : 214.8580
# Epoch(11) - Fold 1 - Validation Loss : 0.6911
# Epoch(11) - Fold 1 - Validation Accuracy : 0.5218
# Epoch(11) - Fold 1 - Validation Utility score : 340.8408
# Epoch(11) - Fold 2 - Validation Loss : 0.6931
# Epoch(11) - Fold 2 - Validation Accuracy : 0.5080
# Epoch(11) - Fold 2 - Validation Utility score : -0.0000
# Epoch(11) - Fold 3 - Validation Loss : 0.6928
# Epoch(11) - Fold 3 - Validation Accuracy : 0.5083
# Epoch(11) - Fold 3 - Validation Utility score : -0.0000
# Epoch(11) - Fold 4 - Validation Loss : 0.6911
# Epoch(11) - Fold 4 - Validation Accuracy : 0.5178
# Epoch(11) - Fold 4 - Validation Utility score : 1171.8279
# Epoch(11) - GLOBAL - Validation Loss: 0.6919
# Epoch(11) - GLOBAL - Validation Accuracy: 0.5160
# Epoch(11) - GLOBAL - Validation Utility score: 1727.5267
# Intermediate early stopping : vepoch_loss = 0.6919, the_last_loss=0.6919
#
#
# Epoch(12) - Training Loss: 0.6908
# Epoch(12) - Fold 0 - Validation Loss : 0.6913
# Epoch(12) - Fold 0 - Validation Accuracy : 0.5230
# Epoch(12) - Fold 0 - Validation Utility score : 196.0110
# Epoch(12) - Fold 1 - Validation Loss : 0.6911
# Epoch(12) - Fold 1 - Validation Accuracy : 0.5217
# Epoch(12) - Fold 1 - Validation Utility score : 386.9280
# Epoch(12) - Fold 2 - Validation Loss : 0.6931
# Epoch(12) - Fold 2 - Validation Accuracy : 0.5088
# Epoch(12) - Fold 2 - Validation Utility score : -0.0000
# Epoch(12) - Fold 3 - Validation Loss : 0.6928
# Epoch(12) - Fold 3 - Validation Accuracy : 0.5080
# Epoch(12) - Fold 3 - Validation Utility score : -0.0000
# Epoch(12) - Fold 4 - Validation Loss : 0.6911
# Epoch(12) - Fold 4 - Validation Accuracy : 0.5188
# Epoch(12) - Fold 4 - Validation Utility score : 1169.0142
# Epoch(12) - GLOBAL - Validation Loss: 0.6919
# Epoch(12) - GLOBAL - Validation Accuracy: 0.5161
# Epoch(12) - GLOBAL - Validation Utility score: 1751.9533
# Intermediate early stopping : vepoch_loss = 0.6919, the_last_loss=0.6919
#
#
# Epoch(13) - Training Loss: 0.6906
# Epoch(13) - Fold 0 - Validation Loss : 0.6912
# Epoch(13) - Fold 0 - Validation Accuracy : 0.5238
# Epoch(13) - Fold 0 - Validation Utility score : 245.1481
# Epoch(13) - Fold 1 - Validation Loss : 0.6910
# Epoch(13) - Fold 1 - Validation Accuracy : 0.5227
# Epoch(13) - Fold 1 - Validation Utility score : 487.2666
# Epoch(13) - Fold 2 - Validation Loss : 0.6933
# Epoch(13) - Fold 2 - Validation Accuracy : 0.5087
# Epoch(13) - Fold 2 - Validation Utility score : -0.0000
# Epoch(13) - Fold 3 - Validation Loss : 0.6929
# Epoch(13) - Fold 3 - Validation Accuracy : 0.5091
# Epoch(13) - Fold 3 - Validation Utility score : -0.0000
# Epoch(13) - Fold 4 - Validation Loss : 0.6909
# Epoch(13) - Fold 4 - Validation Accuracy : 0.5184
# Epoch(13) - Fold 4 - Validation Utility score : 1192.5214
# Epoch(13) - GLOBAL - Validation Loss: 0.6919
# Epoch(13) - GLOBAL - Validation Accuracy: 0.5166
# Epoch(13) - GLOBAL - Validation Utility score: 1924.9360
# Intermediate early stopping : vepoch_loss = 0.6919, the_last_loss=0.6919
#
#
# Epoch(14) - Training Loss: 0.6905
# Epoch(14) - Fold 0 - Validation Loss : 0.6913
# Epoch(14) - Fold 0 - Validation Accuracy : 0.5255
# Epoch(14) - Fold 0 - Validation Utility score : 289.3971
# Epoch(14) - Fold 1 - Validation Loss : 0.6909
# Epoch(14) - Fold 1 - Validation Accuracy : 0.5224
# Epoch(14) - Fold 1 - Validation Utility score : 584.1133
# Epoch(14) - Fold 2 - Validation Loss : 0.6934
# Epoch(14) - Fold 2 - Validation Accuracy : 0.5097
# Epoch(14) - Fold 2 - Validation Utility score : -0.0000
# Epoch(14) - Fold 3 - Validation Loss : 0.6928
# Epoch(14) - Fold 3 - Validation Accuracy : 0.5104
# Epoch(14) - Fold 3 - Validation Utility score : -0.0000
# Epoch(14) - Fold 4 - Validation Loss : 0.6908
# Epoch(14) - Fold 4 - Validation Accuracy : 0.5213
# Epoch(14) - Fold 4 - Validation Utility score : 1517.5980
# Epoch(14) - GLOBAL - Validation Loss: 0.6918
# Epoch(14) - GLOBAL - Validation Accuracy: 0.5179
# Epoch(14) - GLOBAL - Validation Utility score: 2391.1084
# Saving model corresponding to last_utility_score == 2391.108390490101
#
#
# Epoch(15) - Training Loss: 0.6903
# Epoch(15) - Fold 0 - Validation Loss : 0.6914
# Epoch(15) - Fold 0 - Validation Accuracy : 0.5249
# Epoch(15) - Fold 0 - Validation Utility score : 338.6173
# Epoch(15) - Fold 1 - Validation Loss : 0.6910
# Epoch(15) - Fold 1 - Validation Accuracy : 0.5228
# Epoch(15) - Fold 1 - Validation Utility score : 532.0923
# Epoch(15) - Fold 2 - Validation Loss : 0.6935
# Epoch(15) - Fold 2 - Validation Accuracy : 0.5089
# Epoch(15) - Fold 2 - Validation Utility score : -0.0000
# Epoch(15) - Fold 3 - Validation Loss : 0.6928
# Epoch(15) - Fold 3 - Validation Accuracy : 0.5100
# Epoch(15) - Fold 3 - Validation Utility score : -0.0000
# Epoch(15) - Fold 4 - Validation Loss : 0.6908
# Epoch(15) - Fold 4 - Validation Accuracy : 0.5200
# Epoch(15) - Fold 4 - Validation Utility score : 1438.2090
# Epoch(15) - GLOBAL - Validation Loss: 0.6919
# Epoch(15) - GLOBAL - Validation Accuracy: 0.5173
# Epoch(15) - GLOBAL - Validation Utility score: 2308.9186
# Intermediate early stopping : vepoch_loss = 0.6919, the_last_loss=0.6918
#
#
# Epoch(16) - Training Loss: 0.6902
# Epoch(16) - Fold 0 - Validation Loss : 0.6914
# Epoch(16) - Fold 0 - Validation Accuracy : 0.5252
# Epoch(16) - Fold 0 - Validation Utility score : 381.3719
# Epoch(16) - Fold 1 - Validation Loss : 0.6910
# Epoch(16) - Fold 1 - Validation Accuracy : 0.5223
# Epoch(16) - Fold 1 - Validation Utility score : 573.1579
# Epoch(16) - Fold 2 - Validation Loss : 0.6934
# Epoch(16) - Fold 2 - Validation Accuracy : 0.5105
# Epoch(16) - Fold 2 - Validation Utility score : -0.0000
# Epoch(16) - Fold 3 - Validation Loss : 0.6929
# Epoch(16) - Fold 3 - Validation Accuracy : 0.5116
# Epoch(16) - Fold 3 - Validation Utility score : -0.0000
# Epoch(16) - Fold 4 - Validation Loss : 0.6908
# Epoch(16) - Fold 4 - Validation Accuracy : 0.5220
# Epoch(16) - Fold 4 - Validation Utility score : 1552.2401
# Epoch(16) - GLOBAL - Validation Loss: 0.6919
# Epoch(16) - GLOBAL - Validation Accuracy: 0.5183
# Epoch(16) - GLOBAL - Validation Utility score: 2506.7699
# Intermediate early stopping : vepoch_loss = 0.6919, the_last_loss=0.6918
#
#
# Epoch(17) - Training Loss: 0.6901
# Epoch(17) - Fold 0 - Validation Loss : 0.6915
# Epoch(17) - Fold 0 - Validation Accuracy : 0.5237
# Epoch(17) - Fold 0 - Validation Utility score : 219.2148
# Epoch(17) - Fold 1 - Validation Loss : 0.6909
# Epoch(17) - Fold 1 - Validation Accuracy : 0.5224
# Epoch(17) - Fold 1 - Validation Utility score : 611.6319
# Epoch(17) - Fold 2 - Validation Loss : 0.6934
# Epoch(17) - Fold 2 - Validation Accuracy : 0.5114
# Epoch(17) - Fold 2 - Validation Utility score : -0.0000
# Epoch(17) - Fold 3 - Validation Loss : 0.6929
# Epoch(17) - Fold 3 - Validation Accuracy : 0.5108
# Epoch(17) - Fold 3 - Validation Utility score : -0.0000
# Epoch(17) - Fold 4 - Validation Loss : 0.6907
# Epoch(17) - Fold 4 - Validation Accuracy : 0.5237
# Epoch(17) - Fold 4 - Validation Utility score : 1611.3604
# Epoch(17) - GLOBAL - Validation Loss: 0.6919
# Epoch(17) - GLOBAL - Validation Accuracy: 0.5184
# Epoch(17) - GLOBAL - Validation Utility score: 2442.2071
# Intermediate early stopping : vepoch_loss = 0.6919, the_last_loss=0.6918
#
#
# Epoch(18) - Training Loss: 0.6899
# Epoch(18) - Fold 0 - Validation Loss : 0.6918
# Epoch(18) - Fold 0 - Validation Accuracy : 0.5240
# Epoch(18) - Fold 0 - Validation Utility score : 283.3550
# Epoch(18) - Fold 1 - Validation Loss : 0.6910
# Epoch(18) - Fold 1 - Validation Accuracy : 0.5225
# Epoch(18) - Fold 1 - Validation Utility score : 552.1833
# Epoch(18) - Fold 2 - Validation Loss : 0.6935
# Epoch(18) - Fold 2 - Validation Accuracy : 0.5115
# Epoch(18) - Fold 2 - Validation Utility score : -0.0000
# Epoch(18) - Fold 3 - Validation Loss : 0.6931
# Epoch(18) - Fold 3 - Validation Accuracy : 0.5094
# Epoch(18) - Fold 3 - Validation Utility score : -0.0000
# Epoch(18) - Fold 4 - Validation Loss : 0.6907
# Epoch(18) - Fold 4 - Validation Accuracy : 0.5218
# Epoch(18) - Fold 4 - Validation Utility score : 1542.7779
# Epoch(18) - GLOBAL - Validation Loss: 0.6920
# Epoch(18) - GLOBAL - Validation Accuracy: 0.5178
# Epoch(18) - GLOBAL - Validation Utility score: 2378.3162
# Intermediate early stopping : vepoch_loss = 0.6920, the_last_loss=0.6918
#
#
# Epoch(19) - Training Loss: 0.6897
# Epoch(19) - Fold 0 - Validation Loss : 0.6917
# Epoch(19) - Fold 0 - Validation Accuracy : 0.5229
# Epoch(19) - Fold 0 - Validation Utility score : 270.8452
# Epoch(19) - Fold 1 - Validation Loss : 0.6908
# Epoch(19) - Fold 1 - Validation Accuracy : 0.5221
# Epoch(19) - Fold 1 - Validation Utility score : 578.0386
# Epoch(19) - Fold 2 - Validation Loss : 0.6938
# Epoch(19) - Fold 2 - Validation Accuracy : 0.5099
# Epoch(19) - Fold 2 - Validation Utility score : -0.0000
# Epoch(19) - Fold 3 - Validation Loss : 0.6930
# Epoch(19) - Fold 3 - Validation Accuracy : 0.5115
# Epoch(19) - Fold 3 - Validation Utility score : -0.0000
# Epoch(19) - Fold 4 - Validation Loss : 0.6906
# Epoch(19) - Fold 4 - Validation Accuracy : 0.5235
# Epoch(19) - Fold 4 - Validation Utility score : 1592.7855
# Epoch(19) - GLOBAL - Validation Loss: 0.6920
# Epoch(19) - GLOBAL - Validation Accuracy: 0.5180
# Epoch(19) - GLOBAL - Validation Utility score: 2441.6693
# Intermediate early stopping : vepoch_loss = 0.6920, the_last_loss=0.6918
# Meet Early stopping!
# Training summary:
# {'utility_score': 2391.108390490101, 'utility_scores': [289.3971208298359, 584.1132905977131, -0.0, -0.0, 1517.5979790625522], 'utility_score_std': 562.9498714517656, 'accuracy_scores': [0.5255134583492792, 0.5223657423657424, 0.5097115708096752, 0.510446564241094, 0.5213269474573884]}

# %% [markdown]
# ### Note

# %% [markdown]
# Note utility score précédent :
#
# {'utility_score': 2699.3290911247423, 'utility_scores': [433.21587581983806, 842.8579165327393, -0.0, -0.0, 1423.255298772165], 'utility_score_std': 541.5654345633293, 'accuracy_scores': [0.5243157432212159, 0.5228992628992629, 0.5123754728769456, 0.5104606336878834, 0.5277785603606142]}
#
# (avec std scale)
#
#
# Training summary:
# {'utility_score': 2697.374406045479, 'utility_scores': [448.22515142892547, 938.181355255796, -0.0, -0.0, 1310.9678993607574], 'utility_score_std': 518.5674763422022, 'accuracy_scores': [0.5212753894345934, 0.5206107406107406, 0.5085924573123425, 0.5062820079914457, 0.525750105648683]}
#
#
# Essayer :
# > avec features supplémentaires
# > augmenter le dropout de la couche avec bcp de 0, ou supprimer la couche
# > bouger le weight decay : essayer 1e-5, et 1e-3
# > augmenter la taille du batch
# > label smoothing   (voir loss_fn = SmoothBCEwLogits(smoothing=0.005)  dans janestreet_kaggle....)
# > différents triggers

# %%
'''
model_load = nn.Sequential(
        #nn.Dropout(0.2),
        nn.Linear(len(FEATURES_LIST_TOTRAIN), 130),
        #nn.BatchNorm1d(130),
        nn.ReLU(),
        nn.Dropout(0.3),

        nn.Linear(130, 130),
        #nn.BatchNorm1d(130),
        nn.ReLU(),
        nn.Dropout(0.3),    

        nn.Linear(130, 130),
        #nn.BatchNorm1d(130),
        nn.ReLU(),
        nn.Dropout(0.3),    

        nn.Linear(130, 130),
        #nn.BatchNorm1d(130),
        nn.ReLU(),
        nn.Dropout(0.3),    

        nn.Linear(130, 130),
        #nn.BatchNorm1d(130),
        nn.ReLU(),
        nn.Dropout(0.3),    

        nn.Linear(130, 130),
        #nn.BatchNorm1d(130),
        nn.ReLU(),
        nn.Dropout(0.3),    
    
        nn.Linear(130, 130),
        #nn.BatchNorm1d(130),
        nn.ReLU(),
        nn.Dropout(0.3),    
    
        nn.Linear(130, 130),
        #nn.BatchNorm1d(130),
        nn.ReLU(),
        nn.Dropout(0.3),    

        nn.Linear(130, 60),
        #nn.BatchNorm1d(130),
        nn.ReLU(),
        nn.Dropout(0.3),    
    
        nn.Linear(60, 30),
        #nn.BatchNorm1d(130),
        nn.ReLU(),
        nn.Dropout(0.3),    
       
        nn.Linear(30, 1),
        nn.Sigmoid(),
    ).double().to('cuda')
    
model_load.load_state_dict(torch.load(f'model_NN_allfolds_V1.pt',map_location=torch.device('cuda')))
'''

#model_load.eval()
#print(accuracy_score(ts_test_y.cpu().numpy(), (model_load(ts_test).squeeze() > 0.5).cpu().numpy()))
#
#model_load.eval()
#print(utility_function(df.loc[test_index], (model_load(ts_test).squeeze() > 0.5).cpu().numpy()))

# %% [markdown]
# # Data for model inference

# %% [markdown]
# ## First, fill NA with :

# %%
list(f_mean)
# Out:
# [0.009838564545944745,
#  0.38557755173112973,
#  0.35768747744650975,
#  0.00891916614596665,
#  0.0041500560373424495,
#  -0.0037146189993207766,
#  -0.012589244366156346,
#  0.051776552018932685,
#  0.026828095990947754,
#  0.24881331937245502,
#  0.18234851148590248,
#  0.08912156181298928,
#  0.049485535154017296,
#  0.14310535183278583,
#  0.08902722352210106,
#  0.21167757450938102,
#  0.146300650876364,
#  0.12121931699105562,
#  0.11358210894993667,
#  0.2938148492026861,
#  0.26876788737703755,
#  0.18691131282167164,
#  0.1769785779830002,
#  0.25244128771902047,
#  0.23856075429165213,
#  0.29407078502434514,
#  0.273177703966479,
#  0.13548298050171867,
#  0.16087630644126466,
#  0.32189235718153003,
#  0.3425343272966006,
#  0.2205604165416505,
#  0.25013120792951216,
#  0.3082216783372597,
#  0.3353533199754549,
#  0.34145307300650396,
#  0.36582532760649067,
#  0.029320465264380657,
#  0.02289177995103487,
#  0.04002162079212139,
#  0.05074972651124518,
#  0.4450543980970518,
#  0.36018357114469624,
#  0.34602868865463743,
#  0.4115306048129169,
#  0.43803102237933605,
#  0.47611584684954844,
#  0.3478667314970123,
#  0.4996310121501766,
#  0.5640008775247856,
#  0.5122603244317466,
#  0.45738658177408503,
#  0.04574377016024373,
#  0.36269998611838594,
#  0.35886983636928554,
#  0.652597182609052,
#  0.8049459750150331,
#  0.6613497470714732,
#  0.679812464521779,
#  0.7625897106372482,
#  0.5563956951455176,
#  0.5581652498654769,
#  0.5455413826521486,
#  0.546778335577234,
#  0.43505876086903456,
#  0.6075653248439333,
#  0.6085039517279847,
#  0.5951947177318683,
#  0.5959424881601522,
#  0.36954104040881697,
#  0.24337091134397526,
#  0.33227354399541986,
#  0.005393298121375514,
#  -0.03286771852370292,
#  -0.00020445421701550574,
#  -0.019091946690617916,
#  -0.031898281803949866,
#  -0.07680002772370834,
#  -0.00605952373252944,
#  -0.035434597323818526,
#  -0.002099458966825259,
#  -0.014418274525843731,
#  -0.03461507559647192,
#  -0.0800853052057879,
#  0.3982158398248166,
#  0.5578243392749649,
#  0.4024042638598482,
#  0.44445105036718896,
#  0.5140947514539359,
#  0.40051646364922716,
#  0.41025294617564356,
#  0.5205121351461534,
#  0.4050807138243217,
#  0.4088298932713245,
#  0.42889387778006083,
#  0.41763183586073954,
#  0.40226847198530646,
#  0.5590945852445534,
#  0.40710700821605167,
#  0.4368573700084827,
#  0.5001226990638947,
#  0.40856460238921344,
#  0.40506301819893675,
#  0.48140573756748783,
#  0.40165573205168165,
#  0.40706131905131204,
#  0.4530453026311098,
#  0.41501192155955596,
#  0.39999263512557864,
#  0.4165405195231404,
#  0.4007356675614491,
#  0.40687807118570485,
#  0.41228491406734663,
#  0.4026373333613518,
#  0.40711205681095564,
#  0.37341742416551793,
#  0.40443262685246384,
#  0.40103337181422305,
#  0.38581705373929415,
#  0.41559987309867774,
#  0.33512703226889273,
#  0.2687757036832287,
#  0.34355231662463237,
#  0.27999728178893696,
#  0.33515369461396705,
#  0.24487524464105123,
#  0.3391777949954427,
#  0.2323808666181667,
#  0.3425608266217579,
#  0.24561818215100586]

# %% [markdown]
# ## Then, normalize with :

# %%
ts_train_mean
# Out:
# tensor([ 0.0088,  0.3957,  0.3306,  0.0092,  0.0034, -0.0050, -0.0146,  0.0553,
#          0.0251,  0.2647,  0.1671,  0.0949,  0.0445,  0.1525,  0.0800,  0.2217,
#          0.1283,  0.1218,  0.1096,  0.2977,  0.2646,  0.1881,  0.1725,  0.2547,
#          0.2327,  0.2979,  0.2685,  0.1399,  0.1629,  0.3306,  0.3439,  0.2268,
#          0.2519,  0.3164,  0.3360,  0.3528,  0.3677,  0.0265,  0.0186,  0.0432,
#          0.0530,  0.4542,  0.3776,  0.4162,  0.4393,  0.4865,  0.4921,  0.3684,
#          0.5014,  0.5438,  0.5307,  0.4567,  0.0565,  0.3890,  0.3769,  0.7755,
#          0.9247,  0.7859,  0.8085,  0.8990,  0.5534,  0.5555,  0.5592,  0.5614,
#          0.4423,  0.6188,  0.6172,  0.5977,  0.5981,  0.3774,  0.2389,  0.3080,
#          0.0041, -0.0322, -0.0016, -0.0199, -0.0316, -0.0932, -0.0081, -0.0358,
#         -0.0025, -0.0149, -0.0350, -0.1015,  0.3934,  0.5416,  0.3924,  0.4281,
#          0.4976,  0.3994,  0.4332,  0.5235,  0.4224,  0.4221,  0.4348,  0.4547,
#          0.3984,  0.5422,  0.3973,  0.4259,  0.4865,  0.4105,  0.4340,  0.4839,
#          0.4168,  0.4198,  0.4614,  0.4553,  0.3950,  0.3824,  0.3900,  0.3918,
#          0.3807,  0.4035,  0.4320,  0.3767,  0.4279,  0.4207,  0.3952,  0.4465,
#          0.3616,  0.2999,  0.3709,  0.3035,  0.3601,  0.2778,  0.3743,  0.2571,
#          0.3739,  0.2682], device='cuda:0', dtype=torch.float64)

# %%
ts_train_std
# Out:
# tensor([ 1.0000,  2.5724,  2.4543,  1.9501,  1.7327,  1.7503,  1.6707,  1.6297,
#          1.8147,  2.4146,  1.7088,  1.6546,  2.3538,  2.2777,  2.0171,  1.8925,
#          2.2236,  1.5821,  1.9931,  1.7196,  1.9315,  2.4339,  1.7864,  2.1404,
#          2.6117,  2.0852,  2.2918,  1.4115,  1.8827,  1.7403,  2.0817,  1.6850,
#          2.4817,  1.9481,  2.0704,  2.4316,  2.2853,  2.0566,  2.1225,  1.6162,
#          2.3138,  1.9912,  2.4127,  2.3259,  2.7887,  1.9650,  2.8462,  2.2005,
#          3.0387,  3.5713,  3.7193,  2.8348,  1.8877,  2.2007,  1.9352,  7.1295,
#         11.0556,  7.5957,  8.1579,  9.9465,  2.2164,  1.9947,  2.1712,  2.2567,
#          2.3735,  2.1915,  1.7553,  2.5883,  2.5263,  2.2991,  2.4406,  1.8076,
#          1.8125,  2.1476,  1.7792,  1.9738,  2.2283,  2.6795,  2.1807,  1.7949,
#          1.7688,  2.2805,  1.9767,  2.4821,  1.9748,  2.4948,  1.9679,  2.6387,
#          2.5943,  2.6160,  2.0864,  2.6942,  2.0670,  2.2104,  2.1212,  2.5054,
#          2.1243,  2.5619,  2.3017,  2.1175,  2.2689,  2.6136,  2.3357,  2.2557,
#          1.8389,  2.0931,  2.7896,  2.4935,  2.4409,  2.5761,  1.9721,  1.9469,
#          2.6040,  2.8786,  2.1073,  2.3353,  2.3193,  2.5076,  2.4064,  2.0617,
#          1.9008,  2.1498,  2.1102,  1.9852,  1.7631,  2.2454,  2.5548,  1.8003,
#          2.3295,  1.7714], device='cuda:0', dtype=torch.float64)
