# %% [markdown]
# # Pytorch classifier notebook
#
# V1 : only 1 split. First implementation
# All folds V1 : with all folds
# All folds V2 : add activation stats plot
# All folds V3 : try 2 outputs regression and classification

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import matplotlib.pyplot as plt

from sklearn.metrics import accuracy_score

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision.transforms as transforms
import torchvision.utils as utils

from torch.utils.tensorboard import SummaryWriter
import io
import PIL.Image

torch.set_printoptions(edgeitems=2)
torch.manual_seed(42)

DATASET_INPUT_FILE = 'train.csv'

FEATURES_LIST_TOTRAIN = ['feature_'+str(i) for i in range(130)]

# For custom non-overlaped folds generation
TRAIN_PERCENT = 0.70  
TEST_PERCENT = 0.30

#pd.set_option('display.max_rows', 500)

# %%
# Deterministic Behavior
seed = 42
#os.environ['PYTHONHASHSEED'] = str(seed)
# Torch RNG
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
torch.cuda.manual_seed_all(seed)
# Python RNG
np.random.seed(seed)
#random.seed(seed)
# CuDA Determinism
torch.backends.cudnn.deterministic = True
#torch.backends.cudnn.benchmark = False

# %%
#BATCH_SIZE = 50000
#BATCH_SIZE = 4096 # Gave once better results than 50000
#BATCH_SIZE = 2048

#BATCH_SIZE = 300000

#BATCH_SIZE = 4096

#BATCH_SIZE = 8192
BATCH_SIZE = 40960

NUM_EPOCHS = 100
MODEL_COMMENT = "All folds, 3 layers 200, 100 and 1, batch size 40960, lr=1e-4, patience 5, standard scale, 0.7 dropout, activ stats, CLASSIF+REG"

# %%
def pyStandardScale(tensor, mean, std):
    return((tensor - mean) / std)

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection._split import _BaseKFold, indexable, _num_samples
from sklearn.utils.validation import _deprecate_positional_args

# modified code for group gaps; source
# https://github.com/getgaurav2/scikit-learn/blob/d4a3af5cc9da3a76f0266932644b884c99724c57/sklearn/model_selection/_split.py#L2243
class PurgedGroupTimeSeriesSplit(_BaseKFold):
    """Time Series cross-validator variant with non-overlapping groups.
    Allows for a gap in groups to avoid potentially leaking info from
    train into test if the model has windowed or lag features.
    Provides train/test indices to split time series data samples
    that are observed at fixed time intervals according to a
    third-party provided group.
    In each split, test indices must be higher than before, and thus shuffling
    in cross validator is inappropriate.
    This cross-validation object is a variation of :class:`KFold`.
    In the kth split, it returns first k folds as train set and the
    (k+1)th fold as test set.
    The same group will not appear in two different folds (the number of
    distinct groups has to be at least equal to the number of folds).
    Note that unlike standard cross-validation methods, successive
    training sets are supersets of those that come before them.
    Read more in the :ref:`User Guide <cross_validation>`.
    Parameters
    ----------
    n_splits : int, default=5
        Number of splits. Must be at least 2.
    max_train_group_size : int, default=Inf
        Maximum group size for a single training set.
    group_gap : int, default=None
        Gap between train and test
    max_test_group_size : int, default=Inf
        We discard this number of groups from the end of each train split
    """

    @_deprecate_positional_args
    def __init__(self,
                 n_splits=5,
                 *,
                 max_train_group_size=np.inf,
                 max_test_group_size=np.inf,
                 group_gap=None,
                 verbose=False
                 ):
        super().__init__(n_splits, shuffle=False, random_state=None)
        self.max_train_group_size = max_train_group_size
        self.group_gap = group_gap
        self.max_test_group_size = max_test_group_size
        self.verbose = verbose

    def split(self, X, y=None, groups=None):
        """Generate indices to split data into training and test set.
        Parameters
        ----------
        X : array-like of shape (n_samples, n_features)
            Training data, where n_samples is the number of samples
            and n_features is the number of features.
        y : array-like of shape (n_samples,)
            Always ignored, exists for compatibility.
        groups : array-like of shape (n_samples,)
            Group labels for the samples used while splitting the dataset into
            train/test set.
        Yields
        ------
        train : ndarray
            The training set indices for that split.
        test : ndarray
            The testing set indices for that split.
        """
        if groups is None:
            raise ValueError(
                "The 'groups' parameter should not be None")
        X, y, groups = indexable(X, y, groups)
        n_samples = _num_samples(X)
        n_splits = self.n_splits
        group_gap = self.group_gap
        max_test_group_size = self.max_test_group_size
        max_train_group_size = self.max_train_group_size
        n_folds = n_splits + 1
        group_dict = {}
        u, ind = np.unique(groups, return_index=True)
        unique_groups = u[np.argsort(ind)]
        n_samples = _num_samples(X)
        n_groups = _num_samples(unique_groups)
        for idx in np.arange(n_samples):
            if (groups[idx] in group_dict):
                group_dict[groups[idx]].append(idx)
            else:
                group_dict[groups[idx]] = [idx]
        if n_folds > n_groups:
            raise ValueError(
                ("Cannot have number of folds={0} greater than"
                 " the number of groups={1}").format(n_folds,
                                                     n_groups))

        group_test_size = min(n_groups // n_folds, max_test_group_size)
        group_test_starts = range(n_groups - n_splits * group_test_size,
                                  n_groups, group_test_size)
        for group_test_start in group_test_starts:
            train_array = []
            test_array = []

            group_st = max(0, group_test_start - group_gap - max_train_group_size)
            for train_group_idx in unique_groups[group_st:(group_test_start - group_gap)]:
                train_array_tmp = group_dict[train_group_idx]
                
                train_array = np.sort(np.unique(
                                      np.concatenate((train_array,
                                                      train_array_tmp)),
                                      axis=None), axis=None)

            train_end = train_array.size
 
            for test_group_idx in unique_groups[group_test_start:
                                                group_test_start +
                                                group_test_size]:
                test_array_tmp = group_dict[test_group_idx]
                test_array = np.sort(np.unique(
                                              np.concatenate((test_array,
                                                              test_array_tmp)),
                                     axis=None), axis=None)

            test_array  = test_array[group_gap:]
            
            
            if self.verbose > 0:
                    pass
                    
            yield [int(i) for i in train_array], [int(i) for i in test_array]

from matplotlib.colors import ListedColormap
    
# this is code slightly modified from the sklearn docs here:
# https://scikit-learn.org/stable/auto_examples/model_selection/plot_cv_indices.html#sphx-glr-auto-examples-model-selection-plot-cv-indices-py
def plot_cv_indices(cv, X, y, group, ax, n_splits, lw=10):
    """Create a sample plot for indices of a cross-validation object."""
    
    cmap_cv = plt.cm.coolwarm

    jet = plt.cm.get_cmap('jet', 256)
    seq = np.linspace(0, 1, 256)
    _ = np.random.shuffle(seq)   # inplace
    cmap_data = ListedColormap(jet(seq))

    # Generate the training/testing visualizations for each CV split
    for ii, (tr, tt) in enumerate(cv.split(X=X, y=y, groups=group)):
        # Fill in indices with the training/test groups
        indices = np.array([np.nan] * len(X))
        indices[tt] = 1
        indices[tr] = 0

        # Visualize the results
        ax.scatter(range(len(indices)), [ii + .5] * len(indices),
                   c=indices, marker='_', lw=lw, cmap=cmap_cv,
                   vmin=-.2, vmax=1.2)

    # Plot the data classes and groups at the end
    ax.scatter(range(len(X)), [ii + 1.5] * len(X),
               c=y, marker='_', lw=lw, cmap=plt.cm.Set3)

    ax.scatter(range(len(X)), [ii + 2.5] * len(X),
               c=group, marker='_', lw=lw, cmap=cmap_data)

    # Formatting
    yticklabels = list(range(n_splits)) + ['target', 'day']
    ax.set(yticks=np.arange(n_splits+2) + .5, yticklabels=yticklabels,
           xlabel='Sample index', ylabel="CV iteration",
           ylim=[n_splits+2.2, -.2], xlim=[0, len(y)])
    ax.set_title('{}'.format(type(cv).__name__), fontsize=15)
    return ax


def plot_cv_indices_custom(cv_custom, X, y, group, ax, n_splits, lw=10):
    """Create a sample plot for indices of a cross-validation object."""
    
    cmap_cv = plt.cm.coolwarm

    jet = plt.cm.get_cmap('jet', 256)
    seq = np.linspace(0, 1, 256)
    _ = np.random.shuffle(seq)   # inplace
    cmap_data = ListedColormap(jet(seq))

    # Generate the training/testing visualizations for each CV split
    for ii, (tr, tt) in enumerate(cv_custom):
        # Fill in indices with the training/test groups
        indices = np.array([np.nan] * len(X))
        indices[tt] = 1
        indices[tr] = 0

        # Visualize the results
        ax.scatter(range(len(indices)), [ii + .5] * len(indices),
                   c=indices, marker='_', lw=lw, cmap=cmap_cv,
                   vmin=-.2, vmax=1.2)

    # Plot the data classes and groups at the end
    ax.scatter(range(len(X)), [ii + 1.5] * len(X),
               c=y, marker='_', lw=lw, cmap=plt.cm.Set3)

    ax.scatter(range(len(X)), [ii + 2.5] * len(X),
               c=group, marker='_', lw=lw, cmap=cmap_data)

    # Formatting
    yticklabels = list(range(n_splits)) + ['target', 'day']
    ax.set(yticks=np.arange(n_splits+2) + .5, yticklabels=yticklabels,
           xlabel='Sample index', ylabel="CV iteration",
           ylim=[n_splits+2.2, -.2], xlim=[0, len(y)])
    ax.set_title('{}'.format(type(cv).__name__), fontsize=15)
    return ax

# %%
# This function accounts for variable instance counts in each split by dividing utility_pi by number of instances (but this has been removed)
# It also does some copy of dataframe to prevent memory overwrite
def utility_function(df_test, df_test_predictions):
    df_test_copy = df_test.copy(deep=True)
    df_test_copy.loc[:, 'utility_pj'] = df_test_copy['weight'] * df_test_copy['resp'] * df_test_predictions
    #df_test_utility_pi = df_test_copy.groupby('date')['utility_pj'].sum() / df_test_copy.groupby('date')['utility_pj'].count()
    df_test_utility_pi = df_test_copy.groupby('date')['utility_pj'].sum()

    nb_unique_dates = df_test_utility_pi.shape[0]
    t = (df_test_utility_pi.sum() / np.sqrt(df_test_utility_pi.pow(2).sum())) * (np.sqrt(250 / np.abs(nb_unique_dates)))
    u = min(max(t, 0), 6) * df_test_utility_pi.sum()
    del df_test_copy
    
    return(u)

# %%
from bisect import bisect_left

def take_closest(myList, myNumber):
    """
    Assumes myList is sorted. Returns closest value to myNumber.

    If two numbers are equally close, return the smallest number.
    """
    pos = bisect_left(myList, myNumber)
    if pos == 0:
        return myList[0]
    if pos == len(myList):
        return myList[-1]
    before = myList[pos - 1]
    after = myList[pos]
    if after - myNumber < myNumber - before:
       return after
    else:
       return before

# %%
class SaveOutputActivationStats:
    def __init__(self):
        self.outputs = []
        
    def __call__(self, module, module_in, module_out):
        #self.outputs.append(module_out)
        self.outputs.append({'mean': module_out.mean().item(), 'std': module_out.std().item(),'near_zero': (module_out<=0.05).long().sum().item()/module_out.numel()})
        
    def clear(self):
        self.outputs = []

# %%
#fig, ax = plt.subplots(1, 1)
#
#plot_cv_indices(cv, df.loc[:, FEATURES_LIST_TOTRAIN], (df['resp'] > 0), df['date'], 
#                         ax, 5, lw=20);

# %%
torch.device
# Out:
# torch.device

# %%
torch.cuda.is_available()
# Out:
# True

# %%
torch.cuda.current_device()
# Out:
# 0

# %%
torch.cuda.get_device_name(0)
# Out:
# 'GeForce RTX 3090'

# %% [markdown]
# # Load data

# %%
# Load data
    
df = pd.read_csv(DATASET_INPUT_FILE)
df['resp_positive'] = ((df['resp'])>0)*1  # Target to predict

print('Data loaded')
# Out:
# Data loaded

# %% [markdown]
# # Non overlap fold generation

# %%
date_indexes_list = df.groupby('date')['ts_id'].first().to_list()

# %%
base_train_split_size = int((df.shape[0] // 5) * TRAIN_PERCENT)

# %%
base_test_split_size = int((df.shape[0] // 5) * TEST_PERCENT)

# %%
train_split_start_indexes = [take_closest(date_indexes_list, (base_train_split_size + base_test_split_size)*fold_indice) for fold_indice in range(5)]

# %%
test_split_start_indexes = [take_closest(date_indexes_list, (base_train_split_size + base_test_split_size)*fold_indice) for fold_indice in range(5)]

# %%
train_split_start_indexes
# Out:
# [0, 477711, 958233, 1435933, 1913985]

# %%
df.shape[0] - 1
# Out:
# 2390490

# %%
NB_FOLDS = 5
last_index = df.shape[0] - 1

cv_table = []

for fold_indice in range(NB_FOLDS):
    fold_train_start_index = train_split_start_indexes[fold_indice]
    
    if (fold_indice == NB_FOLDS - 1):    
        nextfold_train_start_index = last_index
        
    else:
        nextfold_train_start_index = train_split_start_indexes[fold_indice + 1]
    
    fold_test_start_index = take_closest(date_indexes_list, int(TRAIN_PERCENT * (nextfold_train_start_index - fold_train_start_index) + fold_train_start_index  ))
    
    cv_table.append(fold_train_start_index)
    cv_table.append(fold_test_start_index)

# %%
cv_table.append(last_index)

# %%
cv_tuples = []

for i in range(0, NB_FOLDS*2, 2):
    cv_tuples.append([df.loc[cv_table[i]:cv_table[i+1]-1, :].index.to_list(), df.loc[cv_table[i+1]:cv_table[i+2]-1, :].index.to_list()])

# %%
cv_tuples_generator = iter(cv_tuples)

# %%
#fig, ax = plt.subplots(1, 1)

#plot_cv_indices_custom(cv_tuples_generator, df.loc[:, FEATURES_LIST_TOTRAIN], (df['resp'] > 0), df['date'], 
#                         ax, 5, lw=20); 

#cv_tuples_generator = iter(cv_tuples)

# %%
# Size of training set :
#train_sets_table =  [cv_tuples[i][0] for i in range(5)]
#sum([len(train_set_table) for train_set_table in train_sets_table])

# %%
# Our old time series split (with overlap : required 1 neural network trained per split)
# But in this script it's not needed because we're training 1 unique network, with a different fold strategy (non overlaped)
#cv = PurgedGroupTimeSeriesSplit(
#    n_splits=5,
#    max_train_group_size=180,
#    group_gap=20,
#    max_test_group_size=60
#)

# %%
#train_index, test_index = next(cv.split(df, (df['resp'] > 0)*1, df['date']))

# %%
#(df.loc[train_index, 'resp'] > 0).astype(np.byte)

# %%
f_mean = df.loc[:, FEATURES_LIST_TOTRAIN].mean(axis=0)

# %%
f_mean.shape
# Out:
# (130,)

# %%
df.fillna(f_mean, inplace=True)

# %%
#print('Sum of model parameters:')
#[print(p.sum()) for p in model.parameters()]

# %%
#writer = SummaryWriter()

#writer.add_text('test', 'test:'  + str(model).replace('\n', '<BR>'))

#writer.flush()
#writer.close()

# %%
#str([p.numel() for p in model.parameters()])

# %%
folds_list = []

for fold, (train_index, test_index) in enumerate(cv_tuples_generator):
    folds_list.append((train_index, test_index))

# %%
folds_list_train = [folds_list[i][0] for i in range(5)]
folds_list_train_flat = [folds_list_train_item for sublist in folds_list_train for folds_list_train_item in sublist]
folds_list_train_unique = list(set(folds_list_train_flat))

# %%
len(folds_list_train_unique)
# Out:
# 1677155

# %%
np.sum([len(folds_list_train_item) for folds_list_train_item in folds_list_train])
# Out:
# 1677155

# %%
len(folds_list_train_flat)
# Out:
# 1677155

# %%
folds_list_test = [folds_list[i][1] for i in range(5)]
folds_list_test_flat = [folds_list_test_item for sublist in folds_list_test for folds_list_test_item in sublist]
folds_list_test_unique = set(folds_list_test_flat)

# %%
np.sum([len(folds_list_test_item) for folds_list_test_item in folds_list_test])
# Out:
# 713335

# %%
len(folds_list_test_flat)
# Out:
# 713335

# %%
len(folds_list_train_flat) + len(folds_list_test_flat)
# Out:
# 2390490

# %%
df.loc[folds_list_test[4], FEATURES_LIST_TOTRAIN].to_numpy().shape
# Out:
# (141980, 130)

# %% [markdown]
# # Training

# %%
patience=5

utility_scores = [None] * 5
accuracy_scores = [None] * 5

writer = SummaryWriter()

ts_train = torch.tensor(df.loc[folds_list_train_unique, FEATURES_LIST_TOTRAIN].to_numpy(), device='cuda')
ts_train_y = torch.tensor((df.loc[folds_list_train_unique, 'resp'] > 0).astype(np.byte).to_numpy(), device='cuda')
ts_train_y_reg = torch.tensor(df.loc[folds_list_train_unique, 'resp'].to_numpy(), device='cuda')

# Normalize data
ts_train_mean = torch.mean(ts_train, axis=0)
ts_train_std = torch.std(ts_train, axis=0)
ts_train = pyStandardScale(ts_train, ts_train_mean, ts_train_std)

train_dataset = torch.utils.data.TensorDataset(ts_train, ts_train_y, ts_train_y_reg)
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True) # pin_memory : VOIR RESULTAT

ts_test = [None] * 5
ts_test_y = [None] * 5    
ts_test_y_reg = [None] * 5   
test_dataset = [None] * 5
test_loader = [None] * 5

for fold_indice in range(5):
    ts_test[fold_indice] = torch.tensor(df.loc[folds_list_test[fold_indice], FEATURES_LIST_TOTRAIN].to_numpy(), device='cuda')
    ts_test_y[fold_indice] = torch.tensor((df.loc[folds_list_test[fold_indice], 'resp'] > 0).astype(np.byte).to_numpy(), device='cuda')
    ts_test_y_reg[fold_indice] = torch.tensor(df.loc[folds_list_test[fold_indice], 'resp'].to_numpy(), device='cuda')

    # Normalize
    ts_test[fold_indice] = pyStandardScale(ts_test[fold_indice], ts_train_mean, ts_train_std)
    
    test_dataset[fold_indice] = torch.utils.data.TensorDataset(ts_test[fold_indice], ts_test_y[fold_indice], ts_test_y_reg[fold_indice])
    test_loader[fold_indice] = torch.utils.data.DataLoader(test_dataset[fold_indice], batch_size=BATCH_SIZE)

torch.manual_seed(seed)

'''
model = nn.Sequential(
        #nn.Dropout(0.2),
        nn.Linear(len(FEATURES_LIST_TOTRAIN), 200),
        #nn.BatchNorm1d(130),
        nn.ReLU(),
        nn.Dropout(0.7),

        nn.Linear(200, 100),
        #nn.BatchNorm1d(130),
        nn.ReLU(),
        nn.Dropout(0.7),
    
        nn.Linear(100, 1),
        nn.Sigmoid(),
    ).double().to('cuda')
'''

class MLP(torch.nn.Module):
    #def __init__(self, n_feature, n_hidden): 
    def __init__(self): 
        super(MLP, self).__init__() 
        self.layer1 = nn.Linear(len(FEATURES_LIST_TOTRAIN), 200)
        self.act1 = nn.ReLU()
        self.drop1 = nn.Dropout(0.7)

        self.layer2 = nn.Linear(200, 100)
        self.act2 = nn.ReLU()
        self.drop2 = nn.Dropout(0.7)

        self.layer3_classif = nn.Linear(100, 1)
        self.act3_classif = nn.Sigmoid()  

        self.layer3_reg = nn.Linear(100, 1)
        self.act3_reg = nn.Sigmoid()  


    def forward(self, x):
        x = self.drop1(self.act1(self.layer1(x)))
        x = self.drop2(self.act2(self.layer2(x)))

        x_out_classif = self.act3_classif(self.layer3_classif(x))
        x_out_reg = self.act3_reg(self.layer3_reg(x))

        return x_out_classif, x_out_reg

model = MLP().double().to('cuda')
print('Model created')

#print('Number of model parameters :')
#numel_list = [p.numel() for p in model.parameters()]
#sum(numel_list), numel_list

loss_fn = nn.BCELoss().to('cuda')
loss_fn_reg = nn.MSELoss().to('cuda')

#optimizer = torch.optim.Adam(model.parameters(), lr=1e-3) 
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4) 

model.eval()
#start_accuracy = accuracy_score(ts_test_y.cpu().numpy(), (model(ts_test).squeeze() > 0.5).cpu().numpy())
#start_utility_score = utility_function(df.loc[test_index], (model(ts_test).squeeze() > 0.5).cpu().numpy())
#print('Start Validation Accuracy: {:.4f}'.format(start_accuracy))
#print('Start Validation Utility: {:.4f}'.format(start_utility_score))

### Call back to save activation stats (mean, std dev and near 0 values after activation functions)

hook_handles = []
save_output_activation_stats = []

for layer in model.modules():
    if ('activation' in str(type(layer))):
        save_output_activation_stats_1layer = SaveOutputActivationStats()
        handle = layer.register_forward_hook(save_output_activation_stats_1layer)
        save_output_activation_stats.append(save_output_activation_stats_1layer)
        hook_handles.append(handle)

Val_Loss = 0
N_Samples = 0

the_last_loss = 100
the_last_utility_score = 0
the_last_accuracy = 0
trigger_times=0
early_stopping_met = False

for epoch in range(NUM_EPOCHS): 
    running_loss = 0.0        
    model.train()

    for batch in train_loader:
        #inputs, labels = batch[0], batch[1]
        inputs, labels, labels_reg = batch[0].to('cuda'), batch[1].to('cuda'), batch[2].to('cuda')
        optimizer.zero_grad()

        with torch.set_grad_enabled(True):
            outputs_classif, outputs_reg = model(inputs)
            loss_classif = loss_fn(outputs_classif, labels.unsqueeze(-1).double())
            loss_reg = loss_fn_reg(outputs_reg, labels_reg.unsqueeze(-1).double())
            loss = loss_classif + loss_reg
            
            loss.backward()
            optimizer.step()

    # update local train loss
        running_loss += loss.item() * inputs.size(0)

    # update global train loss
    epoch_loss = running_loss / len(train_loader.dataset)
    print('Epoch({}) - Training Loss: {:.4f}'.format(epoch, epoch_loss))

    writer.add_scalar(f"Global train/loss", epoch_loss, epoch)

    # Write activation stats graphs
    for layer_number,save_output_activation_stats_layer in enumerate(save_output_activation_stats):
        df_stats_layer = pd.DataFrame(save_output_activation_stats_layer.outputs)

        fig, ax = plt.subplots(1, 3, figsize=(25, 4))

        ax[0].set_title(f'Layer {layer_number} : Mean activation value', fontsize=16)
        ax[0].set_xlabel('Batch instances')
        ax[0].set_ylabel('Mean')
        ax[0].plot(range(df_stats_layer.shape[0]), df_stats_layer['mean'])

        ax[1].set_title(f'Layer {layer_number} : Std deviation activation value', fontsize=16)
        ax[1].set_xlabel('Batch instances')
        ax[1].set_ylabel('Standard deviation')
        ax[1].plot(range(df_stats_layer.shape[0]), df_stats_layer['std'])

        ax[2].set_title(f'Layer {layer_number} : Percentage of activation values near zero', fontsize=16)
        ax[2].set_xlabel('Batch instances')
        ax[2].set_ylabel('Percentage')
        ax[2].plot(range(df_stats_layer.shape[0]), df_stats_layer['near_zero']);
        
        plot_buf = io.BytesIO()
        plt.savefig(plot_buf, format='jpeg')
        plt.close()
        
        plot_buf.seek(0)
        image = PIL.Image.open(plot_buf)
        image = transforms.ToTensor()(image)
        writer.add_image("Train activation stats/Activation stats layer " + str(layer_number), image, epoch)
    
    # Validation 
    model.eval()

    vrunning_loss = [None] * 5
    vrunning_loss_classif = [None] * 5
    vrunning_loss_reg = [None] * 5
    num_samples = [None] * 5
    vepoch_loss_folds = [None] * 5
    vepoch_accuracy_folds = [None] * 5
    vepoch_utility_score_folds = [None] * 5
    
    for fold_indice in range(5):    
        vrunning_loss[fold_indice] = 0.0
        num_samples[fold_indice] = 0

        for batch in test_loader[fold_indice]:
            inputs, labels, labels_reg = batch[0].to('cuda'), batch[1].to('cuda'), batch[2].to('cuda')

            optimizer.zero_grad()
            with torch.no_grad():
                outputs_classif, outputs_reg = model(inputs)
                loss_classif = loss_fn(outputs_classif, labels.unsqueeze(-1).double())
                loss_reg = loss_fn_reg(outputs_reg, labels_reg.unsqueeze(-1).double())
                loss = loss_classif + loss_reg
                
            vrunning_loss[fold_indice] += loss.item() * inputs.size(0)
            num_samples[fold_indice] += labels.size(0)
            
            vrunning_loss_classif[fold_indice] += loss_classif.item() * inputs.size(0)
            vrunning_loss_reg[fold_indice] += loss_reg.item() * inputs.size(0)
            
            vepoch_loss_folds[fold_indice] = vrunning_loss[fold_indice] / num_samples[fold_indice]
            vepoch_loss_classif_folds[fold_indice] = vrunning_loss_classif[fold_indice] / num_samples[fold_indice]
            vepoch_loss_reg_folds[fold_indice] = vrunning_loss_reg[fold_indice] / num_samples[fold_indice]

        print('Epoch({}) - Fold {} - Validation Loss : {:.4f}'.format(epoch, fold_indice, vepoch_loss_folds[fold_indice]))
        print('Epoch({}) - Fold {} -> Validation Loss Classif : {:.4f}'.format(epoch, fold_indice, vepoch_loss_classif_folds[fold_indice]))
        print('Epoch({}) - Fold {} -> Validation Loss Reg : {:.4f}'.format(epoch, fold_indice, vepoch_loss_reg_folds[fold_indice]))

        model.eval()
        with torch.no_grad():
            vepoch_accuracy_folds[fold_indice] = accuracy_score(ts_test_y[fold_indice].cpu().numpy(), (model(ts_test[fold_indice])[0].squeeze() > 0.5).cpu().numpy())  # model...[0] is the classification output of model
            vepoch_utility_score_folds[fold_indice] = utility_function(df.loc[folds_list_test[fold_indice]], (model(ts_test[fold_indice])[0].squeeze() > 0.5).cpu().numpy())
        print('Epoch({}) - Fold {} - Validation Accuracy : {:.4f}'.format(epoch, fold_indice, vepoch_accuracy_folds[fold_indice]))
        print('Epoch({}) - Fold {} - Validation Utility score : {:.4f}'.format(epoch, fold_indice, vepoch_utility_score_folds[fold_indice]))
        
            
    # update epoch loss
    vepoch_loss = sum(vepoch_loss_folds) / len(vepoch_loss_folds)
    vepoch_accuracy = sum(vepoch_accuracy_folds) / len(vepoch_accuracy_folds)
    vepoch_utility_score = sum(vepoch_utility_score_folds) #/ len(vepoch_utility_score_folds)
    print('Epoch({}) - GLOBAL - Validation Loss: {:.4f}'.format(epoch, vepoch_loss))
    print('Epoch({}) - GLOBAL - Validation Accuracy: {:.4f}'.format(epoch, vepoch_accuracy))
    print('Epoch({}) - GLOBAL - Validation Utility score: {:.4f}'.format(epoch, vepoch_utility_score))

    #print(f'Sum of model parameters ({epoch}):')
    #[print(p.sum()) for p in model.parameters()]

    writer.add_scalar("Global valid/Loss", vepoch_loss, epoch)
    writer.add_scalar("Global valid/Accuracy", vepoch_accuracy, epoch)
    writer.add_scalar("Global valid/Utility", vepoch_utility_score, epoch)

    for fold_indice in range(5):
        writer.add_scalar("Fold valid Loss/Loss fold "+str(fold_indice), vepoch_loss_folds[fold_indice], epoch)
        writer.add_scalar("Fold valid Accuracy/Accuracy fold "+str(fold_indice), vepoch_accuracy_folds[fold_indice], epoch)
        writer.add_scalar("Fold valid Utility/Utility fold "+str(fold_indice), vepoch_utility_score_folds[fold_indice], epoch)
        
    
    writer.flush()

    # Check if Early Stopping
    #if vepoch_loss > the_last_loss:
    #if (vepoch_utility_score < the_last_utility_score) and (vepoch_loss > the_last_loss) and (vepoch_accuracy < the_last_accuracy):
    if (vepoch_loss > the_last_loss):
        trigger_times += 1

        print(f'Intermediate early stopping : vepoch_loss = {vepoch_loss:.4f}, the_last_loss={the_last_loss:.4f}')
        #print(f'Intermediate early stopping : vepoch_accuracy = {vepoch_accuracy:.4f}, the_last_utility_score={the_last_accuracy:.4f}')
        #print(f'Intermediate early stopping : vepoch_utility_score = {vepoch_utility_score:.4f}, the_last_utility_score={the_last_utility_score:.4f}')

        if trigger_times >= patience:
            print('Meet Early stopping!')
            early_stopping_met = True
            ##torch.save(model.state_dict(), f'model_{fold}.pt')
            break
    else:
        trigger_times = 0
        the_last_loss = vepoch_loss
        the_last_utility_score = vepoch_utility_score
        the_last_accuracy = vepoch_accuracy
        
        the_last_utility_score_folds = vepoch_utility_score_folds
        the_last_accuracy_folds = vepoch_accuracy_folds
        
        the_best_epoch = epoch

        # Save model for the best version so far
        print(f'Saving model corresponding to last_utility_score == {the_last_utility_score}')
        torch.save(model.state_dict(), f'model_NN_allfolds_V1.pt')

    print('\n')

if (early_stopping_met == False):
    print("Didn't meet early stopping : saving final model")
    # Save model if don't meet early stopping
    torch.save(model.state_dict(), f'model_NN_allfolds_V1.pt')

#utility_scores.append(the_last_utility_score)
#accuracy_scores.append(the_last_accuracy)
writer.add_text(f"Global valid/Utility", f"Best utility: {the_last_utility_score}", the_best_epoch)
        
scores_results = {'utility_score': the_last_utility_score, 'utility_scores': the_last_utility_score_folds, 'utility_score_std': np.std(the_last_utility_score_folds), 'accuracy_scores': the_last_accuracy_folds}

writer.add_text('Final utility score', str(scores_results))
writer.add_text('Batch size', str(BATCH_SIZE))
writer.add_text('Patience', str(patience))
writer.add_text('Number of epochs', str(NUM_EPOCHS))
writer.add_text('Number of parameters per layer', str([p.numel() for p in model.parameters()]))
writer.add_text('Model architecture', str(model).replace('\n', '<BR>'))
writer.add_text('Comment', MODEL_COMMENT)

writer.close()

print('Training summary:')
print(scores_results)
# Out:
# Model created
# Epoch(0) - Training Loss: 0.9061
# Epoch(0) - Fold 0 - Validation Loss : 0.8282
# Epoch(0) - Fold 0 - Validation Accuracy : 0.5037
# Epoch(0) - Fold 0 - Validation Utility score : 60.8619
# Epoch(0) - Fold 1 - Validation Loss : 0.8331
# Epoch(0) - Fold 1 - Validation Accuracy : 0.5005
# Epoch(0) - Fold 1 - Validation Utility score : 10.2261
# Epoch(0) - Fold 2 - Validation Loss : 0.8324
# Epoch(0) - Fold 2 - Validation Accuracy : 0.5009
# Epoch(0) - Fold 2 - Validation Utility score : -0.0000
# Epoch(0) - Fold 3 - Validation Loss : 0.8316
# Epoch(0) - Fold 3 - Validation Accuracy : 0.5016
# Epoch(0) - Fold 3 - Validation Utility score : -0.0000
# Epoch(0) - Fold 4 - Validation Loss : 0.8321
# Epoch(0) - Fold 4 - Validation Accuracy : 0.5079
# Epoch(0) - Fold 4 - Validation Utility score : 116.3406
# Epoch(0) - GLOBAL - Validation Loss: 0.8315
# Epoch(0) - GLOBAL - Validation Accuracy: 0.5029
# Epoch(0) - GLOBAL - Validation Utility score: 187.4287
# Saving model corresponding to last_utility_score == 187.42869953910048
#
#
# Epoch(1) - Training Loss: 0.8146
# Epoch(1) - Fold 0 - Validation Loss : 0.7522
# Epoch(1) - Fold 0 - Validation Accuracy : 0.5105
# Epoch(1) - Fold 0 - Validation Utility score : 95.3433
# Epoch(1) - Fold 1 - Validation Loss : 0.7548
# Epoch(1) - Fold 1 - Validation Accuracy : 0.5077
# Epoch(1) - Fold 1 - Validation Utility score : 256.8196
# Epoch(1) - Fold 2 - Validation Loss : 0.7552
# Epoch(1) - Fold 2 - Validation Accuracy : 0.5034
# Epoch(1) - Fold 2 - Validation Utility score : -0.0000
# Epoch(1) - Fold 3 - Validation Loss : 0.7547
# Epoch(1) - Fold 3 - Validation Accuracy : 0.4998
# Epoch(1) - Fold 3 - Validation Utility score : -0.0000
# Epoch(1) - Fold 4 - Validation Loss : 0.7546
# Epoch(1) - Fold 4 - Validation Accuracy : 0.5102
# Epoch(1) - Fold 4 - Validation Utility score : 1053.5516
# Epoch(1) - GLOBAL - Validation Loss: 0.7543
# Epoch(1) - GLOBAL - Validation Accuracy: 0.5063
# Epoch(1) - GLOBAL - Validation Utility score: 1405.7145
# Saving model corresponding to last_utility_score == 1405.714520933573
#
#
# Epoch(2) - Training Loss: 0.7624
# Epoch(2) - Fold 0 - Validation Loss : 0.7167
# Epoch(2) - Fold 0 - Validation Accuracy : 0.5121
# Epoch(2) - Fold 0 - Validation Utility score : 96.7146
# Epoch(2) - Fold 1 - Validation Loss : 0.7173
# Epoch(2) - Fold 1 - Validation Accuracy : 0.5148
# Epoch(2) - Fold 1 - Validation Utility score : 556.8530
# Epoch(2) - Fold 2 - Validation Loss : 0.7182
# Epoch(2) - Fold 2 - Validation Accuracy : 0.5049
# Epoch(2) - Fold 2 - Validation Utility score : -0.0000
# Epoch(2) - Fold 3 - Validation Loss : 0.7179
# Epoch(2) - Fold 3 - Validation Accuracy : 0.4999
# Epoch(2) - Fold 3 - Validation Utility score : -0.0000
# Epoch(2) - Fold 4 - Validation Loss : 0.7175
# Epoch(2) - Fold 4 - Validation Accuracy : 0.5108
# Epoch(2) - Fold 4 - Validation Utility score : 1079.6953
# Epoch(2) - GLOBAL - Validation Loss: 0.7175
# Epoch(2) - GLOBAL - Validation Accuracy: 0.5085
# Epoch(2) - GLOBAL - Validation Utility score: 1733.2629
# Saving model corresponding to last_utility_score == 1733.2629074676165
#
#
# Epoch(3) - Training Loss: 0.7378
# Epoch(3) - Fold 0 - Validation Loss : 0.7043
# Epoch(3) - Fold 0 - Validation Accuracy : 0.5150
# Epoch(3) - Fold 0 - Validation Utility score : 150.1870
# Epoch(3) - Fold 1 - Validation Loss : 0.7044
# Epoch(3) - Fold 1 - Validation Accuracy : 0.5172
# Epoch(3) - Fold 1 - Validation Utility score : 898.2674
# Epoch(3) - Fold 2 - Validation Loss : 0.7054
# Epoch(3) - Fold 2 - Validation Accuracy : 0.5042
# Epoch(3) - Fold 2 - Validation Utility score : -0.0000
# Epoch(3) - Fold 3 - Validation Loss : 0.7051
# Epoch(3) - Fold 3 - Validation Accuracy : 0.5019
# Epoch(3) - Fold 3 - Validation Utility score : -0.0000
# Epoch(3) - Fold 4 - Validation Loss : 0.7046
# Epoch(3) - Fold 4 - Validation Accuracy : 0.5110
# Epoch(3) - Fold 4 - Validation Utility score : 973.9034
# Epoch(3) - GLOBAL - Validation Loss: 0.7048
# Epoch(3) - GLOBAL - Validation Accuracy: 0.5098
# Epoch(3) - GLOBAL - Validation Utility score: 2022.3577
# Saving model corresponding to last_utility_score == 2022.3577488436304
#
#
# Epoch(4) - Training Loss: 0.7251
# Epoch(4) - Fold 0 - Validation Loss : 0.6994
# Epoch(4) - Fold 0 - Validation Accuracy : 0.5170
# Epoch(4) - Fold 0 - Validation Utility score : 197.2891
# Epoch(4) - Fold 1 - Validation Loss : 0.6993
# Epoch(4) - Fold 1 - Validation Accuracy : 0.5193
# Epoch(4) - Fold 1 - Validation Utility score : 928.2074
# Epoch(4) - Fold 2 - Validation Loss : 0.7003
# Epoch(4) - Fold 2 - Validation Accuracy : 0.5046
# Epoch(4) - Fold 2 - Validation Utility score : -0.0000
# Epoch(4) - Fold 3 - Validation Loss : 0.7001
# Epoch(4) - Fold 3 - Validation Accuracy : 0.5023
# Epoch(4) - Fold 3 - Validation Utility score : -0.0000
# Epoch(4) - Fold 4 - Validation Loss : 0.6996
# Epoch(4) - Fold 4 - Validation Accuracy : 0.5137
# Epoch(4) - Fold 4 - Validation Utility score : 1071.7102
# Epoch(4) - GLOBAL - Validation Loss: 0.6997
# Epoch(4) - GLOBAL - Validation Accuracy: 0.5114
# Epoch(4) - GLOBAL - Validation Utility score: 2197.2067
# Saving model corresponding to last_utility_score == 2197.206672540505
#
#
# Epoch(5) - Training Loss: 0.7171
# Epoch(5) - Fold 0 - Validation Loss : 0.6969
# Epoch(5) - Fold 0 - Validation Accuracy : 0.5197
# Epoch(5) - Fold 0 - Validation Utility score : 272.9397
# Epoch(5) - Fold 1 - Validation Loss : 0.6968
# Epoch(5) - Fold 1 - Validation Accuracy : 0.5219
# Epoch(5) - Fold 1 - Validation Utility score : 1051.8681
# Epoch(5) - Fold 2 - Validation Loss : 0.6978
# Epoch(5) - Fold 2 - Validation Accuracy : 0.5057
# Epoch(5) - Fold 2 - Validation Utility score : -0.0000
# Epoch(5) - Fold 3 - Validation Loss : 0.6976
# Epoch(5) - Fold 3 - Validation Accuracy : 0.5043
# Epoch(5) - Fold 3 - Validation Utility score : -0.0000
# Epoch(5) - Fold 4 - Validation Loss : 0.6971
# Epoch(5) - Fold 4 - Validation Accuracy : 0.5160
# Epoch(5) - Fold 4 - Validation Utility score : 1209.5370
# Epoch(5) - GLOBAL - Validation Loss: 0.6972
# Epoch(5) - GLOBAL - Validation Accuracy: 0.5135
# Epoch(5) - GLOBAL - Validation Utility score: 2534.3447
# Saving model corresponding to last_utility_score == 2534.3447454226844
#
#
# Epoch(6) - Training Loss: 0.7117
# Epoch(6) - Fold 0 - Validation Loss : 0.6956
# Epoch(6) - Fold 0 - Validation Accuracy : 0.5200
# Epoch(6) - Fold 0 - Validation Utility score : 327.4221
# Epoch(6) - Fold 1 - Validation Loss : 0.6954
# Epoch(6) - Fold 1 - Validation Accuracy : 0.5226
# Epoch(6) - Fold 1 - Validation Utility score : 1201.2148
# Epoch(6) - Fold 2 - Validation Loss : 0.6964
# Epoch(6) - Fold 2 - Validation Accuracy : 0.5052
# Epoch(6) - Fold 2 - Validation Utility score : -0.0000
# Epoch(6) - Fold 3 - Validation Loss : 0.6962
# Epoch(6) - Fold 3 - Validation Accuracy : 0.5059
# Epoch(6) - Fold 3 - Validation Utility score : -0.0000
# Epoch(6) - Fold 4 - Validation Loss : 0.6957
# Epoch(6) - Fold 4 - Validation Accuracy : 0.5170
# Epoch(6) - Fold 4 - Validation Utility score : 1239.4393
# Epoch(6) - GLOBAL - Validation Loss: 0.6958
# Epoch(6) - GLOBAL - Validation Accuracy: 0.5141
# Epoch(6) - GLOBAL - Validation Utility score: 2768.0762
# Saving model corresponding to last_utility_score == 2768.076151607729
#
#
# Epoch(7) - Training Loss: 0.7075
# Epoch(7) - Fold 0 - Validation Loss : 0.6947
# Epoch(7) - Fold 0 - Validation Accuracy : 0.5214
# Epoch(7) - Fold 0 - Validation Utility score : 348.6519
# Epoch(7) - Fold 1 - Validation Loss : 0.6946
# Epoch(7) - Fold 1 - Validation Accuracy : 0.5228
# Epoch(7) - Fold 1 - Validation Utility score : 1224.3260
# Epoch(7) - Fold 2 - Validation Loss : 0.6955
# Epoch(7) - Fold 2 - Validation Accuracy : 0.5056
# Epoch(7) - Fold 2 - Validation Utility score : -0.0000
# Epoch(7) - Fold 3 - Validation Loss : 0.6953
# Epoch(7) - Fold 3 - Validation Accuracy : 0.5067
# Epoch(7) - Fold 3 - Validation Utility score : -0.0000
# Epoch(7) - Fold 4 - Validation Loss : 0.6948
# Epoch(7) - Fold 4 - Validation Accuracy : 0.5174
# Epoch(7) - Fold 4 - Validation Utility score : 1350.4290
# Epoch(7) - GLOBAL - Validation Loss: 0.6950
# Epoch(7) - GLOBAL - Validation Accuracy: 0.5148
# Epoch(7) - GLOBAL - Validation Utility score: 2923.4069
# Saving model corresponding to last_utility_score == 2923.4068911450513
#
#
# Epoch(8) - Training Loss: 0.7043
# Epoch(8) - Fold 0 - Validation Loss : 0.6942
# Epoch(8) - Fold 0 - Validation Accuracy : 0.5223
# Epoch(8) - Fold 0 - Validation Utility score : 303.7674
# Epoch(8) - Fold 1 - Validation Loss : 0.6940
# Epoch(8) - Fold 1 - Validation Accuracy : 0.5236
# Epoch(8) - Fold 1 - Validation Utility score : 1181.4728
# Epoch(8) - Fold 2 - Validation Loss : 0.6950
# Epoch(8) - Fold 2 - Validation Accuracy : 0.5052
# Epoch(8) - Fold 2 - Validation Utility score : -0.0000
# Epoch(8) - Fold 3 - Validation Loss : 0.6947
# Epoch(8) - Fold 3 - Validation Accuracy : 0.5073
# Epoch(8) - Fold 3 - Validation Utility score : -0.0000
# Epoch(8) - Fold 4 - Validation Loss : 0.6942
# Epoch(8) - Fold 4 - Validation Accuracy : 0.5176
# Epoch(8) - Fold 4 - Validation Utility score : 1318.9101
# Epoch(8) - GLOBAL - Validation Loss: 0.6944
# Epoch(8) - GLOBAL - Validation Accuracy: 0.5152
# Epoch(8) - GLOBAL - Validation Utility score: 2804.1504
# Saving model corresponding to last_utility_score == 2804.1504050696485
#
#
# Epoch(9) - Training Loss: 0.7021
# Epoch(9) - Fold 0 - Validation Loss : 0.6939
# Epoch(9) - Fold 0 - Validation Accuracy : 0.5234
# Epoch(9) - Fold 0 - Validation Utility score : 376.0267
# Epoch(9) - Fold 1 - Validation Loss : 0.6937
# Epoch(9) - Fold 1 - Validation Accuracy : 0.5228
# Epoch(9) - Fold 1 - Validation Utility score : 1046.7757
# Epoch(9) - Fold 2 - Validation Loss : 0.6946
# Epoch(9) - Fold 2 - Validation Accuracy : 0.5052
# Epoch(9) - Fold 2 - Validation Utility score : -0.0000
# Epoch(9) - Fold 3 - Validation Loss : 0.6944
# Epoch(9) - Fold 3 - Validation Accuracy : 0.5072
# Epoch(9) - Fold 3 - Validation Utility score : -0.0000
# Epoch(9) - Fold 4 - Validation Loss : 0.6939
# Epoch(9) - Fold 4 - Validation Accuracy : 0.5181
# Epoch(9) - Fold 4 - Validation Utility score : 1271.4033
# Epoch(9) - GLOBAL - Validation Loss: 0.6941
# Epoch(9) - GLOBAL - Validation Accuracy: 0.5154
# Epoch(9) - GLOBAL - Validation Utility score: 2694.2056
# Saving model corresponding to last_utility_score == 2694.205603219926
#
#
# Epoch(10) - Training Loss: 0.7001
# Epoch(10) - Fold 0 - Validation Loss : 0.6936
# Epoch(10) - Fold 0 - Validation Accuracy : 0.5206
# Epoch(10) - Fold 0 - Validation Utility score : 298.6084
# Epoch(10) - Fold 1 - Validation Loss : 0.6936
# Epoch(10) - Fold 1 - Validation Accuracy : 0.5207
# Epoch(10) - Fold 1 - Validation Utility score : 1185.9707
# Epoch(10) - Fold 2 - Validation Loss : 0.6944
# Epoch(10) - Fold 2 - Validation Accuracy : 0.5040
# Epoch(10) - Fold 2 - Validation Utility score : -0.0000
# Epoch(10) - Fold 3 - Validation Loss : 0.6941
# Epoch(10) - Fold 3 - Validation Accuracy : 0.5077
# Epoch(10) - Fold 3 - Validation Utility score : -0.0000
# Epoch(10) - Fold 4 - Validation Loss : 0.6936
# Epoch(10) - Fold 4 - Validation Accuracy : 0.5194
# Epoch(10) - Fold 4 - Validation Utility score : 1234.8802
# Epoch(10) - GLOBAL - Validation Loss: 0.6939
# Epoch(10) - GLOBAL - Validation Accuracy: 0.5145
# Epoch(10) - GLOBAL - Validation Utility score: 2719.4594
# Saving model corresponding to last_utility_score == 2719.4593669775168
#
#
# Epoch(11) - Training Loss: 0.6990
# Epoch(11) - Fold 0 - Validation Loss : 0.6935
# Epoch(11) - Fold 0 - Validation Accuracy : 0.5205
# Epoch(11) - Fold 0 - Validation Utility score : 302.5520
# Epoch(11) - Fold 1 - Validation Loss : 0.6934
# Epoch(11) - Fold 1 - Validation Accuracy : 0.5207
# Epoch(11) - Fold 1 - Validation Utility score : 1157.2449
# Epoch(11) - Fold 2 - Validation Loss : 0.6942
# Epoch(11) - Fold 2 - Validation Accuracy : 0.5048
# Epoch(11) - Fold 2 - Validation Utility score : -0.0000
# Epoch(11) - Fold 3 - Validation Loss : 0.6939
# Epoch(11) - Fold 3 - Validation Accuracy : 0.5085
# Epoch(11) - Fold 3 - Validation Utility score : -0.0000
# Epoch(11) - Fold 4 - Validation Loss : 0.6935
# Epoch(11) - Fold 4 - Validation Accuracy : 0.5194
# Epoch(11) - Fold 4 - Validation Utility score : 1239.5228
# Epoch(11) - GLOBAL - Validation Loss: 0.6937
# Epoch(11) - GLOBAL - Validation Accuracy: 0.5148
# Epoch(11) - GLOBAL - Validation Utility score: 2699.3197
# Saving model corresponding to last_utility_score == 2699.3197028302893
#
#
# Epoch(12) - Training Loss: 0.6979
# Epoch(12) - Fold 0 - Validation Loss : 0.6934
# Epoch(12) - Fold 0 - Validation Accuracy : 0.5207
# Epoch(12) - Fold 0 - Validation Utility score : 357.6800
# Epoch(12) - Fold 1 - Validation Loss : 0.6933
# Epoch(12) - Fold 1 - Validation Accuracy : 0.5214
# Epoch(12) - Fold 1 - Validation Utility score : 1144.2332
# Epoch(12) - Fold 2 - Validation Loss : 0.6941
# Epoch(12) - Fold 2 - Validation Accuracy : 0.5049
# Epoch(12) - Fold 2 - Validation Utility score : -0.0000
# Epoch(12) - Fold 3 - Validation Loss : 0.6938
# Epoch(12) - Fold 3 - Validation Accuracy : 0.5083
# Epoch(12) - Fold 3 - Validation Utility score : -0.0000
# Epoch(12) - Fold 4 - Validation Loss : 0.6934
# Epoch(12) - Fold 4 - Validation Accuracy : 0.5197
# Epoch(12) - Fold 4 - Validation Utility score : 1233.0500
# Epoch(12) - GLOBAL - Validation Loss: 0.6936
# Epoch(12) - GLOBAL - Validation Accuracy: 0.5150
# Epoch(12) - GLOBAL - Validation Utility score: 2734.9632
# Saving model corresponding to last_utility_score == 2734.9632321995787
#
#
# Epoch(13) - Training Loss: 0.6971
# Epoch(13) - Fold 0 - Validation Loss : 0.6933
# Epoch(13) - Fold 0 - Validation Accuracy : 0.5217
# Epoch(13) - Fold 0 - Validation Utility score : 353.9030
# Epoch(13) - Fold 1 - Validation Loss : 0.6932
# Epoch(13) - Fold 1 - Validation Accuracy : 0.5213
# Epoch(13) - Fold 1 - Validation Utility score : 998.8553
# Epoch(13) - Fold 2 - Validation Loss : 0.6940
# Epoch(13) - Fold 2 - Validation Accuracy : 0.5051
# Epoch(13) - Fold 2 - Validation Utility score : -0.0000
# Epoch(13) - Fold 3 - Validation Loss : 0.6937
# Epoch(13) - Fold 3 - Validation Accuracy : 0.5093
# Epoch(13) - Fold 3 - Validation Utility score : -0.0000
# Epoch(13) - Fold 4 - Validation Loss : 0.6933
# Epoch(13) - Fold 4 - Validation Accuracy : 0.5192
# Epoch(13) - Fold 4 - Validation Utility score : 1027.8976
# Epoch(13) - GLOBAL - Validation Loss: 0.6935
# Epoch(13) - GLOBAL - Validation Accuracy: 0.5153
# Epoch(13) - GLOBAL - Validation Utility score: 2380.6560
# Saving model corresponding to last_utility_score == 2380.655993931048
#
#
# Epoch(14) - Training Loss: 0.6965
# Epoch(14) - Fold 0 - Validation Loss : 0.6933
# Epoch(14) - Fold 0 - Validation Accuracy : 0.5212
# Epoch(14) - Fold 0 - Validation Utility score : 356.9420
# Epoch(14) - Fold 1 - Validation Loss : 0.6932
# Epoch(14) - Fold 1 - Validation Accuracy : 0.5209
# Epoch(14) - Fold 1 - Validation Utility score : 1055.6779
# Epoch(14) - Fold 2 - Validation Loss : 0.6940
# Epoch(14) - Fold 2 - Validation Accuracy : 0.5050
# Epoch(14) - Fold 2 - Validation Utility score : -0.0000
# Epoch(14) - Fold 3 - Validation Loss : 0.6937
# Epoch(14) - Fold 3 - Validation Accuracy : 0.5103
# Epoch(14) - Fold 3 - Validation Utility score : -0.0000
# Epoch(14) - Fold 4 - Validation Loss : 0.6933
# Epoch(14) - Fold 4 - Validation Accuracy : 0.5195
# Epoch(14) - Fold 4 - Validation Utility score : 996.8751
# Epoch(14) - GLOBAL - Validation Loss: 0.6935
# Epoch(14) - GLOBAL - Validation Accuracy: 0.5154
# Epoch(14) - GLOBAL - Validation Utility score: 2409.4950
# Saving model corresponding to last_utility_score == 2409.495001898874
#
#
# Epoch(15) - Training Loss: 0.6959
# Epoch(15) - Fold 0 - Validation Loss : 0.6933
# Epoch(15) - Fold 0 - Validation Accuracy : 0.5207
# Epoch(15) - Fold 0 - Validation Utility score : 363.2000
# Epoch(15) - Fold 1 - Validation Loss : 0.6932
# Epoch(15) - Fold 1 - Validation Accuracy : 0.5204
# Epoch(15) - Fold 1 - Validation Utility score : 1086.5394
# Epoch(15) - Fold 2 - Validation Loss : 0.6939
# Epoch(15) - Fold 2 - Validation Accuracy : 0.5058
# Epoch(15) - Fold 2 - Validation Utility score : -0.0000
# Epoch(15) - Fold 3 - Validation Loss : 0.6936
# Epoch(15) - Fold 3 - Validation Accuracy : 0.5102
# Epoch(15) - Fold 3 - Validation Utility score : -0.0000
# Epoch(15) - Fold 4 - Validation Loss : 0.6933
# Epoch(15) - Fold 4 - Validation Accuracy : 0.5200
# Epoch(15) - Fold 4 - Validation Utility score : 997.3525
# Epoch(15) - GLOBAL - Validation Loss: 0.6934
# Epoch(15) - GLOBAL - Validation Accuracy: 0.5154
# Epoch(15) - GLOBAL - Validation Utility score: 2447.0919
# Saving model corresponding to last_utility_score == 2447.0919358358733
#
#
# Epoch(16) - Training Loss: 0.6955
# Epoch(16) - Fold 0 - Validation Loss : 0.6932
# Epoch(16) - Fold 0 - Validation Accuracy : 0.5217
# Epoch(16) - Fold 0 - Validation Utility score : 387.9282
# Epoch(16) - Fold 1 - Validation Loss : 0.6931
# Epoch(16) - Fold 1 - Validation Accuracy : 0.5202
# Epoch(16) - Fold 1 - Validation Utility score : 896.6421
# Epoch(16) - Fold 2 - Validation Loss : 0.6939
# Epoch(16) - Fold 2 - Validation Accuracy : 0.5044
# Epoch(16) - Fold 2 - Validation Utility score : -0.0000
# Epoch(16) - Fold 3 - Validation Loss : 0.6936
# Epoch(16) - Fold 3 - Validation Accuracy : 0.5098
# Epoch(16) - Fold 3 - Validation Utility score : -0.0000
# Epoch(16) - Fold 4 - Validation Loss : 0.6932
# Epoch(16) - Fold 4 - Validation Accuracy : 0.5191
# Epoch(16) - Fold 4 - Validation Utility score : 972.1727
# Epoch(16) - GLOBAL - Validation Loss: 0.6934
# Epoch(16) - GLOBAL - Validation Accuracy: 0.5151
# Epoch(16) - GLOBAL - Validation Utility score: 2256.7429
# Saving model corresponding to last_utility_score == 2256.7429001659107
#
#
# Epoch(17) - Training Loss: 0.6953
# Epoch(17) - Fold 0 - Validation Loss : 0.6932
# Epoch(17) - Fold 0 - Validation Accuracy : 0.5217
# Epoch(17) - Fold 0 - Validation Utility score : 446.8588
# Epoch(17) - Fold 1 - Validation Loss : 0.6931
# Epoch(17) - Fold 1 - Validation Accuracy : 0.5202
# Epoch(17) - Fold 1 - Validation Utility score : 1005.4192
# Epoch(17) - Fold 2 - Validation Loss : 0.6939
# Epoch(17) - Fold 2 - Validation Accuracy : 0.5048
# Epoch(17) - Fold 2 - Validation Utility score : -0.0000
# Epoch(17) - Fold 3 - Validation Loss : 0.6936
# Epoch(17) - Fold 3 - Validation Accuracy : 0.5096
# Epoch(17) - Fold 3 - Validation Utility score : -0.0000
# Epoch(17) - Fold 4 - Validation Loss : 0.6932
# Epoch(17) - Fold 4 - Validation Accuracy : 0.5197
# Epoch(17) - Fold 4 - Validation Utility score : 990.8009
# Epoch(17) - GLOBAL - Validation Loss: 0.6934
# Epoch(17) - GLOBAL - Validation Accuracy: 0.5152
# Epoch(17) - GLOBAL - Validation Utility score: 2443.0788
# Saving model corresponding to last_utility_score == 2443.0787981521
#
#
# Epoch(18) - Training Loss: 0.6950
# Epoch(18) - Fold 0 - Validation Loss : 0.6932
# Epoch(18) - Fold 0 - Validation Accuracy : 0.5217
# Epoch(18) - Fold 0 - Validation Utility score : 378.9617
# Epoch(18) - Fold 1 - Validation Loss : 0.6931
# Epoch(18) - Fold 1 - Validation Accuracy : 0.5204
# Epoch(18) - Fold 1 - Validation Utility score : 809.0692
# Epoch(18) - Fold 2 - Validation Loss : 0.6938
# Epoch(18) - Fold 2 - Validation Accuracy : 0.5050
# Epoch(18) - Fold 2 - Validation Utility score : -0.0000
# Epoch(18) - Fold 3 - Validation Loss : 0.6935
# Epoch(18) - Fold 3 - Validation Accuracy : 0.5099
# Epoch(18) - Fold 3 - Validation Utility score : -0.0000
# Epoch(18) - Fold 4 - Validation Loss : 0.6932
# Epoch(18) - Fold 4 - Validation Accuracy : 0.5191
# Epoch(18) - Fold 4 - Validation Utility score : 864.6226
# Epoch(18) - GLOBAL - Validation Loss: 0.6934
# Epoch(18) - GLOBAL - Validation Accuracy: 0.5152
# Epoch(18) - GLOBAL - Validation Utility score: 2052.6535
# Saving model corresponding to last_utility_score == 2052.653454959228
#
#
# Epoch(19) - Training Loss: 0.6948
# Epoch(19) - Fold 0 - Validation Loss : 0.6932
# Epoch(19) - Fold 0 - Validation Accuracy : 0.5225
# Epoch(19) - Fold 0 - Validation Utility score : 434.4399
# Epoch(19) - Fold 1 - Validation Loss : 0.6931
# Epoch(19) - Fold 1 - Validation Accuracy : 0.5202
# Epoch(19) - Fold 1 - Validation Utility score : 955.9555
# Epoch(19) - Fold 2 - Validation Loss : 0.6938
# Epoch(19) - Fold 2 - Validation Accuracy : 0.5045
# Epoch(19) - Fold 2 - Validation Utility score : -0.0000
# Epoch(19) - Fold 3 - Validation Loss : 0.6935
# Epoch(19) - Fold 3 - Validation Accuracy : 0.5106
# Epoch(19) - Fold 3 - Validation Utility score : -0.0000
# Epoch(19) - Fold 4 - Validation Loss : 0.6932
# Epoch(19) - Fold 4 - Validation Accuracy : 0.5192
# Epoch(19) - Fold 4 - Validation Utility score : 862.5237
# Epoch(19) - GLOBAL - Validation Loss: 0.6934
# Epoch(19) - GLOBAL - Validation Accuracy: 0.5154
# Epoch(19) - GLOBAL - Validation Utility score: 2252.9191
# Saving model corresponding to last_utility_score == 2252.919115106187
#
#
# Epoch(20) - Training Loss: 0.6946
# Epoch(20) - Fold 0 - Validation Loss : 0.6931
# Epoch(20) - Fold 0 - Validation Accuracy : 0.5224
# Epoch(20) - Fold 0 - Validation Utility score : 499.8202
# Epoch(20) - Fold 1 - Validation Loss : 0.6931
# Epoch(20) - Fold 1 - Validation Accuracy : 0.5198
# Epoch(20) - Fold 1 - Validation Utility score : 1027.6621
# Epoch(20) - Fold 2 - Validation Loss : 0.6938
# Epoch(20) - Fold 2 - Validation Accuracy : 0.5052
# Epoch(20) - Fold 2 - Validation Utility score : -0.0000
# Epoch(20) - Fold 3 - Validation Loss : 0.6935
# Epoch(20) - Fold 3 - Validation Accuracy : 0.5091
# Epoch(20) - Fold 3 - Validation Utility score : -0.0000
# Epoch(20) - Fold 4 - Validation Loss : 0.6932
# Epoch(20) - Fold 4 - Validation Accuracy : 0.5210
# Epoch(20) - Fold 4 - Validation Utility score : 1105.4832
# Epoch(20) - GLOBAL - Validation Loss: 0.6934
# Epoch(20) - GLOBAL - Validation Accuracy: 0.5155
# Epoch(20) - GLOBAL - Validation Utility score: 2632.9655
# Saving model corresponding to last_utility_score == 2632.9654736815355
#
#
# Epoch(21) - Training Loss: 0.6944
# Epoch(21) - Fold 0 - Validation Loss : 0.6931
# Epoch(21) - Fold 0 - Validation Accuracy : 0.5226
# Epoch(21) - Fold 0 - Validation Utility score : 486.4027
# Epoch(21) - Fold 1 - Validation Loss : 0.6931
# Epoch(21) - Fold 1 - Validation Accuracy : 0.5198
# Epoch(21) - Fold 1 - Validation Utility score : 1100.4016
# Epoch(21) - Fold 2 - Validation Loss : 0.6938
# Epoch(21) - Fold 2 - Validation Accuracy : 0.5053
# Epoch(21) - Fold 2 - Validation Utility score : -0.0000
# Epoch(21) - Fold 3 - Validation Loss : 0.6935
# Epoch(21) - Fold 3 - Validation Accuracy : 0.5108
# Epoch(21) - Fold 3 - Validation Utility score : -0.0000
# Epoch(21) - Fold 4 - Validation Loss : 0.6932
# Epoch(21) - Fold 4 - Validation Accuracy : 0.5205
# Epoch(21) - Fold 4 - Validation Utility score : 955.4790
# Epoch(21) - GLOBAL - Validation Loss: 0.6933
# Epoch(21) - GLOBAL - Validation Accuracy: 0.5158
# Epoch(21) - GLOBAL - Validation Utility score: 2542.2833
# Saving model corresponding to last_utility_score == 2542.2832592180275
#
#
# Epoch(22) - Training Loss: 0.6943
# Epoch(22) - Fold 0 - Validation Loss : 0.6931
# Epoch(22) - Fold 0 - Validation Accuracy : 0.5228
# Epoch(22) - Fold 0 - Validation Utility score : 497.2825
# Epoch(22) - Fold 1 - Validation Loss : 0.6931
# Epoch(22) - Fold 1 - Validation Accuracy : 0.5199
# Epoch(22) - Fold 1 - Validation Utility score : 1073.5587
# Epoch(22) - Fold 2 - Validation Loss : 0.6938
# Epoch(22) - Fold 2 - Validation Accuracy : 0.5046
# Epoch(22) - Fold 2 - Validation Utility score : -0.0000
# Epoch(22) - Fold 3 - Validation Loss : 0.6935
# Epoch(22) - Fold 3 - Validation Accuracy : 0.5098
# Epoch(22) - Fold 3 - Validation Utility score : -0.0000
# Epoch(22) - Fold 4 - Validation Loss : 0.6932
# Epoch(22) - Fold 4 - Validation Accuracy : 0.5210
# Epoch(22) - Fold 4 - Validation Utility score : 1047.7261
# Epoch(22) - GLOBAL - Validation Loss: 0.6933
# Epoch(22) - GLOBAL - Validation Accuracy: 0.5156
# Epoch(22) - GLOBAL - Validation Utility score: 2618.5674
# Intermediate early stopping : vepoch_loss = 0.6933, the_last_loss=0.6933
#
#
# Epoch(23) - Training Loss: 0.6942
# Epoch(23) - Fold 0 - Validation Loss : 0.6931
# Epoch(23) - Fold 0 - Validation Accuracy : 0.5232
# Epoch(23) - Fold 0 - Validation Utility score : 537.6786
# Epoch(23) - Fold 1 - Validation Loss : 0.6931
# Epoch(23) - Fold 1 - Validation Accuracy : 0.5198
# Epoch(23) - Fold 1 - Validation Utility score : 1112.8253
# Epoch(23) - Fold 2 - Validation Loss : 0.6938
# Epoch(23) - Fold 2 - Validation Accuracy : 0.5048
# Epoch(23) - Fold 2 - Validation Utility score : -0.0000
# Epoch(23) - Fold 3 - Validation Loss : 0.6935
# Epoch(23) - Fold 3 - Validation Accuracy : 0.5089
# Epoch(23) - Fold 3 - Validation Utility score : -0.0000
# Epoch(23) - Fold 4 - Validation Loss : 0.6932
# Epoch(23) - Fold 4 - Validation Accuracy : 0.5214
# Epoch(23) - Fold 4 - Validation Utility score : 1176.3385
# Epoch(23) - GLOBAL - Validation Loss: 0.6933
# Epoch(23) - GLOBAL - Validation Accuracy: 0.5156
# Epoch(23) - GLOBAL - Validation Utility score: 2826.8424
# Saving model corresponding to last_utility_score == 2826.842404352144
#
#
# Epoch(24) - Training Loss: 0.6941
# Epoch(24) - Fold 0 - Validation Loss : 0.6931
# Epoch(24) - Fold 0 - Validation Accuracy : 0.5225
# Epoch(24) - Fold 0 - Validation Utility score : 351.2031
# Epoch(24) - Fold 1 - Validation Loss : 0.6930
# Epoch(24) - Fold 1 - Validation Accuracy : 0.5205
# Epoch(24) - Fold 1 - Validation Utility score : 725.1411
# Epoch(24) - Fold 2 - Validation Loss : 0.6938
# Epoch(24) - Fold 2 - Validation Accuracy : 0.5045
# Epoch(24) - Fold 2 - Validation Utility score : -0.0000
# Epoch(24) - Fold 3 - Validation Loss : 0.6935
# Epoch(24) - Fold 3 - Validation Accuracy : 0.5104
# Epoch(24) - Fold 3 - Validation Utility score : -0.0000
# Epoch(24) - Fold 4 - Validation Loss : 0.6932
# Epoch(24) - Fold 4 - Validation Accuracy : 0.5183
# Epoch(24) - Fold 4 - Validation Utility score : 921.7571
# Epoch(24) - GLOBAL - Validation Loss: 0.6933
# Epoch(24) - GLOBAL - Validation Accuracy: 0.5152
# Epoch(24) - GLOBAL - Validation Utility score: 1998.1014
# Saving model corresponding to last_utility_score == 1998.1013532446973
#
#
# Epoch(25) - Training Loss: 0.6940
# Epoch(25) - Fold 0 - Validation Loss : 0.6931
# Epoch(25) - Fold 0 - Validation Accuracy : 0.5238
# Epoch(25) - Fold 0 - Validation Utility score : 570.6150
# Epoch(25) - Fold 1 - Validation Loss : 0.6930
# Epoch(25) - Fold 1 - Validation Accuracy : 0.5196
# Epoch(25) - Fold 1 - Validation Utility score : 1021.6429
# Epoch(25) - Fold 2 - Validation Loss : 0.6938
# Epoch(25) - Fold 2 - Validation Accuracy : 0.5047
# Epoch(25) - Fold 2 - Validation Utility score : -0.0000
# Epoch(25) - Fold 3 - Validation Loss : 0.6935
# Epoch(25) - Fold 3 - Validation Accuracy : 0.5093
# Epoch(25) - Fold 3 - Validation Utility score : -0.0000
# Epoch(25) - Fold 4 - Validation Loss : 0.6932
# Epoch(25) - Fold 4 - Validation Accuracy : 0.5213
# Epoch(25) - Fold 4 - Validation Utility score : 1102.6269
# Epoch(25) - GLOBAL - Validation Loss: 0.6933
# Epoch(25) - GLOBAL - Validation Accuracy: 0.5157
# Epoch(25) - GLOBAL - Validation Utility score: 2694.8849
# Saving model corresponding to last_utility_score == 2694.884854077808
#
#
# Epoch(26) - Training Loss: 0.6939
# Epoch(26) - Fold 0 - Validation Loss : 0.6931
# Epoch(26) - Fold 0 - Validation Accuracy : 0.5236
# Epoch(26) - Fold 0 - Validation Utility score : 554.7425
# Epoch(26) - Fold 1 - Validation Loss : 0.6930
# Epoch(26) - Fold 1 - Validation Accuracy : 0.5202
# Epoch(26) - Fold 1 - Validation Utility score : 1000.8136
# Epoch(26) - Fold 2 - Validation Loss : 0.6938
# Epoch(26) - Fold 2 - Validation Accuracy : 0.5042
# Epoch(26) - Fold 2 - Validation Utility score : -0.0000
# Epoch(26) - Fold 3 - Validation Loss : 0.6935
# Epoch(26) - Fold 3 - Validation Accuracy : 0.5093
# Epoch(26) - Fold 3 - Validation Utility score : -0.0000
# Epoch(26) - Fold 4 - Validation Loss : 0.6931
# Epoch(26) - Fold 4 - Validation Accuracy : 0.5215
# Epoch(26) - Fold 4 - Validation Utility score : 1077.2651
# Epoch(26) - GLOBAL - Validation Loss: 0.6933
# Epoch(26) - GLOBAL - Validation Accuracy: 0.5158
# Epoch(26) - GLOBAL - Validation Utility score: 2632.8213
# Saving model corresponding to last_utility_score == 2632.821301198521
#
#
# Epoch(27) - Training Loss: 0.6938
# Epoch(27) - Fold 0 - Validation Loss : 0.6931
# Epoch(27) - Fold 0 - Validation Accuracy : 0.5238
# Epoch(27) - Fold 0 - Validation Utility score : 496.3232
# Epoch(27) - Fold 1 - Validation Loss : 0.6930
# Epoch(27) - Fold 1 - Validation Accuracy : 0.5205
# Epoch(27) - Fold 1 - Validation Utility score : 817.9561
# Epoch(27) - Fold 2 - Validation Loss : 0.6938
# Epoch(27) - Fold 2 - Validation Accuracy : 0.5050
# Epoch(27) - Fold 2 - Validation Utility score : -0.0000
# Epoch(27) - Fold 3 - Validation Loss : 0.6935
# Epoch(27) - Fold 3 - Validation Accuracy : 0.5106
# Epoch(27) - Fold 3 - Validation Utility score : -0.0000
# Epoch(27) - Fold 4 - Validation Loss : 0.6931
# Epoch(27) - Fold 4 - Validation Accuracy : 0.5198
# Epoch(27) - Fold 4 - Validation Utility score : 1033.7147
# Epoch(27) - GLOBAL - Validation Loss: 0.6933
# Epoch(27) - GLOBAL - Validation Accuracy: 0.5160
# Epoch(27) - GLOBAL - Validation Utility score: 2347.9939
# Saving model corresponding to last_utility_score == 2347.9939175243926
#
#
# Epoch(28) - Training Loss: 0.6937
# Epoch(28) - Fold 0 - Validation Loss : 0.6930
# Epoch(28) - Fold 0 - Validation Accuracy : 0.5239
# Epoch(28) - Fold 0 - Validation Utility score : 588.4183
# Epoch(28) - Fold 1 - Validation Loss : 0.6930
# Epoch(28) - Fold 1 - Validation Accuracy : 0.5200
# Epoch(28) - Fold 1 - Validation Utility score : 980.9437
# Epoch(28) - Fold 2 - Validation Loss : 0.6938
# Epoch(28) - Fold 2 - Validation Accuracy : 0.5046
# Epoch(28) - Fold 2 - Validation Utility score : -0.0000
# Epoch(28) - Fold 3 - Validation Loss : 0.6935
# Epoch(28) - Fold 3 - Validation Accuracy : 0.5094
# Epoch(28) - Fold 3 - Validation Utility score : -0.0000
# Epoch(28) - Fold 4 - Validation Loss : 0.6931
# Epoch(28) - Fold 4 - Validation Accuracy : 0.5220
# Epoch(28) - Fold 4 - Validation Utility score : 1163.9679
# Epoch(28) - GLOBAL - Validation Loss: 0.6933
# Epoch(28) - GLOBAL - Validation Accuracy: 0.5160
# Epoch(28) - GLOBAL - Validation Utility score: 2733.3299
# Saving model corresponding to last_utility_score == 2733.3299169886595
#
#
# Epoch(29) - Training Loss: 0.6937
# Epoch(29) - Fold 0 - Validation Loss : 0.6930
# Epoch(29) - Fold 0 - Validation Accuracy : 0.5245
# Epoch(29) - Fold 0 - Validation Utility score : 561.8409
# Epoch(29) - Fold 1 - Validation Loss : 0.6929
# Epoch(29) - Fold 1 - Validation Accuracy : 0.5202
# Epoch(29) - Fold 1 - Validation Utility score : 812.8614
# Epoch(29) - Fold 2 - Validation Loss : 0.6937
# Epoch(29) - Fold 2 - Validation Accuracy : 0.5051
# Epoch(29) - Fold 2 - Validation Utility score : -0.0000
# Epoch(29) - Fold 3 - Validation Loss : 0.6935
# Epoch(29) - Fold 3 - Validation Accuracy : 0.5105
# Epoch(29) - Fold 3 - Validation Utility score : -0.0000
# Epoch(29) - Fold 4 - Validation Loss : 0.6931
# Epoch(29) - Fold 4 - Validation Accuracy : 0.5199
# Epoch(29) - Fold 4 - Validation Utility score : 1083.8331
# Epoch(29) - GLOBAL - Validation Loss: 0.6933
# Epoch(29) - GLOBAL - Validation Accuracy: 0.5160
# Epoch(29) - GLOBAL - Validation Utility score: 2458.5353
# Saving model corresponding to last_utility_score == 2458.535327309657
#
#
# Epoch(30) - Training Loss: 0.6937
# Epoch(30) - Fold 0 - Validation Loss : 0.6930
# Epoch(30) - Fold 0 - Validation Accuracy : 0.5218
# Epoch(30) - Fold 0 - Validation Utility score : 593.3321
# Epoch(30) - Fold 1 - Validation Loss : 0.6930
# Epoch(30) - Fold 1 - Validation Accuracy : 0.5195
# Epoch(30) - Fold 1 - Validation Utility score : 1091.2335
# Epoch(30) - Fold 2 - Validation Loss : 0.6938
# Epoch(30) - Fold 2 - Validation Accuracy : 0.5051
# Epoch(30) - Fold 2 - Validation Utility score : -0.0000
# Epoch(30) - Fold 3 - Validation Loss : 0.6935
# Epoch(30) - Fold 3 - Validation Accuracy : 0.5085
# Epoch(30) - Fold 3 - Validation Utility score : -0.0000
# Epoch(30) - Fold 4 - Validation Loss : 0.6931
# Epoch(30) - Fold 4 - Validation Accuracy : 0.5226
# Epoch(30) - Fold 4 - Validation Utility score : 1241.7317
# Epoch(30) - GLOBAL - Validation Loss: 0.6933
# Epoch(30) - GLOBAL - Validation Accuracy: 0.5155
# Epoch(30) - GLOBAL - Validation Utility score: 2926.2973
# Intermediate early stopping : vepoch_loss = 0.6933, the_last_loss=0.6933
#
#
# Epoch(31) - Training Loss: 0.6936
# Epoch(31) - Fold 0 - Validation Loss : 0.6930
# Epoch(31) - Fold 0 - Validation Accuracy : 0.5248
# Epoch(31) - Fold 0 - Validation Utility score : 358.8811
# Epoch(31) - Fold 1 - Validation Loss : 0.6929
# Epoch(31) - Fold 1 - Validation Accuracy : 0.5215
# Epoch(31) - Fold 1 - Validation Utility score : 621.6475
# Epoch(31) - Fold 2 - Validation Loss : 0.6937
# Epoch(31) - Fold 2 - Validation Accuracy : 0.5054
# Epoch(31) - Fold 2 - Validation Utility score : -0.0000
# Epoch(31) - Fold 3 - Validation Loss : 0.6935
# Epoch(31) - Fold 3 - Validation Accuracy : 0.5110
# Epoch(31) - Fold 3 - Validation Utility score : -0.0000
# Epoch(31) - Fold 4 - Validation Loss : 0.6931
# Epoch(31) - Fold 4 - Validation Accuracy : 0.5164
# Epoch(31) - Fold 4 - Validation Utility score : 933.6631
# Epoch(31) - GLOBAL - Validation Loss: 0.6932
# Epoch(31) - GLOBAL - Validation Accuracy: 0.5158
# Epoch(31) - GLOBAL - Validation Utility score: 1914.1917
# Saving model corresponding to last_utility_score == 1914.191709731593
#
#
# Epoch(32) - Training Loss: 0.6936
# Epoch(32) - Fold 0 - Validation Loss : 0.6930
# Epoch(32) - Fold 0 - Validation Accuracy : 0.5249
# Epoch(32) - Fold 0 - Validation Utility score : 560.8654
# Epoch(32) - Fold 1 - Validation Loss : 0.6929
# Epoch(32) - Fold 1 - Validation Accuracy : 0.5208
# Epoch(32) - Fold 1 - Validation Utility score : 878.5906
# Epoch(32) - Fold 2 - Validation Loss : 0.6937
# Epoch(32) - Fold 2 - Validation Accuracy : 0.5058
# Epoch(32) - Fold 2 - Validation Utility score : -0.0000
# Epoch(32) - Fold 3 - Validation Loss : 0.6935
# Epoch(32) - Fold 3 - Validation Accuracy : 0.5104
# Epoch(32) - Fold 3 - Validation Utility score : -0.0000
# Epoch(32) - Fold 4 - Validation Loss : 0.6931
# Epoch(32) - Fold 4 - Validation Accuracy : 0.5207
# Epoch(32) - Fold 4 - Validation Utility score : 1015.9511
# Epoch(32) - GLOBAL - Validation Loss: 0.6932
# Epoch(32) - GLOBAL - Validation Accuracy: 0.5165
# Epoch(32) - GLOBAL - Validation Utility score: 2455.4071
# Saving model corresponding to last_utility_score == 2455.407063289763
#
#
# Epoch(33) - Training Loss: 0.6935
# Epoch(33) - Fold 0 - Validation Loss : 0.6930
# Epoch(33) - Fold 0 - Validation Accuracy : 0.5243
# Epoch(33) - Fold 0 - Validation Utility score : 304.3191
# Epoch(33) - Fold 1 - Validation Loss : 0.6929
# Epoch(33) - Fold 1 - Validation Accuracy : 0.5215
# Epoch(33) - Fold 1 - Validation Utility score : 623.0777
# Epoch(33) - Fold 2 - Validation Loss : 0.6937
# Epoch(33) - Fold 2 - Validation Accuracy : 0.5053
# Epoch(33) - Fold 2 - Validation Utility score : -0.0000
# Epoch(33) - Fold 3 - Validation Loss : 0.6935
# Epoch(33) - Fold 3 - Validation Accuracy : 0.5112
# Epoch(33) - Fold 3 - Validation Utility score : -0.0000
# Epoch(33) - Fold 4 - Validation Loss : 0.6931
# Epoch(33) - Fold 4 - Validation Accuracy : 0.5164
# Epoch(33) - Fold 4 - Validation Utility score : 915.0773
# Epoch(33) - GLOBAL - Validation Loss: 0.6932
# Epoch(33) - GLOBAL - Validation Accuracy: 0.5158
# Epoch(33) - GLOBAL - Validation Utility score: 1842.4740
# Intermediate early stopping : vepoch_loss = 0.6932, the_last_loss=0.6932
#
#
# Epoch(34) - Training Loss: 0.6934
# Epoch(34) - Fold 0 - Validation Loss : 0.6930
# Epoch(34) - Fold 0 - Validation Accuracy : 0.5248
# Epoch(34) - Fold 0 - Validation Utility score : 446.6092
# Epoch(34) - Fold 1 - Validation Loss : 0.6928
# Epoch(34) - Fold 1 - Validation Accuracy : 0.5218
# Epoch(34) - Fold 1 - Validation Utility score : 695.6505
# Epoch(34) - Fold 2 - Validation Loss : 0.6937
# Epoch(34) - Fold 2 - Validation Accuracy : 0.5067
# Epoch(34) - Fold 2 - Validation Utility score : -0.0000
# Epoch(34) - Fold 3 - Validation Loss : 0.6935
# Epoch(34) - Fold 3 - Validation Accuracy : 0.5110
# Epoch(34) - Fold 3 - Validation Utility score : -0.0000
# Epoch(34) - Fold 4 - Validation Loss : 0.6930
# Epoch(34) - Fold 4 - Validation Accuracy : 0.5182
# Epoch(34) - Fold 4 - Validation Utility score : 1030.0107
# Epoch(34) - GLOBAL - Validation Loss: 0.6932
# Epoch(34) - GLOBAL - Validation Accuracy: 0.5165
# Epoch(34) - GLOBAL - Validation Utility score: 2172.2704
# Saving model corresponding to last_utility_score == 2172.270389199049
#
#
# Epoch(35) - Training Loss: 0.6934
# Epoch(35) - Fold 0 - Validation Loss : 0.6930
# Epoch(35) - Fold 0 - Validation Accuracy : 0.5247
# Epoch(35) - Fold 0 - Validation Utility score : 492.9580
# Epoch(35) - Fold 1 - Validation Loss : 0.6928
# Epoch(35) - Fold 1 - Validation Accuracy : 0.5209
# Epoch(35) - Fold 1 - Validation Utility score : 714.7737
# Epoch(35) - Fold 2 - Validation Loss : 0.6937
# Epoch(35) - Fold 2 - Validation Accuracy : 0.5063
# Epoch(35) - Fold 2 - Validation Utility score : -0.0000
# Epoch(35) - Fold 3 - Validation Loss : 0.6935
# Epoch(35) - Fold 3 - Validation Accuracy : 0.5114
# Epoch(35) - Fold 3 - Validation Utility score : -0.0000
# Epoch(35) - Fold 4 - Validation Loss : 0.6930
# Epoch(35) - Fold 4 - Validation Accuracy : 0.5190
# Epoch(35) - Fold 4 - Validation Utility score : 1083.0886
# Epoch(35) - GLOBAL - Validation Loss: 0.6932
# Epoch(35) - GLOBAL - Validation Accuracy: 0.5165
# Epoch(35) - GLOBAL - Validation Utility score: 2290.8203
# Saving model corresponding to last_utility_score == 2290.8202923306308
#
#
# Epoch(36) - Training Loss: 0.6933
# Epoch(36) - Fold 0 - Validation Loss : 0.6930
# Epoch(36) - Fold 0 - Validation Accuracy : 0.5241
# Epoch(36) - Fold 0 - Validation Utility score : 395.4877
# Epoch(36) - Fold 1 - Validation Loss : 0.6928
# Epoch(36) - Fold 1 - Validation Accuracy : 0.5220
# Epoch(36) - Fold 1 - Validation Utility score : 710.9095
# Epoch(36) - Fold 2 - Validation Loss : 0.6937
# Epoch(36) - Fold 2 - Validation Accuracy : 0.5065
# Epoch(36) - Fold 2 - Validation Utility score : -0.0000
# Epoch(36) - Fold 3 - Validation Loss : 0.6935
# Epoch(36) - Fold 3 - Validation Accuracy : 0.5110
# Epoch(36) - Fold 3 - Validation Utility score : -0.0000
# Epoch(36) - Fold 4 - Validation Loss : 0.6930
# Epoch(36) - Fold 4 - Validation Accuracy : 0.5187
# Epoch(36) - Fold 4 - Validation Utility score : 1064.6769
# Epoch(36) - GLOBAL - Validation Loss: 0.6932
# Epoch(36) - GLOBAL - Validation Accuracy: 0.5165
# Epoch(36) - GLOBAL - Validation Utility score: 2171.0742
# Saving model corresponding to last_utility_score == 2171.0741591813826
#
#
# Epoch(37) - Training Loss: 0.6933
# Epoch(37) - Fold 0 - Validation Loss : 0.6930
# Epoch(37) - Fold 0 - Validation Accuracy : 0.5252
# Epoch(37) - Fold 0 - Validation Utility score : 552.5812
# Epoch(37) - Fold 1 - Validation Loss : 0.6928
# Epoch(37) - Fold 1 - Validation Accuracy : 0.5214
# Epoch(37) - Fold 1 - Validation Utility score : 841.3398
# Epoch(37) - Fold 2 - Validation Loss : 0.6937
# Epoch(37) - Fold 2 - Validation Accuracy : 0.5066
# Epoch(37) - Fold 2 - Validation Utility score : -0.0000
# Epoch(37) - Fold 3 - Validation Loss : 0.6935
# Epoch(37) - Fold 3 - Validation Accuracy : 0.5111
# Epoch(37) - Fold 3 - Validation Utility score : -0.0000
# Epoch(37) - Fold 4 - Validation Loss : 0.6930
# Epoch(37) - Fold 4 - Validation Accuracy : 0.5201
# Epoch(37) - Fold 4 - Validation Utility score : 1131.5925
# Epoch(37) - GLOBAL - Validation Loss: 0.6932
# Epoch(37) - GLOBAL - Validation Accuracy: 0.5169
# Epoch(37) - GLOBAL - Validation Utility score: 2525.5134
# Intermediate early stopping : vepoch_loss = 0.6932, the_last_loss=0.6932
#
#
# Epoch(38) - Training Loss: 0.6933
# Epoch(38) - Fold 0 - Validation Loss : 0.6930
# Epoch(38) - Fold 0 - Validation Accuracy : 0.5227
# Epoch(38) - Fold 0 - Validation Utility score : 244.8375
# Epoch(38) - Fold 1 - Validation Loss : 0.6928
# Epoch(38) - Fold 1 - Validation Accuracy : 0.5227
# Epoch(38) - Fold 1 - Validation Utility score : 495.4040
# Epoch(38) - Fold 2 - Validation Loss : 0.6937
# Epoch(38) - Fold 2 - Validation Accuracy : 0.5049
# Epoch(38) - Fold 2 - Validation Utility score : -0.0000
# Epoch(38) - Fold 3 - Validation Loss : 0.6935
# Epoch(38) - Fold 3 - Validation Accuracy : 0.5104
# Epoch(38) - Fold 3 - Validation Utility score : -0.0000
# Epoch(38) - Fold 4 - Validation Loss : 0.6930
# Epoch(38) - Fold 4 - Validation Accuracy : 0.5139
# Epoch(38) - Fold 4 - Validation Utility score : 676.2104
# Epoch(38) - GLOBAL - Validation Loss: 0.6932
# Epoch(38) - GLOBAL - Validation Accuracy: 0.5149
# Epoch(38) - GLOBAL - Validation Utility score: 1416.4519
# Intermediate early stopping : vepoch_loss = 0.6932, the_last_loss=0.6932
#
#
# Epoch(39) - Training Loss: 0.6932
# Epoch(39) - Fold 0 - Validation Loss : 0.6929
# Epoch(39) - Fold 0 - Validation Accuracy : 0.5248
# Epoch(39) - Fold 0 - Validation Utility score : 585.8416
# Epoch(39) - Fold 1 - Validation Loss : 0.6928
# Epoch(39) - Fold 1 - Validation Accuracy : 0.5206
# Epoch(39) - Fold 1 - Validation Utility score : 829.3359
# Epoch(39) - Fold 2 - Validation Loss : 0.6937
# Epoch(39) - Fold 2 - Validation Accuracy : 0.5063
# Epoch(39) - Fold 2 - Validation Utility score : -0.0000
# Epoch(39) - Fold 3 - Validation Loss : 0.6934
# Epoch(39) - Fold 3 - Validation Accuracy : 0.5106
# Epoch(39) - Fold 3 - Validation Utility score : -0.0000
# Epoch(39) - Fold 4 - Validation Loss : 0.6929
# Epoch(39) - Fold 4 - Validation Accuracy : 0.5220
# Epoch(39) - Fold 4 - Validation Utility score : 1264.5901
# Epoch(39) - GLOBAL - Validation Loss: 0.6932
# Epoch(39) - GLOBAL - Validation Accuracy: 0.5169
# Epoch(39) - GLOBAL - Validation Utility score: 2679.7676
# Saving model corresponding to last_utility_score == 2679.7675796033373
#
#
# Epoch(40) - Training Loss: 0.6932
# Epoch(40) - Fold 0 - Validation Loss : 0.6930
# Epoch(40) - Fold 0 - Validation Accuracy : 0.5235
# Epoch(40) - Fold 0 - Validation Utility score : 545.2170
# Epoch(40) - Fold 1 - Validation Loss : 0.6928
# Epoch(40) - Fold 1 - Validation Accuracy : 0.5210
# Epoch(40) - Fold 1 - Validation Utility score : 1136.6865
# Epoch(40) - Fold 2 - Validation Loss : 0.6937
# Epoch(40) - Fold 2 - Validation Accuracy : 0.5049
# Epoch(40) - Fold 2 - Validation Utility score : -0.0000
# Epoch(40) - Fold 3 - Validation Loss : 0.6934
# Epoch(40) - Fold 3 - Validation Accuracy : 0.5103
# Epoch(40) - Fold 3 - Validation Utility score : -0.0000
# Epoch(40) - Fold 4 - Validation Loss : 0.6929
# Epoch(40) - Fold 4 - Validation Accuracy : 0.5237
# Epoch(40) - Fold 4 - Validation Utility score : 1287.2208
# Epoch(40) - GLOBAL - Validation Loss: 0.6932
# Epoch(40) - GLOBAL - Validation Accuracy: 0.5167
# Epoch(40) - GLOBAL - Validation Utility score: 2969.1243
# Intermediate early stopping : vepoch_loss = 0.6932, the_last_loss=0.6932
#
#
# Epoch(41) - Training Loss: 0.6932
# Epoch(41) - Fold 0 - Validation Loss : 0.6930
# Epoch(41) - Fold 0 - Validation Accuracy : 0.5249
# Epoch(41) - Fold 0 - Validation Utility score : 514.3359
# Epoch(41) - Fold 1 - Validation Loss : 0.6928
# Epoch(41) - Fold 1 - Validation Accuracy : 0.5214
# Epoch(41) - Fold 1 - Validation Utility score : 800.3064
# Epoch(41) - Fold 2 - Validation Loss : 0.6937
# Epoch(41) - Fold 2 - Validation Accuracy : 0.5071
# Epoch(41) - Fold 2 - Validation Utility score : -0.0000
# Epoch(41) - Fold 3 - Validation Loss : 0.6934
# Epoch(41) - Fold 3 - Validation Accuracy : 0.5118
# Epoch(41) - Fold 3 - Validation Utility score : -0.0000
# Epoch(41) - Fold 4 - Validation Loss : 0.6929
# Epoch(41) - Fold 4 - Validation Accuracy : 0.5214
# Epoch(41) - Fold 4 - Validation Utility score : 1188.9031
# Epoch(41) - GLOBAL - Validation Loss: 0.6931
# Epoch(41) - GLOBAL - Validation Accuracy: 0.5173
# Epoch(41) - GLOBAL - Validation Utility score: 2503.5454
# Saving model corresponding to last_utility_score == 2503.5453764930435
#
#
# Epoch(42) - Training Loss: 0.6931
# Epoch(42) - Fold 0 - Validation Loss : 0.6929
# Epoch(42) - Fold 0 - Validation Accuracy : 0.5249
# Epoch(42) - Fold 0 - Validation Utility score : 605.7582
# Epoch(42) - Fold 1 - Validation Loss : 0.6928
# Epoch(42) - Fold 1 - Validation Accuracy : 0.5211
# Epoch(42) - Fold 1 - Validation Utility score : 939.2895
# Epoch(42) - Fold 2 - Validation Loss : 0.6937
# Epoch(42) - Fold 2 - Validation Accuracy : 0.5066
# Epoch(42) - Fold 2 - Validation Utility score : -0.0000
# Epoch(42) - Fold 3 - Validation Loss : 0.6934
# Epoch(42) - Fold 3 - Validation Accuracy : 0.5107
# Epoch(42) - Fold 3 - Validation Utility score : -0.0000
# Epoch(42) - Fold 4 - Validation Loss : 0.6929
# Epoch(42) - Fold 4 - Validation Accuracy : 0.5227
# Epoch(42) - Fold 4 - Validation Utility score : 1238.3673
# Epoch(42) - GLOBAL - Validation Loss: 0.6931
# Epoch(42) - GLOBAL - Validation Accuracy: 0.5172
# Epoch(42) - GLOBAL - Validation Utility score: 2783.4150
# Saving model corresponding to last_utility_score == 2783.4150292224303
#
#
# Epoch(43) - Training Loss: 0.6931
# Epoch(43) - Fold 0 - Validation Loss : 0.6929
# Epoch(43) - Fold 0 - Validation Accuracy : 0.5246
# Epoch(43) - Fold 0 - Validation Utility score : 464.4702
# Epoch(43) - Fold 1 - Validation Loss : 0.6927
# Epoch(43) - Fold 1 - Validation Accuracy : 0.5220
# Epoch(43) - Fold 1 - Validation Utility score : 825.4181
# Epoch(43) - Fold 2 - Validation Loss : 0.6936
# Epoch(43) - Fold 2 - Validation Accuracy : 0.5073
# Epoch(43) - Fold 2 - Validation Utility score : -0.0000
# Epoch(43) - Fold 3 - Validation Loss : 0.6934
# Epoch(43) - Fold 3 - Validation Accuracy : 0.5120
# Epoch(43) - Fold 3 - Validation Utility score : -0.0000
# Epoch(43) - Fold 4 - Validation Loss : 0.6929
# Epoch(43) - Fold 4 - Validation Accuracy : 0.5220
# Epoch(43) - Fold 4 - Validation Utility score : 1160.4864
# Epoch(43) - GLOBAL - Validation Loss: 0.6931
# Epoch(43) - GLOBAL - Validation Accuracy: 0.5176
# Epoch(43) - GLOBAL - Validation Utility score: 2450.3747
# Saving model corresponding to last_utility_score == 2450.37469941604
#
#
# Epoch(44) - Training Loss: 0.6931
# Epoch(44) - Fold 0 - Validation Loss : 0.6929
# Epoch(44) - Fold 0 - Validation Accuracy : 0.5236
# Epoch(44) - Fold 0 - Validation Utility score : 530.4871
# Epoch(44) - Fold 1 - Validation Loss : 0.6928
# Epoch(44) - Fold 1 - Validation Accuracy : 0.5210
# Epoch(44) - Fold 1 - Validation Utility score : 1069.7220
# Epoch(44) - Fold 2 - Validation Loss : 0.6937
# Epoch(44) - Fold 2 - Validation Accuracy : 0.5049
# Epoch(44) - Fold 2 - Validation Utility score : -0.0000
# Epoch(44) - Fold 3 - Validation Loss : 0.6934
# Epoch(44) - Fold 3 - Validation Accuracy : 0.5105
# Epoch(44) - Fold 3 - Validation Utility score : -0.0000
# Epoch(44) - Fold 4 - Validation Loss : 0.6928
# Epoch(44) - Fold 4 - Validation Accuracy : 0.5238
# Epoch(44) - Fold 4 - Validation Utility score : 1299.7060
# Epoch(44) - GLOBAL - Validation Loss: 0.6931
# Epoch(44) - GLOBAL - Validation Accuracy: 0.5167
# Epoch(44) - GLOBAL - Validation Utility score: 2899.9152
# Saving model corresponding to last_utility_score == 2899.915169698104
#
#
# Epoch(45) - Training Loss: 0.6931
# Epoch(45) - Fold 0 - Validation Loss : 0.6929
# Epoch(45) - Fold 0 - Validation Accuracy : 0.5251
# Epoch(45) - Fold 0 - Validation Utility score : 610.1611
# Epoch(45) - Fold 1 - Validation Loss : 0.6927
# Epoch(45) - Fold 1 - Validation Accuracy : 0.5216
# Epoch(45) - Fold 1 - Validation Utility score : 911.2834
# Epoch(45) - Fold 2 - Validation Loss : 0.6936
# Epoch(45) - Fold 2 - Validation Accuracy : 0.5067
# Epoch(45) - Fold 2 - Validation Utility score : -0.0000
# Epoch(45) - Fold 3 - Validation Loss : 0.6934
# Epoch(45) - Fold 3 - Validation Accuracy : 0.5110
# Epoch(45) - Fold 3 - Validation Utility score : -0.0000
# Epoch(45) - Fold 4 - Validation Loss : 0.6928
# Epoch(45) - Fold 4 - Validation Accuracy : 0.5228
# Epoch(45) - Fold 4 - Validation Utility score : 1337.1315
# Epoch(45) - GLOBAL - Validation Loss: 0.6931
# Epoch(45) - GLOBAL - Validation Accuracy: 0.5174
# Epoch(45) - GLOBAL - Validation Utility score: 2858.5760
# Saving model corresponding to last_utility_score == 2858.575995187147
#
#
# Epoch(46) - Training Loss: 0.6930
# Epoch(46) - Fold 0 - Validation Loss : 0.6929
# Epoch(46) - Fold 0 - Validation Accuracy : 0.5244
# Epoch(46) - Fold 0 - Validation Utility score : 418.7497
# Epoch(46) - Fold 1 - Validation Loss : 0.6927
# Epoch(46) - Fold 1 - Validation Accuracy : 0.5229
# Epoch(46) - Fold 1 - Validation Utility score : 764.0506
# Epoch(46) - Fold 2 - Validation Loss : 0.6936
# Epoch(46) - Fold 2 - Validation Accuracy : 0.5067
# Epoch(46) - Fold 2 - Validation Utility score : -0.0000
# Epoch(46) - Fold 3 - Validation Loss : 0.6934
# Epoch(46) - Fold 3 - Validation Accuracy : 0.5130
# Epoch(46) - Fold 3 - Validation Utility score : -0.0000
# Epoch(46) - Fold 4 - Validation Loss : 0.6928
# Epoch(46) - Fold 4 - Validation Accuracy : 0.5196
# Epoch(46) - Fold 4 - Validation Utility score : 1020.9536
# Epoch(46) - GLOBAL - Validation Loss: 0.6931
# Epoch(46) - GLOBAL - Validation Accuracy: 0.5173
# Epoch(46) - GLOBAL - Validation Utility score: 2203.7539
# Saving model corresponding to last_utility_score == 2203.753908001992
#
#
# Epoch(47) - Training Loss: 0.6930
# Epoch(47) - Fold 0 - Validation Loss : 0.6929
# Epoch(47) - Fold 0 - Validation Accuracy : 0.5254
# Epoch(47) - Fold 0 - Validation Utility score : 578.1134
# Epoch(47) - Fold 1 - Validation Loss : 0.6927
# Epoch(47) - Fold 1 - Validation Accuracy : 0.5214
# Epoch(47) - Fold 1 - Validation Utility score : 847.1942
# Epoch(47) - Fold 2 - Validation Loss : 0.6936
# Epoch(47) - Fold 2 - Validation Accuracy : 0.5074
# Epoch(47) - Fold 2 - Validation Utility score : -0.0000
# Epoch(47) - Fold 3 - Validation Loss : 0.6934
# Epoch(47) - Fold 3 - Validation Accuracy : 0.5115
# Epoch(47) - Fold 3 - Validation Utility score : -0.0000
# Epoch(47) - Fold 4 - Validation Loss : 0.6928
# Epoch(47) - Fold 4 - Validation Accuracy : 0.5232
# Epoch(47) - Fold 4 - Validation Utility score : 1334.6523
# Epoch(47) - GLOBAL - Validation Loss: 0.6931
# Epoch(47) - GLOBAL - Validation Accuracy: 0.5178
# Epoch(47) - GLOBAL - Validation Utility score: 2759.9600
# Saving model corresponding to last_utility_score == 2759.9599998879266
#
#
# Epoch(48) - Training Loss: 0.6930
# Epoch(48) - Fold 0 - Validation Loss : 0.6929
# Epoch(48) - Fold 0 - Validation Accuracy : 0.5251
# Epoch(48) - Fold 0 - Validation Utility score : 426.2434

# %%
model(ts_test[fold_indice])[0]
# Out:
# tensor([[0.4941],
#         [0.4949],
#         ...,
#         [0.4862],
#         [0.4976]], device='cuda:0', dtype=torch.float64,
#        grad_fn=<SigmoidBackward>)

# %%
accuracy_score(ts_test_y[fold_indice].cpu().numpy(), (model(ts_test[fold_indice])[0].squeeze() > 0.5).cpu().numpy())
# Out:
# 0.5127142067440575

# %%
plt.savefig(plot_buf, format='raw')

# %%
 transforms.ToTensor()(image).shape
# Out:
# Traceback (most recent call last):
#
#   File "<ipython-input-265-9ccfd1e98ad3>", line 1, in <module>
#     transforms.ToTensor()(image).shape
#
#   File "/opt/anaconda3/envs/janestreet/lib/python3.8/site-packages/torchvision/transforms/transforms.py", line 104, in __call__
#     return F.to_tensor(pic)
#
#   File "/opt/anaconda3/envs/janestreet/lib/python3.8/site-packages/torchvision/transforms/functional.py", line 64, in to_tensor
#     raise TypeError('pic should be PIL Image or ndarray. Got {}'.format(type(pic)))
#
# TypeError: pic should be PIL Image or ndarray. Got <class 'torch.Tensor'>

# %%
utils.make_grid( transforms.ToTensor()(image)).unsqueeze(0)

# %%
model

# %%
model[0]

# %%
model

# %%
model[3]

# %%
for i, param_object in enumerate(model[0].parameters()):
    print(f'Object {i}')
    print(param_object.shape)
    print(param_object)

# %%
help(model[4])

# %%
for i, param_object in enumerate(model[0].parameters()):
    print(f'Object {i}')
    print(param_object.shape)
    print(param_object)

# %%
#model.eval()
#accuracy_score(ts_test_y.cpu().numpy(), (model(ts_test).squeeze() > 0.5).cpu().numpy())

# %%
#model.eval()
#utility_function(df.loc[test_index], (model(ts_test).squeeze() > 0.5).cpu().numpy())

# %%
'''
model_load = nn.Sequential(
        #nn.Dropout(0.2),
        nn.Linear(len(FEATURES_LIST_TOTRAIN), 130),
        #nn.BatchNorm1d(130),
        nn.ReLU(),
        nn.Dropout(0.3),

        nn.Linear(130, 130),
        #nn.BatchNorm1d(130),
        nn.ReLU(),
        nn.Dropout(0.3),    

        nn.Linear(130, 130),
        #nn.BatchNorm1d(130),
        nn.ReLU(),
        nn.Dropout(0.3),    

        nn.Linear(130, 130),
        #nn.BatchNorm1d(130),
        nn.ReLU(),
        nn.Dropout(0.3),    

        nn.Linear(130, 130),
        #nn.BatchNorm1d(130),
        nn.ReLU(),
        nn.Dropout(0.3),    

        nn.Linear(130, 130),
        #nn.BatchNorm1d(130),
        nn.ReLU(),
        nn.Dropout(0.3),    
    
        nn.Linear(130, 130),
        #nn.BatchNorm1d(130),
        nn.ReLU(),
        nn.Dropout(0.3),    
    
        nn.Linear(130, 130),
        #nn.BatchNorm1d(130),
        nn.ReLU(),
        nn.Dropout(0.3),    

        nn.Linear(130, 60),
        #nn.BatchNorm1d(130),
        nn.ReLU(),
        nn.Dropout(0.3),    
    
        nn.Linear(60, 30),
        #nn.BatchNorm1d(130),
        nn.ReLU(),
        nn.Dropout(0.3),    
       
        nn.Linear(30, 1),
        nn.Sigmoid(),
    ).double().to('cuda')
    
model_load.load_state_dict(torch.load(f'model_NN_allfolds_V1.pt',map_location=torch.device('cuda')))
'''

#model_load.eval()
#print(accuracy_score(ts_test_y.cpu().numpy(), (model_load(ts_test).squeeze() > 0.5).cpu().numpy()))
#
#model_load.eval()
#print(utility_function(df.loc[test_index], (model_load(ts_test).squeeze() > 0.5).cpu().numpy()))

# %% [markdown]
# # Data for model inference

# %% [markdown]
# ## First, fill NA with :

# %%
f_mean
# Out:
# feature_0      0.009839
# feature_1      0.385578
# feature_2      0.357687
# feature_3      0.008919
# feature_4      0.004150
#                  ...
# feature_125    0.244875
# feature_126    0.339178
# feature_127    0.232381
# feature_128    0.342561
# feature_129    0.245618
# Length: 130, dtype: float64

# %% [markdown]
# ## Then, normalize with :

# %%
ts_train_mean
# Out:
# tensor([ 0.0088,  0.3957,  0.3306,  0.0092,  0.0034, -0.0050, -0.0146,  0.0553,
#          0.0251,  0.2647,  0.1671,  0.0949,  0.0445,  0.1525,  0.0800,  0.2217,
#          0.1283,  0.1218,  0.1096,  0.2977,  0.2646,  0.1881,  0.1725,  0.2547,
#          0.2327,  0.2979,  0.2685,  0.1399,  0.1629,  0.3306,  0.3439,  0.2268,
#          0.2519,  0.3164,  0.3360,  0.3528,  0.3677,  0.0265,  0.0186,  0.0432,
#          0.0530,  0.4542,  0.3776,  0.4162,  0.4393,  0.4865,  0.4921,  0.3684,
#          0.5014,  0.5438,  0.5307,  0.4567,  0.0565,  0.3890,  0.3769,  0.7755,
#          0.9247,  0.7859,  0.8085,  0.8990,  0.5534,  0.5555,  0.5592,  0.5614,
#          0.4423,  0.6188,  0.6172,  0.5977,  0.5981,  0.3774,  0.2389,  0.3080,
#          0.0041, -0.0322, -0.0016, -0.0199, -0.0316, -0.0932, -0.0081, -0.0358,
#         -0.0025, -0.0149, -0.0350, -0.1015,  0.3934,  0.5416,  0.3924,  0.4281,
#          0.4976,  0.3994,  0.4332,  0.5235,  0.4224,  0.4221,  0.4348,  0.4547,
#          0.3984,  0.5422,  0.3973,  0.4259,  0.4865,  0.4105,  0.4340,  0.4839,
#          0.4168,  0.4198,  0.4614,  0.4553,  0.3950,  0.3824,  0.3900,  0.3918,
#          0.3807,  0.4035,  0.4320,  0.3767,  0.4279,  0.4207,  0.3952,  0.4465,
#          0.3616,  0.2999,  0.3709,  0.3035,  0.3601,  0.2778,  0.3743,  0.2571,
#          0.3739,  0.2682], device='cuda:0', dtype=torch.float64)

# %%
ts_train_std
# Out:
# tensor([ 1.0000,  2.5724,  2.4543,  1.9501,  1.7327,  1.7503,  1.6707,  1.6297,
#          1.8147,  2.4146,  1.7088,  1.6546,  2.3538,  2.2777,  2.0171,  1.8925,
#          2.2236,  1.5821,  1.9931,  1.7196,  1.9315,  2.4339,  1.7864,  2.1404,
#          2.6117,  2.0852,  2.2918,  1.4115,  1.8827,  1.7403,  2.0817,  1.6850,
#          2.4817,  1.9481,  2.0704,  2.4316,  2.2853,  2.0566,  2.1225,  1.6162,
#          2.3138,  1.9912,  2.4127,  2.3259,  2.7887,  1.9650,  2.8462,  2.2005,
#          3.0387,  3.5713,  3.7193,  2.8348,  1.8877,  2.2007,  1.9352,  7.1295,
#         11.0556,  7.5957,  8.1579,  9.9465,  2.2164,  1.9947,  2.1712,  2.2567,
#          2.3735,  2.1915,  1.7553,  2.5883,  2.5263,  2.2991,  2.4406,  1.8076,
#          1.8125,  2.1476,  1.7792,  1.9738,  2.2283,  2.6795,  2.1807,  1.7949,
#          1.7688,  2.2805,  1.9767,  2.4821,  1.9748,  2.4948,  1.9679,  2.6387,
#          2.5943,  2.6160,  2.0864,  2.6942,  2.0670,  2.2104,  2.1212,  2.5054,
#          2.1243,  2.5619,  2.3017,  2.1175,  2.2689,  2.6136,  2.3357,  2.2557,
#          1.8389,  2.0931,  2.7896,  2.4935,  2.4409,  2.5761,  1.9721,  1.9469,
#          2.6040,  2.8786,  2.1073,  2.3353,  2.3193,  2.5076,  2.4064,  2.0617,
#          1.9008,  2.1498,  2.1102,  1.9852,  1.7631,  2.2454,  2.5548,  1.8003,
#          2.3295,  1.7714], device='cuda:0', dtype=torch.float64)

# %%
class SaveOutput:
    def __init__(self):
        self.outputs = []
        
    def __call__(self, module, module_in, module_out):
        self.outputs.append(module_out)
        print(type(module_out))
        
    def clear(self):
        self.outputs = []

# %%
model2 =  nn.Sequential(
        nn.Linear(4, 2),
        nn.ReLU(),

        nn.Linear(2, 2),
        nn.ReLU(),


    
        nn.Linear(2, 1),
        nn.Sigmoid(),

)

model2.eval()
# Out:
# Sequential(
#   (0): Linear(in_features=4, out_features=2, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=2, out_features=2, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=2, out_features=1, bias=True)
#   (5): Sigmoid()
# )

# %%
for i, param_object in enumerate(model2.parameters()):
    print(f'Object {i}')
    print(param_object.shape)
    print(param_object.data)
# Out:
# Object 0
# torch.Size([2, 4])
# tensor([[-0.2763,  0.3851, -0.2556, -0.4877],
#         [ 0.0357, -0.1960,  0.0569,  0.4818]])
# Object 1
# torch.Size([2])
# tensor([-0.4964,  0.2155])
# Object 2
# torch.Size([2, 2])
# tensor([[-0.5303, -0.5134],
#         [-0.3836,  0.2876]])
# Object 3
# torch.Size([2])
# tensor([0.5339, 0.6289])
# Object 4
# torch.Size([1, 2])
# tensor([[0.3987, 0.4664]])
# Object 5
# torch.Size([1])
# tensor([-0.0542])

# %%
'activation' in str(type(model2[1]))
# Out:
# True

# %%
isinstance(model2[1], torch.nn.ReLU)
# Out:
# True

# %%
save_output = SaveOutput()

hook_handles = []

for layer in model2.modules():
    if ('activation' in str(type(layer))):
        handle = layer.register_forward_hook(save_output)
        hook_handles.append(handle)

# %%
hook_handles
# Out:
# [<torch.utils.hooks.RemovableHandle at 0x7f98e3339310>,
#  <torch.utils.hooks.RemovableHandle at 0x7f9a481c43d0>,
#  <torch.utils.hooks.RemovableHandle at 0x7f9a481c48b0>]

# %%
#with torch.no_grad():
print(model2(torch.tensor([1, 1, 1, 2], dtype=torch.float)))
# Out:
# <class 'torch.Tensor'>
# <class 'torch.Tensor'>
# <class 'torch.Tensor'>
# tensor([0.5947], grad_fn=<SigmoidBackward>)

# %%
save_output.outputs
# Out:
# [tensor([0.0000, 1.0757]), tensor([0.0000, 0.9383]), tensor([0.5947])]

# %%
activation.append([0.11, 01.11])

# %%
# Pour récupérer les gradients : https://discuss.pytorch.org/t/how-to-print-the-computed-gradient-values-for-a-network/34179
print(model2[0].weight.grad)
# Out:
# None

# %%
model
# Out:
# Sequential(
#   (0): Linear(in_features=130, out_features=2000, bias=True)
#   (1): ReLU()
#   (2): Dropout(p=0.7, inplace=False)
#   (3): Linear(in_features=2000, out_features=1000, bias=True)
#   (4): ReLU()
#   (5): Dropout(p=0.7, inplace=False)
#   (6): Linear(in_features=1000, out_features=1, bias=True)
#   (7): Sigmoid()
# )

# %% [markdown]
# # Test

# %%
patience=5

utility_scores = [None] * 5
accuracy_scores = [None] * 5

ts_train = torch.tensor(df.loc[folds_list_train_unique, FEATURES_LIST_TOTRAIN].to_numpy(), device='cuda')
ts_train_y = torch.tensor((df.loc[folds_list_train_unique, 'resp'] > 0).astype(np.byte).to_numpy(), device='cuda')

# Normalize data
ts_train_mean = torch.mean(ts_train, axis=0)
ts_train_std = torch.std(ts_train, axis=0)
ts_train = pyStandardScale(ts_train, ts_train_mean, ts_train_std)

train_dataset = torch.utils.data.TensorDataset(ts_train, ts_train_y)
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True) # pin_memory : VOIR RESULTAT

ts_test = [None] * 5
ts_test_y = [None] * 5    
test_dataset = [None] * 5
test_loader = [None] * 5

for fold_indice in range(5):
    ts_test[fold_indice] = torch.tensor(df.loc[folds_list_test[fold_indice], FEATURES_LIST_TOTRAIN].to_numpy(), device='cuda')
    ts_test_y[fold_indice] = torch.tensor((df.loc[folds_list_test[fold_indice], 'resp'] > 0).astype(np.byte).to_numpy(), device='cuda')

    # Normalize
    ts_test[fold_indice] = pyStandardScale(ts_test[fold_indice], ts_train_mean, ts_train_std)
    
    test_dataset[fold_indice] = torch.utils.data.TensorDataset(ts_test[fold_indice], ts_test_y[fold_indice])
    test_loader[fold_indice] = torch.utils.data.DataLoader(test_dataset[fold_indice], batch_size=BATCH_SIZE)

torch.manual_seed(seed)

model = nn.Sequential(
        #nn.Dropout(0.2),
        nn.Linear(len(FEATURES_LIST_TOTRAIN), 50),
        #nn.BatchNorm1d(130),
        nn.ReLU(),
        nn.Dropout(0.3),

        nn.Linear(50, 20),
        #nn.BatchNorm1d(130),
        nn.ReLU(),
        nn.Dropout(0.3),
    
        nn.Linear(20, 1),
        nn.Sigmoid(),
    ).double().to('cuda')

loss_fn = nn.BCELoss().to('cuda')
#optimizer = torch.optim.Adam(model.parameters(), lr=1e-3) 
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4) 

model.eval()
#start_accuracy = accuracy_score(ts_test_y.cpu().numpy(), (model(ts_test).squeeze() > 0.5).cpu().numpy())
#start_utility_score = utility_function(df.loc[test_index], (model(ts_test).squeeze() > 0.5).cpu().numpy())
#print('Start Validation Accuracy: {:.4f}'.format(start_accuracy))
#print('Start Validation Utility: {:.4f}'.format(start_utility_score))

class SaveOutputActivationStats:
    def __init__(self):
        self.outputs = []
        
    def __call__(self, module, module_in, module_out):
        #self.outputs.append(module_out)
        self.outputs.append({'mean': module_out.mean().item(), 'std': module_out.std().item(),'near_zero': (module_out<=0.05).long().sum().item()/module_out.numel()})
        
    def clear(self):
        self.outputs = []

hook_handles = []
save_output_activation_stats = []

for layer in model.modules():
    if ('activation' in str(type(layer))):
        save_output_activation_stats_1layer = SaveOutputActivationStats()
        handle = layer.register_forward_hook(save_output_activation_stats_1layer)
        save_output_activation_stats.append(save_output_activation_stats_1layer)
        hook_handles.append(handle)

Val_Loss = 0
N_Samples = 0

the_last_loss = 100
the_last_utility_score = 0
the_last_accuracy = 0
trigger_times=0
early_stopping_met = False

# %%
epoch = 3

running_loss = 0.0        
model.train()

for batch in train_loader:
    #inputs, labels = batch[0], batch[1]
    inputs, labels = batch[0].to('cuda'), batch[1].to('cuda')
    optimizer.zero_grad()

    with torch.set_grad_enabled(True):
        outputs = model(inputs)
        loss = loss_fn(outputs, labels.unsqueeze(-1).double())
        loss.backward()
        optimizer.step()

# update local train loss
    running_loss += loss.item() * inputs.size(0)

# update global train loss
epoch_loss = running_loss / len(train_loader.dataset)
print('Epoch({}) - Training Loss: {:.4f}'.format(epoch, epoch_loss))
# Out:
# Epoch(3) - Training Loss: 0.6917

# %%
#len(save_output_activation_stats.outputs)

# %%
save_output_activation_stats
# Out:
# [<__main__.SaveOutputActivationStats at 0x7fba1b412910>,
#  <__main__.SaveOutputActivationStats at 0x7fba1aca0640>,
#  <__main__.SaveOutputActivationStats at 0x7fba1aca07f0>]

# %%
pd.DataFrame(save_output_activation_stats[0].outputs)
# Out:
#          mean       std  near_zero
# 0    0.202752  0.336518   0.535918
# 1    0.203848  0.345865   0.536560
# 2    0.203794  0.348174   0.536831
# 3    0.203259  0.343263   0.534746
# 4    0.204196  0.342250   0.536084
# ..        ...       ...        ...
# 815  0.193571  0.336461   0.539084
# 816  0.193751  0.327682   0.539075
# 817  0.191811  0.315676   0.540120
# 818  0.192280  0.318822   0.540847
# 819  0.191002  0.312394   0.539947
#
# [820 rows x 3 columns]

# %%
# %%time
for layer_number,save_output_activation_stats_layer in enumerate(save_output_activation_stats):
    df_stats_layer = pd.DataFrame(save_output_activation_stats_layer.outputs)

    fig, ax = plt.subplots(1, 3, figsize=(25, 4))

    ax[0].set_title(f'Layer {layer_number} : Mean activation value', fontsize=16)
    ax[0].set_xlabel('Batch instances')
    ax[0].set_ylabel('Mean')
    ax[0].plot(range(df_stats_layer.shape[0]), df_stats_layer['mean'])

    ax[1].set_title(f'Layer {layer_number} : Std deviation activation value', fontsize=16)
    ax[1].set_xlabel('Batch instances')
    ax[1].set_ylabel('Standard deviation')
    ax[1].plot(range(df_stats_layer.shape[0]), df_stats_layer['std'])

    ax[2].set_title(f'Layer {layer_number} : Percentage of activation values near zero', fontsize=16)
    ax[2].set_xlabel('Batch instances')
    ax[2].set_ylabel('Percentage')
    ax[2].plot(range(df_stats_layer.shape[0]), df_stats_layer['near_zero']);
# Out:
# CPU times: user 210 ms, sys: 3.98 ms, total: 214 ms
# Wall time: 212 ms
