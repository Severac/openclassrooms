# %%
CROSS_VALIDATION_RESULT_FILE = '/home/francois/coding/OC/PJ9/cross_validation/etat_21-12_matin/hyperopt_results.csv'

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt
import pickle

df = pd.read_csv(CROSS_VALIDATION_RESULT_FILE)

pd.set_option('display.max_rows', 200)
pd.options.display.max_colwidth = 1000

# %%
df[df['accuracy'].isnull()]
# Out:
#       Unnamed: 0   ids status         loss utility_scores  utility_score_std  \
# 25            25    25     ok  1876.030142            NaN                NaN
# 42            42    42     ok  3387.739343            NaN                NaN
# 43            43    43     ok -3387.739343            NaN                NaN
# 44            44    44     ok  3387.739343            NaN                NaN
# 45            45    45     ok -3387.739343            NaN                NaN
# ...          ...   ...    ...          ...            ...                ...
# 1645        1645  1645     ok -3641.386462            NaN                NaN
# 1646        1646  1646     ok  3641.386462            NaN                NaN
# 1647        1647  1647     ok -3641.386462            NaN                NaN
# 1648        1648  1648     ok  3641.386462            NaN                NaN
# 1649        1649  1649     ok -3641.386462            NaN                NaN
#
#      accuracy  \
# 25        NaN
# ...

# %%
df.dropna(inplace=True)

# %% [markdown]
# V2 of the notebook to analyze the run with gamma params

# %%
df.drop(columns=['Unnamed: 0'], inplace=True)
df[['utility1', 'utility2', 'utility3', 'utility4', 'utility5']] = pd.DataFrame(df['utility_scores'].apply(lambda x : x[1:-1].split(', ')).tolist(), dtype=float, index=df.index)

# %%
#df.loc[128:].sort_values(by='loss')

# %%
#df.loc[0:127].sort_values(by='loss')

# %%
#trials = pickle.load(open('/home/francois/coding/OC/PJ9/cross_validation/etat_20-12_soir/trials_results.pkl', 'rb'))

# %% [markdown]
# Best loss

# %%
df.sort_values(by='loss').head(1)
# Out:
#      ids status         loss  \
# 113  113     ok -3641.386462
#
#                                                                                         utility_scores  \
# 113  [143.1717637986452, 216.75405151348141, 932.7505815612767, 104.51025663653327, 2244.199808479232]
#
#      utility_score_std  \
# 113         816.445984
#
#                                                                                                  accuracy  \
# 113  [0.5179593881246869, 0.5165242553316816, 0.5165833044973628, 0.5136296634625366, 0.5191180885935289]
#
#                                                                                                                                                                                  vals  \
# 113  {'colsample_bytree': [1], 'features': [0], 'gamma': [2], 'learning_rate': [1], 'max_depth': [2], 'n_estimators': [0], 'random_state': [0], 'subsample': [1], 'tree_method': [0]}
#
# ...

# %%
df.query('loss <= -3641')
# Out:
#      ids status         loss  \
# 113  113     ok -3641.386462
#
#                                                                                         utility_scores  \
# 113  [143.1717637986452, 216.75405151348141, 932.7505815612767, 104.51025663653327, 2244.199808479232]
#
#      utility_score_std  \
# 113         816.445984
#
#                                                                                                  accuracy  \
# 113  [0.5179593881246869, 0.5165242553316816, 0.5165833044973628, 0.5136296634625366, 0.5191180885935289]
#
#                                                                                                                                                                                  vals  \
# 113  {'colsample_bytree': [1], 'features': [0], 'gamma': [2], 'learning_rate': [1], 'max_depth': [2], 'n_estimators': [0], 'random_state': [0], 'subsample': [1], 'tree_method': [0]}
#
# ...

# %%
df.corr(method='spearman')
# Out:
#                         ids      loss  utility_score_std  utility1  utility2  \
# ids                1.000000 -0.130525           0.076538  0.009425  0.059505
# loss              -0.130525  1.000000          -0.686811 -0.470280 -0.605887
# utility_score_std  0.076538 -0.686811           1.000000  0.100384  0.186799
# utility1           0.009425 -0.470280           0.100384  1.000000  0.405564
# utility2           0.059505 -0.605887           0.186799  0.405564  1.000000
# utility3           0.106115 -0.649183           0.185759  0.400704  0.451298
# utility4           0.087801 -0.285310          -0.002629 -0.054197  0.233591
# utility5           0.094173 -0.763552           0.987147  0.180557  0.282369
#
#                    utility3  utility4  utility5
# ids                0.106115  0.087801  0.094173
# loss              -0.649183 -0.285310 -0.763552
# utility_score_std  0.185759 -0.002629  0.987147
# utility1           0.400704 -0.054197  0.180557
# ...

# %%
fig, axs = plt.subplots(figsize=(10, 10))
plt.title('Corrélation des features (coefficient de spearman)')
sns.heatmap(df.corr(method='spearman'), cmap=sns.diverging_palette(2, 255, n=20), square=True, center=0)
plt.show()

# %%
df.dtypes
# Out:
# ids                    int64
# status                object
# loss                 float64
# utility_scores        object
# utility_score_std    float64
# accuracy              object
# vals                  object
# book_time             object
# utility1             float64
# utility2             float64
# utility3             float64
# utility4             float64
# utility5             float64
# dtype: object

# %%
sns.displot(-df['loss'])

# %%
sns.displot(df['utility5'])

# %%
sns.jointplot(df['utility_score_std'], df['utility4'])
# Out:
# /home/francois/anaconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.jointplot(df['utility_score_std'], df['utility5'])
# Out:
# /home/francois/anaconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
ax = sns.jointplot(df['utility1'], df['utility5'])
# Out:
# /home/francois/anaconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
ax = sns.jointplot(df['utility2'], df['utility5'])
# Out:
# /home/francois/anaconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
ax = sns.jointplot(df['utility3'], df['utility5'])
# Out:
# /home/francois/anaconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
ax = sns.jointplot(df['utility4'], df['utility5'])
# Out:
# /home/francois/anaconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# Utility 4 and 1 are incompatible :

# %%
ax = sns.jointplot(df['utility4'], df['utility1'])
# Out:
# /home/francois/anaconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# Utility 4 and 2 are incompatible

# %%
ax = sns.jointplot(df['utility4'], df['utility2'])
# Out:
# /home/francois/anaconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# Utility 1 and 2 are mostly incompatible :

# %%
ax = sns.jointplot(df['utility1'], df['utility2'])
# Out:
# /home/francois/anaconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# Utility 1 and 4 are mostly incompatible :

# %%
ax = sns.jointplot(df['utility1'], df['utility4'])
# Out:
# /home/francois/anaconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# Box plots for utility scores :

# %%
for i in range(1,6):
    df['utility'+str(i)].plot.box()
    plt.show()

# %%
# Models that perform in the best 20% of all utilities
df[(df['utility5'] > df['utility5'].quantile(0.8)) 
   & (df['utility1'] > df['utility1'].quantile(0.8)) 
   & (df['utility2'] > df['utility2'].quantile(0.8))
   & (df['utility3'] > df['utility3'].quantile(0.8))
   & (df['utility4'] > df['utility4'].quantile(0.8))]
# Out:
# Empty DataFrame
# Columns: [ids, status, loss, utility_scores, utility_score_std, accuracy, vals, book_time, utility1, utility2, utility3, utility4, utility5]
# Index: []

# %%
df['utility5'].quantile(0.8)
# Out:
# 2005.7427183888035

# %%
df.head(2)
# Out:
#    ids status         loss  \
# 0    0     ok -3274.574518
# 1    1     ok -2710.652084
#
#                                                                                        utility_scores  \
# 0  [33.07447331386709, 207.45100670546046, 649.1073320290134, 206.64612232040054, 2178.2955840065497]
# 1   [21.151621110201134, 164.11045108406887, 449.2509769778469, 35.87898617147539, 2040.260048440777]
#
#    utility_score_std  \
# 0         788.489288
# 1         764.673459
#
#                                                                                              accuracy  \
# 0  [0.5152044079682503, 0.5146982487271335, 0.51683146860724, 0.5135846810748714, 0.5168616186534848]
# 1   [0.5140330597618772, 0.51720164487853, 0.5166392288038141, 0.5118649697925965, 0.517691157671224]
#
#                                                                                                                                                                                vals  \
# ...

# %%
pd.concat([df.sort_values(by='loss', ascending=True).head(1),
            df.sort_values(by='utility1', ascending=False).head(1), 
           df.sort_values(by='utility2', ascending=False).head(1),
           df.sort_values(by='utility3', ascending=False).head(1),
           df.sort_values(by='utility4', ascending=False).head(1),
           df.sort_values(by='utility5', ascending=False).head(1)], axis=0)
# Out:
#        ids status         loss  \
# 113    113     ok -3641.386462
# 768    768     ok -2970.193311
# 1136  1136     ok -3188.682910
# 17      17     ok -3229.080033
# 109    109     ok -2911.632657
# 319    319     ok -3083.802130
#
#                                                                                          utility_scores  \
# 113   [143.1717637986452, 216.75405151348141, 932.7505815612767, 104.51025663653327, 2244.199808479232]
# 768    [320.5617282413911, 212.94263363963776, 575.748869634276, 62.97257568435906, 1797.9675042522535]
# 1136    [204.93372753500478, 415.04590001516743, 645.5437629718652, 52.1578582539327, 1871.00166164696]
# 17    [261.48180976101315, 207.15113000064008, 944.2887240020398, 7.119925819097419, 1809.038443570358]
# 109     [31.91080308378941, 161.0089306545413, 591.1637882656056, 291.015533883735, 1836.5336006250188]
# 319   [133.9792458175221, 101.27508237934157, 357.05623443101365, 58.28318483638094, 2433.208382378865]
#
# ...

# %% [markdown]
# # Best global utility score

# %%
df.sort_values(by='loss').head(1)
# Out:
#      ids status         loss  \
# 113  113     ok -3641.386462
#
#                                                                                         utility_scores  \
# 113  [143.1717637986452, 216.75405151348141, 932.7505815612767, 104.51025663653327, 2244.199808479232]
#
#      utility_score_std  \
# 113         816.445984
#
#                                                                                                  accuracy  \
# 113  [0.5179593881246869, 0.5165242553316816, 0.5165833044973628, 0.5136296634625366, 0.5191180885935289]
#
#                                                                                                                                                                                  vals  \
# 113  {'colsample_bytree': [1], 'features': [0], 'gamma': [2], 'learning_rate': [1], 'max_depth': [2], 'n_estimators': [0], 'random_state': [0], 'subsample': [1], 'tree_method': [0]}
#
# ...

# %% [markdown]
# # Best global utility score 1

# %%
df.sort_values(by='utility1', ascending=False).head(5)
# Out:
#      ids status         loss  \
# 768  768     ok -2970.193311
# 93    93     ok -3224.320420
# 529  529     ok -2965.125561
# 61    61     ok -3211.829407
# 380  380     ok -2920.568639
#
#                                                                                          utility_scores  \
# 768    [320.5617282413911, 212.94263363963776, 575.748869634276, 62.97257568435906, 1797.9675042522535]
# 93    [314.5592847958135, 187.32083583136912, 822.4261878260372, 8.978375998673846, 1891.0357355554588]
# 529     [313.9238517240447, 286.2525546879141, 635.1925553421216, 80.23443236140658, 1649.522166936587]
# 61     [310.7490624064034, 259.88458274524095, 504.8093005482838, 53.76553970138903, 2082.620921571326]
# 380  [293.13149596743955, 169.71527721967178, 777.9409145759781, 37.93841665824761, 1641.8425344845882]
#
#      utility_score_std  \
# 768         624.793434
# 93          679.304027
# 529         557.301591
# 61          734.298089
# 380         584.989472
#
# ...

# %% [markdown]
# # Best global utility score 2

# %%
df.sort_values(by='utility2', ascending=False).head(5)
# Out:
#        ids status         loss  \
# 1136  1136     ok -3188.682910
# 383    383     ok -2655.602414
# 743    743     ok -2273.530618
# 24      24     ok -3101.317438
# 1257  1257     ok -3178.467586
#
#                                                                                           utility_scores  \
# 1136     [204.93372753500478, 415.04590001516743, 645.5437629718652, 52.1578582539327, 1871.00166164696]
# 383                 [-0.0, 401.8484730832203, 459.28576121319793, 67.98598654982274, 1726.4821929281668]
# 743    [128.77626023814696, 398.71928893960404, 591.8969071070148, 55.07685287915721, 1099.061308498123]
# 24    [107.74970792338645, 396.21172179514855, 578.0175922711783, 78.27160646523951, 1941.0668093948755]
# 1257      [207.58923575010695, 391.056906405809, 677.1256449450012, 47.78195268904699, 1854.91384578527]
#
#       utility_score_std  \
# 1136         648.199908
# 383          624.074295
# 743          374.988872
# 24           685.992842
# ...

# %% [markdown]
# # Best global utility score 3

# %%
df.sort_values(by='utility3', ascending=False).head(5)
# Out:
#        ids status         loss  \
# 17      17     ok -3229.080033
# 113    113     ok -3641.386462
# 1258  1258     ok -2845.855151
# 128    128     ok -3572.077268
# 1494  1494     ok -3012.994975
#
#                                                                                           utility_scores  \
# 17     [261.48180976101315, 207.15113000064008, 944.2887240020398, 7.119925819097419, 1809.038443570358]
# 113    [143.1717637986452, 216.75405151348141, 932.7505815612767, 104.51025663653327, 2244.199808479232]
# 1258   [134.5511502858892, 168.69715347207654, 914.6956828100797, 78.50213704954243, 1549.4090277054006]
# 128      [111.1086021075963, 291.3632567278618, 888.73908437463, 235.37791057401373, 2045.4884145626306]
# 1494  [73.17655137510697, 175.29736261887263, 887.4051541454749, 194.87213557268288, 1682.2437710385382]
#
#       utility_score_std  \
# 17           661.852662
# 113          816.445984
# 1258         577.976392
# 128          717.575535
# ...

# %% [markdown]
# # Best global utility score 4

# %%
df.sort_values(by='utility4', ascending=False).head(1)
# Out:
#      ids status         loss  \
# 109  109     ok -2911.632657
#
#                                                                                       utility_scores  \
# 109  [31.91080308378941, 161.0089306545413, 591.1637882656056, 291.015533883735, 1836.5336006250188]
#
#      utility_score_std  \
# 109         653.978832
#
#                                                                                                  accuracy  \
# 109  [0.5169074866104111, 0.5149817215266299, 0.5172648819822371, 0.5145293112158393, 0.5166882821423154]
#
#                                                                                                                                                                                  vals  \
# 109  {'colsample_bytree': [3], 'features': [0], 'gamma': [2], 'learning_rate': [1], 'max_depth': [1], 'n_estimators': [1], 'random_state': [0], 'subsample': [0], 'tree_method': [0]}
#
#                       book_time   utility1    utility2    utility3  \
# ...

# %% [markdown]
# # Best global utility score 5

# %%
df.sort_values(by='utility5', ascending=False).head(1)
# Out:
#      ids status        loss  \
# 319  319     ok -3083.80213
#
#                                                                                         utility_scores  \
# 319  [133.9792458175221, 101.27508237934157, 357.05623443101365, 58.28318483638094, 2433.208382378865]
#
#      utility_score_std  \
# 319         914.071013
#
#                                                                                                 accuracy  \
# 319  [0.5155743074018417, 0.5168334983856776, 0.516516894383452, 0.5125846879952388, 0.5182483107428398]
#
#                                                                                                                                                                                  vals  \
# 319  {'colsample_bytree': [3], 'features': [0], 'gamma': [4], 'learning_rate': [1], 'max_depth': [0], 'n_estimators': [0], 'random_state': [0], 'subsample': [1], 'tree_method': [0]}
#
#                       book_time    utility1    utility2    utility3  \
# ...

# %% [markdown]
# # Best global loss

# %%
df.sort_values(by='loss').head(1)
# Out:
#      ids status         loss  \
# 113  113     ok -3641.386462
#
#                                                                                         utility_scores  \
# 113  [143.1717637986452, 216.75405151348141, 932.7505815612767, 104.51025663653327, 2244.199808479232]
#
#      utility_score_std  \
# 113         816.445984
#
#                                                                                                  accuracy  \
# 113  [0.5179593881246869, 0.5165242553316816, 0.5165833044973628, 0.5136296634625366, 0.5191180885935289]
#
#                                                                                                                                                                                  vals  \
# 113  {'colsample_bytree': [1], 'features': [0], 'gamma': [2], 'learning_rate': [1], 'max_depth': [2], 'n_estimators': [0], 'random_state': [0], 'subsample': [1], 'tree_method': [0]}
#
# ...

# %% [markdown]
# => Ce modèle semble plus équilibré sur les 5 splits que le best loss du run sans les gamma

# %% [markdown]
# # Sort by standard deviation

# %%
df.sort_values(by='utility_score_std')
# Out:
#        ids status         loss  \
# 31      31     ok -1008.224607
# 33      33     ok -1310.015405
# 29      29     ok -1253.474330
# 713    713     ok -1059.036812
# 127    127     ok -1417.355657
# ...    ...    ...          ...
# 18      18     ok -2975.965911
# 1357  1357     ok -2973.633505
# 882    882     ok -3030.269425
# 319    319     ok -3083.802130
# 904    904     ok -3044.280313
#
#                                                                                           utility_scores  \
# 31    [2.3175397650358045, 45.361806778316364, 424.81577468359825, 8.014871563467345, 527.7146141710002]
# 33                    [-0.0, 225.604577946704, 335.8394336180109, 2.2771588239232052, 746.2942350643202]
# 29      [110.3313845524479, 42.71476299453391, 325.6836230584016, 0.9349647929910532, 773.8095942378997]
# 713                [9.275774459387373, 0.11265576128745836, 242.12467550568675, -0.0, 807.5237057747428]
# ...

# %% [markdown]
# # Sort by utility score

# %%
df.sort_values(by='loss')
# Out:
#        ids status         loss  \
# 113    113     ok -3641.386462
# 128    128     ok -3572.077268
# 210    210     ok -3541.762583
# 59      59     ok -3479.811071
# 629    629     ok -3450.608004
# ...    ...    ...          ...
# 478    478     ok -1208.464660
# 543    543     ok -1157.927904
# 1482  1482     ok -1116.566465
# 713    713     ok -1059.036812
# 31      31     ok -1008.224607
#
#                                                                                           utility_scores  \
# 113    [143.1717637986452, 216.75405151348141, 932.7505815612767, 104.51025663653327, 2244.199808479232]
# 128      [111.1086021075963, 291.3632567278618, 888.73908437463, 235.37791057401373, 2045.4884145626306]
# 210     [185.4807879409001, 305.0034507287337, 736.6960128841297, 15.327404297068433, 2299.254927259086]
# 59     [48.575864459019186, 238.23978477603364, 834.1973075461718, 93.49158119056351, 2265.306532580492]
# ...

# %% [markdown]
# # Sort by utility scores individually

# %%
df.sort_values(by='utility1', ascending=False).head(5)
# Out:
#      ids status         loss  \
# 768  768     ok -2970.193311
# 93    93     ok -3224.320420
# 529  529     ok -2965.125561
# 61    61     ok -3211.829407
# 380  380     ok -2920.568639
#
#                                                                                          utility_scores  \
# 768    [320.5617282413911, 212.94263363963776, 575.748869634276, 62.97257568435906, 1797.9675042522535]
# 93    [314.5592847958135, 187.32083583136912, 822.4261878260372, 8.978375998673846, 1891.0357355554588]
# 529     [313.9238517240447, 286.2525546879141, 635.1925553421216, 80.23443236140658, 1649.522166936587]
# 61     [310.7490624064034, 259.88458274524095, 504.8093005482838, 53.76553970138903, 2082.620921571326]
# 380  [293.13149596743955, 169.71527721967178, 777.9409145759781, 37.93841665824761, 1641.8425344845882]
#
#      utility_score_std  \
# 768         624.793434
# 93          679.304027
# 529         557.301591
# 61          734.298089
# 380         584.989472
#
# ...

# %%
df.sort_values(by='utility2', ascending=False).head(5)
# Out:
#        ids status         loss  \
# 1136  1136     ok -3188.682910
# 383    383     ok -2655.602414
# 743    743     ok -2273.530618
# 24      24     ok -3101.317438
# 1257  1257     ok -3178.467586
#
#                                                                                           utility_scores  \
# 1136     [204.93372753500478, 415.04590001516743, 645.5437629718652, 52.1578582539327, 1871.00166164696]
# 383                 [-0.0, 401.8484730832203, 459.28576121319793, 67.98598654982274, 1726.4821929281668]
# 743    [128.77626023814696, 398.71928893960404, 591.8969071070148, 55.07685287915721, 1099.061308498123]
# 24    [107.74970792338645, 396.21172179514855, 578.0175922711783, 78.27160646523951, 1941.0668093948755]
# 1257      [207.58923575010695, 391.056906405809, 677.1256449450012, 47.78195268904699, 1854.91384578527]
#
#       utility_score_std  \
# 1136         648.199908
# 383          624.074295
# 743          374.988872
# 24           685.992842
# ...

# %%
df.sort_values(by='utility3', ascending=False).head(5)
# Out:
#        ids status         loss  \
# 17      17     ok -3229.080033
# 113    113     ok -3641.386462
# 1258  1258     ok -2845.855151
# 128    128     ok -3572.077268
# 1494  1494     ok -3012.994975
#
#                                                                                           utility_scores  \
# 17     [261.48180976101315, 207.15113000064008, 944.2887240020398, 7.119925819097419, 1809.038443570358]
# 113    [143.1717637986452, 216.75405151348141, 932.7505815612767, 104.51025663653327, 2244.199808479232]
# 1258   [134.5511502858892, 168.69715347207654, 914.6956828100797, 78.50213704954243, 1549.4090277054006]
# 128      [111.1086021075963, 291.3632567278618, 888.73908437463, 235.37791057401373, 2045.4884145626306]
# 1494  [73.17655137510697, 175.29736261887263, 887.4051541454749, 194.87213557268288, 1682.2437710385382]
#
#       utility_score_std  \
# 17           661.852662
# 113          816.445984
# 1258         577.976392
# 128          717.575535
# ...

# %%
df.sort_values(by='utility4', ascending=False).head(5)
# Out:
#      ids status         loss  \
# 109  109     ok -2911.632657
# 22    22     ok -1876.030142
# 684  684     ok -3259.966909
# 939  939     ok -3277.745924
# 128  128     ok -3572.077268
#
#                                                                                         utility_scores  \
# 109    [31.91080308378941, 161.0089306545413, 591.1637882656056, 291.015533883735, 1836.5336006250188]
# 22                [-0.0, 185.1571801828048, 299.2452992779382, 276.51819222845774, 1115.1094701066572]
# 684    [15.0574044152475, 331.7492204795345, 753.5748120218273, 259.3114715716607, 1900.2740008334993]
# 939  [58.89271210820291, 153.49631630858582, 745.2716071044758, 244.6883802884693, 2075.3969078784253]
# 128    [111.1086021075963, 291.3632567278618, 888.73908437463, 235.37791057401373, 2045.4884145626306]
#
#      utility_score_std  \
# 109         653.978832
# 22          384.672472
# 684         667.976966
# 939         748.449103
# 128         717.575535
#
# ...

# %%
df.dtypes
# Out:
# ids                    int64
# status                object
# loss                 float64
# utility_scores        object
# utility_score_std    float64
# accuracy              object
# vals                  object
# book_time             object
# utility1             float64
# utility2             float64
# utility3             float64
# utility4             float64
# utility5             float64
# dtype: object

# %%
df.sort_values(by='utility5', ascending=False).head(5)
# Out:
#        ids status         loss  \
# 319    319     ok -3083.802130
# 904    904     ok -3044.280313
# 882    882     ok -3030.269425
# 1357  1357     ok -2973.633505
# 18      18     ok -2975.965911
#
#                                                                                          utility_scores  \
# 319   [133.9792458175221, 101.27508237934157, 357.05623443101365, 58.28318483638094, 2433.208382378865]
# 904   [16.09096607825307, 156.98806602324723, 385.2656039587606, 53.11294864219443, 2432.8227282636817]
# 882   [37.46841412757786, 159.16331675728213, 428.42941369277514, 19.88026510012336, 2385.328015526316]
# 1357     [53.7279585031876, 134.40195901083226, 344.3702713352762, 62.7405721622982, 2378.392744470386]
# 18    [23.711309497417158, 133.87639558050893, 394.5092845550538, 72.92558453550251, 2350.943336506053]
#
#       utility_score_std  \
# 319          914.071013
# 904          921.005173
# 882          901.550555
# 1357         897.967777
# ...

# %%
df.sort_values(by='vals')
# Out:
#        ids status         loss  \
# 205    205     ok -2774.814007
# 757    757     ok -2719.051161
# 768    768     ok -2970.193311
# 623    623     ok -2717.977288
# 1246  1246     ok -2687.741420
# ...    ...    ...          ...
# 30      30     ok -2246.881771
# 27      27     ok -2432.095366
# 4        4     ok -2164.150125
# 243    243     ok -2567.888058
# 22      22     ok -1876.030142
#
#                                                                                            utility_scores  \
# 205     [109.71885727282165, 185.5853112209027, 481.92405859792007, 55.06063328943545, 1942.525147059526]
# 757    [177.99017018533337, 176.31384485945466, 751.6808752419086, 76.71358780507708, 1536.3526827906746]
# 768      [320.5617282413911, 212.94263363963776, 575.748869634276, 62.97257568435906, 1797.9675042522535]
# 623   [121.90143571124739, 204.17983759514328, 654.8758589908242, 137.19816712484857, 1599.8219889834756]
# ...
