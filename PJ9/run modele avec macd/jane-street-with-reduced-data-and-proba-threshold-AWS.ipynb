# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from xgboost import XGBClassifier

from sklearn.model_selection import TimeSeriesSplit, GridSearchCV

#import janestreet
#env = janestreet.make_env() # initialize the environment

#!pip install datatable # Internet is not activated in this competition
#!pip install ../input/python-datatable/datatable-0.11.0-cp37-cp37m-manylinux2010_x86_64.whl
import datatable as dt

import pickle
INPUT_FILE = 'train.csv'
MODEL_FILE = 'model.pickle'
XGBOOST_MODEL_FILE = 'model_xgboost.model'

XGBOOST_MODEL_INTERFACE = 'sklearn' # or 'xgboost'
#XGBOOST_MODEL_INTERFACE = 'xgboost' # or 'xgboost'

DF_FILE = 'dataframe.pickle'
LOAD_DF = False

CALCULATE_MACD = True

PREDICT_THRESHOLD = 0.5

TIMESERIES_SPLIT = True

DO_GRIDSEARCH = False

import xgboost as xgb
import gc

from scipy import stats

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

INPUT_DIR = './'

pd.set_option('display.max_rows', 500)

# %% [markdown]
# Thanks to following notebooks :
# https://www.kaggle.com/drcapa/jane-street-market-prediction-starter-xgb/output?select=example_sample_submission.csv

# %% [markdown]
# # Load data alternative

# %% [markdown]
# CUDF

# %%
# CUDF
#import sys
#!cp ../input/rapids/rapids.0.15.0 /opt/conda/envs/rapids.tar.gz
#!cd /opt/conda/envs/ && tar -xzvf rapids.tar.gz > /dev/null
#sys.path = ["/opt/conda/envs/rapids/lib/python3.7/site-packages"] + sys.path
#sys.path = ["/opt/conda/envs/rapids/lib/python3.7"] + sys.path
#sys.path = ["/opt/conda/envs/rapids/lib"] + sys.path 
#!cp /opt/conda/envs/rapids/lib/libxgboost.so /opt/conda/lib/

#import cudf

# %%
#dtypes_tab = {"feature_"+str(i) : "float32" for i in range(1,130)}
#dtypes_tab['feature_0'] = 'int8'

# %%
#df = cudf.read_csv('../input/jane-street-market-prediction/train.csv', dtypes=dtypes_tab)

# %%
#df['resp_positive'] = ((df['resp'])>0)*1  # Target to predict

# %% [markdown]
# DASK

# %%
# DASK

#import dask.dataframe as dd

#dtypes = {"feature_"+str(i) : "float32" for i in range(1,130)}
#dtypes['feature_0'] = 'int8'

#df = dd.read_csv('../input/jane-street-market-prediction/train.csv')

#print(df.shape)
#df.head()

# %% [markdown]
# # Load data

# %%
# %%time
#dtypes = {"feature_"+str(i) : "float32" for i in range(1,130)}
#dtypes['feature_0'] = 'int8'

if (LOAD_DF != True):
    # Thanks to his notebook for this fast loading : https://www.kaggle.com/carlmcbrideellis/jane-street-eda-of-day-0-and-feature-importance
    train_data_datatable = dt.fread(INPUT_FILE)
    df = train_data_datatable.to_pandas()

    # Thanks to this notebook to gain memory usage : https://www.kaggle.com/jorijnsmit/one-liner-to-halve-your-memory-usage
    float64_cols = df.select_dtypes(include='float64').columns
    mapper = {col_name: np.float32 for col_name in float64_cols}
    mapper['feature_0'] = 'int8'
    df = df.astype(mapper)
    
    del train_data_datatable
    
    df['resp_positive'] = ((df['resp'])>0)*1  # Target to predict
    
    # Temporal features
    
    if (CALCULATE_MACD == True):
        FEATURES_FOR_MACD = ['feature_'+str(i) for i in range(1,130)]

        for feature in FEATURES_FOR_MACD:
            #df.loc[:, feature + '_macd'] = df[feature].ewm(span=12, adjust=False).mean().astype('float32') # Short term exponential moving average\
            #- df[feature].ewm(span=26, adjust=False).mean().astype('float32') # Long term exponential moving average
            
            macd_feature = df[feature].ewm(span=12, adjust=False).mean().astype('float32') # Short term exponential moving average\
            - df[feature].ewm(span=26, adjust=False).mean().astype('float32') # Long term exponential moving average

            # We calculate MACD (which is short term EWMA (span 12) minus long term EWMA (span 26)) minus signal (which is MACD EWMA span 9)
            df.loc[:, feature + '_macd_minus_signal'] = macd_feature - macd_feature.ewm(span=9, adjust=False).mean().astype('float32')
            
            del macd_feature
            gc.collect()
    
else:
    with open(DF_FILE, 'rb') as f:
        df = pickle.load(f)
# Out:
# CPU times: user 2min 29s, sys: 2min 24s, total: 4min 53s
# Wall time: 4min 25s

# %%
df.dtypes
# Out:
# date                               int32
# weight                           float32
# resp_1                           float32
# resp_2                           float32
# resp_3                           float32
# resp_4                           float32
# resp                             float32
# feature_0                           int8
# feature_1                        float32
# feature_2                        float32
# feature_3                        float32
# feature_4                        float32
# feature_5                        float32
# feature_6                        float32
# feature_7                        float32
# feature_8                        float32
# feature_9                        float32
# feature_10                       float32
# feature_11                       float32
# feature_12                       float32
# feature_13                       float32
# feature_14                       float32
# feature_15                       float32
# feature_16                       float32
# feature_17                       float32
# feature_18                       float32
# feature_19                       float32
# feature_20                       float32
# feature_21                       float32
# feature_22                       float32
# feature_23                       float32
# feature_24                       float32
# feature_25                       float32
# feature_26                       float32
# feature_27                       float32
# feature_28                       float32
# feature_29                       float32
# feature_30                       float32
# feature_31                       float32
# feature_32                       float32
# feature_33                       float32
# feature_34                       float32
# feature_35                       float32
# feature_36                       float32
# feature_37                       float32
# feature_38                       float32
# feature_39                       float32
# feature_40                       float32
# feature_41                       float32
# feature_42                       float32
# feature_43                       float32
# feature_44                       float32
# feature_45                       float32
# feature_46                       float32
# feature_47                       float32
# feature_48                       float32
# feature_49                       float32
# feature_50                       float32
# feature_51                       float32
# feature_52                       float32
# feature_53                       float32
# feature_54                       float32
# feature_55                       float32
# feature_56                       float32
# feature_57                       float32
# feature_58                       float32
# feature_59                       float32
# feature_60                       float32
# feature_61                       float32
# feature_62                       float32
# feature_63                       float32
# feature_64                       float32
# feature_65                       float32
# feature_66                       float32
# feature_67                       float32
# feature_68                       float32
# feature_69                       float32
# feature_70                       float32
# feature_71                       float32
# feature_72                       float32
# feature_73                       float32
# feature_74                       float32
# feature_75                       float32
# feature_76                       float32
# feature_77                       float32
# feature_78                       float32
# feature_79                       float32
# feature_80                       float32
# feature_81                       float32
# feature_82                       float32
# feature_83                       float32
# feature_84                       float32
# feature_85                       float32
# feature_86                       float32
# feature_87                       float32
# feature_88                       float32
# feature_89                       float32
# feature_90                       float32
# feature_91                       float32
# feature_92                       float32
# feature_93                       float32
# feature_94                       float32
# feature_95                       float32
# feature_96                       float32
# feature_97                       float32
# feature_98                       float32
# feature_99                       float32
# feature_100                      float32
# feature_101                      float32
# feature_102                      float32
# feature_103                      float32
# feature_104                      float32
# feature_105                      float32
# feature_106                      float32
# feature_107                      float32
# feature_108                      float32
# feature_109                      float32
# feature_110                      float32
# feature_111                      float32
# feature_112                      float32
# feature_113                      float32
# feature_114                      float32
# feature_115                      float32
# feature_116                      float32
# feature_117                      float32
# feature_118                      float32
# feature_119                      float32
# feature_120                      float32
# feature_121                      float32
# feature_122                      float32
# feature_123                      float32
# feature_124                      float32
# feature_125                      float32
# feature_126                      float32
# feature_127                      float32
# feature_128                      float32
# feature_129                      float32
# ts_id                              int32
# resp_positive                      int64
# feature_1_macd_minus_signal      float32
# feature_2_macd_minus_signal      float32
# feature_3_macd_minus_signal      float32
# feature_4_macd_minus_signal      float32
# feature_5_macd_minus_signal      float32
# feature_6_macd_minus_signal      float32
# feature_7_macd_minus_signal      float32
# feature_8_macd_minus_signal      float32
# feature_9_macd_minus_signal      float32
# feature_10_macd_minus_signal     float32
# feature_11_macd_minus_signal     float32
# feature_12_macd_minus_signal     float32
# feature_13_macd_minus_signal     float32
# feature_14_macd_minus_signal     float32
# feature_15_macd_minus_signal     float32
# feature_16_macd_minus_signal     float32
# feature_17_macd_minus_signal     float32
# feature_18_macd_minus_signal     float32
# feature_19_macd_minus_signal     float32
# feature_20_macd_minus_signal     float32
# feature_21_macd_minus_signal     float32
# feature_22_macd_minus_signal     float32
# feature_23_macd_minus_signal     float32
# feature_24_macd_minus_signal     float32
# feature_25_macd_minus_signal     float32
# feature_26_macd_minus_signal     float32
# feature_27_macd_minus_signal     float32
# feature_28_macd_minus_signal     float32
# feature_29_macd_minus_signal     float32
# feature_30_macd_minus_signal     float32
# feature_31_macd_minus_signal     float32
# feature_32_macd_minus_signal     float32
# feature_33_macd_minus_signal     float32
# feature_34_macd_minus_signal     float32
# feature_35_macd_minus_signal     float32
# feature_36_macd_minus_signal     float32
# feature_37_macd_minus_signal     float32
# feature_38_macd_minus_signal     float32
# feature_39_macd_minus_signal     float32
# feature_40_macd_minus_signal     float32
# feature_41_macd_minus_signal     float32
# feature_42_macd_minus_signal     float32
# feature_43_macd_minus_signal     float32
# feature_44_macd_minus_signal     float32
# feature_45_macd_minus_signal     float32
# feature_46_macd_minus_signal     float32
# feature_47_macd_minus_signal     float32
# feature_48_macd_minus_signal     float32
# feature_49_macd_minus_signal     float32
# feature_50_macd_minus_signal     float32
# feature_51_macd_minus_signal     float32
# feature_52_macd_minus_signal     float32
# feature_53_macd_minus_signal     float32
# feature_54_macd_minus_signal     float32
# feature_55_macd_minus_signal     float32
# feature_56_macd_minus_signal     float32
# feature_57_macd_minus_signal     float32
# feature_58_macd_minus_signal     float32
# feature_59_macd_minus_signal     float32
# feature_60_macd_minus_signal     float32
# feature_61_macd_minus_signal     float32
# feature_62_macd_minus_signal     float32
# feature_63_macd_minus_signal     float32
# feature_64_macd_minus_signal     float32
# feature_65_macd_minus_signal     float32
# feature_66_macd_minus_signal     float32
# feature_67_macd_minus_signal     float32
# feature_68_macd_minus_signal     float32
# feature_69_macd_minus_signal     float32
# feature_70_macd_minus_signal     float32
# feature_71_macd_minus_signal     float32
# feature_72_macd_minus_signal     float32
# feature_73_macd_minus_signal     float32
# feature_74_macd_minus_signal     float32
# feature_75_macd_minus_signal     float32
# feature_76_macd_minus_signal     float32
# feature_77_macd_minus_signal     float32
# feature_78_macd_minus_signal     float32
# feature_79_macd_minus_signal     float32
# feature_80_macd_minus_signal     float32
# feature_81_macd_minus_signal     float32
# feature_82_macd_minus_signal     float32
# feature_83_macd_minus_signal     float32
# feature_84_macd_minus_signal     float32
# feature_85_macd_minus_signal     float32
# feature_86_macd_minus_signal     float32
# feature_87_macd_minus_signal     float32
# feature_88_macd_minus_signal     float32
# feature_89_macd_minus_signal     float32
# feature_90_macd_minus_signal     float32
# feature_91_macd_minus_signal     float32
# feature_92_macd_minus_signal     float32
# feature_93_macd_minus_signal     float32
# feature_94_macd_minus_signal     float32
# feature_95_macd_minus_signal     float32
# feature_96_macd_minus_signal     float32
# feature_97_macd_minus_signal     float32
# feature_98_macd_minus_signal     float32
# feature_99_macd_minus_signal     float32
# feature_100_macd_minus_signal    float32
# feature_101_macd_minus_signal    float32
# feature_102_macd_minus_signal    float32
# feature_103_macd_minus_signal    float32
# feature_104_macd_minus_signal    float32
# feature_105_macd_minus_signal    float32
# feature_106_macd_minus_signal    float32
# feature_107_macd_minus_signal    float32
# feature_108_macd_minus_signal    float32
# feature_109_macd_minus_signal    float32
# feature_110_macd_minus_signal    float32
# feature_111_macd_minus_signal    float32
# feature_112_macd_minus_signal    float32
# feature_113_macd_minus_signal    float32
# feature_114_macd_minus_signal    float32
# feature_115_macd_minus_signal    float32
# feature_116_macd_minus_signal    float32
# feature_117_macd_minus_signal    float32
# feature_118_macd_minus_signal    float32
# feature_119_macd_minus_signal    float32
# feature_120_macd_minus_signal    float32
# feature_121_macd_minus_signal    float32
# feature_122_macd_minus_signal    float32
# feature_123_macd_minus_signal    float32
# feature_124_macd_minus_signal    float32
# feature_125_macd_minus_signal    float32
# feature_126_macd_minus_signal    float32
# feature_127_macd_minus_signal    float32
# feature_128_macd_minus_signal    float32
# feature_129_macd_minus_signal    float32
# dtype: object

# %% [markdown]
# With (CALCULATE_MACD == True) : at this point, free RAM = 3.9 Gb

# %%
df['resp'].sum()
# Out:
# 976.0646

# %% [markdown]
# # Remove first half of the data

# %%
#df.drop(index=df[df['date'] <= 249].index, inplace=True)

# %%
df.shape
# Out:
# (2390491, 268)

# %%
if (CALCULATE_MACD == True):
    FEATURES_FOR_MACD = ['feature_'+str(i) for i in range(1,130)]

    #for feature in FEATURES_FOR_MACD:
    #    df.loc[:, feature + '_macd_minus_signal_sup0']  = ((df.loc[:, feature + '_macd_minus_signal'] > 0) * 1).astype(np.byte)

# %%
if (CALCULATE_MACD == True):
    #FEATURES_TODROP = ['feature_'+str(i)+'_macd' for i in range(1, 130)] + ['feature_'+str(i)+'_macd_minus_signal' for i in range(1,130)]
    FEATURES_TODROP = ['feature_'+str(i)+'_macd' for i in range(1, 130)]

# %%
if (CALCULATE_MACD == True):
    #df.drop(FEATURES_TODROP, axis=1,inplace=True)
    pass

# %%
df[df['resp'] > 0].shape
# Out:
# (1204974, 268)

# %%
gc.collect()
# Out:
# 180

# %% [markdown]
# ## Drop of 0 weights

# %%
#df.drop(df[df['weight'] == 0].index, axis=0, inplace=True)
#df.reset_index(drop=True, inplace=True)

# %%
df.shape
# Out:
# (2390491, 268)

# %%
#df[(df['resp'] > 0) & (df['resp_1'] > 0) & (df['resp_2'] > 0) & (df['resp_3'] > 0) & (df['resp_4'] > 0)].shape

# %%
#df.loc[:, 'resp_all_positive'] =  ((df['resp'] > 0) & (df['resp_1'] > 0) & (df['resp_2'] > 0) & (df['resp_3'] > 0) & (df['resp_4'] > 0))*1

# %% [markdown]
# # Drop features related to resp_1,2,3,4 (and not to resp)
# Insight from notebook https://www.kaggle.com/carlmcbrideellis/jane-street-eda-of-day-0-and-feature-importance
# Commented because this does not improve performance

# %%
#FEATURES_INDICE_TODROP = [7, 8, 17, 18, 27, 28, 55, 72, 78, 84, 90, 96, 102, 108, 114, 120, 121,
#11, 12, 21, 22, 31, 32, 57, 74, 80, 86, 92, 98, 104, 110, 116, 124, 125,
#13, 14, 23, 24, 33, 34, 58, 75, 81, 87, 93, 99, 105, 111, 117, 126,127,
#9, 10, 19, 20, 29, 30, 56, 73, 79, 85, 91, 97, 103, 109, 115, 122, 123,]

#FEATURES_TODROP = ['feature_'+str(feat) for feat in FEATURES_INDICE_TODROP]

# %%
#df.drop(columns=FEATURES_TODROP, axis=1, inplace=True)

# %% [markdown]
# # Split train test

# %%
df.shape
# Out:
# (2390491, 268)

# %%
if (TIMESERIES_SPLIT == False):
    train_size = int(df.shape[0] * 0.90)
    print(train_size)
    display(df.iloc[0:train_size-1, :])

# %%
if (TIMESERIES_SPLIT == False):
    df_train = df.iloc[0:train_size-1, :].copy(deep=True)
    y_train = df.iloc[0:train_size-1]['resp_positive'].copy(deep=True)
    #y_train = df.iloc[0:train_size-1]['resp_all_positive'].copy(deep=True)

    df_test = df.iloc[train_size:df.shape[0]-1].copy(deep=True) # This will be used for training steps
    df_test_origin = df_test.copy(deep=True) # We keep this for utility function
    y_test = df.iloc[train_size:df.shape[0]-1]['resp_positive'].copy(deep=True)
    #y_test = df.iloc[train_size:df.shape[0]-1]['resp_all_positive'].copy(deep=True)
    
else:
    tscv = TimeSeriesSplit(n_splits=10)

    for (train_index, test_index) in tscv.split(df):
        pass

    df_train, df_test = df.loc[train_index], df.loc[test_index]
    y_train, y_test = df.loc[train_index]['resp_positive'], df.loc[test_index]['resp_positive']
    
    df_test_origin = df_test.copy(deep=True) # We keep this for utility function
    
    print(df_train.shape)
    print(df_test.shape)
    
    df_train.reset_index(drop=True, inplace=True)
    df_test.reset_index(drop=True, inplace=True)
# Out:
# (2173174, 268)
# (217317, 268)

# %%
del df
gc.collect()
# Out:
# 20

# %%
df_train['resp'].sum()
# Out:
# 817.8456

# %%
df_test['resp'].sum()
# Out:
# 158.21907

# %%
df_train['feature_1'].sum()
# Out:
# 852591.6

# %%
df_train.drop(['date', 'resp_1', 'resp_2', 'resp_3', 'resp_4', 'resp', 'resp_positive', 'ts_id'], axis=1,inplace=True)
#df_train.drop(['date', 'resp_1', 'resp_2', 'resp_3', 'resp_4', 'resp', 'resp_positive', 'resp_all_positive', 'ts_id'], axis=1,inplace=True)

# %%
df_test.drop(['date', 'resp_1', 'resp_2', 'resp_3', 'resp_4', 'resp', 'resp_positive', 'ts_id'], axis=1,inplace=True)
#df_test.drop(['date', 'resp_1', 'resp_2', 'resp_3', 'resp_4', 'resp', 'resp_positive', 'resp_all_positive', 'ts_id'], axis=1,inplace=True)

# %%
list(df_train.columns)
# Out:
# ['weight',
#  'feature_0',
#  'feature_1',
#  'feature_2',
#  'feature_3',
#  'feature_4',
#  'feature_5',
#  'feature_6',
#  'feature_7',
#  'feature_8',
#  'feature_9',
#  'feature_10',
#  'feature_11',
#  'feature_12',
#  'feature_13',
#  'feature_14',
#  'feature_15',
#  'feature_16',
#  'feature_17',
#  'feature_18',
#  'feature_19',
#  'feature_20',
#  'feature_21',
#  'feature_22',
#  'feature_23',
#  'feature_24',
#  'feature_25',
#  'feature_26',
#  'feature_27',
#  'feature_28',
#  'feature_29',
#  'feature_30',
#  'feature_31',
#  'feature_32',
#  'feature_33',
#  'feature_34',
#  'feature_35',
#  'feature_36',
#  'feature_37',
#  'feature_38',
#  'feature_39',
#  'feature_40',
#  'feature_41',
#  'feature_42',
#  'feature_43',
#  'feature_44',
#  'feature_45',
#  'feature_46',
#  'feature_47',
#  'feature_48',
#  'feature_49',
#  'feature_50',
#  'feature_51',
#  'feature_52',
#  'feature_53',
#  'feature_54',
#  'feature_55',
#  'feature_56',
#  'feature_57',
#  'feature_58',
#  'feature_59',
#  'feature_60',
#  'feature_61',
#  'feature_62',
#  'feature_63',
#  'feature_64',
#  'feature_65',
#  'feature_66',
#  'feature_67',
#  'feature_68',
#  'feature_69',
#  'feature_70',
#  'feature_71',
#  'feature_72',
#  'feature_73',
#  'feature_74',
#  'feature_75',
#  'feature_76',
#  'feature_77',
#  'feature_78',
#  'feature_79',
#  'feature_80',
#  'feature_81',
#  'feature_82',
#  'feature_83',
#  'feature_84',
#  'feature_85',
#  'feature_86',
#  'feature_87',
#  'feature_88',
#  'feature_89',
#  'feature_90',
#  'feature_91',
#  'feature_92',
#  'feature_93',
#  'feature_94',
#  'feature_95',
#  'feature_96',
#  'feature_97',
#  'feature_98',
#  'feature_99',
#  'feature_100',
#  'feature_101',
#  'feature_102',
#  'feature_103',
#  'feature_104',
#  'feature_105',
#  'feature_106',
#  'feature_107',
#  'feature_108',
#  'feature_109',
#  'feature_110',
#  'feature_111',
#  'feature_112',
#  'feature_113',
#  'feature_114',
#  'feature_115',
#  'feature_116',
#  'feature_117',
#  'feature_118',
#  'feature_119',
#  'feature_120',
#  'feature_121',
#  'feature_122',
#  'feature_123',
#  'feature_124',
#  'feature_125',
#  'feature_126',
#  'feature_127',
#  'feature_128',
#  'feature_129',
#  'feature_1_macd_minus_signal',
#  'feature_2_macd_minus_signal',
#  'feature_3_macd_minus_signal',
#  'feature_4_macd_minus_signal',
#  'feature_5_macd_minus_signal',
#  'feature_6_macd_minus_signal',
#  'feature_7_macd_minus_signal',
#  'feature_8_macd_minus_signal',
#  'feature_9_macd_minus_signal',
#  'feature_10_macd_minus_signal',
#  'feature_11_macd_minus_signal',
#  'feature_12_macd_minus_signal',
#  'feature_13_macd_minus_signal',
#  'feature_14_macd_minus_signal',
#  'feature_15_macd_minus_signal',
#  'feature_16_macd_minus_signal',
#  'feature_17_macd_minus_signal',
#  'feature_18_macd_minus_signal',
#  'feature_19_macd_minus_signal',
#  'feature_20_macd_minus_signal',
#  'feature_21_macd_minus_signal',
#  'feature_22_macd_minus_signal',
#  'feature_23_macd_minus_signal',
#  'feature_24_macd_minus_signal',
#  'feature_25_macd_minus_signal',
#  'feature_26_macd_minus_signal',
#  'feature_27_macd_minus_signal',
#  'feature_28_macd_minus_signal',
#  'feature_29_macd_minus_signal',
#  'feature_30_macd_minus_signal',
#  'feature_31_macd_minus_signal',
#  'feature_32_macd_minus_signal',
#  'feature_33_macd_minus_signal',
#  'feature_34_macd_minus_signal',
#  'feature_35_macd_minus_signal',
#  'feature_36_macd_minus_signal',
#  'feature_37_macd_minus_signal',
#  'feature_38_macd_minus_signal',
#  'feature_39_macd_minus_signal',
#  'feature_40_macd_minus_signal',
#  'feature_41_macd_minus_signal',
#  'feature_42_macd_minus_signal',
#  'feature_43_macd_minus_signal',
#  'feature_44_macd_minus_signal',
#  'feature_45_macd_minus_signal',
#  'feature_46_macd_minus_signal',
#  'feature_47_macd_minus_signal',
#  'feature_48_macd_minus_signal',
#  'feature_49_macd_minus_signal',
#  'feature_50_macd_minus_signal',
#  'feature_51_macd_minus_signal',
#  'feature_52_macd_minus_signal',
#  'feature_53_macd_minus_signal',
#  'feature_54_macd_minus_signal',
#  'feature_55_macd_minus_signal',
#  'feature_56_macd_minus_signal',
#  'feature_57_macd_minus_signal',
#  'feature_58_macd_minus_signal',
#  'feature_59_macd_minus_signal',
#  'feature_60_macd_minus_signal',
#  'feature_61_macd_minus_signal',
#  'feature_62_macd_minus_signal',
#  'feature_63_macd_minus_signal',
#  'feature_64_macd_minus_signal',
#  'feature_65_macd_minus_signal',
#  'feature_66_macd_minus_signal',
#  'feature_67_macd_minus_signal',
#  'feature_68_macd_minus_signal',
#  'feature_69_macd_minus_signal',
#  'feature_70_macd_minus_signal',
#  'feature_71_macd_minus_signal',
#  'feature_72_macd_minus_signal',
#  'feature_73_macd_minus_signal',
#  'feature_74_macd_minus_signal',
#  'feature_75_macd_minus_signal',
#  'feature_76_macd_minus_signal',
#  'feature_77_macd_minus_signal',
#  'feature_78_macd_minus_signal',
#  'feature_79_macd_minus_signal',
#  'feature_80_macd_minus_signal',
#  'feature_81_macd_minus_signal',
#  'feature_82_macd_minus_signal',
#  'feature_83_macd_minus_signal',
#  'feature_84_macd_minus_signal',
#  'feature_85_macd_minus_signal',
#  'feature_86_macd_minus_signal',
#  'feature_87_macd_minus_signal',
#  'feature_88_macd_minus_signal',
#  'feature_89_macd_minus_signal',
#  'feature_90_macd_minus_signal',
#  'feature_91_macd_minus_signal',
#  'feature_92_macd_minus_signal',
#  'feature_93_macd_minus_signal',
#  'feature_94_macd_minus_signal',
#  'feature_95_macd_minus_signal',
#  'feature_96_macd_minus_signal',
#  'feature_97_macd_minus_signal',
#  'feature_98_macd_minus_signal',
#  'feature_99_macd_minus_signal',
#  'feature_100_macd_minus_signal',
#  'feature_101_macd_minus_signal',
#  'feature_102_macd_minus_signal',
#  'feature_103_macd_minus_signal',
#  'feature_104_macd_minus_signal',
#  'feature_105_macd_minus_signal',
#  'feature_106_macd_minus_signal',
#  'feature_107_macd_minus_signal',
#  'feature_108_macd_minus_signal',
#  'feature_109_macd_minus_signal',
#  'feature_110_macd_minus_signal',
#  'feature_111_macd_minus_signal',
#  'feature_112_macd_minus_signal',
#  'feature_113_macd_minus_signal',
#  'feature_114_macd_minus_signal',
#  'feature_115_macd_minus_signal',
#  'feature_116_macd_minus_signal',
#  'feature_117_macd_minus_signal',
#  'feature_118_macd_minus_signal',
#  'feature_119_macd_minus_signal',
#  'feature_120_macd_minus_signal',
#  'feature_121_macd_minus_signal',
#  'feature_122_macd_minus_signal',
#  'feature_123_macd_minus_signal',
#  'feature_124_macd_minus_signal',
#  'feature_125_macd_minus_signal',
#  'feature_126_macd_minus_signal',
#  'feature_127_macd_minus_signal',
#  'feature_128_macd_minus_signal',
#  'feature_129_macd_minus_signal']

# %%
df_test.shape
# Out:
# (217317, 260)

# %%
df_train.shape[0] + df_test.shape[0]
# Out:
# 2390491

# %%
'''
tscv = TimeSeriesSplit(n_splits=10)

for (train_index, test_index) in tscv.split(df):
    pass

df_train, df_test = df.loc[train_index], df.loc[test_index]
y_train, y_test = df.loc[train_index]['resp_positive'], df.loc[test_index]['resp_positive']
'''
# Out:
# "\ntscv = TimeSeriesSplit(n_splits=10)\n\nfor (train_index, test_index) in tscv.split(df):\n    pass\n\ndf_train, df_test = df.loc[train_index], df.loc[test_index]\ny_train, y_test = df.loc[train_index]['resp_positive'], df.loc[test_index]['resp_positive']\n"

# %%
df_train.index
# Out:
# RangeIndex(start=0, stop=2173174, step=1)

# %%
df_test.index
# Out:
# RangeIndex(start=0, stop=217317, step=1)

# %%
#df_test.reset_index(drop=True, inplace=True)

# %%
#df_train.reset_index(drop=True, inplace=True)

# %%
gc.collect()
# Out:
# 280

# %% [markdown]
# With (CALCULATE_MACD == True) : at this point, free RAM = 3.1 Gb

# %% [markdown]
# # Data clean

# %% [markdown]
# ## Remove outliers

# %%
#df_train_bck = df_train.copy(deep=True)

# %%
df_train.shape
# Out:
# (2173174, 260)

# %%
#df_train[(df_train['feature_1'] < df_train.feature_1.quantile(0.001)) | (df_train['feature_1'] > df_train.feature_1.quantile(0.999))].shape

# %%
#low_quantile_to_remove = 0.0001
#high_quantile_to_remove = 1 - low_quantile_to_remove

# %%
#for feat in ['feature_'+str(i) for i in range(1,130)]:
#    index_to_drop = df_train[(df_train[feat] < df_train[feat].quantile(low_quantile_to_remove)) | (df_train[feat] > df_train[feat].quantile(high_quantile_to_remove))].index
#    df_train.drop(index=index_to_drop, axis=0, inplace=True)
#    y_train.drop(index=index_to_drop, axis=0, inplace=True)

# %%
#df_train.reset_index(drop=True, inplace=True)
#y_train.reset_index(drop=True, inplace=True)

# %%
df_train.shape
# Out:
# (2173174, 260)

# %%
y_train.shape
# Out:
# (2173174,)

# %%
#df_train = df_train_bck

# %%
# This was tested and worsen performances, so commented out for now

# Thanks to : https://www.kaggle.com/blurredmachine/jane-street-market-eda-viz-prediction

#threshold = 4

#z = np.abs(stats.zscore(df_train, nan_policy='omit'))
#print(f"Z score array:\n{z}")
#print('-'*30)

#row_index = np.where(z > threshold)
#print(f"Outlier Data Rows: {len(set(row_index[0]))}")
#print('-'*30)

#print(f"Outlier Rows Index:\n{row_index}")
#print('-'*30)

#print(f"Sample outlier row data:\n{z[row_index[0][0]]}")

#print(df_train.shape)
#print(df_train[(z < 5000).all(axis=1)].reset_index(drop=True).shape)
#df_train = df_train[(z < threshold).all(axis=1)].reset_index(drop=True)
#y_train = y_train[(z < threshold).all(axis=1)].reset_index(drop=True)
#print(df_train.shape)

#del z
#del row_index
#gc.collect()

# %% [markdown]
# ## Remove missing (commented, because handled automatically by xgboost)

# %%
#cols_with_missing_train = [col for col in df_train.columns if df_train[col].isnull().any()]

# %%
# Finally we do not remove null values and let xgboost handle them (provides better performance)
#for col in cols_with_missing_train:
#    df_train[col].fillna(-999, inplace=True)

# %%
#df_medians = df_train[cols_with_missing_train].median()
#df_train.loc[:, cols_with_missing_train].fillna(df_medians, inplace=True)

#Commented for now (handled by xgboost)
#df_train.fillna({col:-999 for col in cols_with_missing_train}, inplace=True)

# %%
# Finally we do not remove null values and let xgboost handle them (provides better performance)
#for col in cols_with_missing_train:
#    df_test[col].fillna(-999, inplace=True)

# %%
#df_test.loc[:, cols_with_missing_train].fillna(df_medians, inplace=True)

#Commented for now (handled by xgboost)
#df_test.fillna({col:-999 for col in cols_with_missing_train}, inplace=True)

# %%
gc.collect()
# Out:
# 320

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2173174 entries, 0 to 2173173
# Columns: 260 entries, weight to feature_129_macd_minus_signal
# dtypes: float32(259), int8(1)
# memory usage: 2.1 GB

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 217317 entries, 0 to 217316
# Columns: 260 entries, weight to feature_129_macd_minus_signal
# dtypes: float32(259), int8(1)
# memory usage: 214.9 MB

# %% [markdown]
# ## Example with feature 1

# %%
'''
df_train_subsample = df_train.loc[2000:2020, :]

exp1 = df_train_subsample['feature_1'].ewm(span=12, adjust=False).mean() # Short term exponential moving average
exp2 = df_train_subsample['feature_1'].ewm(span=26, adjust=False).mean() # Long term exponential moving average

macd = exp1 - exp2

exp3 = macd.ewm(span=9, adjust=False).mean() # Signal line
resp = df_train_subsample['resp'] * df_train_subsample['feature_1'].mean() / np.abs(df_train_subsample['resp'].mean()) # Resp augmented to fit mean of feature 1 for better visualisation



plt.figure(figsize=(20,10))

plt.plot(df_train_subsample.ts_id, df_train_subsample.feature_1, label='Feature 1')
plt.plot(df_train_subsample.ts_id, macd, label='Feature 1 MACD', color='orange')
plt.plot(df_train_subsample.ts_id, exp3, label='Signal Line', color='Magenta')
plt.plot(df_train_subsample.ts_id, resp, label='Resp', color='red')
plt.legend(loc='upper left')
plt.show()
'''
# Out:
# "\ndf_train_subsample = df_train.loc[2000:2020, :]\n\nexp1 = df_train_subsample['feature_1'].ewm(span=12, adjust=False).mean() # Short term exponential moving average\nexp2 = df_train_subsample['feature_1'].ewm(span=26, adjust=False).mean() # Long term exponential moving average\n\nmacd = exp1 - exp2\n\nexp3 = macd.ewm(span=9, adjust=False).mean() # Signal line\nresp = df_train_subsample['resp'] * df_train_subsample['feature_1'].mean() / np.abs(df_train_subsample['resp'].mean()) # Resp augmented to fit mean of feature 1 for better visualisation\n\n\n\nplt.figure(figsize=(20,10))\n\nplt.plot(df_train_subsample.ts_id, df_train_subsample.feature_1, label='Feature 1')\nplt.plot(df_train_subsample.ts_id, macd, label='Feature 1 MACD', color='orange')\nplt.plot(df_train_subsample.ts_id, exp3, label='Signal Line', color='Magenta')\nplt.plot(df_train_subsample.ts_id, resp, label='Resp', color='red')\nplt.legend(loc='upper left')\nplt.show()\n"

# %% [markdown]
# # Feature definition

# %%
FEATURES_LIST_TOTRAIN = ['feature_'+str(i) for i in range(130)] + ['weight']
#FEATURES_LIST_TOTRAIN = [feat for feat in FEATURES_LIST_TOTRAIN if feat not in FEATURES_TODROP]

if (CALCULATE_MACD == True):
    FEATURES_LIST_TOTRAIN.extend(['feature_'+str(i)+'_macd_minus_signal' for i in range(1,130)])

# %%
len(FEATURES_LIST_TOTRAIN)
# Out:
# 260

# %%
#FEATURES_LIST = ['feature_'+str(i) for i in range(130)] + ['feature_'+str(i)+'_macd' for i in range(1, 130)] + ['feature_'+str(i)+'_macd_minus_signal' for i in range(1,130)]+  ['weight']

# %%
#df[FEATURES_LIST]

# %% [markdown]
# # Utility calculation function

# %%
def utility_function(df_test, df_test_predictions):
    df_test.loc[:, 'utility_pj'] = df_test['weight'] * df_test['resp'] * df_test_predictions
    #df_test_utility_pi = df_test.groupby('date').sum('utility_pj')['utility_pj']
    df_test_utility_pi = df_test.groupby(by=['date'])['utility_pj'].sum()
    df_test_origin.groupby(by=['date'])['utility_pj'].sum()
    nb_unique_dates = df_test_utility_pi.shape[0]
    t = (df_test_utility_pi.sum() / np.sqrt(df_test_utility_pi.pow(2).sum())) * (np.sqrt(250 / np.abs(nb_unique_dates)))
    u = min(max(t, 0), 6) * df_test_utility_pi.sum()
    
    return(u)

# %% [markdown]
# # Train model

# %%
if (XGBOOST_MODEL_INTERFACE == 'xgboost'):
    params = {

        'random_state' : 42,
        'max_depth': 12,
        #'max_depth': 50,
        #'learning_rate': 0.05,
        'learning_rate': 0.01,
        'subsample': 0.9,
        'colsample_bytree': 0.2,
        'tree_method': 'gpu_hist',
        'seed': 42,
        'objective' : "binary:logistic",
        #"disable_default_eval_metric": 1,
    }

# %%
if (XGBOOST_MODEL_INTERFACE == 'xgboost'):
    d_train = xgb.DMatrix(df_train, label=y_train) #missing = ?

# %%
if (XGBOOST_MODEL_INTERFACE == 'xgboost'):
    del df_train
    gc.collect()

# %%
if (XGBOOST_MODEL_INTERFACE == 'xgboost'):
    d_test = xgb.DMatrix(df_test, label=y_test)

# %%
if (XGBOOST_MODEL_INTERFACE == 'xgboost'):
    del df_test
    gc.collect()

# %%
from sklearn.metrics import brier_score_loss
#brier_score_loss(y_true, y_prob)

#def brier_score_custom(predt: np.ndarray, dtrain: xgb.DMatrix):
def brier_score_custom(y_pred_scores, y_true):
    probas = 1/(1+np.exp(-y_pred_scores)) # y_pred_scores 
    #print(probas)
    #print(y_true.get_label())
    #print(probas - y_true.get_label())
    #print('*************')
    
    #print(y_pred_scores)
    #print(y_true.get_label())
    brier_score = brier_score_loss(y_true.get_label(), probas)
    #print(brier_score)
    
    return('brier_loss', brier_score)

# %%
if (XGBOOST_MODEL_INTERFACE == 'sklearn'):
    model = XGBClassifier(
    random_state= 42,
    max_depth= 12,
    n_estimators= 500,
    learning_rate= 0.01,
    subsample= 0.9,
    colsample_bytree= 0.2,
    tree_method= 'gpu_hist',
    objective= 'binary:logistic',
    disable_default_eval_metric=True,
    )

'''
if (XGBOOST_MODEL_INTERFACE == 'sklearn'):
    model = XGBClassifier(
    random_state= 42,
    max_depth= 12,
    n_estimators= 500,
    learning_rate= 0.05,
    subsample= 0.9,
    colsample_bytree= 0.7,
    tree_method= 'gpu_hist',
    #objective= 'binary:logistic',
    verbosity=3
    )
'''
# Out:
# "\nif (XGBOOST_MODEL_INTERFACE == 'sklearn'):\n    model = XGBClassifier(\n    random_state= 42,\n    max_depth= 12,\n    n_estimators= 500,\n    learning_rate= 0.05,\n    subsample= 0.9,\n    colsample_bytree= 0.7,\n    tree_method= 'gpu_hist',\n    #objective= 'binary:logistic',\n    verbosity=3\n    )\n"

# %%
if (XGBOOST_MODEL_INTERFACE == 'sklearn'):
    display(model)
# Out:
# XGBClassifier(base_score=None, booster=None, colsample_bylevel=None,
#               colsample_bynode=None, colsample_bytree=0.2,
#               disable_default_eval_metric=True, gamma=None, gpu_id=None,
#               importance_type='gain', interaction_constraints=None,
#               learning_rate=0.01, max_delta_step=None, max_depth=12,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=500, n_jobs=None, num_parallel_tree=None,
#               objective='binary:logistic', random_state=42, reg_alpha=None,
#               reg_lambda=None, scale_pos_weight=None, subsample=0.9,
#               tree_method='gpu_hist', use_label_encoder=True,
#               validate_parameters=None, verbosity=None)

# %%
# %%time
if (XGBOOST_MODEL_INTERFACE == 'sklearn'):
    #FEATURES_LIST_TOTRAIN = ['feature_'+str(i) for i in range(130)] + ['weight']
        
    if (DO_GRIDSEARCH == True):
        param_search = { 'random_state': [42],
                 'max_depth': [12],
                 'n_estimators': [500],
                'learning_rate': [0.01],
                'subsample': [0.9],
                'colsample_bytree': [0.2],
                 'tree_method': ['gpu_hist'],
               }
        
        model = XGBClassifier()
        
        tscv_subsplits = TimeSeriesSplit(n_splits=3)

        grid_search = GridSearchCV(estimator=model, cv=tscv_subsplits,
                        param_grid=param_search, verbose=10)

        grid_search.fit(df_train[FEATURES_LIST_TOTRAIN], y_train)
        
        model = grid_search.best_estimator_
        
    
    else:
        model.fit(df_train[FEATURES_LIST_TOTRAIN], y_train, verbose=True)
        
        #model.fit(df_train, y_train, verbose=True)
        
        
        #model.fit(df_train, y_train, verbose=True, eval_metric=brier_score_custom)
        #model.fit(df_train, y_train, early_stopping_rounds=10, verbose=True, eval_metric=brier_score_custom)
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow_p37/lib/python3.7/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# CPU times: user 1min 42s, sys: 17.1 s, total: 1min 59s
# Wall time: 1min 52s

# %% [markdown]
# learning rate 0.1, max depth 12, subsample 0.9, colsample by tree 0.2, learning rate 0.01 SANS FEATURES MACD, AVEC tout le training set, et pas d'eval set, interface scikit learn :
# => utility score 2137 avec threshold 0.504

# %%
model
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=0.2,
#               disable_default_eval_metric=True, gamma=0, gpu_id=0,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.01, max_delta_step=0, max_depth=12,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=500, n_jobs=8, num_parallel_tree=1,
#               objective='binary:logistic', random_state=42, reg_alpha=0,
#               reg_lambda=1, scale_pos_weight=1, subsample=0.9,
#               tree_method='gpu_hist', use_label_encoder=True,
#               validate_parameters=1, verbosity=None)

# %%
if (XGBOOST_MODEL_INTERFACE == 'sklearn'):
    display(model.feature_importances_)
# Out:
# array([0.01145606, 0.00344648, 0.00335691, 0.00655591, 0.00604713,
#        0.0070866 , 0.00727312, 0.00482214, 0.00475721, 0.00357085,
#        0.00429018, 0.00355919, 0.00379336, 0.0032736 , 0.0031109 ,
#        0.00315759, 0.00325198, 0.00411633, 0.00441886, 0.00381789,
#        0.00458922, 0.00380041, 0.00411239, 0.00362101, 0.00411021,
#        0.00373456, 0.00432679, 0.00697872, 0.00524878, 0.00408274,
#        0.00391348, 0.00580846, 0.00362384, 0.00427589, 0.00387592,
#        0.00403019, 0.00370148, 0.00597709, 0.00557459, 0.00805433,
#        0.00618757, 0.00857716, 0.00909896, 0.01033322, 0.00877773,
#        0.00907925, 0.00380428, 0.00392857, 0.00376579, 0.00381871,
#        0.00421699, 0.00359809, 0.00333187, 0.0044306 , 0.00363134,
#        0.00532281, 0.00387121, 0.00489497, 0.00450179, 0.00425707,
#        0.00701055, 0.00716643, 0.00782184, 0.00764031, 0.00568329,
#        0.00488273, 0.00490953, 0.00494679, 0.00499598, 0.00480942,
#        0.00442504, 0.00495972, 0.00407572, 0.00329741, 0.00331998,
#        0.00309927, 0.00304927, 0.00617918, 0.00431398, 0.00321296,
#        0.00358858, 0.00301872, 0.00301807, 0.00693353, 0.00466373,
#        0.00330672, 0.00419662, 0.00347545, 0.00307181, 0.00533773,
#        0.00562755, 0.00318748, 0.00513267, 0.00361552, 0.00292719,
#        0.00577157, 0.00461617, 0.00324245, 0.00393232, 0.00342191,
#        0.00314165, 0.00524961, 0.00500299, 0.00308935, 0.00412891,
#        0.0033574 , 0.00310413, 0.00636289, 0.00495453, 0.00326715,
#        0.00438206, 0.00358307, 0.00311975, 0.00561292, 0.005484  ,
#        0.00306838, 0.00438077, 0.00356278, 0.00317276, 0.0060333 ,
#        0.00587406, 0.00573162, 0.00408697, 0.00367914, 0.00599208,
#        0.00547946, 0.00536585, 0.00493572, 0.00438613, 0.00400012,
#        0.00335301, 0.00278908, 0.00285855, 0.00319237, 0.00321308,
#        0.00362174, 0.00360825, 0.00293273, 0.00292462, 0.00280212,
#        0.00291807, 0.00278121, 0.00278172, 0.00279499, 0.00280315,
#        0.00274645, 0.00280152, 0.00279802, 0.00292065, 0.00268117,
#        0.00291365, 0.00281761, 0.00275888, 0.00272162, 0.00274844,
#        0.00267829, 0.00272244, 0.00293586, 0.00291245, 0.00268845,
#        0.00272723, 0.00284338, 0.00276558, 0.00281562, 0.0028096 ,
#        0.00279741, 0.00278229, 0.00296679, 0.00296494, 0.0030028 ,
#        0.00294429, 0.0031572 , 0.0028295 , 0.00332069, 0.00334273,
#        0.00404866, 0.00291597, 0.00277547, 0.00295054, 0.00293438,
#        0.00319282, 0.0028932 , 0.00271639, 0.0028125 , 0.0028675 ,
#        0.0036549 , 0.00313915, 0.00366666, 0.00340097, 0.00328524,
#        0.00289348, 0.00308952, 0.00300599, 0.00304145, 0.00439435,
#        0.00303703, 0.00317022, 0.00297047, 0.00304625, 0.00279525,
#        0.00276324, 0.00290626, 0.00292909, 0.00270374, 0.00288441,
#        0.00283353, 0.00276994, 0.0033238 , 0.00306093, 0.00271853,
#        0.00282607, 0.00274025, 0.00273909, 0.00358695, 0.00313776,
#        0.00267671, 0.00304239, 0.00285038, 0.00275573, 0.00329465,
#        0.00304536, 0.00279101, 0.0029755 , 0.00279272, 0.00269314,
#        0.00319407, 0.00308211, 0.00280843, 0.00288163, 0.00288722,
#        0.00269198, 0.00343586, 0.0029613 , 0.00282401, 0.00294959,
#        0.00281363, 0.00271468, 0.00316947, 0.00312477, 0.00276816,
#        0.00306088, 0.00293299, 0.00280209, 0.00352685, 0.00306986,
#        0.00275258, 0.00295713, 0.00285859, 0.00275441, 0.00331256,
#        0.00280646, 0.00319213, 0.0027941 , 0.00286581, 0.00289189,
#        0.00308092, 0.00277327, 0.00307606, 0.00283327, 0.00301635],
#       dtype=float32)

# %%
    params = {

        'random_state' : 42,
        'max_depth': 12,
        #'max_depth': 50,
        #'learning_rate': 0.05,
        'learning_rate': 0.01,
        'subsample': 0.9,
        'colsample_bytree': 0.2,
        #'tree_method': 'gpu_hist',
        'seed': 42,
        'objective' : "binary:logistic",
        #"disable_default_eval_metric": 1,
    }

# %%
# %%time
if (XGBOOST_MODEL_INTERFACE == 'xgboost'):
    #watchlist = [(d_train, 'train'), (d_test, 'valid')]
    # A essayer : pas de watchlist (on va d'abord essayer avec le wrapper scikit learn)
    #model = xgb.train(dtrain=d_train, early_stopping_rounds=10, verbose_eval=1000, params=params, num_boost_round=500, feval=brier_score_custom, maximize=False)
    #model = xgb.train(dtrain=d_train, verbose_eval=1000, params=params, num_boost_round=500, feval=brier_score_custom, maximize=False)
    model = xgb.train(dtrain=d_train, verbose_eval=1000, params=params, num_boost_round=500)

    #model = xgb.train(dtrain=d_train, evals=watchlist, early_stopping_rounds=10, verbose_eval=1000, params=params, num_boost_round=500, feval=brier_score_custom, maximize=False)


    #model = xgb.train(dtrain=d_train, evals=watchlist, early_stopping_rounds=10, verbose_eval=1000, params=params, num_boost_round=500)
# Out:
# CPU times: user 4 µs, sys: 2 µs, total: 6 µs
# Wall time: 13.4 µs

# %% [markdown]
# Stopping. Best iteration:
# [37]	train-rmse:0.48218	valid-rmse:0.49920
#
# With just basic features and weight :
# [13]	train-error:0.40596	valid-error:0.47772
#
# With just basic features and weight, but prediction on all resp positive :
# [5]	train-error:0.25558	valid-error:0.26560
#
# With max depth 50 :
# [0]	train-brier_loss:0.23657	valid-brier_loss:0.25021
#
# learning rate 0.1, max depth 20 :
# [19]	train-brier_loss:0.23434	valid-brier_loss:0.24996
#
# learning rate 0.1, max depth 12 :
# [19]	train-brier_loss:0.23434	valid-brier_loss:0.24930
#
#
# learning rate 0.1, max depth 12, num_boost_round=1000 (au lieu de 500) :
# [19]	train-brier_loss:0.23434	valid-brier_loss:0.24930  => sûrement le early stopping
#
#
# learning rate 0.1, max depth 12, subsample 0.7 :
# [15]	train-brier_loss:0.23684	valid-brier_loss:0.24923
#
# learning rate 0.1, max depth 12, subsample 0.7, learning rate 0.05 :
# [40]	train-brier_loss:0.23427	valid-brier_loss:0.24905
#
# learning rate 0.1, max depth 12, subsample 0.5, learning rate 0.05 :
# [44]	train-brier_loss:0.23404	valid-brier_loss:0.24900
#
# learning rate 0.1, max depth 12, subsample 0.5, learning rate 0.02 :
# [96]	train-brier_loss:0.23530	valid-brier_loss:0.24882 => utility score 2035.28
#
# learning rate 0.1, max depth 12, subsample 0.5, colsample by tree 0.2, learning rate 0.02 :
# [156]	train-brier_loss:0.23395	valid-brier_loss:0.24877  => utility score 2162.89
#
# learning rate 0.1, max depth 12, subsample 0.9, colsample by tree 0.2, learning rate 0.02 :
# [143]	train-brier_loss:0.23329	valid-brier_loss:0.24862 => utility score 2187.13
#
# learning rate 0.1, max depth 12, subsample 0.9, colsample by tree 0.2, learning rate 0.01 :
# [327]	train-brier_loss:0.23182	valid-brier_loss:0.24859 => utility score 2191 => 2214.06 avec threshold 0.503   => BEST
#
# learning rate 0.1, max depth 12, subsample 0.9, colsample by tree 0.2, learning rate 0.01 ET FEATURES MACD, AVEC la moitié du training set :
# [265]	train-brier_loss:0.22946	valid-brier_loss:0.24851  => utility score 1480.29 avec threshold 0.503
#
# learning rate 0.1, max depth 12, subsample 0.9, colsample by tree 0.2, learning rate 0.01 SANS FEATURES MACD, AVEC la moitié du training set :
# [286]	train-brier_loss:0.22920	valid-brier_loss:0.24832  => utility score 1423 avec threshold 0.503

# %%
'''
# This part uses scikit learn wrapper
# %%time
#tscv_subsplits = TimeSeriesSplit(n_splits=2)

#grid_search = GridSearchCV(estimator=model, cv=tscv_subsplits,
#                        param_grid=param_search, verbose=10)

#grid_search.fit(df_train[FEATURES_LIST], y_train)

model = xgb.XGBClassifier(random_state=42, max_depth=12, n_estimators=500, learning_rate=0.05, subsample=0.9, colsample_bytree=0.7, missing=-999, verbose=10, tree_method = 'gpu_hist')
#model = xgb.XGBClassifier(random_state=42, max_depth=12, n_estimators=500, learning_rate=0.05, subsample=0.9, colsample_bytree=0.7, missing=-999, verbose=10)

#model.fit(df_train[FEATURES_LIST], y_train)
model.fit(df_train, y_train, early_stopping_rounds=10,  eval_set=[(df_test, y_test)])

#model = grid_search
'''
# Out:
# "\n# This part uses scikit learn wrapper\n%%time\n#tscv_subsplits = TimeSeriesSplit(n_splits=2)\n\n#grid_search = GridSearchCV(estimator=model, cv=tscv_subsplits,\n#                        param_grid=param_search, verbose=10)\n\n#grid_search.fit(df_train[FEATURES_LIST], y_train)\n\nmodel = xgb.XGBClassifier(random_state=42, max_depth=12, n_estimators=500, learning_rate=0.05, subsample=0.9, colsample_bytree=0.7, missing=-999, verbose=10, tree_method = 'gpu_hist')\n#model = xgb.XGBClassifier(random_state=42, max_depth=12, n_estimators=500, learning_rate=0.05, subsample=0.9, colsample_bytree=0.7, missing=-999, verbose=10)\n\n#model.fit(df_train[FEATURES_LIST], y_train)\nmodel.fit(df_train, y_train, early_stopping_rounds=10,  eval_set=[(df_test, y_test)])\n\n#model = grid_search\n"

# %%
print('Model training ended')
# Out:
# Model training ended

# %%
if (XGBOOST_MODEL_INTERFACE == 'xgboost'):
    model.save_model(XGBOOST_MODEL_FILE)

# %%
#model.best_estimator_

# %%
#model.best_estimator_.feature_importances_

# %%
if (XGBOOST_MODEL_INTERFACE == 'xgboost'):
    df_gains = pd.DataFrame.from_dict(model.get_score(importance_type='gain'), orient='index', columns=['gain']).sort_values(by='gain', ascending=False)

# %%
if (XGBOOST_MODEL_INTERFACE == 'xgboost'):
    df_gains_cumulated = pd.concat([df_gains, pd.DataFrame({'% Gain cumulé' : (df_gains['gain'] / df_gains['gain'].sum()).cumsum()})], axis=1)

# %%
if (XGBOOST_MODEL_INTERFACE == 'xgboost'):
    df_gains_cumulated['% Gain cumulé'].plot.bar()

# %%
#model.feature_importances_

# %% [markdown]
# # Save model

# %%
print('Saving model')
# Out:
# Saving model

# %%
with open(MODEL_FILE, 'wb') as f:
    pickle.dump(model, f, pickle.HIGHEST_PROTOCOL)

# %%
if (XGBOOST_MODEL_INTERFACE == 'xgboost'):
    model.save_model(XGBOOST_MODEL_FILE)

# %%
# !ls -l
# Out:
# total 8905528
# -rw-rw-r-- 1 ubuntu ubuntu      78206 Dec 15 23:25 jane-street-with-reduced-data-and-proba-threshold-AWS.ipynb
# -rw-rw-r-- 1 ubuntu ubuntu  125300915 Dec 15 23:25 model.pickle
# -rw-rw-r-- 1 ubuntu ubuntu 6192438027 Dec 15 02:24 train.csv
# -rw-rw-r-- 1 ubuntu ubuntu 2801423942 Dec 15 23:10 train.csv.zip

# %%
'''
df_grid_search_results = pd.concat([pd.DataFrame(grid_search.cv_results_["params"]),pd.DataFrame(grid_search.cv_results_["mean_test_score"], columns=["mean_test_score"])],axis=1)
df_grid_search_results = pd.concat([df_grid_search_results,pd.DataFrame(grid_search.cv_results_["std_test_score"], columns=["std_test_score"])],axis=1)
df_grid_search_results = pd.concat([df_grid_search_results,pd.DataFrame(grid_search.cv_results_["mean_fit_time"], columns=["mean_fit_time"])],axis=1)
df_grid_search_results = pd.concat([df_grid_search_results,pd.DataFrame(grid_search.cv_results_["mean_score_time"], columns=["mean_score_time"])],axis=1)
'''
# Out:
# '\ndf_grid_search_results = pd.concat([pd.DataFrame(grid_search.cv_results_["params"]),pd.DataFrame(grid_search.cv_results_["mean_test_score"], columns=["mean_test_score"])],axis=1)\ndf_grid_search_results = pd.concat([df_grid_search_results,pd.DataFrame(grid_search.cv_results_["std_test_score"], columns=["std_test_score"])],axis=1)\ndf_grid_search_results = pd.concat([df_grid_search_results,pd.DataFrame(grid_search.cv_results_["mean_fit_time"], columns=["mean_fit_time"])],axis=1)\ndf_grid_search_results = pd.concat([df_grid_search_results,pd.DataFrame(grid_search.cv_results_["mean_score_time"], columns=["mean_score_time"])],axis=1)\n'

# %%
#df_grid_search_results

# %% [markdown]
# # Test predictions

# %%
print('Testing predictions')
# Out:
# Testing predictions

# %%
PREDICT_THRESHOLD = 0.5
#PREDICT_THRESHOLD = 0.5

# %%
if (XGBOOST_MODEL_INTERFACE == 'sklearn'):
    #df_test_predictions = (pd.Series([p[1] for p in model.predict_proba(df_test)]) > PREDICT_THRESHOLD).astype(np.byte)
    
    df_test_predictions = (pd.Series([p[1] for p in model.predict_proba(df_test[FEATURES_LIST_TOTRAIN])]) > PREDICT_THRESHOLD).astype(np.byte)
    
    
else:
    df_test_predictions = (pd.Series(model.predict(d_test)) > PREDICT_THRESHOLD).astype(np.byte)

# %%
df_test_predictions
# Out:
# 0         1
# 1         0
# 2         0
# 3         1
# 4         1
#          ..
# 217312    0
# 217313    0
# 217314    0
# 217315    1
# 217316    0
# Length: 217317, dtype: int8

# %%
df_test_origin.reset_index(drop=True, inplace=True)

# %%
df_test_origin.shape
# Out:
# (217317, 268)

# %%
if (XGBOOST_MODEL_INTERFACE == 'xgboost'):
    #df_test_predictions = model.predict(df_test[FEATURES_LIST])
    test_predictions = model.predict(d_test)

# %%
if (XGBOOST_MODEL_INTERFACE == 'xgboost'):
    test_predictions

# %%
print('Calculating utility score')
# Out:
# Calculating utility score

# %%
utility_score = utility_function(df_test_origin, df_test_predictions)

# %%
utility_score
# Out:
# 2321.8284301757812

# %% [markdown]
# Utility score avec les features macd et macd - minus signal et threshold 0.5001: 1217.0041
# Utility score avec juste les features de base et threshold 0.5001: 1269.3579711914062
# Utility score avec juste les features de base et threshold 0.5001 et y_train portant sur *tous* les resp positifs : 2.67
# Utility score avec juste les features de base et threshold 0.5001, erreur RMSE: 1294.3004150390625

# %%
print('Calculating accuracy score')
# Out:
# Calculating accuracy score

# %%
accuracy_score(y_test, df_test_predictions)
# Out:
# 0.5270227363712917

# %%
THRESHOLD_LIST = [0.5, 0.5001, 0.5005, 0.501, 0.51, 0.52, 0.53, 0.54]

if (XGBOOST_MODEL_INTERFACE == 'sklearn'):
    df_test_predictions_tab = [(pd.Series([p[1] for p in model.predict_proba(df_test[FEATURES_LIST_TOTRAIN])]) > threshold).astype(np.byte) for threshold in THRESHOLD_LIST]
    utility_score_tab = [utility_function(df_test_origin, df_test_predictions_series) for df_test_predictions_series in df_test_predictions_tab]

# %%
if (XGBOOST_MODEL_INTERFACE == 'sklearn'):
# Out:
#   File "<ipython-input-147-553dbe074839>", line 2
#
#     ^
# SyntaxError: unexpected EOF while parsing

# %%
utility_score_tab

# %%
plt.scatter(THRESHOLD_LIST, utility_score_tab)

# %% [markdown]
# # Analyse model results

# %%
if (XGBOOST_MODEL_INTERFACE == 'sklearn'):
    #df_featimportance = pd.DataFrame(model.feature_importances_, index=df_train.columns, columns=['Importance']).sort_values(by='Importance', ascending=False)
    df_featimportance = pd.DataFrame(model.feature_importances_, index=df_train[FEATURES_LIST_TOTRAIN].columns, columns=['Importance']).sort_values(by='Importance', ascending=False)
    df_featimportance_cumulated = pd.concat([df_featimportance, pd.DataFrame({'% feat importance cumulé' : (df_featimportance['Importance'] / df_featimportance['Importance'].sum()).cumsum()})], axis=1)

# %%
if (XGBOOST_MODEL_INTERFACE == 'sklearn'):
    display(df_featimportance_cumulated)
# Out:
#                                Importance  % feat importance cumulé
# feature_0                        0.011456                  0.011456
# feature_43                       0.010333                  0.021789
# feature_42                       0.009099                  0.030888
# feature_45                       0.009079                  0.039967
# feature_44                       0.008778                  0.048745
# feature_41                       0.008577                  0.057322
# feature_39                       0.008054                  0.065377
# feature_62                       0.007822                  0.073199
# feature_63                       0.007640                  0.080839
# feature_6                        0.007273                  0.088112
# feature_61                       0.007166                  0.095278
# feature_5                        0.007087                  0.102365
# feature_60                       0.007011                  0.109376
# feature_27                       0.006979                  0.116354
# feature_83                       0.006934                  0.123288
# feature_3                        0.006556                  0.129844
# feature_107                      0.006363                  0.136207
# feature_40                       0.006188                  0.142394
# feature_77                       0.006179                  0.148573
# feature_4                        0.006047                  0.154620
# feature_119                      0.006033                  0.160654
# feature_124                      0.005992                  0.166646
# feature_37                       0.005977                  0.172623
# feature_120                      0.005874                  0.178497
# feature_31                       0.005808                  0.184305
# feature_95                       0.005772                  0.190077
# feature_121                      0.005732                  0.195809
# feature_64                       0.005683                  0.201492
# feature_90                       0.005628                  0.207120
# feature_113                      0.005613                  0.212732
# feature_38                       0.005575                  0.218307
# feature_114                      0.005484                  0.223791
# feature_125                      0.005479                  0.229270
# feature_126                      0.005366                  0.234636
# feature_89                       0.005338                  0.239974
# feature_55                       0.005323                  0.245297
# feature_101                      0.005250                  0.250546
# feature_28                       0.005249                  0.255795
# feature_92                       0.005133                  0.260928
# feature_102                      0.005003                  0.265931
# feature_68                       0.004996                  0.270927
# feature_71                       0.004960                  0.275887
# feature_108                      0.004955                  0.280841
# feature_67                       0.004947                  0.285788
# feature_127                      0.004936                  0.290724
# feature_66                       0.004910                  0.295633
# feature_57                       0.004895                  0.300528
# feature_65                       0.004883                  0.305411
# feature_7                        0.004822                  0.310233
# feature_69                       0.004809                  0.315042
# feature_8                        0.004757                  0.319800
# feature_84                       0.004664                  0.324463
# feature_96                       0.004616                  0.329080
# feature_20                       0.004589                  0.333669
# feature_58                       0.004502                  0.338171
# feature_53                       0.004431                  0.342601
# feature_70                       0.004425                  0.347026
# feature_18                       0.004419                  0.351445
# feature_64_macd_minus_signal     0.004394                  0.355839
# feature_128                      0.004386                  0.360226
# feature_110                      0.004382                  0.364608
# feature_116                      0.004381                  0.368988
# feature_26                       0.004327                  0.373315
# feature_78                       0.004314                  0.377629
# feature_10                       0.004290                  0.381919
# feature_33                       0.004276                  0.386195
# feature_59                       0.004257                  0.390452
# feature_50                       0.004217                  0.394669
# feature_86                       0.004197                  0.398866
# feature_104                      0.004129                  0.402995
# feature_17                       0.004116                  0.407111
# feature_22                       0.004112                  0.411224
# feature_24                       0.004110                  0.415334
# feature_122                      0.004087                  0.419421
# feature_29                       0.004083                  0.423503
# feature_72                       0.004076                  0.427579
# feature_45_macd_minus_signal     0.004049                  0.431628
# feature_35                       0.004030                  0.435658
# feature_129                      0.004000                  0.439658
# feature_98                       0.003932                  0.443591
# feature_47                       0.003929                  0.447519
# feature_30                       0.003913                  0.451433
# feature_34                       0.003876                  0.455308
# feature_56                       0.003871                  0.459180
# feature_49                       0.003819                  0.462998
# feature_19                       0.003818                  0.466816
# feature_46                       0.003804                  0.470621
# feature_21                       0.003800                  0.474421
# feature_12                       0.003793                  0.478214
# feature_48                       0.003766                  0.481980
# feature_25                       0.003735                  0.485715
# feature_36                       0.003701                  0.489416
# feature_123                      0.003679                  0.493095
# feature_57_macd_minus_signal     0.003667                  0.496762
# feature_55_macd_minus_signal     0.003655                  0.500417
# feature_54                       0.003631                  0.504048
# feature_32                       0.003624                  0.507672
# feature_5_macd_minus_signal      0.003622                  0.511294
# feature_23                       0.003621                  0.514915
# feature_93                       0.003616                  0.518530
# feature_6_macd_minus_signal      0.003608                  0.522139
# feature_51                       0.003598                  0.525737
# feature_80                       0.003589                  0.529325
# feature_83_macd_minus_signal     0.003587                  0.532912
# feature_111                      0.003583                  0.536495
# feature_9                        0.003571                  0.540066
# feature_117                      0.003563                  0.543629
# feature_11                       0.003559                  0.547188
# feature_113_macd_minus_signal    0.003527                  0.550715
# feature_87                       0.003475                  0.554190
# feature_1                        0.003446                  0.557637
# feature_101_macd_minus_signal    0.003436                  0.561073
# feature_99                       0.003422                  0.564495
# feature_58_macd_minus_signal     0.003401                  0.567896
# feature_105                      0.003357                  0.571253
# feature_2                        0.003357                  0.574610
# weight                           0.003353                  0.577963
# feature_44_macd_minus_signal     0.003343                  0.581306
# feature_52                       0.003332                  0.584638
# feature_77_macd_minus_signal     0.003324                  0.587961
# feature_43_macd_minus_signal     0.003321                  0.591282
# feature_74                       0.003320                  0.594602
# feature_119_macd_minus_signal    0.003313                  0.597915
# feature_85                       0.003307                  0.601221
# feature_73                       0.003297                  0.604519
# feature_89_macd_minus_signal     0.003295                  0.607813
# feature_59_macd_minus_signal     0.003285                  0.611099
# feature_13                       0.003274                  0.614372
# feature_109                      0.003267                  0.617639
# feature_16                       0.003252                  0.620891
# feature_97                       0.003242                  0.624134
# feature_4_macd_minus_signal      0.003213                  0.627347
# feature_79                       0.003213                  0.630560
# feature_95_macd_minus_signal     0.003194                  0.633754
# feature_50_macd_minus_signal     0.003193                  0.636947
# feature_3_macd_minus_signal      0.003192                  0.640139
# feature_121_macd_minus_signal    0.003192                  0.643331
# feature_91                       0.003187                  0.646519
# feature_118                      0.003173                  0.649692
# feature_66_macd_minus_signal     0.003170                  0.652862
# feature_107_macd_minus_signal    0.003169                  0.656031
# feature_15                       0.003158                  0.659189
# feature_41_macd_minus_signal     0.003157                  0.662346
# feature_100                      0.003142                  0.665488
# feature_56_macd_minus_signal     0.003139                  0.668627
# feature_84_macd_minus_signal     0.003138                  0.671765
# feature_108_macd_minus_signal    0.003125                  0.674889
# feature_112                      0.003120                  0.678009
# feature_14                       0.003111                  0.681120
# feature_106                      0.003104                  0.684224
# feature_75                       0.003099                  0.687323
# feature_61_macd_minus_signal     0.003090                  0.690413
# feature_103                      0.003089                  0.693502
# feature_96_macd_minus_signal     0.003082                  0.696584
# feature_125_macd_minus_signal    0.003081                  0.699665
# feature_127_macd_minus_signal    0.003076                  0.702741
# feature_88                       0.003072                  0.705813
# feature_114_macd_minus_signal    0.003070                  0.708883
# feature_115                      0.003068                  0.711951
# feature_78_macd_minus_signal     0.003061                  0.715012
# feature_110_macd_minus_signal    0.003061                  0.718073
# feature_76                       0.003049                  0.721122
# feature_68_macd_minus_signal     0.003046                  0.724169
# feature_90_macd_minus_signal     0.003045                  0.727214
# feature_86_macd_minus_signal     0.003042                  0.730256
# feature_63_macd_minus_signal     0.003041                  0.733298
# feature_65_macd_minus_signal     0.003037                  0.736335
# feature_81                       0.003019                  0.739354
# feature_82                       0.003018                  0.742372
# feature_129_macd_minus_signal    0.003016                  0.745388
# feature_62_macd_minus_signal     0.003006                  0.748394
# feature_39_macd_minus_signal     0.003003                  0.751397
# feature_92_macd_minus_signal     0.002975                  0.754372
# feature_67_macd_minus_signal     0.002970                  0.757343
# feature_37_macd_minus_signal     0.002967                  0.760310
# feature_38_macd_minus_signal     0.002965                  0.763275
# feature_102_macd_minus_signal    0.002961                  0.766236
# feature_116_macd_minus_signal    0.002957                  0.769193
# feature_48_macd_minus_signal     0.002951                  0.772144
# feature_104_macd_minus_signal    0.002950                  0.775093
# feature_40_macd_minus_signal     0.002944                  0.778037
# feature_27_macd_minus_signal     0.002936                  0.780973
# feature_49_macd_minus_signal     0.002934                  0.783908
# feature_111_macd_minus_signal    0.002933                  0.786841
# feature_7_macd_minus_signal      0.002933                  0.789773
# feature_72_macd_minus_signal     0.002929                  0.792702
# feature_94                       0.002927                  0.795630
# feature_8_macd_minus_signal      0.002925                  0.798554
# feature_18_macd_minus_signal     0.002921                  0.801475
# feature_10_macd_minus_signal     0.002918                  0.804393
# feature_46_macd_minus_signal     0.002916                  0.807309
# feature_20_macd_minus_signal     0.002914                  0.810223
# feature_28_macd_minus_signal     0.002912                  0.813135
# feature_71_macd_minus_signal     0.002906                  0.816041
# feature_60_macd_minus_signal     0.002893                  0.818935
# feature_51_macd_minus_signal     0.002893                  0.821828
# feature_124_macd_minus_signal    0.002892                  0.824720
# feature_99_macd_minus_signal     0.002887                  0.827607
# feature_74_macd_minus_signal     0.002884                  0.830492
# feature_98_macd_minus_signal     0.002882                  0.833373
# feature_54_macd_minus_signal     0.002867                  0.836241
# feature_123_macd_minus_signal    0.002866                  0.839107
# feature_117_macd_minus_signal    0.002859                  0.841965
# feature_2_macd_minus_signal      0.002859                  0.844824
# feature_87_macd_minus_signal     0.002850                  0.847674
# feature_31_macd_minus_signal     0.002843                  0.850517
# feature_75_macd_minus_signal     0.002834                  0.853351
# feature_128_macd_minus_signal    0.002833                  0.856184
# feature_42_macd_minus_signal     0.002830                  0.859014
# feature_80_macd_minus_signal     0.002826                  0.861840
# feature_103_macd_minus_signal    0.002824                  0.864664
# feature_21_macd_minus_signal     0.002818                  0.867481
# feature_33_macd_minus_signal     0.002816                  0.870297
# feature_105_macd_minus_signal    0.002814                  0.873111
# feature_53_macd_minus_signal     0.002812                  0.875923
# feature_34_macd_minus_signal     0.002810                  0.878733
# feature_97_macd_minus_signal     0.002808                  0.881541
# feature_120_macd_minus_signal    0.002806                  0.884348
# feature_14_macd_minus_signal     0.002803                  0.887151
# feature_9_macd_minus_signal      0.002802                  0.889953
# feature_112_macd_minus_signal    0.002802                  0.892755
# feature_16_macd_minus_signal     0.002802                  0.895557
# feature_17_macd_minus_signal     0.002798                  0.898355
# feature_35_macd_minus_signal     0.002797                  0.901152
# feature_69_macd_minus_signal     0.002795                  0.903947
# feature_13_macd_minus_signal     0.002795                  0.906742
# feature_122_macd_minus_signal    0.002794                  0.909536
# feature_93_macd_minus_signal     0.002793                  0.912329
# feature_91_macd_minus_signal     0.002791                  0.915120
# feature_1_macd_minus_signal      0.002789                  0.917909
# feature_36_macd_minus_signal     0.002782                  0.920691
# feature_12_macd_minus_signal     0.002782                  0.923473
# feature_11_macd_minus_signal     0.002781                  0.926254
# feature_47_macd_minus_signal     0.002775                  0.929030
# feature_126_macd_minus_signal    0.002773                  0.931803
# feature_76_macd_minus_signal     0.002770                  0.934573
# feature_109_macd_minus_signal    0.002768                  0.937341
# feature_32_macd_minus_signal     0.002766                  0.940107
# feature_70_macd_minus_signal     0.002763                  0.942870
# feature_22_macd_minus_signal     0.002759                  0.945629
# feature_88_macd_minus_signal     0.002756                  0.948385
# feature_118_macd_minus_signal    0.002754                  0.951139
# feature_115_macd_minus_signal    0.002753                  0.953892
# feature_24_macd_minus_signal     0.002748                  0.956640
# feature_15_macd_minus_signal     0.002746                  0.959387
# feature_81_macd_minus_signal     0.002740                  0.962127
# feature_82_macd_minus_signal     0.002739                  0.964866
# feature_30_macd_minus_signal     0.002727                  0.967593
# feature_26_macd_minus_signal     0.002722                  0.970316
# feature_23_macd_minus_signal     0.002722                  0.973037
# feature_79_macd_minus_signal     0.002719                  0.975756
# feature_52_macd_minus_signal     0.002716                  0.978472
# feature_106_macd_minus_signal    0.002715                  0.981187
# feature_73_macd_minus_signal     0.002704                  0.983890
# feature_94_macd_minus_signal     0.002693                  0.986584
# feature_100_macd_minus_signal    0.002692                  0.989276
# feature_29_macd_minus_signal     0.002688                  0.991964
# feature_19_macd_minus_signal     0.002681                  0.994645
# feature_25_macd_minus_signal     0.002678                  0.997324
# feature_85_macd_minus_signal     0.002677                  1.000000

# %%
if (XGBOOST_MODEL_INTERFACE == 'sklearn'):
    display(df_featimportance_cumulated)
# Out:
#                                Importance  % feat importance cumulé
# feature_0                        0.011456                  0.011456
# feature_43                       0.010333                  0.021789
# feature_42                       0.009099                  0.030888
# feature_45                       0.009079                  0.039967
# feature_44                       0.008778                  0.048745
# feature_41                       0.008577                  0.057322
# feature_39                       0.008054                  0.065377
# feature_62                       0.007822                  0.073199
# feature_63                       0.007640                  0.080839
# feature_6                        0.007273                  0.088112
# feature_61                       0.007166                  0.095278
# feature_5                        0.007087                  0.102365
# feature_60                       0.007011                  0.109376
# feature_27                       0.006979                  0.116354
# feature_83                       0.006934                  0.123288
# feature_3                        0.006556                  0.129844
# feature_107                      0.006363                  0.136207
# feature_40                       0.006188                  0.142394
# feature_77                       0.006179                  0.148573
# feature_4                        0.006047                  0.154620
# feature_119                      0.006033                  0.160654
# feature_124                      0.005992                  0.166646
# feature_37                       0.005977                  0.172623
# feature_120                      0.005874                  0.178497
# feature_31                       0.005808                  0.184305
# feature_95                       0.005772                  0.190077
# feature_121                      0.005732                  0.195809
# feature_64                       0.005683                  0.201492
# feature_90                       0.005628                  0.207120
# feature_113                      0.005613                  0.212732
# feature_38                       0.005575                  0.218307
# feature_114                      0.005484                  0.223791
# feature_125                      0.005479                  0.229270
# feature_126                      0.005366                  0.234636
# feature_89                       0.005338                  0.239974
# feature_55                       0.005323                  0.245297
# feature_101                      0.005250                  0.250546
# feature_28                       0.005249                  0.255795
# feature_92                       0.005133                  0.260928
# feature_102                      0.005003                  0.265931
# feature_68                       0.004996                  0.270927
# feature_71                       0.004960                  0.275887
# feature_108                      0.004955                  0.280841
# feature_67                       0.004947                  0.285788
# feature_127                      0.004936                  0.290724
# feature_66                       0.004910                  0.295633
# feature_57                       0.004895                  0.300528
# feature_65                       0.004883                  0.305411
# feature_7                        0.004822                  0.310233
# feature_69                       0.004809                  0.315042
# feature_8                        0.004757                  0.319800
# feature_84                       0.004664                  0.324463
# feature_96                       0.004616                  0.329080
# feature_20                       0.004589                  0.333669
# feature_58                       0.004502                  0.338171
# feature_53                       0.004431                  0.342601
# feature_70                       0.004425                  0.347026
# feature_18                       0.004419                  0.351445
# feature_64_macd_minus_signal     0.004394                  0.355839
# feature_128                      0.004386                  0.360226
# feature_110                      0.004382                  0.364608
# feature_116                      0.004381                  0.368988
# feature_26                       0.004327                  0.373315
# feature_78                       0.004314                  0.377629
# feature_10                       0.004290                  0.381919
# feature_33                       0.004276                  0.386195
# feature_59                       0.004257                  0.390452
# feature_50                       0.004217                  0.394669
# feature_86                       0.004197                  0.398866
# feature_104                      0.004129                  0.402995
# feature_17                       0.004116                  0.407111
# feature_22                       0.004112                  0.411224
# feature_24                       0.004110                  0.415334
# feature_122                      0.004087                  0.419421
# feature_29                       0.004083                  0.423503
# feature_72                       0.004076                  0.427579
# feature_45_macd_minus_signal     0.004049                  0.431628
# feature_35                       0.004030                  0.435658
# feature_129                      0.004000                  0.439658
# feature_98                       0.003932                  0.443591
# feature_47                       0.003929                  0.447519
# feature_30                       0.003913                  0.451433
# feature_34                       0.003876                  0.455308
# feature_56                       0.003871                  0.459180
# feature_49                       0.003819                  0.462998
# feature_19                       0.003818                  0.466816
# feature_46                       0.003804                  0.470621
# feature_21                       0.003800                  0.474421
# feature_12                       0.003793                  0.478214
# feature_48                       0.003766                  0.481980
# feature_25                       0.003735                  0.485715
# feature_36                       0.003701                  0.489416
# feature_123                      0.003679                  0.493095
# feature_57_macd_minus_signal     0.003667                  0.496762
# feature_55_macd_minus_signal     0.003655                  0.500417
# feature_54                       0.003631                  0.504048
# feature_32                       0.003624                  0.507672
# feature_5_macd_minus_signal      0.003622                  0.511294
# feature_23                       0.003621                  0.514915
# feature_93                       0.003616                  0.518530
# feature_6_macd_minus_signal      0.003608                  0.522139
# feature_51                       0.003598                  0.525737
# feature_80                       0.003589                  0.529325
# feature_83_macd_minus_signal     0.003587                  0.532912
# feature_111                      0.003583                  0.536495
# feature_9                        0.003571                  0.540066
# feature_117                      0.003563                  0.543629
# feature_11                       0.003559                  0.547188
# feature_113_macd_minus_signal    0.003527                  0.550715
# feature_87                       0.003475                  0.554190
# feature_1                        0.003446                  0.557637
# feature_101_macd_minus_signal    0.003436                  0.561073
# feature_99                       0.003422                  0.564495
# feature_58_macd_minus_signal     0.003401                  0.567896
# feature_105                      0.003357                  0.571253
# feature_2                        0.003357                  0.574610
# weight                           0.003353                  0.577963
# feature_44_macd_minus_signal     0.003343                  0.581306
# feature_52                       0.003332                  0.584638
# feature_77_macd_minus_signal     0.003324                  0.587961
# feature_43_macd_minus_signal     0.003321                  0.591282
# feature_74                       0.003320                  0.594602
# feature_119_macd_minus_signal    0.003313                  0.597915
# feature_85                       0.003307                  0.601221
# feature_73                       0.003297                  0.604519
# feature_89_macd_minus_signal     0.003295                  0.607813
# feature_59_macd_minus_signal     0.003285                  0.611099
# feature_13                       0.003274                  0.614372
# feature_109                      0.003267                  0.617639
# feature_16                       0.003252                  0.620891
# feature_97                       0.003242                  0.624134
# feature_4_macd_minus_signal      0.003213                  0.627347
# feature_79                       0.003213                  0.630560
# feature_95_macd_minus_signal     0.003194                  0.633754
# feature_50_macd_minus_signal     0.003193                  0.636947
# feature_3_macd_minus_signal      0.003192                  0.640139
# feature_121_macd_minus_signal    0.003192                  0.643331
# feature_91                       0.003187                  0.646519
# feature_118                      0.003173                  0.649692
# feature_66_macd_minus_signal     0.003170                  0.652862
# feature_107_macd_minus_signal    0.003169                  0.656031
# feature_15                       0.003158                  0.659189
# feature_41_macd_minus_signal     0.003157                  0.662346
# feature_100                      0.003142                  0.665488
# feature_56_macd_minus_signal     0.003139                  0.668627
# feature_84_macd_minus_signal     0.003138                  0.671765
# feature_108_macd_minus_signal    0.003125                  0.674889
# feature_112                      0.003120                  0.678009
# feature_14                       0.003111                  0.681120
# feature_106                      0.003104                  0.684224
# feature_75                       0.003099                  0.687323
# feature_61_macd_minus_signal     0.003090                  0.690413
# feature_103                      0.003089                  0.693502
# feature_96_macd_minus_signal     0.003082                  0.696584
# feature_125_macd_minus_signal    0.003081                  0.699665
# feature_127_macd_minus_signal    0.003076                  0.702741
# feature_88                       0.003072                  0.705813
# feature_114_macd_minus_signal    0.003070                  0.708883
# feature_115                      0.003068                  0.711951
# feature_78_macd_minus_signal     0.003061                  0.715012
# feature_110_macd_minus_signal    0.003061                  0.718073
# feature_76                       0.003049                  0.721122
# feature_68_macd_minus_signal     0.003046                  0.724169
# feature_90_macd_minus_signal     0.003045                  0.727214
# feature_86_macd_minus_signal     0.003042                  0.730256
# feature_63_macd_minus_signal     0.003041                  0.733298
# feature_65_macd_minus_signal     0.003037                  0.736335
# feature_81                       0.003019                  0.739354
# feature_82                       0.003018                  0.742372
# feature_129_macd_minus_signal    0.003016                  0.745388
# feature_62_macd_minus_signal     0.003006                  0.748394
# feature_39_macd_minus_signal     0.003003                  0.751397
# feature_92_macd_minus_signal     0.002975                  0.754372
# feature_67_macd_minus_signal     0.002970                  0.757343
# feature_37_macd_minus_signal     0.002967                  0.760310
# feature_38_macd_minus_signal     0.002965                  0.763275
# feature_102_macd_minus_signal    0.002961                  0.766236
# feature_116_macd_minus_signal    0.002957                  0.769193
# feature_48_macd_minus_signal     0.002951                  0.772144
# feature_104_macd_minus_signal    0.002950                  0.775093
# feature_40_macd_minus_signal     0.002944                  0.778037
# feature_27_macd_minus_signal     0.002936                  0.780973
# feature_49_macd_minus_signal     0.002934                  0.783908
# feature_111_macd_minus_signal    0.002933                  0.786841
# feature_7_macd_minus_signal      0.002933                  0.789773
# feature_72_macd_minus_signal     0.002929                  0.792702
# feature_94                       0.002927                  0.795630
# feature_8_macd_minus_signal      0.002925                  0.798554
# feature_18_macd_minus_signal     0.002921                  0.801475
# feature_10_macd_minus_signal     0.002918                  0.804393
# feature_46_macd_minus_signal     0.002916                  0.807309
# feature_20_macd_minus_signal     0.002914                  0.810223
# feature_28_macd_minus_signal     0.002912                  0.813135
# feature_71_macd_minus_signal     0.002906                  0.816041
# feature_60_macd_minus_signal     0.002893                  0.818935
# feature_51_macd_minus_signal     0.002893                  0.821828
# feature_124_macd_minus_signal    0.002892                  0.824720
# feature_99_macd_minus_signal     0.002887                  0.827607
# feature_74_macd_minus_signal     0.002884                  0.830492
# feature_98_macd_minus_signal     0.002882                  0.833373
# feature_54_macd_minus_signal     0.002867                  0.836241
# feature_123_macd_minus_signal    0.002866                  0.839107
# feature_117_macd_minus_signal    0.002859                  0.841965
# feature_2_macd_minus_signal      0.002859                  0.844824
# feature_87_macd_minus_signal     0.002850                  0.847674
# feature_31_macd_minus_signal     0.002843                  0.850517
# feature_75_macd_minus_signal     0.002834                  0.853351
# feature_128_macd_minus_signal    0.002833                  0.856184
# feature_42_macd_minus_signal     0.002830                  0.859014
# feature_80_macd_minus_signal     0.002826                  0.861840
# feature_103_macd_minus_signal    0.002824                  0.864664
# feature_21_macd_minus_signal     0.002818                  0.867481
# feature_33_macd_minus_signal     0.002816                  0.870297
# feature_105_macd_minus_signal    0.002814                  0.873111
# feature_53_macd_minus_signal     0.002812                  0.875923
# feature_34_macd_minus_signal     0.002810                  0.878733
# feature_97_macd_minus_signal     0.002808                  0.881541
# feature_120_macd_minus_signal    0.002806                  0.884348
# feature_14_macd_minus_signal     0.002803                  0.887151
# feature_9_macd_minus_signal      0.002802                  0.889953
# feature_112_macd_minus_signal    0.002802                  0.892755
# feature_16_macd_minus_signal     0.002802                  0.895557
# feature_17_macd_minus_signal     0.002798                  0.898355
# feature_35_macd_minus_signal     0.002797                  0.901152
# feature_69_macd_minus_signal     0.002795                  0.903947
# feature_13_macd_minus_signal     0.002795                  0.906742
# feature_122_macd_minus_signal    0.002794                  0.909536
# feature_93_macd_minus_signal     0.002793                  0.912329
# feature_91_macd_minus_signal     0.002791                  0.915120
# feature_1_macd_minus_signal      0.002789                  0.917909
# feature_36_macd_minus_signal     0.002782                  0.920691
# feature_12_macd_minus_signal     0.002782                  0.923473
# feature_11_macd_minus_signal     0.002781                  0.926254
# feature_47_macd_minus_signal     0.002775                  0.929030
# feature_126_macd_minus_signal    0.002773                  0.931803
# feature_76_macd_minus_signal     0.002770                  0.934573
# feature_109_macd_minus_signal    0.002768                  0.937341
# feature_32_macd_minus_signal     0.002766                  0.940107
# feature_70_macd_minus_signal     0.002763                  0.942870
# feature_22_macd_minus_signal     0.002759                  0.945629
# feature_88_macd_minus_signal     0.002756                  0.948385
# feature_118_macd_minus_signal    0.002754                  0.951139
# feature_115_macd_minus_signal    0.002753                  0.953892
# feature_24_macd_minus_signal     0.002748                  0.956640
# feature_15_macd_minus_signal     0.002746                  0.959387
# feature_81_macd_minus_signal     0.002740                  0.962127
# feature_82_macd_minus_signal     0.002739                  0.964866
# feature_30_macd_minus_signal     0.002727                  0.967593
# feature_26_macd_minus_signal     0.002722                  0.970316
# feature_23_macd_minus_signal     0.002722                  0.973037
# feature_79_macd_minus_signal     0.002719                  0.975756
# feature_52_macd_minus_signal     0.002716                  0.978472
# feature_106_macd_minus_signal    0.002715                  0.981187
# feature_73_macd_minus_signal     0.002704                  0.983890
# feature_94_macd_minus_signal     0.002693                  0.986584
# feature_100_macd_minus_signal    0.002692                  0.989276
# feature_29_macd_minus_signal     0.002688                  0.991964
# feature_19_macd_minus_signal     0.002681                  0.994645
# feature_25_macd_minus_signal     0.002678                  0.997324
# feature_85_macd_minus_signal     0.002677                  1.000000

# %%
if (XGBOOST_MODEL_INTERFACE == 'xgboost'):
    df_gains_cumulated = pd.concat([df_gains, pd.DataFrame({'% Gain cumulé' : (df_gains['gain'] / df_gains['gain'].sum()).cumsum()})], axis=1)

# %%
if (XGBOOST_MODEL_INTERFACE == 'xgboost'):
    display(df_gains_cumulated)

# %%
df_gains_cumulated
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-119-0468026d6501> in <module>
# ----> 1 df_gains_cumulated
#
# NameError: name 'df_gains_cumulated' is not defined
